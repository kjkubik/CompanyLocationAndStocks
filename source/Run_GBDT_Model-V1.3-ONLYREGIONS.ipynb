# %%
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta
from functools import partial
import numpy as np
import psycopg2
import pandas as pd
from sqlalchemy import create_engine
from config import db_password
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

#import necessary libraries 
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols


#from joblib import Parallel, delayed, Model 
#from collections import Counter <--????
#from sklearn.metrics import confusion_matrix
#from imblearn.metrics import classification_report_imbalanced

# %%
# GET Tabled input

# creating database engine
db_name = 'Company_Stock_DB'
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/{db_name}"
engine = create_engine(db_string)

# read data from PostgreSQL database table and load into Dataframe instance
stock_df = pd.read_sql("select * from \"company_all_star\"", engine);

#sort the dataframe by ticker column
stock_df.sort_values(by=['ticker'])

# Print the DataFrame
stock_df.head()
# Out:
#   ticker    date_val                company_name company_url employee_count  \
# 0    AMD  2020-03-12  Advanced Micro Devices Inc     amd.com         5k-10k
# 1    AMD  2020-03-15  Advanced Micro Devices Inc     amd.com         5k-10k
# 2    AMD  2020-03-16  Advanced Micro Devices Inc     amd.com         5k-10k
# 3    AMD  2020-03-17  Advanced Micro Devices Inc     amd.com         5k-10k
# 4    AMD  2020-03-18  Advanced Micro Devices Inc     amd.com         5k-10k
#
#    revenue      sector    city_name state_name region  ...   latitude  \
# 0  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 1  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 2  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 3  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 4  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                381223.0        4.028436
# 1        41.0812                374962.0        0.946776
# 2        41.1240                434519.0        4.205026
# 3        39.6363                591862.0        1.062215
# 4        40.2337                396388.0        0.657230
#
# [5 rows x 21 columns]

# %%
# check dtypes
stock_df.dtypes
# Out:
# ticker                     object
# date_val                   object
# company_name               object
# company_url                object
# employee_count             object
# revenue                    object
# sector                     object
# city_name                  object
# state_name                 object
# region                     object
# country_code               object
# latitude                  float64
# longitude                 float64
# open_val                  float64
# high_val                  float64
# low_val                   float64
# close_val                 float64
# volume                    float64
# volume_weight             float64
# number_of_transactions    float64
# percent_change            float64
# dtype: object

# %%
# preserve date column as type object
stock_df['date'] = stock_df['date_val']

# have the user enter beginning date as yyyy-mm-dd
begin_date = '2022-03-08'
# have the user enter ending date as yyyy-mm-dd
end_date = '2022-03-10'

# Convert the date to datetime64
stock_df['date_val'] = pd.to_datetime(stock_df['date_val'], format='%Y-%m-%d')

stock_df = stock_df.loc[(stock_df['date_val'] >= begin_date)
                     & (stock_df['date_val'] <= end_date)]

# drop throw-aways 
stock_df.drop(["longitude", "latitude", "company_name", "company_url","date_val"], axis=1, inplace=True)

stock_df
# Out:
#       ticker employee_count    revenue      sector    city_name state_name  \
# 501      AMD         5k-10k    over-1b  Technology  Santa Clara         CA
# 502      AMD         5k-10k    over-1b  Technology  Santa Clara         CA
# 503      AMD         5k-10k    over-1b  Technology  Santa Clara         CA
# 1006    ADBE       over-10k     1m-10m  Technology     San Jose         CA
# 1007    ADBE       over-10k     1m-10m  Technology     San Jose         CA
# ...      ...            ...        ...         ...          ...        ...
# 50368     ZM          1k-5k  100m-200m  Technology     San Jose         CA
# 50369     ZM          1k-5k  100m-200m  Technology     San Jose         CA
# 50871     ZS          1k-5k  100m-200m  Technology     San Jose         CA
# 50872     ZS          1k-5k  100m-200m  Technology     San Jose         CA
# 50873     ZS          1k-5k  100m-200m  Technology     San Jose         CA
#
#       region country_code  open_val  high_val  low_val  close_val  \
# 501        W           US   108.410    111.71  106.850     111.05
# 502        W           US   108.890    109.07  103.070     106.46
# 503        W           US   108.130    108.19  104.080     104.29
# 1006       W           US   443.800    453.11  438.930     450.87
# 1007       W           US   444.680    447.65  433.010     438.95
# ...      ...          ...       ...       ...      ...        ...
# 50368      W           US   105.835    106.90  101.055     103.33
# 50369      W           US   103.480    103.49   97.900      98.12
# 50871      W           US   203.840    213.57  199.120     212.35
# 50872      W           US   212.130    213.51  204.870     208.41
# 50873      W           US   211.020    211.67  200.500     201.14
#
#             volume  volume_weight  number_of_transactions  percent_change  \
# 501    102310329.0       109.6319                602679.0        2.435200
# 502    102557375.0       105.3382                639388.0        2.231610
# 503     87584432.0       105.9691                542478.0        3.551281
# 1006     2905656.0       447.8637                 67082.0        1.593060
# 1007     2686310.0       437.7568                 66371.0        1.288567
# ...            ...            ...                     ...             ...
# 50368    5030777.0       103.3206                 88819.0        2.366892
# 50369    6454629.0        99.6973                104681.0        5.179745
# 50871    3050554.0       209.3268                 45960.0        4.174843
# 50872    2305091.0       208.7971                 40754.0        1.753642
# 50873    1893573.0       202.9376                 37307.0        4.682021
#
#              date
# 501    2022-03-08
# 502    2022-03-09
# 503    2022-03-10
# 1006   2022-03-08
# 1007   2022-03-09
# ...           ...
# 50368  2022-03-09
# 50369  2022-03-10
# 50871  2022-03-08
# 50872  2022-03-09
# 50873  2022-03-10
#
# [306 rows x 17 columns]

# %%
# check dtypes
stock_df.dtypes
# Out:
# ticker                     object
# employee_count             object
# revenue                    object
# sector                     object
# city_name                  object
# state_name                 object
# region                     object
# country_code               object
# open_val                  float64
# high_val                  float64
# low_val                   float64
# close_val                 float64
# volume                    float64
# volume_weight             float64
# number_of_transactions    float64
# percent_change            float64
# date                       object
# dtype: object

# %%
# drop fields that will not be used to represent a period of time
stock_df.drop(columns = ['open_val', 'high_val', 'low_val', 'close_val', 'number_of_transactions'], axis=1, inplace=True)
pd.set_option('display.max_rows', None)
stock_df
# Out:
#       ticker employee_count    revenue                  sector      city_name  \
# 501      AMD         5k-10k    over-1b              Technology    Santa Clara
# 502      AMD         5k-10k    over-1b              Technology    Santa Clara
# 503      AMD         5k-10k    over-1b              Technology    Santa Clara
# 1006    ADBE       over-10k     1m-10m              Technology       San Jose
# 1007    ADBE       over-10k     1m-10m              Technology       San Jose
# 1008    ADBE       over-10k     1m-10m              Technology       San Jose
# 1321    ABNB         5k-10k    200m-1b              Technology  San Francisco
# 1322    ABNB         5k-10k    200m-1b              Technology  San Francisco
# 1323    ABNB         5k-10k    200m-1b              Technology  San Francisco
# 1825    ALGN       over-10k    200m-1b              Technology          Tempe
# 1826    ALGN       over-10k    200m-1b              Technology          Tempe
# 1827    ALGN       over-10k    200m-1b              Technology          Tempe
# 2329    AMZN       over-10k    over-1b              Technology        Seattle
# 2330    AMZN       over-10k    over-1b              Technology        Seattle
# 2331    AMZN       over-10k    over-1b              Technology        Seattle
# 2833    AMGN       over-10k    over-1b              Technology  Thousand Oaks
# 2834    AMGN       over-10k    over-1b              Technology  Thousand Oaks
# 2835    AMGN       over-10k    over-1b              Technology  Thousand Oaks
# 3336     AEP       over-10k    over-1b                  Energy       Columbus
# 3337     AEP       over-10k    over-1b                  Energy       Columbus
# 3338     AEP       over-10k    over-1b                  Energy       Columbus
# 3840     ADI       over-10k    over-1b              Technology        Norwood
# 3841     ADI       over-10k    over-1b              Technology        Norwood
# 3842     ADI       over-10k    over-1b              Technology        Norwood
# 4344    ANSS          1k-5k    200m-1b              Technology     Canonsburg
# 4345    ANSS          1k-5k    200m-1b              Technology     Canonsburg
# 4346    ANSS          1k-5k    200m-1b              Technology     Canonsburg
# 4848    AAPL       over-10k    over-1b              Technology      Capertino
# 4849    AAPL       over-10k    over-1b              Technology      Capertino
# 4850    AAPL       over-10k    over-1b              Technology      Capertino
# 5352    AMAT       over-10k    over-1b              Technology    Santa Clara
# 5353    AMAT       over-10k    over-1b              Technology    Santa Clara
# 5354    AMAT       over-10k    over-1b              Technology    Santa Clara
# 5856    ASML       over-10k    over-1b              Technology      Veldhoven
# 5857    ASML       over-10k    over-1b              Technology      Veldhoven
# 5858    ASML       over-10k    over-1b              Technology      Veldhoven
# 6360    TEAM          1k-5k  100m-200m              Technology         Sydney
# 6361    TEAM          1k-5k  100m-200m              Technology         Sydney
# 6362    TEAM          1k-5k  100m-200m              Technology         Sydney
# 6864    ADSK       over-10k    over-1b              Healthcare     San Rafael
# 6865    ADSK       over-10k    over-1b              Healthcare     San Rafael
# 6866    ADSK       over-10k    over-1b              Healthcare     San Rafael
# 7368    ATVI         5k-10k    over-1b              Technology     San Monica
# 7369    ATVI         5k-10k    over-1b              Technology     San Monica
# 7370    ATVI         5k-10k    over-1b              Technology     San Monica
# 7872     ADP       over-10k    over-1b  Consumer Discretionary       Roseland
# 7873     ADP       over-10k    over-1b  Consumer Discretionary       Roseland
# 7874     ADP       over-10k    over-1b  Consumer Discretionary       Roseland
# 8376     AZN       over-10k    over-1b              Healthcare      Cambridge
# 8377     AZN       over-10k    over-1b              Healthcare      Cambridge
# 8378     AZN       over-10k    over-1b              Healthcare      Cambridge
# 8880    AVGO       over-10k    over-1b              Technology       San Jose
# 8881    AVGO       over-10k    over-1b              Technology       San Jose
# 8882    AVGO       over-10k    over-1b              Technology       San Jose
# 9384    BIDU       over-10k    over-1b              Technology        Beijing
# 9385    BIDU       over-10k    over-1b              Technology        Beijing
# 9386    BIDU       over-10k    over-1b              Technology        Beijing
# 9887    BIIB         5k-10k    over-1b              Technology      Cambridge
# 9888    BIIB         5k-10k    over-1b              Technology      Cambridge
# 9889    BIIB         5k-10k    over-1b              Technology      Cambridge
# 10391   BMRN          1k-5k    over-1b              Healthcare         Novato
# 10392   BMRN          1k-5k    over-1b              Healthcare         Novato
# 10393   BMRN          1k-5k    over-1b              Healthcare         Novato
# 10895   BKNG       over-10k    over-1b              Healthcare        Norwalk
# 10896   BKNG       over-10k    over-1b              Healthcare        Norwalk
# 10897   BKNG       over-10k    over-1b              Healthcare        Norwalk
# 11399   CDNS         5k-10k    over-1b              Technology       San Jose
# 11400   CDNS         5k-10k    over-1b              Technology       San Jose
# 11401   CDNS         5k-10k    over-1b              Technology       San Jose
# 11903   CHTR       over-10k    over-1b              Technology       Stamford
# 11904   CHTR       over-10k    over-1b              Technology       Stamford
# 11905   CHTR       over-10k    over-1b              Technology       Stamford
# 12407   CPRT         5k-10k    over-1b              Technology         Dallas
# 12408   CPRT         5k-10k    over-1b              Technology         Dallas
# 12409   CPRT         5k-10k    over-1b              Technology         Dallas
# 12911   CRWD          1k-5k   50m-100m             Industrials         Austin
# 12912   CRWD          1k-5k   50m-100m             Industrials         Austin
# 12913   CRWD          1k-5k   50m-100m             Industrials         Austin
# 13415   CTAS       over-10k    over-1b        Consumer Staples     Cincinnati
# 13416   CTAS       over-10k    over-1b        Consumer Staples     Cincinnati
# 13417   CTAS       over-10k    over-1b        Consumer Staples     Cincinnati
# 13919   CSCO       over-10k    over-1b              Technology       San Jose
# 13920   CSCO       over-10k    over-1b              Technology       San Jose
# 13921   CSCO       over-10k    over-1b              Technology       San Jose
# 14423  CMCSA       over-10k    over-1b  Communication Services         Tupelo
# 14424  CMCSA       over-10k    over-1b  Communication Services         Tupelo
# 14425  CMCSA       over-10k    over-1b  Communication Services         Tupelo
# 14927   COST       over-10k    over-1b  Consumer Discretionary       Issaquah
# 14928   COST       over-10k    over-1b  Consumer Discretionary       Issaquah
# 14929   COST       over-10k    over-1b  Consumer Discretionary       Issaquah
# 15431    CSX       over-10k    over-1b  Communication Services   Jacksonville
# 15432    CSX       over-10k    over-1b  Communication Services   Jacksonville
# 15433    CSX       over-10k    over-1b  Communication Services   Jacksonville
# 15935   CTSH       over-10k    over-1b             Industrials        Teaneck
# 15936   CTSH       over-10k    over-1b             Industrials        Teaneck
# 15937   CTSH       over-10k    over-1b             Industrials        Teaneck
# 16439   DDOG          1k-5k   50m-100m              Technology       New York
# 16440   DDOG          1k-5k   50m-100m              Technology       New York
# 16441   DDOG          1k-5k   50m-100m              Technology       New York
# 16943   DOCU         5k-10k     1m-10m              Technology  San Francisco
# 16944   DOCU         5k-10k     1m-10m              Technology  San Francisco
# 16945   DOCU         5k-10k     1m-10m              Technology  San Francisco
# 17447   DXCM         5k-10k    200m-1b              Healthcare      San Diego
# 17448   DXCM         5k-10k    200m-1b              Healthcare      San Diego
# 17449   DXCM         5k-10k    200m-1b              Healthcare      San Diego
# 17951   DLTR       over-10k    over-1b              Technology     Chesapeake
# 17952   DLTR       over-10k    over-1b              Technology     Chesapeake
# 17953   DLTR       over-10k    over-1b              Technology     Chesapeake
# 18455     EA         5k-10k    over-1b        Consumer Staples   Redwood City
# 18456     EA         5k-10k    over-1b        Consumer Staples   Redwood City
# 18457     EA         5k-10k    over-1b        Consumer Staples   Redwood City
# 18959   EBAY       over-10k    over-1b              Technology       San Jose
# 18960   EBAY       over-10k    over-1b              Technology       San Jose
# 18961   EBAY       over-10k    over-1b              Technology       San Jose
# 19463    EXC       over-10k    over-1b              Technology        Chicago
# 19464    EXC       over-10k    over-1b              Technology        Chicago
# 19465    EXC       over-10k    over-1b              Technology        Chicago
# 19967   FAST       over-10k    over-1b             Industrials         Winona
# 19968   FAST       over-10k    over-1b             Industrials         Winona
# 19969   FAST       over-10k    over-1b             Industrials         Winona
# 20471     FB       over-10k     1m-10m             Industrials     Menlo Park
# 20472     FB       over-10k     1m-10m             Industrials     Menlo Park
# 20473     FB       over-10k     1m-10m             Industrials     Menlo Park
# 20975   FISV       over-10k    over-1b              Technology     Brookfield
# 20976   FISV       over-10k    over-1b              Technology     Brookfield
# 20977   FISV       over-10k    over-1b              Technology     Brookfield
# 21479   FTNT         5k-10k     1m-10m              Financials      Sunnyvale
# 21480   FTNT         5k-10k     1m-10m              Financials      Sunnyvale
# 21481   FTNT         5k-10k     1m-10m              Financials      Sunnyvale
# 21983   GILD       over-10k    over-1b              Technology    Foster City
# 21984   GILD       over-10k    over-1b              Technology    Foster City
# 21985   GILD       over-10k    over-1b              Technology    Foster City
# 22487   GOOG       over-10k    over-1b              Healthcare  Mountain View
# 22488   GOOG       over-10k    over-1b              Healthcare  Mountain View
# 22489   GOOG       over-10k    over-1b              Healthcare  Mountain View
# 22991  GOOGL       over-10k    over-1b              Technology  Mountain View
# 22992  GOOGL       over-10k    over-1b              Technology  Mountain View
# 22993  GOOGL       over-10k    over-1b              Technology  Mountain View
# 23495    HON       over-10k    over-1b              Technology      Charlotte
# 23496    HON       over-10k    over-1b              Technology      Charlotte
# 23497    HON       over-10k    over-1b              Technology      Charlotte
# 23999   ILMN         5k-10k    over-1b              Healthcare      San Diego
# 24000   ILMN         5k-10k    over-1b              Healthcare      San Diego
# 24001   ILMN         5k-10k    over-1b              Healthcare      San Diego
# 24503   INTC       over-10k    over-1b              Technology  Mountain View
# 24504   INTC       over-10k    over-1b              Technology  Mountain View
# 24505   INTC       over-10k    over-1b              Technology  Mountain View
# 25007   INTU         5k-10k    over-1b              Technology  Mountain View
# 25008   INTU         5k-10k    over-1b              Technology  Mountain View
# 25009   INTU         5k-10k    over-1b              Technology  Mountain View
# 25511   ISRG         5k-10k    over-1b              Healthcare      Sunnyvale
# 25512   ISRG         5k-10k    over-1b              Healthcare      Sunnyvale
# 25513   ISRG         5k-10k    over-1b              Healthcare      Sunnyvale
# 26015   MRVL         5k-10k    over-1b        Consumer Staples     Wilmington
# 26016   MRVL         5k-10k    over-1b        Consumer Staples     Wilmington
# 26017   MRVL         5k-10k    over-1b        Consumer Staples     Wilmington
# 26519   IDXX         5k-10k    over-1b             Industrials      Westbrook
# 26520   IDXX         5k-10k    over-1b             Industrials      Westbrook
# 26521   IDXX         5k-10k    over-1b             Industrials      Westbrook
# 27023     JD         500-1k    over-1b              Technology      Westbrook
# 27024     JD         500-1k    over-1b              Technology      Westbrook
# 27025     JD         500-1k    over-1b              Technology      Westbrook
# 27527    KDP       over-10k    over-1b              Healthcare          Plano
# 27528    KDP       over-10k    over-1b              Healthcare          Plano
# 27529    KDP       over-10k    over-1b              Healthcare          Plano
# 28031   KLAC       over-10k    over-1b        Consumer Staples       Milpitas
# 28032   KLAC       over-10k    over-1b        Consumer Staples       Milpitas
# 28033   KLAC       over-10k    over-1b        Consumer Staples       Milpitas
# 28535    KHC       over-10k    over-1b  Consumer Discretionary        Chicago
# 28536    KHC       over-10k    over-1b  Consumer Discretionary        Chicago
# 28537    KHC       over-10k    over-1b  Consumer Discretionary        Chicago
# 29039   LRCX       over-10k    over-1b        Consumer Staples        Fremont
# 29040   LRCX       over-10k    over-1b        Consumer Staples        Fremont
# 29041   LRCX       over-10k    over-1b        Consumer Staples        Fremont
# 29199   LCID          1k-5k     1m-10m              Technology         Newark
# 29200   LCID          1k-5k     1m-10m              Technology         Newark
# 29201   LCID          1k-5k     1m-10m              Technology         Newark
# 29703   LULU       over-10k    over-1b              Technology      Vancouver
# 29704   LULU       over-10k    over-1b              Technology      Vancouver
# 29705   LULU       over-10k    over-1b              Technology      Vancouver
# 30207   MELI         5k-10k    200m-1b  Consumer Discretionary   Buenos Aires
# 30208   MELI         5k-10k    200m-1b  Consumer Discretionary   Buenos Aires
# 30209   MELI         5k-10k    200m-1b  Consumer Discretionary   Buenos Aires
# 30711    MAR       over-10k    over-1b              Technology     Washington
# 30712    MAR       over-10k    over-1b              Technology     Washington
# 30713    MAR       over-10k    over-1b              Technology     Washington
# 31215   MTCH          1k-5k    over-1b        Consumer Staples         Dallas
# 31216   MTCH          1k-5k    over-1b        Consumer Staples         Dallas
# 31217   MTCH          1k-5k    over-1b        Consumer Staples         Dallas
# 31719   MCHP       over-10k    10m-50m  Consumer Discretionary       Chandler
# 31720   MCHP       over-10k    10m-50m  Consumer Discretionary       Chandler
# 31721   MCHP       over-10k    10m-50m  Consumer Discretionary       Chandler
# 32223   MDLZ       over-10k    over-1b              Technology        Chicago
# 32224   MDLZ       over-10k    over-1b              Technology        Chicago
# 32225   MDLZ       over-10k    over-1b              Technology        Chicago
# 32727   MRNA         500-1k   50m-100m              Technology      Cambridge
# 32728   MRNA         500-1k   50m-100m              Technology      Cambridge
# 32729   MRNA         500-1k   50m-100m              Technology      Cambridge
# 33231   MNST          1k-5k    over-1b  Communication Services         Corona
# 33232   MNST          1k-5k    over-1b  Communication Services         Corona
# 33233   MNST          1k-5k    over-1b  Communication Services         Corona
# 33735   MSFT       over-10k    over-1b              Healthcare        Redmond
# 33736   MSFT       over-10k    over-1b              Healthcare        Redmond
# 33737   MSFT       over-10k    over-1b              Healthcare        Redmond
# 34239     MU       over-10k    over-1b              Technology          Boise
# 34240     MU       over-10k    over-1b              Technology          Boise
# 34241     MU       over-10k    over-1b              Technology          Boise
# 34743   NFLX         5k-10k    over-1b              Technology      Los Gatos
# 34744   NFLX         5k-10k    over-1b              Technology      Los Gatos
# 34745   NFLX         5k-10k    over-1b              Technology      Los Gatos
# 35247   NTES       over-10k    over-1b              Technology       Hangzhou
# 35248   NTES       over-10k    over-1b              Technology       Hangzhou
# 35249   NTES       over-10k    over-1b              Technology       Hangzhou
# 35751   NVDA       over-10k    over-1b              Technology    Santa Clara
# 35752   NVDA       over-10k    over-1b              Technology    Santa Clara
# 35753   NVDA       over-10k    over-1b              Technology    Santa Clara
# 36255   NXPI       over-10k    over-1b              Technology      Eindhoven
# 36256   NXPI       over-10k    over-1b              Technology      Eindhoven
# 36257   NXPI       over-10k    over-1b              Technology      Eindhoven
# 36759   OKTA          1k-5k  100m-200m              Technology  San Francisco
# 36760   OKTA          1k-5k  100m-200m              Technology  San Francisco
# 36761   OKTA          1k-5k  100m-200m              Technology  San Francisco
# 37263   ODFL       over-10k    over-1b              Technology    Thomasville
# 37264   ODFL       over-10k    over-1b              Technology    Thomasville
# 37265   ODFL       over-10k    over-1b              Technology    Thomasville
# 37767   ORLY       over-10k    over-1b             Industrials    Springfield
# 37768   ORLY       over-10k    over-1b             Industrials    Springfield
# 37769   ORLY       over-10k    over-1b             Industrials    Springfield
# 38271   PCAR       over-10k    over-1b              Technology       Bellevue
# 38272   PCAR       over-10k    over-1b              Technology       Bellevue
# 38273   PCAR       over-10k    over-1b              Technology       Bellevue
# 38775   PANW         5k-10k    200m-1b  Consumer Discretionary    Santa Clara
# 38776   PANW         5k-10k    200m-1b  Consumer Discretionary    Santa Clara
# 38777   PANW         5k-10k    200m-1b  Consumer Discretionary    Santa Clara
# 39279   PAYX       over-10k    over-1b             Industrials      Rochester
# 39280   PAYX       over-10k    over-1b             Industrials      Rochester
# 39281   PAYX       over-10k    over-1b             Industrials      Rochester
# 39783    PDD          1k-5k    over-1b             Industrials       Shanghai
# 39784    PDD          1k-5k    over-1b             Industrials       Shanghai
# 39785    PDD          1k-5k    over-1b             Industrials       Shanghai
# 40287   PYPL       over-10k    over-1b              Financials       San Jose
# 40288   PYPL       over-10k    over-1b              Financials       San Jose
# 40289   PYPL       over-10k    over-1b              Financials       San Jose
# 40791    PEP       over-10k    over-1b  Consumer Discretionary       Harrison
# 40792    PEP       over-10k    over-1b  Consumer Discretionary       Harrison
# 40793    PEP       over-10k    over-1b  Consumer Discretionary       Harrison
# 41296   QCOM       over-10k    over-1b        Consumer Staples      San Diego
# 41297   QCOM       over-10k    over-1b        Consumer Staples      San Diego
# 41298   QCOM       over-10k    over-1b        Consumer Staples      San Diego
# 41800   REGN         5k-10k    over-1b              Technology      Tarrytown
# 41801   REGN         5k-10k    over-1b              Technology      Tarrytown
# 41802   REGN         5k-10k    over-1b              Technology      Tarrytown
# 42304   ROST       over-10k    over-1b              Healthcare      San Bruno
# 42305   ROST       over-10k    over-1b              Healthcare      San Bruno
# 42306   ROST       over-10k    over-1b              Healthcare      San Bruno
# 42808   SIRI          1k-5k    over-1b              Healthcare       New York
# 42809   SIRI          1k-5k    over-1b              Healthcare       New York
# 42810   SIRI          1k-5k    over-1b              Healthcare       New York
# 43312   SGEN         500-1k    200m-1b  Communication Services        Bothell
# 43313   SGEN         500-1k    200m-1b  Communication Services        Bothell
# 43314   SGEN         500-1k    200m-1b  Communication Services        Bothell
# 43816   SPLK         5k-10k    200m-1b              Technology  San Francisco
# 43817   SPLK         5k-10k    200m-1b              Technology  San Francisco
# 43818   SPLK         5k-10k    200m-1b              Technology  San Francisco
# 44320   SWKS         5k-10k    over-1b  Consumer Discretionary         Irvine
# 44321   SWKS         5k-10k    over-1b  Consumer Discretionary         Irvine
# 44322   SWKS         5k-10k    over-1b  Consumer Discretionary         Irvine
# 44824   SBUX       over-10k    over-1b  Consumer Discretionary        Seattle
# 44825   SBUX       over-10k    over-1b  Consumer Discretionary        Seattle
# 44826   SBUX       over-10k    over-1b  Consumer Discretionary        Seattle
# 45328   SNPS       over-10k    over-1b              Technology  Mountain View
# 45329   SNPS       over-10k    over-1b              Technology  Mountain View
# 45330   SNPS       over-10k    over-1b              Technology  Mountain View
# 45832   TSLA       over-10k    over-1b              Technology         Austin
# 45833   TSLA       over-10k    over-1b              Technology         Austin
# 45834   TSLA       over-10k    over-1b              Technology         Austin
# 46335    TXN       over-10k    over-1b  Communication Services         Dallas
# 46336    TXN       over-10k    over-1b  Communication Services         Dallas
# 46337    TXN       over-10k    over-1b  Communication Services         Dallas
# 46839   TMUS       over-10k    200m-1b  Consumer Discretionary       Bellevue
# 46840   TMUS       over-10k    200m-1b  Consumer Discretionary       Bellevue
# 46841   TMUS       over-10k    200m-1b  Consumer Discretionary       Bellevue
# 47343   VRSN         500-1k    over-1b             Industrials         Reston
# 47344   VRSN         500-1k    over-1b             Industrials         Reston
# 47345   VRSN         500-1k    over-1b             Industrials         Reston
# 47847   VRSK         5k-10k    over-1b              Technology    Jersey City
# 47848   VRSK         5k-10k    over-1b              Technology    Jersey City
# 47849   VRSK         5k-10k    over-1b              Technology    Jersey City
# 48351   VRTX          1k-5k    over-1b              Healthcare         Boston
# 48352   VRTX          1k-5k    over-1b              Healthcare         Boston
# 48353   VRTX          1k-5k    over-1b              Healthcare         Boston
# 48855    WBA       over-10k    over-1b              Healthcare        Chicago
# 48856    WBA       over-10k    over-1b              Healthcare        Chicago
# 48857    WBA       over-10k    over-1b              Healthcare        Chicago
# 49360   WDAY       over-10k    over-1b              Technology     Pleasanton
# 49361   WDAY       over-10k    over-1b              Technology     Pleasanton
# 49362   WDAY       over-10k    over-1b              Technology     Pleasanton
# 49863    XEL       over-10k    over-1b               Utilities    Minneapolis
# 49864    XEL       over-10k    over-1b               Utilities    Minneapolis
# 49865    XEL       over-10k    over-1b               Utilities    Minneapolis
# 50367     ZM          1k-5k  100m-200m              Technology       San Jose
# 50368     ZM          1k-5k  100m-200m              Technology       San Jose
# 50369     ZM          1k-5k  100m-200m              Technology       San Jose
# 50871     ZS          1k-5k  100m-200m              Technology       San Jose
# 50872     ZS          1k-5k  100m-200m              Technology       San Jose
# 50873     ZS          1k-5k  100m-200m              Technology       San Jose
#
#       state_name region country_code       volume  volume_weight  \
# 501           CA      W           US  102310329.0       109.6319
# 502           CA      W           US  102557375.0       105.3382
# 503           CA      W           US   87584432.0       105.9691
# 1006          CA      W           US    2905656.0       447.8637
# 1007          CA      W           US    2686310.0       437.7568
# 1008          CA      W           US    4434498.0       422.5279
# 1321          CA      W           US    7023908.0       148.5454
# 1322          CA      W           US    5302511.0       149.8916
# 1323          CA      W           US    4577255.0       147.8527
# 1825          AZ     SW           US     694358.0       438.9188
# 1826          AZ     SW           US     532709.0       427.7159
# 1827          AZ     SW           US     957114.0       409.9722
# 2329          WA     NW           US    4132233.0      2821.5439
# 2330          WA     NW           US    6753145.0      2930.5557
# 2331          WA     NW           US    3437028.0      2946.3903
# 2833          CA      W           US    2640854.0       231.8198
# 2834          CA      W           US    3957273.0       227.5793
# 2835          CA      W           US    2667024.0       228.6386
# 3336          OH     MW           US    3006258.0        95.0679
# 3337          OH     MW           US    2897953.0        95.5087
# 3338          OH     MW           US    2254945.0        95.8241
# 3840          MA     SE           US    3046254.0       153.5888
# 3841          MA     SE           US    4035714.0       150.1401
# 3842          MA     SE           US    3964265.0       149.4415
# 4344          PA     SE           US     404751.0       310.8922
# 4345          PA     SE           US     452440.0       301.8731
# 4346          PA     SE           US     691956.0       298.0095
# 4848          CA      W           US   91445405.0       161.9446
# 4849          CA      W           US  105342033.0       158.0284
# 4850          CA      W           US   96917302.0       156.1598
# 5352          CA      W           US    7623175.0       128.1947
# 5353          CA      W           US    5604387.0       124.5674
# 5354          CA      W           US    6015969.0       125.9169
# 5856          NL     NL  Netherlands    1593366.0       614.6359
# 5857          NL     NL  Netherlands     735546.0       601.0389
# 5858          NL     NL  Netherlands     818991.0       595.6976
# 6360         AUS     AU    Australia    2614939.0       260.4580
# 6361         AUS     AU    Australia    1684942.0       256.1528
# 6362         AUS     AU    Australia    1466375.0       248.8555
# 6864          CA      W           US    1850028.0       205.2018
# 6865          CA      W           US    1458925.0       199.9849
# 6866          CA      W           US    1987062.0       195.0114
# 7368          CA      W           US    9914482.0        80.9645
# 7369          CA      W           US    6981412.0        80.8130
# 7370          CA      W           US   10714298.0        80.4348
# 7872          NJ     NE           US    1791687.0       209.3495
# 7873          NJ     NE           US    2399303.0       207.7212
# 7874          NJ     NE           US    1664796.0       208.5401
# 8376          UK     GB           UK    9256766.0        59.9165
# 8377          UK     GB           UK    6667621.0        60.6449
# 8378          UK     GB           UK    6342213.0        60.5447
# 8880          CA      W           US    2256049.0       595.6417
# 8881          CA      W           US    1932364.0       584.2682
# 8882          CA      W           US    1981534.0       582.1116
# 9384          CN     CH           CH    3303007.0       143.0105
# 9385          CN     CH           CH    4452305.0       135.0444
# 9386          CN     CH           CH    7837318.0       123.2120
# 9887          MA     SE           US    1236890.0       204.3033
# 9888          MA     SE           US    1166270.0       198.5026
# 9889          MA     SE           US     787917.0       199.0211
# 10391         CA      W           US    1583428.0        78.6484
# 10392         CA      W           US     821615.0        77.6476
# 10393         CA      W           US     842813.0        76.5255
# 10895         CT     NE           US     776359.0      2049.4691
# 10896         CT     NE           US     638530.0      2028.4670
# 10897         CT     NE           US     360797.0      2030.8021
# 11399         CA      W           US    2086904.0       150.3021
# 11400         CA      W           US    1603218.0       148.1470
# 11401         CA      W           US    1382365.0       146.3686
# 11903         CT     NE           US    1212273.0       561.2489
# 11904         CT     NE           US    1537737.0       561.1658
# 11905         CT     NE           US    1788310.0       567.4888
# 12407         TX     SE           US    2624716.0       114.6927
# 12408         TX     SE           US    1924115.0       115.1458
# 12409         TX     SE           US    1867003.0       115.7932
# 12911         TX     SE           US    9287180.0       171.3546
# 12912         TX     SE           US   24135352.0       191.8395
# 12913         TX     SE           US    7983054.0       193.1560
# 13415         OH     MW           US     460652.0       373.3328
# 13416         OH     MW           US     487435.0       368.7097
# 13417         OH     MW           US     371905.0       370.5870
# 13919         CA      W           US   19150856.0        55.7380
# 13920         CA      W           US   18550934.0        54.6294
# 13921         CA      W           US   20330307.0        55.0892
# 14423         MS     SE           US   20113718.0        46.3043
# 14424         MS     SE           US   18179456.0        45.3313
# 14425         MS     SE           US   19584780.0        45.3243
# 14927         WA     NW           US    2789706.0       525.2468
# 14928         WA     NW           US    1777660.0       527.6596
# 14929         WA     NW           US    1735112.0       532.3424
# 15431         FL     SE           US   21741832.0        34.6627
# 15432         FL     SE           US   24267691.0        34.8330
# 15433         FL     SE           US   21957297.0        34.9849
# 15935         NJ     NE           US    4135694.0        88.5163
# 15936         NJ     NE           US    2363514.0        87.1445
# 15937         NJ     NE           US    3576086.0        88.5223
# 16439         NY     SE           US    6419730.0       139.3596
# 16440         NY     SE           US    3091661.0       139.1711
# 16441         NY     SE           US    4354633.0       130.0496
# 16943         CA      W           US    5174835.0        98.2739
# 16944         CA      W           US   11491126.0        88.3931
# 16945         CA      W           US   44966816.0        74.0216
# 17447         CA      W           US    1055306.0       407.0818
# 17448         CA      W           US     634775.0       404.8070
# 17449         CA      W           US     607547.0       396.9054
# 17951         VA     SE           US    6167252.0       148.2673
# 17952         VA     SE           US    2537913.0       147.4767
# 17953         VA     SE           US    1682512.0       147.3746
# 18455         CA      W           US    2139504.0       125.1684
# 18456         CA      W           US    1222004.0       123.7974
# 18457         CA      W           US    1195222.0       122.9628
# 18959         CA      W           US   10250423.0        53.0511
# 18960         CA      W           US   18926205.0        53.0869
# 18961         CA      W           US    9217656.0        50.9199
# 19463         IL     MW           US    8573141.0        43.5758
# 19464         IL     MW           US    9859163.0        43.5300
# 19465         IL     MW           US    6407446.0        43.8972
# 19967         MN     MW           US    3616368.0        54.6028
# 19968         MN     MW           US    2401261.0        54.2348
# 19969         MN     MW           US    2446355.0        54.3752
# 20471         CA      W           US   31894695.0       196.9614
# 20472         CA      W           US   24852975.0       193.9663
# 20473         CA      W           US   34694534.0       189.4396
# 20975         WI     NW           US    4452408.0        96.1614
# 20976         WI     NW           US    2764771.0        94.8574
# 20977         WI     NW           US    2720970.0        94.8533
# 21479         CA      W           US    2198856.0       283.2592
# 21480         CA      W           US    1467666.0       283.9637
# 21481         CA      W           US    1369052.0       282.1387
# 21983         CA      W           US   13678135.0        59.3244
# 21984         CA      W           US   13243687.0        57.8358
# 21985         CA      W           US   13007627.0        58.4238
# 22487         CA      W           US    1612872.0      2650.3074
# 22488         CA      W           US    1213260.0      2649.0884
# 22489         CA      W           US    1329990.0      2637.3465
# 22991         CA      W           US    1851270.0      2643.6693
# 22992         CA      W           US    1355070.0      2640.1379
# 22993         CA      W           US    1576322.0      2626.3924
# 23495         NC     SE           US    2899407.0       185.6762
# 23496         NC     SE           US    2455436.0       184.1054
# 23497         NC     SE           US    2725571.0       183.6600
# 23999         CA      W           US     873582.0       324.6330
# 24000         CA      W           US     768526.0       315.4683
# 24001         CA      W           US     642681.0       308.8718
# 24503         CA      W           US   36076458.0        47.5889
# 24504         CA      W           US   36455953.0        46.5762
# 24505         CA      W           US   27082085.0        46.2802
# 25007         CA      W           US    1950593.0       463.3738
# 25008         CA      W           US    1756284.0       450.4148
# 25009         CA      W           US    2303338.0       443.7956
# 25511         CA      W           US    2080804.0       277.0114
# 25512         CA      W           US    1331160.0       274.4961
# 25513         CA      W           US    1842068.0       276.1064
# 26015         DE     NE           US   10367602.0        66.5780
# 26016         DE     NE           US    7677751.0        65.2805
# 26017         DE     NE           US    6971974.0        64.1245
# 26519         ME     SE           US     558578.0       527.6219
# 26520         ME     SE           US     525296.0       520.0078
# 26521         ME     SE           US     334124.0       506.7600
# 27023         ME     SE           US    9487275.0        61.8761
# 27024         ME     SE           US   55348139.0        52.8668
# 27025         ME     SE           US   32963038.0        49.7949
# 27527         TX     SE           US    9897116.0        37.5559
# 27528         TX     SE           US    8174470.0        37.0888
# 27529         TX     SE           US    6844868.0        37.0816
# 28031         CA      W           US    1521253.0       338.4671
# 28032         CA      W           US    1555920.0       328.3266
# 28033         CA      W           US     958881.0       326.6187
# 28535         IL     MW           US   10448481.0        38.5197
# 28536         IL     MW           US    5216457.0        37.4623
# 28537         IL     MW           US    4722638.0        37.6486
# 29039         CA      W           US    1443926.0       515.2334
# 29040         CA      W           US    1110604.0       495.6429
# 29041         CA      W           US    1038936.0       488.7582
# 29199         CA      W           US   18168840.0        25.2081
# 29200         CA      W           US   16508757.0        24.1074
# 29201         CA      W           US   18824699.0        23.2549
# 29703        CAN     CA           CA    1574343.0       304.8735
# 29704        CAN     CA           CA     934837.0       300.6244
# 29705        CAN     CA           CA     978426.0       295.5002
# 30207         AR     SE    Argentina    1123495.0       960.0765
# 30208         AR     SE    Argentina     634605.0       935.0841
# 30209         AR     SE    Argentina     575187.0       903.7596
# 30711       D.C.     SE           US    3509843.0       160.2369
# 30712       D.C.     SE           US    2573293.0       161.8691
# 30713       D.C.     SE           US    2316271.0       163.0318
# 31215         TX     SE           US    5407345.0        98.4019
# 31216         TX     SE           US    2462202.0        95.3778
# 31217         TX     SE           US    3162002.0        90.1154
# 31719         AZ     SW           US    6711334.0        70.8634
# 31720         AZ     SW           US    3607907.0        69.5075
# 31721         AZ     SW           US    3528704.0        69.7539
# 32223         IL     MW           US    8709398.0        61.5561
# 32224         IL     MW           US    7341958.0        60.1671
# 32225         IL     MW           US    9385282.0        59.7370
# 32727         MA     SE           US    9533949.0       140.7141
# 32728         MA     SE           US    5557146.0       138.5617
# 32729         MA     SE           US    5356440.0       140.7167
# 33231         CA      W           US    3537523.0        76.4294
# 33232         CA      W           US    2758616.0        75.3567
# 33233         CA      W           US    1687512.0        74.0202
# 33735         WA     NW           US   35204480.0       286.2058
# 33736         WA     NW           US   30628012.0       283.9699
# 33737         WA     NW           US   27209330.0       283.7288
# 34239         ID     NW           US   19647851.0        79.2627
# 34240         ID     NW           US   21691955.0        75.3013
# 34241         ID     NW           US   22786509.0        73.5912
# 34743         CA      W           US    6485186.0       358.5485
# 34744         CA      W           US    4807767.0       358.9168
# 34745         CA      W           US    4819925.0       346.3833
# 35247         CN     CH           CN    3654682.0        88.5448
# 35248         CN     CH           CN    5597701.0        80.8696
# 35249         CN     CH           CN    4742719.0        80.1779
# 35751         CA      W           US   49274195.0       227.8595
# 35752         CA      W           US   42806565.0       223.6303
# 35753         CA      W           US   36695857.0       224.9843
# 36255         NL     NL  Netherlands    3108923.0       183.8995
# 36256         NL     NL  Netherlands    1899207.0       179.3581
# 36257         NL     NL  Netherlands    2159407.0       180.2879
# 36759         CA      W           US    2456727.0       168.4818
# 36760         CA      W           US    1374880.0       165.3699
# 36761         CA      W           US    2056977.0       157.0688
# 37263         NC     SE           US     880700.0       305.9245
# 37264         NC     SE           US     587580.0       307.8806
# 37265         NC     SE           US     619717.0       308.1769
# 37767         MO     MW           US     493633.0       673.5724
# 37768         MO     MW           US     454342.0       672.3348
# 37769         MO     MW           US     404854.0       679.5612
# 38271         WA     NW           US    2786430.0        87.1980
# 38272         WA     NW           US    1738721.0        85.9713
# 38273         WA     NW           US    1367450.0        85.8099
# 38775         CA      W           US    1731623.0       551.7975
# 38776         CA      W           US    1074692.0       551.1671
# 38777         CA      W           US    1175810.0       551.3746
# 39279         NY     SE           US    1679589.0       121.6811
# 39280         NY     SE           US    1317611.0       121.3758
# 39281         NY     SE           US    1071014.0       121.6751
# 39783         CN     CH           CH    7731168.0        42.7136
# 39784         CN     CH           CH   18296948.0        36.3579
# 39785         CN     CH           CH   17274393.0        33.4402
# 40287         CA      W           US   20811232.0        99.3076
# 40288         CA      W           US   14683698.0        97.9276
# 40289         CA      W           US   15141665.0        97.3225
# 40791         NY     SE           US    5764927.0       157.6512
# 40792         NY     SE           US    5965671.0       154.6174
# 40793         NY     SE           US    4762675.0       154.7930
# 41296         CA      W           US    9276774.0       156.6853
# 41297         CA      W           US    8888772.0       153.5928
# 41298         CA      W           US    7394419.0       154.1756
# 41800         NY     SE           US     538933.0       622.5280
# 41801         NY     SE           US     480626.0       626.3473
# 41802         NY     SE           US     803192.0       645.0864
# 42304         CA      W           US    3488185.0        88.3599
# 42305         CA      W           US    2235105.0        88.9545
# 42306         CA      W           US    2228206.0        88.5806
# 42808         NY     SE           US   29496325.0         6.2707
# 42809         NY     SE           US   25034845.0         6.2000
# 42810         NY     SE           US   21245836.0         6.2143
# 43312         WA     NW           US     986096.0       139.8033
# 43313         WA     NW           US     820110.0       140.4637
# 43314         WA     NW           US     754717.0       138.8715
# 43816         CA      W           US    1838217.0       128.0419
# 43817         CA      W           US    1726490.0       127.1526
# 43818         CA      W           US    1901661.0       123.9052
# 44320         CA      W           US    1826248.0       134.2065
# 44321         CA      W           US    1262372.0       131.1486
# 44322         CA      W           US    1388463.0       128.9609
# 44824         WA     NW           US    8811617.0        87.4006
# 44825         WA     NW           US    9114348.0        86.6866
# 44826         WA     NW           US   15351744.0        84.2136
# 45328         CA      W           US     809770.0       306.8868
# 45329         CA      W           US     941777.0       297.4164
# 45330         CA      W           US     953157.0       297.5679
# 45832         TX     SE           US   19724223.0       850.6831
# 45833         TX     SE           US   19549548.0       830.2271
# 45834         TX     SE           US   22345722.0       808.9169
# 46335         TX     SE           US    6047344.0       172.4020
# 46336         TX     SE           US    6079155.0       171.6576
# 46337         TX     SE           US    4869906.0       171.8460
# 46839         WA     NW           US    4290357.0       121.8272
# 46840         WA     NW           US    4200597.0       122.6250
# 46841         WA     NW           US    4207189.0       125.2409
# 47343         VA     SE           US     813669.0       209.1856
# 47344         VA     SE           US     785306.0       206.7204
# 47345         VA     SE           US     438066.0       205.8594
# 47847         NJ     NE           US    1419459.0       186.6740
# 47848         NJ     NE           US    1247375.0       184.6647
# 47849         NJ     NE           US    1371564.0       183.5925
# 48351         MA     SE           US    1379009.0       238.6797
# 48352         MA     SE           US    1080110.0       239.5513
# 48353         MA     SE           US    1374036.0       239.6352
# 48855         IL     MW           US    5408382.0        48.1664
# 48856         IL     MW           US    4999822.0        47.7198
# 48857         IL     MW           US    5737993.0        47.9174
# 49360         CA      W           US    2392043.0       233.0048
# 49361         CA      W           US    1478994.0       229.0807
# 49362         CA      W           US    1789032.0       226.1950
# 49863         MN     MW           US    2866881.0        69.9416
# 49864         MN     MW           US    1945242.0        69.9773
# 49865         MN     MW           US    3031491.0        70.4602
# 50367         CA      W           US    6427507.0       109.3114
# 50368         CA      W           US    5030777.0       103.3206
# 50369         CA      W           US    6454629.0        99.6973
# 50871         CA      W           US    3050554.0       209.3268
# 50872         CA      W           US    2305091.0       208.7971
# 50873         CA      W           US    1893573.0       202.9376
#
#        percent_change        date
# 501          2.435200  2022-03-08
# 502          2.231610  2022-03-09
# 503          3.551281  2022-03-10
# 1006         1.593060  2022-03-08
# 1007         1.288567  2022-03-09
# 1008         5.295001  2022-03-10
# 1321         1.980334  2022-03-08
# 1322         4.531056  2022-03-09
# 1323         5.832739  2022-03-10
# 1825         2.038225  2022-03-08
# 1826         0.424966  2022-03-09
# 1827         8.556235  2022-03-10
# 2329         0.158423  2022-03-08
# 2330         0.777362  2022-03-09
# 2331         2.707681  2022-03-10
# 2833         1.182598  2022-03-08
# 2834         1.180005  2022-03-09
# 2835         0.324405  2022-03-10
# 3336         0.928050  2022-03-08
# 3337         1.458620  2022-03-09
# 3338         0.840685  2022-03-10
# 3840         0.346202  2022-03-08
# 3841         0.192244  2022-03-09
# 3842         3.655352  2022-03-10
# 4344         1.508011  2022-03-08
# 4345         0.308703  2022-03-09
# 4346         4.547967  2022-03-10
# 4848         0.913454  2022-03-08
# 4849         1.048689  2022-03-09
# 4850         2.642673  2022-03-10
# 5352         0.720439  2022-03-08
# 5353         0.596564  2022-03-09
# 5354         4.892308  2022-03-10
# 5856         2.001149  2022-03-08
# 5857         0.088401  2022-03-09
# 5858         4.584691  2022-03-10
# 6360         2.083902  2022-03-08
# 6361         0.480353  2022-03-09
# 6362         4.610918  2022-03-10
# 6864         1.070495  2022-03-08
# 6865         0.045027  2022-03-09
# 6866         3.001110  2022-03-10
# 7368         0.663635  2022-03-08
# 7369         0.037143  2022-03-09
# 7370         0.606436  2022-03-10
# 7872         0.299529  2022-03-08
# 7873         1.413975  2022-03-09
# 7874         1.595214  2022-03-10
# 8376         2.947189  2022-03-08
# 8377         1.567712  2022-03-09
# 8378         0.412882  2022-03-10
# 8880         1.397782  2022-03-08
# 8881         0.370585  2022-03-09
# 8882         2.390203  2022-03-10
# 9384         4.167269  2022-03-08
# 9385         2.121805  2022-03-09
# 9386        12.494481  2022-03-10
# 9887         1.877365  2022-03-08
# 9888         1.174129  2022-03-09
# 9889         1.720280  2022-03-10
# 10391        2.829205  2022-03-08
# 10392        0.412531  2022-03-09
# 10393        2.351883  2022-03-10
# 10895        1.290345  2022-03-08
# 10896        2.750492  2022-03-09
# 10897        2.162949  2022-03-10
# 11399        0.950023  2022-03-08
# 11400        1.225872  2022-03-09
# 11401        4.083929  2022-03-10
# 11903        0.786239  2022-03-08
# 11904        2.166446  2022-03-09
# 11905        1.841061  2022-03-10
# 12407        2.939870  2022-03-08
# 12408        2.382952  2022-03-09
# 12409        1.785411  2022-03-10
# 12911        5.256959  2022-03-08
# 12912        1.660458  2022-03-09
# 12913        0.303474  2022-03-10
# 13415        0.439052  2022-03-08
# 13416        0.328323  2022-03-09
# 13417        1.388518  2022-03-10
# 13919        0.503235  2022-03-08
# 13920        0.569853  2022-03-09
# 13921        1.085187  2022-03-10
# 14423        1.410859  2022-03-08
# 14424        0.438693  2022-03-09
# 14425        2.045257  2022-03-10
# 14927        0.005686  2022-03-08
# 14928        1.837090  2022-03-09
# 14929        1.714435  2022-03-10
# 15431        3.026058  2022-03-08
# 15432        1.779463  2022-03-09
# 15433        1.714124  2022-03-10
# 15935        1.135214  2022-03-08
# 15936        0.979150  2022-03-09
# 15937        0.181406  2022-03-10
# 16439        7.269996  2022-03-08
# 16440        0.379575  2022-03-09
# 16441       10.819350  2022-03-10
# 16943        2.188640  2022-03-08
# 16944        1.085239  2022-03-09
# 16945        2.203390  2022-03-10
# 17447        2.006780  2022-03-08
# 17448        1.074090  2022-03-09
# 17449        5.663661  2022-03-10
# 17951        4.042864  2022-03-08
# 17952        2.409639  2022-03-09
# 17953        1.083227  2022-03-10
# 18455        1.193163  2022-03-08
# 18456        0.762256  2022-03-09
# 18457        1.845463  2022-03-10
# 18959        1.613202  2022-03-08
# 18960        1.244813  2022-03-09
# 18961        5.368620  2022-03-10
# 19463        0.434385  2022-03-08
# 19464        0.669591  2022-03-09
# 19465        1.378843  2022-03-10
# 19967        0.526794  2022-03-08
# 19968        0.901201  2022-03-09
# 19969        1.604376  2022-03-10
# 20471        1.410034  2022-03-08
# 20472        0.189899  2022-03-09
# 20473        2.608560  2022-03-10
# 20975        0.438185  2022-03-08
# 20976        0.337802  2022-03-09
# 20977        2.110626  2022-03-10
# 21479        0.813721  2022-03-08
# 21480        0.865283  2022-03-09
# 21481        4.427172  2022-03-10
# 21983        1.683053  2022-03-08
# 21984        1.143540  2022-03-09
# 21985        0.531641  2022-03-10
# 22487        1.876712  2022-03-08
# 22488        0.927641  2022-03-09
# 22489        2.629861  2022-03-10
# 22991        1.653333  2022-03-08
# 22992        0.886368  2022-03-09
# 22993        2.710346  2022-03-10
# 23495        0.515132  2022-03-08
# 23496        0.997042  2022-03-09
# 23497        2.221268  2022-03-10
# 23999        0.641582  2022-03-08
# 24000        0.198945  2022-03-09
# 24001        5.451321  2022-03-10
# 24503        1.611237  2022-03-08
# 24504        1.332206  2022-03-09
# 24505        2.799576  2022-03-10
# 25007        1.809499  2022-03-08
# 25008        1.690753  2022-03-09
# 25009        3.988461  2022-03-10
# 25511        0.493783  2022-03-08
# 25512        1.037048  2022-03-09
# 25513        1.638814  2022-03-10
# 26015        0.349830  2022-03-08
# 26016        0.000000  2022-03-09
# 26017        4.365621  2022-03-10
# 26519        1.673062  2022-03-08
# 26520        1.057905  2022-03-09
# 26521        6.146599  2022-03-10
# 27023        1.496422  2022-03-08
# 27024        0.924354  2022-03-09
# 27025       10.966401  2022-03-10
# 27527        0.212145  2022-03-08
# 27528        0.107643  2022-03-09
# 27529        1.419389  2022-03-10
# 28031        2.552022  2022-03-08
# 28032        0.589587  2022-03-09
# 28033        3.817316  2022-03-10
# 28535        2.377908  2022-03-08
# 28536        0.079979  2022-03-09
# 28537        0.980652  2022-03-10
# 29039        1.552807  2022-03-08
# 29040        1.527398  2022-03-09
# 29041        5.504838  2022-03-10
# 29199        0.517310  2022-03-08
# 29200        2.810116  2022-03-09
# 29201        4.698545  2022-03-10
# 29703        0.032688  2022-03-08
# 29704        0.580000  2022-03-09
# 29705        4.762683  2022-03-10
# 30207        3.056878  2022-03-08
# 30208        3.098630  2022-03-09
# 30209        6.657664  2022-03-10
# 30711        0.802781  2022-03-08
# 30712        3.839029  2022-03-09
# 30713        1.648920  2022-03-10
# 31215        4.071113  2022-03-08
# 31216        1.992978  2022-03-09
# 31217        9.818515  2022-03-10
# 31719        0.028209  2022-03-08
# 31720        0.808197  2022-03-09
# 31721        2.705750  2022-03-10
# 32223        0.503247  2022-03-08
# 32224        0.758825  2022-03-09
# 32225        2.280992  2022-03-10
# 32727        7.885671  2022-03-08
# 32728        0.007168  2022-03-09
# 32729        1.811723  2022-03-10
# 33231        2.829556  2022-03-08
# 33232        0.039809  2022-03-09
# 33233        4.049273  2022-03-10
# 33735        1.785210  2022-03-08
# 33736        0.908063  2022-03-09
# 33737        2.739964  2022-03-10
# 34239        0.662749  2022-03-08
# 34240        2.592140  2022-03-09
# 34241        5.002935  2022-03-10
# 34743        0.308931  2022-03-08
# 34744        0.160022  2022-03-09
# 34745        5.778122  2022-03-10
# 35247        2.015432  2022-03-08
# 35248        2.702381  2022-03-09
# 35249        4.618910  2022-03-10
# 35751        2.800733  2022-03-08
# 35752        0.563668  2022-03-09
# 35753        4.004865  2022-03-10
# 36255        0.191257  2022-03-08
# 36256        0.702968  2022-03-09
# 36257        2.945972  2022-03-10
# 36759        3.127744  2022-03-08
# 36760        1.092211  2022-03-09
# 36761        7.864362  2022-03-10
# 37263        0.117451  2022-03-08
# 37264        2.251420  2022-03-09
# 37265        2.383228  2022-03-10
# 37767        1.399179  2022-03-08
# 37768        1.545168  2022-03-09
# 37769        1.113211  2022-03-10
# 38271        2.584586  2022-03-08
# 38272        0.489910  2022-03-09
# 38273        1.303495  2022-03-10
# 38775        3.009096  2022-03-08
# 38776        0.400255  2022-03-09
# 38777        2.358642  2022-03-10
# 39279        1.350791  2022-03-08
# 39280        1.495141  2022-03-09
# 39281        2.046950  2022-03-10
# 39783        5.373207  2022-03-08
# 39784       10.082977  2022-03-09
# 39785       13.314448  2022-03-10
# 40287        2.140236  2022-03-08
# 40288        0.504796  2022-03-09
# 40289        3.187970  2022-03-10
# 40791        1.508041  2022-03-08
# 40792        0.821619  2022-03-09
# 40793        1.106465  2022-03-10
# 41296        0.705083  2022-03-08
# 41297        0.434952  2022-03-09
# 41298        3.551757  2022-03-10
# 41800        0.197686  2022-03-08
# 41801        2.309578  2022-03-09
# 41802        1.385295  2022-03-10
# 42304        0.328500  2022-03-08
# 42305        2.941176  2022-03-09
# 42306        3.252122  2022-03-10
# 42808        3.341103  2022-03-08
# 42809        0.647249  2022-03-09
# 42810        0.161290  2022-03-10
# 43312        1.569166  2022-03-08
# 43313        2.280485  2022-03-09
# 43314        3.063304  2022-03-10
# 43816        1.863799  2022-03-08
# 43817        0.451128  2022-03-09
# 43818        4.405321  2022-03-10
# 44320        1.127570  2022-03-08
# 44321        0.341116  2022-03-09
# 44322        4.105263  2022-03-10
# 44824        1.271676  2022-03-08
# 44825        1.242885  2022-03-09
# 44826        6.361064  2022-03-10
# 45328        1.340050  2022-03-08
# 45329        0.133138  2022-03-09
# 45330        3.708197  2022-03-10
# 45832        2.321675  2022-03-08
# 45833        1.544424  2022-03-09
# 45834        5.337677  2022-03-10
# 46335        0.081112  2022-03-08
# 46336        1.929431  2022-03-09
# 46337        2.035653  2022-03-10
# 46839        1.060656  2022-03-08
# 46840        2.386872  2022-03-09
# 46841        0.112513  2022-03-10
# 47343        0.451221  2022-03-08
# 47344        0.671855  2022-03-09
# 47345        3.168279  2022-03-10
# 47847        0.096026  2022-03-08
# 47848        0.165280  2022-03-09
# 47849        1.690339  2022-03-10
# 48351        0.528045  2022-03-08
# 48352        2.878891  2022-03-09
# 48353        2.522671  2022-03-10
# 48855        0.803958  2022-03-08
# 48856        0.877193  2022-03-09
# 48857        2.023957  2022-03-10
# 49360        3.897317  2022-03-08
# 49361        0.070086  2022-03-09
# 49362        2.796266  2022-03-10
# 49863        0.922117  2022-03-08
# 49864        1.197173  2022-03-09
# 49865        0.817477  2022-03-10
# 50367        2.467811  2022-03-08
# 50368        2.366892  2022-03-09
# 50369        5.179745  2022-03-10
# 50871        4.174843  2022-03-08
# 50872        1.753642  2022-03-09
# 50873        4.682021  2022-03-10

# %%
# get first stock ticker in first row
prev_ticker = stock_df.iat[0,0]
print (prev_ticker)

i = 0
new_ticker_flag = 'yes'
process_list=[]

for rec in stock_df.iterrows():
    new_ticker = stock_df['ticker'].iloc[i]
    print("previous ticker and new ticker: ", prev_ticker, "and", new_ticker)

    if (prev_ticker == new_ticker):
        if (new_ticker_flag == 'yes'):

            new_ticker_flag = 'no'
            begin_vw = stock_df['volume_weight'].iloc[i]
            
        else:

            last_vw = stock_df['volume_weight'].iloc[i]
    else:
            vw_average = 100 - (last_vw/begin_vw) * 100
            print("vwa: ", vw_average)
            
            # append to process_list
            process_list.append(vw_average)
            
            prev_ticker = new_ticker
            new_ticker_flag == 'yes'
            begin_vw = stock_df['volume_weight'].iloc[i]
            
    i=i+1
    
# account for the last record in the dataframe
vw_average = 100 - (last_vw/begin_vw) * 100
print("vwa: ", vw_average)       
process_list.append(vw_average)
# Out:
# AMD
# previous ticker and new ticker:  AMD and AMD
# previous ticker and new ticker:  AMD and AMD
# previous ticker and new ticker:  AMD and AMD
# previous ticker and new ticker:  AMD and ADBE
# vwa:  3.340998377297126
# previous ticker and new ticker:  ADBE and ADBE
# previous ticker and new ticker:  ADBE and ADBE
# previous ticker and new ticker:  ADBE and ABNB
# vwa:  5.657033601964173
# previous ticker and new ticker:  ABNB and ABNB
# previous ticker and new ticker:  ABNB and ABNB
# previous ticker and new ticker:  ABNB and ALGN
# vwa:  0.46632208065682335
# previous ticker and new ticker:  ALGN and ALGN
# previous ticker and new ticker:  ALGN and ALGN
# previous ticker and new ticker:  ALGN and AMZN
# vwa:  6.594978387802016
# previous ticker and new ticker:  AMZN and AMZN
# previous ticker and new ticker:  AMZN and AMZN
# previous ticker and new ticker:  AMZN and AMGN
# vwa:  -4.424754830148132
# previous ticker and new ticker:  AMGN and AMGN
# previous ticker and new ticker:  AMGN and AMGN
# previous ticker and new ticker:  AMGN and AEP
# vwa:  1.3722727739390592
# previous ticker and new ticker:  AEP and AEP
# previous ticker and new ticker:  AEP and AEP
# previous ticker and new ticker:  AEP and ADI
# vwa:  -0.7954314758188588
# previous ticker and new ticker:  ADI and ADI
# previous ticker and new ticker:  ADI and ADI
# previous ticker and new ticker:  ADI and ANSS
# vwa:  2.7002619982707046
# previous ticker and new ticker:  ANSS and ANSS
# previous ticker and new ticker:  ANSS and ANSS
# previous ticker and new ticker:  ANSS and AAPL
# vwa:  4.143783600875167
# previous ticker and new ticker:  AAPL and AAPL
# previous ticker and new ticker:  AAPL and AAPL
# previous ticker and new ticker:  AAPL and AMAT
# vwa:  3.5720857626620557
# previous ticker and new ticker:  AMAT and AMAT
# previous ticker and new ticker:  AMAT and AMAT
# previous ticker and new ticker:  AMAT and ASML
# vwa:  1.7768285272324107
# previous ticker and new ticker:  ASML and ASML
# previous ticker and new ticker:  ASML and ASML
# previous ticker and new ticker:  ASML and TEAM
# vwa:  3.081222557940393
# previous ticker and new ticker:  TEAM and TEAM
# previous ticker and new ticker:  TEAM and TEAM
# previous ticker and new ticker:  TEAM and ADSK
# vwa:  4.454652957482594
# previous ticker and new ticker:  ADSK and ADSK
# previous ticker and new ticker:  ADSK and ADSK
# previous ticker and new ticker:  ADSK and ATVI
# vwa:  4.966038309605452
# previous ticker and new ticker:  ATVI and ATVI
# previous ticker and new ticker:  ATVI and ATVI
# previous ticker and new ticker:  ATVI and ADP
# vwa:  0.6542373509377626
# previous ticker and new ticker:  ADP and ADP
# previous ticker and new ticker:  ADP and ADP
# previous ticker and new ticker:  ADP and AZN
# vwa:  0.38662619208548676
# previous ticker and new ticker:  AZN and AZN
# previous ticker and new ticker:  AZN and AZN
# previous ticker and new ticker:  AZN and AVGO
# vwa:  -1.0484591055886199
# previous ticker and new ticker:  AVGO and AVGO
# previous ticker and new ticker:  AVGO and AVGO
# previous ticker and new ticker:  AVGO and BIDU
# vwa:  2.271516584550753
# previous ticker and new ticker:  BIDU and BIDU
# previous ticker and new ticker:  BIDU and BIDU
# previous ticker and new ticker:  BIDU and BIIB
# vwa:  13.844088371133594
# previous ticker and new ticker:  BIIB and BIIB
# previous ticker and new ticker:  BIIB and BIIB
# previous ticker and new ticker:  BIIB and BMRN
# vwa:  2.585469740332144
# previous ticker and new ticker:  BMRN and BMRN
# previous ticker and new ticker:  BMRN and BMRN
# previous ticker and new ticker:  BMRN and BKNG
# vwa:  2.6992284649147393
# previous ticker and new ticker:  BKNG and BKNG
# previous ticker and new ticker:  BKNG and BKNG
# previous ticker and new ticker:  BKNG and CDNS
# vwa:  0.9108212463412997
# previous ticker and new ticker:  CDNS and CDNS
# previous ticker and new ticker:  CDNS and CDNS
# previous ticker and new ticker:  CDNS and CHTR
# vwa:  2.6170625693187333
# previous ticker and new ticker:  CHTR and CHTR
# previous ticker and new ticker:  CHTR and CHTR
# previous ticker and new ticker:  CHTR and CPRT
# vwa:  -1.1117883705428824
# previous ticker and new ticker:  CPRT and CPRT
# previous ticker and new ticker:  CPRT and CPRT
# previous ticker and new ticker:  CPRT and CRWD
# vwa:  -0.959520527461649
# previous ticker and new ticker:  CRWD and CRWD
# previous ticker and new ticker:  CRWD and CRWD
# previous ticker and new ticker:  CRWD and CTAS
# vwa:  -12.722973296310698
# previous ticker and new ticker:  CTAS and CTAS
# previous ticker and new ticker:  CTAS and CTAS
# previous ticker and new ticker:  CTAS and CSCO
# vwa:  0.7354831935474238
# previous ticker and new ticker:  CSCO and CSCO
# previous ticker and new ticker:  CSCO and CSCO
# previous ticker and new ticker:  CSCO and CMCSA
# vwa:  1.1640173669668883
# previous ticker and new ticker:  CMCSA and CMCSA
# previous ticker and new ticker:  CMCSA and CMCSA
# previous ticker and new ticker:  CMCSA and COST
# vwa:  2.116434110870898
# previous ticker and new ticker:  COST and COST
# previous ticker and new ticker:  COST and COST
# previous ticker and new ticker:  COST and CSX
# vwa:  -1.3509078018181242
# previous ticker and new ticker:  CSX and CSX
# previous ticker and new ticker:  CSX and CSX
# previous ticker and new ticker:  CSX and CTSH
# vwa:  -0.9295294365413014
# previous ticker and new ticker:  CTSH and CTSH
# previous ticker and new ticker:  CTSH and CTSH
# previous ticker and new ticker:  CTSH and DDOG
# vwa:  -0.006778412563562597
# previous ticker and new ticker:  DDOG and DDOG
# previous ticker and new ticker:  DDOG and DDOG
# previous ticker and new ticker:  DDOG and DOCU
# vwa:  6.680558784611904
# previous ticker and new ticker:  DOCU and DOCU
# previous ticker and new ticker:  DOCU and DOCU
# previous ticker and new ticker:  DOCU and DXCM
# vwa:  24.678271646897088
# previous ticker and new ticker:  DXCM and DXCM
# previous ticker and new ticker:  DXCM and DXCM
# previous ticker and new ticker:  DXCM and DLTR
# vwa:  2.499841555186208
# previous ticker and new ticker:  DLTR and DLTR
# previous ticker and new ticker:  DLTR and DLTR
# previous ticker and new ticker:  DLTR and EA
# vwa:  0.6020882554683453
# previous ticker and new ticker:  EA and EA
# previous ticker and new ticker:  EA and EA
# previous ticker and new ticker:  EA and EBAY
# vwa:  1.7621060906746493
# previous ticker and new ticker:  EBAY and EBAY
# previous ticker and new ticker:  EBAY and EBAY
# previous ticker and new ticker:  EBAY and EXC
# vwa:  4.017258831579369
# previous ticker and new ticker:  EXC and EXC
# previous ticker and new ticker:  EXC and EXC
# previous ticker and new ticker:  EXC and FAST
# vwa:  -0.7375653459029934
# previous ticker and new ticker:  FAST and FAST
# previous ticker and new ticker:  FAST and FAST
# previous ticker and new ticker:  FAST and FB
# vwa:  0.4168284410323366
# previous ticker and new ticker:  FB and FB
# previous ticker and new ticker:  FB and FB
# previous ticker and new ticker:  FB and FISV
# vwa:  3.8189208646973327
# previous ticker and new ticker:  FISV and FISV
# previous ticker and new ticker:  FISV and FISV
# previous ticker and new ticker:  FISV and FTNT
# vwa:  1.3603171334859923
# previous ticker and new ticker:  FTNT and FTNT
# previous ticker and new ticker:  FTNT and FTNT
# previous ticker and new ticker:  FTNT and GILD
# vwa:  0.39557408903225166
# previous ticker and new ticker:  GILD and GILD
# previous ticker and new ticker:  GILD and GILD
# previous ticker and new ticker:  GILD and GOOG
# vwa:  1.5180937354612922
# previous ticker and new ticker:  GOOG and GOOG
# previous ticker and new ticker:  GOOG and GOOG
# previous ticker and new ticker:  GOOG and GOOGL
# vwa:  0.489033838112519
# previous ticker and new ticker:  GOOGL and GOOGL
# previous ticker and new ticker:  GOOGL and GOOGL
# previous ticker and new ticker:  GOOGL and HON
# vwa:  0.6535197121667125
# previous ticker and new ticker:  HON and HON
# previous ticker and new ticker:  HON and HON
# previous ticker and new ticker:  HON and ILMN
# vwa:  1.0858688404868246
# previous ticker and new ticker:  ILMN and ILMN
# previous ticker and new ticker:  ILMN and ILMN
# previous ticker and new ticker:  ILMN and INTC
# vwa:  4.85508250855581
# previous ticker and new ticker:  INTC and INTC
# previous ticker and new ticker:  INTC and INTC
# previous ticker and new ticker:  INTC and INTU
# vwa:  2.750011031984357
# previous ticker and new ticker:  INTU and INTU
# previous ticker and new ticker:  INTU and INTU
# previous ticker and new ticker:  INTU and ISRG
# vwa:  4.225141775387399
# previous ticker and new ticker:  ISRG and ISRG
# previous ticker and new ticker:  ISRG and ISRG
# previous ticker and new ticker:  ISRG and MRVL
# vwa:  0.3267013559730714
# previous ticker and new ticker:  MRVL and MRVL
# previous ticker and new ticker:  MRVL and MRVL
# previous ticker and new ticker:  MRVL and IDXX
# vwa:  3.685151251164058
# previous ticker and new ticker:  IDXX and IDXX
# previous ticker and new ticker:  IDXX and IDXX
# previous ticker and new ticker:  IDXX and JD
# vwa:  3.95394884101664
# previous ticker and new ticker:  JD and JD
# previous ticker and new ticker:  JD and JD
# previous ticker and new ticker:  JD and KDP
# vwa:  19.524824609178665
# previous ticker and new ticker:  KDP and KDP
# previous ticker and new ticker:  KDP and KDP
# previous ticker and new ticker:  KDP and KLAC
# vwa:  1.2629174111124968
# previous ticker and new ticker:  KLAC and KLAC
# previous ticker and new ticker:  KLAC and KLAC
# previous ticker and new ticker:  KLAC and KHC
# vwa:  3.5006061150404406
# previous ticker and new ticker:  KHC and KHC
# previous ticker and new ticker:  KHC and KHC
# previous ticker and new ticker:  KHC and LRCX
# vwa:  2.261440250053866
# previous ticker and new ticker:  LRCX and LRCX
# previous ticker and new ticker:  LRCX and LRCX
# previous ticker and new ticker:  LRCX and LCID
# vwa:  5.138486751829362
# previous ticker and new ticker:  LCID and LCID
# previous ticker and new ticker:  LCID and LCID
# previous ticker and new ticker:  LCID and LULU
# vwa:  7.748303124789274
# previous ticker and new ticker:  LULU and LULU
# previous ticker and new ticker:  LULU and LULU
# previous ticker and new ticker:  LULU and MELI
# vwa:  3.0744882713649986
# previous ticker and new ticker:  MELI and MELI
# previous ticker and new ticker:  MELI and MELI
# previous ticker and new ticker:  MELI and MAR
# vwa:  5.865876312981314
# previous ticker and new ticker:  MAR and MAR
# previous ticker and new ticker:  MAR and MAR
# previous ticker and new ticker:  MAR and MTCH
# vwa:  -1.7442299495309896
# previous ticker and new ticker:  MTCH and MTCH
# previous ticker and new ticker:  MTCH and MTCH
# previous ticker and new ticker:  MTCH and MCHP
# vwa:  8.42107723529729
# previous ticker and new ticker:  MCHP and MCHP
# previous ticker and new ticker:  MCHP and MCHP
# previous ticker and new ticker:  MCHP and MDLZ
# vwa:  1.5656883525204819
# previous ticker and new ticker:  MDLZ and MDLZ
# previous ticker and new ticker:  MDLZ and MDLZ
# previous ticker and new ticker:  MDLZ and MRNA
# vwa:  2.9551904685319528
# previous ticker and new ticker:  MRNA and MRNA
# previous ticker and new ticker:  MRNA and MRNA
# previous ticker and new ticker:  MRNA and MNST
# vwa:  -0.0018477181746590077
# previous ticker and new ticker:  MNST and MNST
# previous ticker and new ticker:  MNST and MNST
# previous ticker and new ticker:  MNST and MSFT
# vwa:  3.1521901257892893
# previous ticker and new ticker:  MSFT and MSFT
# previous ticker and new ticker:  MSFT and MSFT
# previous ticker and new ticker:  MSFT and MU
# vwa:  0.8654611471885119
# previous ticker and new ticker:  MU and MU
# previous ticker and new ticker:  MU and MU
# previous ticker and new ticker:  MU and NFLX
# vwa:  7.155320219977355
# previous ticker and new ticker:  NFLX and NFLX
# previous ticker and new ticker:  NFLX and NFLX
# previous ticker and new ticker:  NFLX and NTES
# vwa:  3.3929022154603814
# previous ticker and new ticker:  NTES and NTES
# previous ticker and new ticker:  NTES and NTES
# previous ticker and new ticker:  NTES and NVDA
# vwa:  9.449340898618559
# previous ticker and new ticker:  NVDA and NVDA
# previous ticker and new ticker:  NVDA and NVDA
# previous ticker and new ticker:  NVDA and NXPI
# vwa:  1.26183020677216
# previous ticker and new ticker:  NXPI and NXPI
# previous ticker and new ticker:  NXPI and NXPI
# previous ticker and new ticker:  NXPI and OKTA
# vwa:  1.9638987599204967
# previous ticker and new ticker:  OKTA and OKTA
# previous ticker and new ticker:  OKTA and OKTA
# previous ticker and new ticker:  OKTA and ODFL
# vwa:  6.7740254436977665
# previous ticker and new ticker:  ODFL and ODFL
# previous ticker and new ticker:  ODFL and ODFL
# previous ticker and new ticker:  ODFL and ORLY
# vwa:  -0.7362600903163923
# previous ticker and new ticker:  ORLY and ORLY
# previous ticker and new ticker:  ORLY and ORLY
# previous ticker and new ticker:  ORLY and PCAR
# vwa:  -0.8891100644860188
# previous ticker and new ticker:  PCAR and PCAR
# previous ticker and new ticker:  PCAR and PCAR
# previous ticker and new ticker:  PCAR and PANW
# vwa:  1.591894309502507
# previous ticker and new ticker:  PANW and PANW
# previous ticker and new ticker:  PANW and PANW
# previous ticker and new ticker:  PANW and PAYX
# vwa:  0.07664043421726774
# previous ticker and new ticker:  PAYX and PAYX
# previous ticker and new ticker:  PAYX and PAYX
# previous ticker and new ticker:  PAYX and PDD
# vwa:  0.004930921893375739
# previous ticker and new ticker:  PDD and PDD
# previous ticker and new ticker:  PDD and PDD
# previous ticker and new ticker:  PDD and PYPL
# vwa:  21.71064953551094
# previous ticker and new ticker:  PYPL and PYPL
# previous ticker and new ticker:  PYPL and PYPL
# previous ticker and new ticker:  PYPL and PEP
# vwa:  1.9989406651655912
# previous ticker and new ticker:  PEP and PEP
# previous ticker and new ticker:  PEP and PEP
# previous ticker and new ticker:  PEP and QCOM
# vwa:  1.8129896886290595
# previous ticker and new ticker:  QCOM and QCOM
# previous ticker and new ticker:  QCOM and QCOM
# previous ticker and new ticker:  QCOM and REGN
# vwa:  1.601745664717754
# previous ticker and new ticker:  REGN and REGN
# previous ticker and new ticker:  REGN and REGN
# previous ticker and new ticker:  REGN and ROST
# vwa:  -3.623676364757884
# previous ticker and new ticker:  ROST and ROST
# previous ticker and new ticker:  ROST and ROST
# previous ticker and new ticker:  ROST and SIRI
# vwa:  -0.24977393591439068
# previous ticker and new ticker:  SIRI and SIRI
# previous ticker and new ticker:  SIRI and SIRI
# previous ticker and new ticker:  SIRI and SGEN
# vwa:  0.8994211172596351
# previous ticker and new ticker:  SGEN and SGEN
# previous ticker and new ticker:  SGEN and SGEN
# previous ticker and new ticker:  SGEN and SPLK
# vwa:  0.6665078721317883
# previous ticker and new ticker:  SPLK and SPLK
# previous ticker and new ticker:  SPLK and SPLK
# previous ticker and new ticker:  SPLK and SWKS
# vwa:  3.230739312678125
# previous ticker and new ticker:  SWKS and SWKS
# previous ticker and new ticker:  SWKS and SWKS
# previous ticker and new ticker:  SWKS and SBUX
# vwa:  3.9086035326157855
# previous ticker and new ticker:  SBUX and SBUX
# previous ticker and new ticker:  SBUX and SBUX
# previous ticker and new ticker:  SBUX and SNPS
# vwa:  3.6464280565579656
# previous ticker and new ticker:  SNPS and SNPS
# previous ticker and new ticker:  SNPS and SNPS
# previous ticker and new ticker:  SNPS and TSLA
# vwa:  3.0365919941815633
# previous ticker and new ticker:  TSLA and TSLA
# previous ticker and new ticker:  TSLA and TSLA
# previous ticker and new ticker:  TSLA and TXN
# vwa:  4.909724902257949
# previous ticker and new ticker:  TXN and TXN
# previous ticker and new ticker:  TXN and TXN
# previous ticker and new ticker:  TXN and TMUS
# vwa:  0.3225020591408452
# previous ticker and new ticker:  TMUS and TMUS
# previous ticker and new ticker:  TMUS and TMUS
# previous ticker and new ticker:  TMUS and VRSN
# vwa:  -2.802083606944919
# previous ticker and new ticker:  VRSN and VRSN
# previous ticker and new ticker:  VRSN and VRSN
# previous ticker and new ticker:  VRSN and VRSK
# vwa:  1.5900712094905174
# previous ticker and new ticker:  VRSK and VRSK
# previous ticker and new ticker:  VRSK and VRSK
# previous ticker and new ticker:  VRSK and VRTX
# vwa:  1.650738720978822
# previous ticker and new ticker:  VRTX and VRTX
# previous ticker and new ticker:  VRTX and VRTX
# previous ticker and new ticker:  VRTX and WBA
# vwa:  -0.40032730056221055
# previous ticker and new ticker:  WBA and WBA
# previous ticker and new ticker:  WBA and WBA
# previous ticker and new ticker:  WBA and WDAY
# vwa:  0.5169578793515939
# previous ticker and new ticker:  WDAY and WDAY
# previous ticker and new ticker:  WDAY and WDAY
# previous ticker and new ticker:  WDAY and XEL
# vwa:  2.9226007361221775
# previous ticker and new ticker:  XEL and XEL
# previous ticker and new ticker:  XEL and XEL
# previous ticker and new ticker:  XEL and ZM
# vwa:  -0.741475745479093
# previous ticker and new ticker:  ZM and ZM
# previous ticker and new ticker:  ZM and ZM
# previous ticker and new ticker:  ZM and ZS
# vwa:  8.795148538944701
# previous ticker and new ticker:  ZS and ZS
# previous ticker and new ticker:  ZS and ZS
# vwa:  3.0522608667404256

# %%
len(process_list)
# Out:
# 102

# %%
# process_list

# %%
#combine object dataframe with process list into process_df
stock_df = stock_df.drop(['volume', 'volume_weight', 'percent_change','date'], axis=1)
stock_df.columns.tolist()
stock_df = stock_df.drop_duplicates(subset='ticker')
stock_df["volume_weight_avg"] = process_list
stock_df
# Out:
#       ticker employee_count    revenue                  sector      city_name  \
# 501      AMD         5k-10k    over-1b              Technology    Santa Clara
# 1006    ADBE       over-10k     1m-10m              Technology       San Jose
# 1321    ABNB         5k-10k    200m-1b              Technology  San Francisco
# 1825    ALGN       over-10k    200m-1b              Technology          Tempe
# 2329    AMZN       over-10k    over-1b              Technology        Seattle
# 2833    AMGN       over-10k    over-1b              Technology  Thousand Oaks
# 3336     AEP       over-10k    over-1b                  Energy       Columbus
# 3840     ADI       over-10k    over-1b              Technology        Norwood
# 4344    ANSS          1k-5k    200m-1b              Technology     Canonsburg
# 4848    AAPL       over-10k    over-1b              Technology      Capertino
# 5352    AMAT       over-10k    over-1b              Technology    Santa Clara
# 5856    ASML       over-10k    over-1b              Technology      Veldhoven
# 6360    TEAM          1k-5k  100m-200m              Technology         Sydney
# 6864    ADSK       over-10k    over-1b              Healthcare     San Rafael
# 7368    ATVI         5k-10k    over-1b              Technology     San Monica
# 7872     ADP       over-10k    over-1b  Consumer Discretionary       Roseland
# 8376     AZN       over-10k    over-1b              Healthcare      Cambridge
# 8880    AVGO       over-10k    over-1b              Technology       San Jose
# 9384    BIDU       over-10k    over-1b              Technology        Beijing
# 9887    BIIB         5k-10k    over-1b              Technology      Cambridge
# 10391   BMRN          1k-5k    over-1b              Healthcare         Novato
# 10895   BKNG       over-10k    over-1b              Healthcare        Norwalk
# 11399   CDNS         5k-10k    over-1b              Technology       San Jose
# 11903   CHTR       over-10k    over-1b              Technology       Stamford
# 12407   CPRT         5k-10k    over-1b              Technology         Dallas
# 12911   CRWD          1k-5k   50m-100m             Industrials         Austin
# 13415   CTAS       over-10k    over-1b        Consumer Staples     Cincinnati
# 13919   CSCO       over-10k    over-1b              Technology       San Jose
# 14423  CMCSA       over-10k    over-1b  Communication Services         Tupelo
# 14927   COST       over-10k    over-1b  Consumer Discretionary       Issaquah
# 15431    CSX       over-10k    over-1b  Communication Services   Jacksonville
# 15935   CTSH       over-10k    over-1b             Industrials        Teaneck
# 16439   DDOG          1k-5k   50m-100m              Technology       New York
# 16943   DOCU         5k-10k     1m-10m              Technology  San Francisco
# 17447   DXCM         5k-10k    200m-1b              Healthcare      San Diego
# 17951   DLTR       over-10k    over-1b              Technology     Chesapeake
# 18455     EA         5k-10k    over-1b        Consumer Staples   Redwood City
# 18959   EBAY       over-10k    over-1b              Technology       San Jose
# 19463    EXC       over-10k    over-1b              Technology        Chicago
# 19967   FAST       over-10k    over-1b             Industrials         Winona
# 20471     FB       over-10k     1m-10m             Industrials     Menlo Park
# 20975   FISV       over-10k    over-1b              Technology     Brookfield
# 21479   FTNT         5k-10k     1m-10m              Financials      Sunnyvale
# 21983   GILD       over-10k    over-1b              Technology    Foster City
# 22487   GOOG       over-10k    over-1b              Healthcare  Mountain View
# 22991  GOOGL       over-10k    over-1b              Technology  Mountain View
# 23495    HON       over-10k    over-1b              Technology      Charlotte
# 23999   ILMN         5k-10k    over-1b              Healthcare      San Diego
# 24503   INTC       over-10k    over-1b              Technology  Mountain View
# 25007   INTU         5k-10k    over-1b              Technology  Mountain View
# 25511   ISRG         5k-10k    over-1b              Healthcare      Sunnyvale
# 26015   MRVL         5k-10k    over-1b        Consumer Staples     Wilmington
# 26519   IDXX         5k-10k    over-1b             Industrials      Westbrook
# 27023     JD         500-1k    over-1b              Technology      Westbrook
# 27527    KDP       over-10k    over-1b              Healthcare          Plano
# 28031   KLAC       over-10k    over-1b        Consumer Staples       Milpitas
# 28535    KHC       over-10k    over-1b  Consumer Discretionary        Chicago
# 29039   LRCX       over-10k    over-1b        Consumer Staples        Fremont
# 29199   LCID          1k-5k     1m-10m              Technology         Newark
# 29703   LULU       over-10k    over-1b              Technology      Vancouver
# 30207   MELI         5k-10k    200m-1b  Consumer Discretionary   Buenos Aires
# 30711    MAR       over-10k    over-1b              Technology     Washington
# 31215   MTCH          1k-5k    over-1b        Consumer Staples         Dallas
# 31719   MCHP       over-10k    10m-50m  Consumer Discretionary       Chandler
# 32223   MDLZ       over-10k    over-1b              Technology        Chicago
# 32727   MRNA         500-1k   50m-100m              Technology      Cambridge
# 33231   MNST          1k-5k    over-1b  Communication Services         Corona
# 33735   MSFT       over-10k    over-1b              Healthcare        Redmond
# 34239     MU       over-10k    over-1b              Technology          Boise
# 34743   NFLX         5k-10k    over-1b              Technology      Los Gatos
# 35247   NTES       over-10k    over-1b              Technology       Hangzhou
# 35751   NVDA       over-10k    over-1b              Technology    Santa Clara
# 36255   NXPI       over-10k    over-1b              Technology      Eindhoven
# 36759   OKTA          1k-5k  100m-200m              Technology  San Francisco
# 37263   ODFL       over-10k    over-1b              Technology    Thomasville
# 37767   ORLY       over-10k    over-1b             Industrials    Springfield
# 38271   PCAR       over-10k    over-1b              Technology       Bellevue
# 38775   PANW         5k-10k    200m-1b  Consumer Discretionary    Santa Clara
# 39279   PAYX       over-10k    over-1b             Industrials      Rochester
# 39783    PDD          1k-5k    over-1b             Industrials       Shanghai
# 40287   PYPL       over-10k    over-1b              Financials       San Jose
# 40791    PEP       over-10k    over-1b  Consumer Discretionary       Harrison
# 41296   QCOM       over-10k    over-1b        Consumer Staples      San Diego
# 41800   REGN         5k-10k    over-1b              Technology      Tarrytown
# 42304   ROST       over-10k    over-1b              Healthcare      San Bruno
# 42808   SIRI          1k-5k    over-1b              Healthcare       New York
# 43312   SGEN         500-1k    200m-1b  Communication Services        Bothell
# 43816   SPLK         5k-10k    200m-1b              Technology  San Francisco
# 44320   SWKS         5k-10k    over-1b  Consumer Discretionary         Irvine
# 44824   SBUX       over-10k    over-1b  Consumer Discretionary        Seattle
# 45328   SNPS       over-10k    over-1b              Technology  Mountain View
# 45832   TSLA       over-10k    over-1b              Technology         Austin
# 46335    TXN       over-10k    over-1b  Communication Services         Dallas
# 46839   TMUS       over-10k    200m-1b  Consumer Discretionary       Bellevue
# 47343   VRSN         500-1k    over-1b             Industrials         Reston
# 47847   VRSK         5k-10k    over-1b              Technology    Jersey City
# 48351   VRTX          1k-5k    over-1b              Healthcare         Boston
# 48855    WBA       over-10k    over-1b              Healthcare        Chicago
# 49360   WDAY       over-10k    over-1b              Technology     Pleasanton
# 49863    XEL       over-10k    over-1b               Utilities    Minneapolis
# 50367     ZM          1k-5k  100m-200m              Technology       San Jose
# 50871     ZS          1k-5k  100m-200m              Technology       San Jose
#
#       state_name region country_code  volume_weight_avg
# 501           CA      W           US           3.340998
# 1006          CA      W           US           5.657034
# 1321          CA      W           US           0.466322
# 1825          AZ     SW           US           6.594978
# 2329          WA     NW           US          -4.424755
# 2833          CA      W           US           1.372273
# 3336          OH     MW           US          -0.795431
# 3840          MA     SE           US           2.700262
# 4344          PA     SE           US           4.143784
# 4848          CA      W           US           3.572086
# 5352          CA      W           US           1.776829
# 5856          NL     NL  Netherlands           3.081223
# 6360         AUS     AU    Australia           4.454653
# 6864          CA      W           US           4.966038
# 7368          CA      W           US           0.654237
# 7872          NJ     NE           US           0.386626
# 8376          UK     GB           UK          -1.048459
# 8880          CA      W           US           2.271517
# 9384          CN     CH           CH          13.844088
# 9887          MA     SE           US           2.585470
# 10391         CA      W           US           2.699228
# 10895         CT     NE           US           0.910821
# 11399         CA      W           US           2.617063
# 11903         CT     NE           US          -1.111788
# 12407         TX     SE           US          -0.959521
# 12911         TX     SE           US         -12.722973
# 13415         OH     MW           US           0.735483
# 13919         CA      W           US           1.164017
# 14423         MS     SE           US           2.116434
# 14927         WA     NW           US          -1.350908
# 15431         FL     SE           US          -0.929529
# 15935         NJ     NE           US          -0.006778
# 16439         NY     SE           US           6.680559
# 16943         CA      W           US          24.678272
# 17447         CA      W           US           2.499842
# 17951         VA     SE           US           0.602088
# 18455         CA      W           US           1.762106
# 18959         CA      W           US           4.017259
# 19463         IL     MW           US          -0.737565
# 19967         MN     MW           US           0.416828
# 20471         CA      W           US           3.818921
# 20975         WI     NW           US           1.360317
# 21479         CA      W           US           0.395574
# 21983         CA      W           US           1.518094
# 22487         CA      W           US           0.489034
# 22991         CA      W           US           0.653520
# 23495         NC     SE           US           1.085869
# 23999         CA      W           US           4.855083
# 24503         CA      W           US           2.750011
# 25007         CA      W           US           4.225142
# 25511         CA      W           US           0.326701
# 26015         DE     NE           US           3.685151
# 26519         ME     SE           US           3.953949
# 27023         ME     SE           US          19.524825
# 27527         TX     SE           US           1.262917
# 28031         CA      W           US           3.500606
# 28535         IL     MW           US           2.261440
# 29039         CA      W           US           5.138487
# 29199         CA      W           US           7.748303
# 29703        CAN     CA           CA           3.074488
# 30207         AR     SE    Argentina           5.865876
# 30711       D.C.     SE           US          -1.744230
# 31215         TX     SE           US           8.421077
# 31719         AZ     SW           US           1.565688
# 32223         IL     MW           US           2.955190
# 32727         MA     SE           US          -0.001848
# 33231         CA      W           US           3.152190
# 33735         WA     NW           US           0.865461
# 34239         ID     NW           US           7.155320
# 34743         CA      W           US           3.392902
# 35247         CN     CH           CN           9.449341
# 35751         CA      W           US           1.261830
# 36255         NL     NL  Netherlands           1.963899
# 36759         CA      W           US           6.774025
# 37263         NC     SE           US          -0.736260
# 37767         MO     MW           US          -0.889110
# 38271         WA     NW           US           1.591894
# 38775         CA      W           US           0.076640
# 39279         NY     SE           US           0.004931
# 39783         CN     CH           CH          21.710650
# 40287         CA      W           US           1.998941
# 40791         NY     SE           US           1.812990
# 41296         CA      W           US           1.601746
# 41800         NY     SE           US          -3.623676
# 42304         CA      W           US          -0.249774
# 42808         NY     SE           US           0.899421
# 43312         WA     NW           US           0.666508
# 43816         CA      W           US           3.230739
# 44320         CA      W           US           3.908604
# 44824         WA     NW           US           3.646428
# 45328         CA      W           US           3.036592
# 45832         TX     SE           US           4.909725
# 46335         TX     SE           US           0.322502
# 46839         WA     NW           US          -2.802084
# 47343         VA     SE           US           1.590071
# 47847         NJ     NE           US           1.650739
# 48351         MA     SE           US          -0.400327
# 48855         IL     MW           US           0.516958
# 49360         CA      W           US           2.922601
# 49863         MN     MW           US          -0.741476
# 50367         CA      W           US           8.795149
# 50871         CA      W           US           3.052261

# %%
# unique values for each column (getting to know your data)
stock_df.nunique()
# Out:
# ticker               102
# employee_count         4
# revenue                6
# sector                 9
# city_name             70
# state_name            28
# region                11
# country_code           8
# volume_weight_avg    102
# dtype: int64

# %%
stock_df.dtypes
# Out:
# ticker                object
# employee_count        object
# revenue               object
# sector                object
# city_name             object
# state_name            object
# region                object
# country_code          object
# volume_weight_avg    float64
# dtype: object

# %% [markdown]
# ## Indexes, Features (the possible causes), Targets (the desired effects), Throw-Aways
#
# ### NOTE: we have to keep our ticker columns (so all this must called within the gradient_boosting_decision_tree_model)
#
# #### Indexes/Primary Key:
#
# - Concatinate ticker and date to yield ticker_and_date
#
# #### Features are:
# - TICKER,
# - DATE
# - EMPLOYEE COUNT
# - REVENUE
# - SECTOR
# - CITY NAME
# - STATE NAME
# - COUNTRY CODE
# - VOLUME
# - VOLUME WEIGHT
# - AVERAGE_VOLUME (calculate average using begin_date/end_date) (???)
# - AVERAGE_VOLUME_WEIGHT (calculate average using begin_date/end_date) (???)
# - PERCENT CHANGE (% change from close to open)
#
# #### Target is:
# - PERCENT CHANGE (and/or) Volume Weight (???)(I think the percent change matters more because percent change yields better
#
# #### Throw-aways for modeling:
# - COMPANY NAME
# - COMPANY URL
# - LATITUDE
# - LONGITUDE
# - OPEN
# - HIGH
# - LOW
# - CLOSE
# - VOLUME
# - VOLUME WEIGHT
# - NUMBER OF TRANSACTIONS

# %%
# drop stock ticker
# filtered_df = filtered_df.drop(columns = ['city_name'])
# filtered_df.head()
stock_df.drop(columns="ticker", inplace=True)
stock_df.drop(columns="city_name", inplace=True)
stock_df.drop(columns="state_name", inplace=True)
# stock_df.drop(columns="sector", inplace=True)
# stock_df.drop(columns="revenue", inplace=True)
# stock_df.drop(columns="employee_count", inplace=True)

# %%
# generate our categorical variable list
# categorical preprocessing can be done easiest using Dataframe.dtypes == 'object'
stock_categories = stock_df.dtypes[stock_df.dtypes == "object"].index.tolist()
stock_categories
# Out:
# ['employee_count', 'revenue', 'sector', 'region', 'country_code']

# %%
# Checking the number of unique values in each column
stock_df[stock_categories].nunique()
# there needs to be only 10 at most in each categorie, how are we going to make this smaller...by sector ???
# Out:
# employee_count     4
# revenue            6
# sector             9
# region            11
# country_code       8
# dtype: int64

# %%
#I am catagorizing my own shiza from the tiza
# replace stock's employee count string with integer
stock_df.loc[(stock_df['employee_count'] == '5k-10k'), 'employee_count'] = 0
stock_df.loc[(stock_df['employee_count'] == 'over-10k'), 'employee_count'] = 1
stock_df.loc[(stock_df['employee_count'] == '1k-5k'), 'employee_count'] = 2
stock_df.loc[(stock_df['employee_count'] == '500-1k'), 'employee_count'] = 3

# replace stock's revenue string with integer
stock_df.loc[(stock_df['revenue'] == '1m-10m'), 'revenue'] = 0
stock_df.loc[(stock_df['revenue'] == '10m-50m'), 'revenue'] = 1
stock_df.loc[(stock_df['revenue'] == '50m-100m'), 'revenue'] = 2
stock_df.loc[(stock_df['revenue'] == '100m-200m'), 'revenue'] = 3
stock_df.loc[(stock_df['revenue'] == '200m-1b'), 'revenue'] = 4
stock_df.loc[(stock_df['revenue'] == 'over-1b'), 'revenue'] = 5

# replace stock's sector string with integer
stock_df.loc[(stock_df['sector'] == 'Technology'), 'sector'] = 0
stock_df.loc[(stock_df['sector'] == 'Energy'), 'sector'] = 1
stock_df.loc[(stock_df['sector'] == 'Healthcare'), 'sector'] = 2
stock_df.loc[(stock_df['sector'] == 'Consumer Discretionary'), 'sector'] = 3
stock_df.loc[(stock_df['sector'] == 'Industrials'), 'sector'] = 4
stock_df.loc[(stock_df['sector'] == 'Consumer Staples'), 'sector'] = 5
stock_df.loc[(stock_df['sector'] == 'Communication Services'), 'sector'] = 6
stock_df.loc[(stock_df['sector'] == 'Financials'), 'sector'] = 7
stock_df.loc[(stock_df['sector'] == 'Utilities'), 'sector'] = 8

# replace stock's country code string with integer (Note: China was CN and CH for some reason)
stock_df.loc[(stock_df['country_code'] == 'US'), 'country_code'] = 0
stock_df.loc[(stock_df['country_code'] == 'Netherlands'), 'country_code'] = 1
stock_df.loc[(stock_df['country_code'] == 'Australia'), 'country_code'] = 2
stock_df.loc[(stock_df['country_code'] == 'UK'), 'country_code'] = 3
stock_df.loc[(stock_df['country_code'] == 'CH'), 'country_code'] = 4
stock_df.loc[(stock_df['country_code'] == 'CN'), 'country_code'] = 4
stock_df.loc[(stock_df['country_code'] == 'CA'), 'country_code'] = 5
stock_df.loc[(stock_df['country_code'] == 'Argentina'), 'country_code'] = 6

# replace stock's region string with integer 
stock_df.loc[(stock_df['region'] == 'W'), 'region'] = 0
stock_df.loc[(stock_df['region'] == 'MW'), 'region'] = 1
stock_df.loc[(stock_df['region'] == 'SW'), 'region'] = 2
stock_df.loc[(stock_df['region'] == 'NW'), 'region'] = 3
stock_df.loc[(stock_df['region'] == 'SE'), 'region'] = 4
stock_df.loc[(stock_df['region'] == 'NL'), 'region'] = 5
stock_df.loc[(stock_df['region'] == 'AU'), 'region'] = 6
stock_df.loc[(stock_df['region'] == 'NE'), 'region'] = 7
stock_df.loc[(stock_df['region'] == 'GB'), 'region'] = 8
stock_df.loc[(stock_df['region'] == 'CH'), 'region'] = 9
stock_df.loc[(stock_df['region'] == 'CA'), 'region'] = 10


#create buckets for vwa
stock_df.loc[(stock_df['volume_weight_avg'] < 0), 'volume_weight_avg'] = 0
stock_df.loc[(stock_df['volume_weight_avg'] > 0) & (stock_df['volume_weight_avg'] <= 1), 'volume_weight_avg'] = 1
stock_df.loc[(stock_df['volume_weight_avg'] > 1) & (stock_df['volume_weight_avg'] <= 2), 'volume_weight_avg'] = 2
stock_df.loc[(stock_df['volume_weight_avg'] > 2) & (stock_df['volume_weight_avg'] <= 3), 'volume_weight_avg'] = 3
stock_df.loc[(stock_df['volume_weight_avg'] > 3) & (stock_df['volume_weight_avg'] <= 4), 'volume_weight_avg'] = 4
stock_df.loc[(stock_df['volume_weight_avg'] > 4) & (stock_df['volume_weight_avg'] <= 5), 'volume_weight_avg'] = 5
# stock_df.loc[(stock_df['volume_weight_avg'] > 5) & (stock_df['volume_weight_avg'] <= 6), 'volume_weight_avg'] = 6
# stock_df.loc[(stock_df['volume_weight_avg'] > 6) & (stock_df['volume_weight_avg'] <= 7), 'volume_weight_avg'] = 7
# stock_df.loc[(stock_df['volume_weight_avg'] > 7) & (stock_df['volume_weight_avg'] <= 8), 'volume_weight_avg'] = 8
# stock_df.loc[(stock_df['volume_weight_avg'] > 8) & (stock_df['volume_weight_avg'] <= 9), 'volume_weight_avg'] = 9
# stock_df.loc[(stock_df['volume_weight_avg'] > 9) & (stock_df['volume_weight_avg'] <= 10), 'volume_weight_avg'] = 10
stock_df.loc[(stock_df['volume_weight_avg'] > 5), 'volume_weight_avg'] = 6

stock_df
# Out:
#       employee_count revenue sector region country_code  volume_weight_avg
# 501                0       5      0      0            0                4.0
# 1006               1       0      0      0            0                6.0
# 1321               0       4      0      0            0                1.0
# 1825               1       4      0      2            0                6.0
# 2329               1       5      0      3            0                0.0
# 2833               1       5      0      0            0                2.0
# 3336               1       5      1      1            0                0.0
# 3840               1       5      0      4            0                3.0
# 4344               2       4      0      4            0                5.0
# 4848               1       5      0      0            0                4.0
# 5352               1       5      0      0            0                2.0
# 5856               1       5      0      5            1                4.0
# 6360               2       3      0      6            2                5.0
# 6864               1       5      2      0            0                5.0
# 7368               0       5      0      0            0                1.0
# 7872               1       5      3      7            0                1.0
# 8376               1       5      2      8            3                0.0
# 8880               1       5      0      0            0                3.0
# 9384               1       5      0      9            4                6.0
# 9887               0       5      0      4            0                3.0
# 10391              2       5      2      0            0                3.0
# 10895              1       5      2      7            0                1.0
# 11399              0       5      0      0            0                3.0
# 11903              1       5      0      7            0                0.0
# 12407              0       5      0      4            0                0.0
# 12911              2       2      4      4            0                0.0
# 13415              1       5      5      1            0                1.0
# 13919              1       5      0      0            0                2.0
# 14423              1       5      6      4            0                3.0
# 14927              1       5      3      3            0                0.0
# 15431              1       5      6      4            0                0.0
# 15935              1       5      4      7            0                0.0
# 16439              2       2      0      4            0                6.0
# 16943              0       0      0      0            0                6.0
# 17447              0       4      2      0            0                3.0
# 17951              1       5      0      4            0                1.0
# 18455              0       5      5      0            0                2.0
# 18959              1       5      0      0            0                5.0
# 19463              1       5      0      1            0                0.0
# 19967              1       5      4      1            0                1.0
# 20471              1       0      4      0            0                4.0
# 20975              1       5      0      3            0                2.0
# 21479              0       0      7      0            0                1.0
# 21983              1       5      0      0            0                2.0
# 22487              1       5      2      0            0                1.0
# 22991              1       5      0      0            0                1.0
# 23495              1       5      0      4            0                2.0
# 23999              0       5      2      0            0                5.0
# 24503              1       5      0      0            0                3.0
# 25007              0       5      0      0            0                5.0
# 25511              0       5      2      0            0                1.0
# 26015              0       5      5      7            0                4.0
# 26519              0       5      4      4            0                4.0
# 27023              3       5      0      4            0                6.0
# 27527              1       5      2      4            0                2.0
# 28031              1       5      5      0            0                4.0
# 28535              1       5      3      1            0                3.0
# 29039              1       5      5      0            0                6.0
# 29199              2       0      0      0            0                6.0
# 29703              1       5      0     10            5                4.0
# 30207              0       4      3      4            6                6.0
# 30711              1       5      0      4            0                0.0
# 31215              2       5      5      4            0                6.0
# 31719              1       1      3      2            0                2.0
# 32223              1       5      0      1            0                3.0
# 32727              3       2      0      4            0                0.0
# 33231              2       5      6      0            0                4.0
# 33735              1       5      2      3            0                1.0
# 34239              1       5      0      3            0                6.0
# 34743              0       5      0      0            0                4.0
# 35247              1       5      0      9            4                6.0
# 35751              1       5      0      0            0                2.0
# 36255              1       5      0      5            1                2.0
# 36759              2       3      0      0            0                6.0
# 37263              1       5      0      4            0                0.0
# 37767              1       5      4      1            0                0.0
# 38271              1       5      0      3            0                2.0
# 38775              0       4      3      0            0                1.0
# 39279              1       5      4      4            0                1.0
# 39783              2       5      4      9            4                6.0
# 40287              1       5      7      0            0                2.0
# 40791              1       5      3      4            0                2.0
# 41296              1       5      5      0            0                2.0
# 41800              0       5      0      4            0                0.0
# 42304              1       5      2      0            0                0.0
# 42808              2       5      2      4            0                1.0
# 43312              3       4      6      3            0                1.0
# 43816              0       4      0      0            0                4.0
# 44320              0       5      3      0            0                4.0
# 44824              1       5      3      3            0                4.0
# 45328              1       5      0      0            0                4.0
# 45832              1       5      0      4            0                5.0
# 46335              1       5      6      4            0                1.0
# 46839              1       4      3      3            0                0.0
# 47343              3       5      4      4            0                2.0
# 47847              0       5      0      7            0                2.0
# 48351              2       5      2      4            0                0.0
# 48855              1       5      2      1            0                1.0
# 49360              1       5      0      0            0                3.0
# 49863              1       5      8      1            0                0.0
# 50367              2       3      0      0            0                6.0
# 50871              2       3      0      0            0                4.0

# %%
# using: obj_df["body_style"].astype('category').cat.codes to define values for each feature

# stock_df['employee_count'] = stock_df['employee_count'].astype('category').cat.codes
# stock_df['revenue'] = stock_df['revenue'].astype('category').cat.codes
# stock_df['sector'] = stock_df['sector'].astype('category').cat.codes
# #stock_df['city_name'] = stock_df['city_name'].astype('category').cat.codes
# # stock_df['state_name'] = stock_df['state_name'].astype('category').cat.codes
# stock_df['country_code'] = stock_df['country_code'].astype('category').cat.codes
# stock_df['region'] = stock_df['region'].astype('category').cat.codes

# stock_df

# %%
# # NOTE: Scikit-learn is flexible enough to perform all of the one-hot encodings at the same time.
# #       Remember, the only difference from our single variable examples is that we need to pass our 
# #       categorical variable list

# # Create a OneHotEncoder instance
# enc = OneHotEncoder(sparse=False)

# # Fit and transform the OneHotEncoder using the categorical variable list
# encode_df = pd.DataFrame(enc.fit_transform(stock_df[stock_categories]))

# # Add the encoded variable names to the dataframe
# encode_df.columns = enc.get_feature_names(stock_categories)
# encode_df.head()

# NOTE: OneHotEncoder was giving us mean_squared_error of around 32.00. So, we removed it and categorical codes instead.
#       Now the mean_squared_error is around 25.00. I have tried to remove city. This didn't work so I added region and 
#       removed city and state. I am still getting the same mean_squared_error. This didn't help.

# %%
# Check volumne weight average buckets
vwa_counts = stock_df['volume_weight_avg'].value_counts()
vwa_counts
# Out:
# 0.0    19
# 1.0    18
# 2.0    17
# 4.0    15
# 6.0    15
# 3.0    11
# 5.0     7
# Name: volume_weight_avg, dtype: int64

# %%
# ['employee_count', 'revenue', 'sector', 'region', 'country_code']
# # using employee_count, revenue, sector, region, country_code and variable weighted average 
# # as the predictor variable and rating as the response variable
# #fit multiple linear regression model
# model = ols('rating ~ assists + rebounds', data=df).fit()

model = ols('volume_weight_avg ~ employee_count + revenue + sector + region + country_code', data = stock_df).fit()

# model = ols('volume_weight_avg ~ region + country_code', data = stock_df).fit()

# %%
#view model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      volume_weight_avg   R-squared:                       0.502
# Model:                            OLS   Adj. R-squared:                  0.320
# Method:                 Least Squares   F-statistic:                     2.762
# Date:                Thu, 24 Mar 2022   Prob (F-statistic):           0.000303
# Time:                        13:05:18   Log-Likelihood:                -182.00
# No. Observations:                 102   AIC:                             420.0
# Df Residuals:                      74   BIC:                             493.5
# Df Model:                          27
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               5.1834      0.867      5.976      0.000       3.455       6.912
# employee_count[T.1]    -0.3043      0.491     -0.620      0.537      -1.283       0.674
# employee_count[T.2]     1.3036      0.757      1.722      0.089      -0.205       2.812
# employee_count[T.3]     0.7984      1.046      0.763      0.448      -1.287       2.883
# revenue[T.1]           -6.3711      2.764     -2.305      0.024     -11.878      -0.864
# revenue[T.2]           -3.0847      1.390     -2.219      0.030      -5.854      -0.315
# revenue[T.3]           -1.1536      1.385     -0.833      0.407      -3.913       1.605
# revenue[T.4]           -2.5817      1.091     -2.366      0.021      -4.756      -0.407
# revenue[T.5]           -1.8947      0.877     -2.161      0.034      -3.642      -0.148
# sector[T.1]            -1.6421      1.833     -0.896      0.373      -5.294       2.010
# sector[T.2]            -1.0329      0.562     -1.838      0.070      -2.153       0.087
# sector[T.3]            -0.2107      0.699     -0.301      0.764      -1.604       1.182
# sector[T.4]            -1.0279      0.663     -1.550      0.125      -2.349       0.293
# sector[T.5]             0.8050      0.714      1.128      0.263      -0.617       2.227
# sector[T.6]            -0.8755      0.846     -1.035      0.304      -2.561       0.810
# sector[T.7]            -2.5838      1.282     -2.016      0.047      -5.138      -0.030
# sector[T.8]            -1.6421      1.833     -0.896      0.373      -5.294       2.010
# region[T.1]            -1.3423      0.757     -1.774      0.080      -2.850       0.166
# region[T.2]             3.7027      1.883      1.966      0.053      -0.049       7.455
# region[T.3]            -0.8942      0.704     -1.269      0.208      -2.298       0.510
# region[T.4]            -0.8913      0.505     -1.763      0.082      -1.898       0.116
# region[T.5]             0.0078      0.629      0.012      0.990      -1.245       1.261
# region[T.6]            -0.1667      0.977     -0.171      0.865      -2.113       1.780
# region[T.7]            -1.5080      0.770     -1.959      0.054      -3.042       0.026
# region[T.8]            -0.9757      0.891     -1.096      0.277      -2.750       0.799
# region[T.9]             1.4112      0.540      2.611      0.011       0.334       2.488
# region[T.10]            0.5078      0.868      0.585      0.560      -1.222       2.237
# country_code[T.1]       0.0078      0.629      0.012      0.990      -1.245       1.261
# country_code[T.2]      -0.1667      0.977     -0.171      0.865      -2.113       1.780
# country_code[T.3]      -0.9757      0.891     -1.096      0.277      -2.750       0.799
# country_code[T.4]       1.4112      0.540      2.611      0.011       0.334       2.488
# country_code[T.5]       0.5078      0.868      0.585      0.560      -1.222       2.237
# country_code[T.6]       4.5003      1.946      2.313      0.024       0.624       8.377
# ==============================================================================
# Omnibus:                        2.845   Durbin-Watson:                   1.697
# Prob(Omnibus):                  0.241   Jarque-Bera (JB):                2.856
# Skew:                           0.385   Prob(JB):                        0.240
# Kurtosis:                       2.719   Cond. No.                     7.25e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.41e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Once again we can create a residual vs. predictor plot for each 
# of the individual predictors using the plot_regress_exog() function 
# from the statsmodels library.

# For example, here’s what the residual vs. predictor plot looks like for the predictor variable assists:
#create residual vs. predictor plot for 'assists'
# fig = plt.figure(figsize=(12,8))
# fig = sm.graphics.plot_regress_exog(model, 'assists', fig=fig)

# create residual vs. predictor plot for the single feature employee_count
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(model, 'region[T.1]', fig=fig)

# %%
# when you create a single record for each stocks VWA you have to reste the index OR 
# your merge/join of stock encodes and stock dataframe will not work
#stock_df.reset_index(drop=True,inplace=True)

# %%
#print(stock_df.index)
#print(encode_df.index)

# %%
# I AM COMING UP WITH NO ROWS HERE ???

# Now that our categorical variables have been encoded, 
# they are ready to replace our unencoded categorical 
# variables in our dataset.

# TWO STEP REPLACE: 

# Merge one-hot encoded features 
#new_stock_df = stock_df.merge(encode_df,left_index=True, right_index=True)

# Drop the original stock categories
#new_stock_df = new_stock_df.drop(columns=stock_categories)
#new_stock_df.head()

# %%
# create features array
X = stock_df.drop(columns=["volume_weight_avg"]).values
    
# create target
y = stock_df["volume_weight_avg"].values

# %%
# split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
# max_depth refers to the number of leaves of each tree 
# n_estimators refers to the total number of trees in the ensemble
# learning_rate hyperparameter scales the contribution of each tree NOTE: If you set it to a low value, 
# you will need more trees in the ensemble to fit the training set, but the overall variance will be lower.

# best way to tune the model: https://neptune.ai/blog/lightgbm-parameters-guide
    
regressor = GradientBoostingRegressor(
max_depth=100,
n_estimators=100,
learning_rate=.001
)
regressor.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.001, max_depth=100)

# %%
# Use staged_predict() method to measures the validation error at each stage of training 
# (i.e. with one tree, with two trees…) to find the optimal number of trees.
errors = [mean_squared_error(y_test, y_pred) for y_pred in 
           regressor.staged_predict(X_test)]
print(errors)

# mean_squared_error: 
# The smaller the mean squared error, the closer you are to finding the line of best fit. Depending on your data, 
# it may be impossible to get a very small value for the mean squared error. For example, the above data is scattered 
# wildly around the regression line, so 6.08 is as good as it gets (and is in fact, the line of best fit). It is 
# bucketting the VWA that works.
# Out:
# [3.7237075586595476, 3.719272631682299, 3.715066817386968, 3.710664889211522, 3.7067390160837896, 3.7025818212284523, 3.6986863735817503, 3.694561286083658, 3.6909087648854877, 3.6866031864118565, 3.6827681375708, 3.6784941925753385, 3.674901500878415, 3.670871782871008, 3.6673091442624157, 3.6633111427418026, 3.6591165467577604, 3.655385983462738, 3.6514350537988034, 3.6477339458206535, 3.6438141001371496, 3.6396975486358247, 3.635596642045507, 3.631511341676098, 3.627441608922252, 3.6235997927691455, 3.6200010796773197, 3.615977444795758, 3.6121815367050307, 3.608401190043385, 3.6048602079569596, 3.601110099507183, 3.5973754362699686, 3.5936561794215907, 3.589739921307952, 3.5858388117915023, 3.5821650779608927, 3.5785065965420633, 3.575079786338584, 3.571878998811644, 3.5682647663040914, 3.564453350633909, 3.560656822483791, 3.557087320082108, 3.5533206136884226, 3.5497808199571166, 3.5460437869094923, 3.5423214567353627, 3.5390336120654666, 3.5355520471333857, 3.5318732481336426, 3.5286262777747264, 3.5249760456094306, 3.5217559621269947, 3.518345923804522, 3.5149504645784893, 3.5115695475428508, 3.508403556462099, 3.5052506922450104, 3.5021109218529363, 3.498574006541745, 3.495672150231282, 3.492374823824828, 3.489499503545323, 3.4862302197352117, 3.4831697032841684, 3.4797165664468475, 3.4762774183992033, 3.473467320058858, 3.4702671189043026, 3.4670809567507734, 3.463908797892507, 3.460539174276244, 3.4575827818927536, 3.4546389929178503, 3.4517077754637384, 3.448602779224079, 3.445300393850874, 3.442011617149105, 3.4387364149078343, 3.435685742425697, 3.432437733239615, 3.429414121400084, 3.4267954464803583, 3.4235875637739173, 3.420782896569304, 3.4176012441343735, 3.4150319648528265, 3.4120872803185898, 3.409542821057284, 3.406413666972132, 3.403683039356089, 3.400964448100585, 3.3978737642286827, 3.394796152586728, 3.391941961034683, 3.389272079214235, 3.386443468430459, 3.383417632795582, 3.380783932392722]

# %%
# best_n_estimators = np.argmin(errors) + 1
best_n_estimators = np.argmin(errors)

print(best_n_estimators)
# Out:
# 99

# %%
# build and fit our model using the optimal number of trees
best_regressor = GradientBoostingRegressor(
     max_depth=10,
     n_estimators=best_n_estimators,
     learning_rate=.01
)

best_regressor.fit(X_train, y_train)

# # Sklearn provides numerous metrics to evaluate 
# # the performance of our machine learning models.
# # They categorize the each metric according 
# # to the problem domain which they’re applicable. 
# # https://scikit-learn.org/stable/modules/model_evaluation.html <-- GO TO THIS SITE TO SEE WHICH METRICS YOU WILL USE.

# # We use the mean absolute error 
# # which can be interpreted as 
# # the average distance from 
# # our predictions and the actual values

# # this will give you the value of the stocks for the next period of time
y_pred = best_regressor.predict(X_test)

print(X_train)
print(y_train)

print(X_test)
print(y_pred)

# # this is the how well the model performed (looking for smallest error)
mean_absolute_error(y_test, y_pred)
# Out:
# [[0 0 7 0 0]
#  [1 5 0 0 0]
#  [0 4 0 0 0]
#  [1 5 2 4 0]
#  [1 5 2 3 0]
#  [2 3 0 0 0]
#  [0 5 0 4 0]
#  [1 5 0 0 0]
#  [1 5 0 0 0]
#  [2 0 0 0 0]
#  [1 5 0 4 0]
#  [1 5 8 1 0]
#  [3 5 0 4 0]
#  [0 5 5 7 0]
#  [1 5 0 4 0]
#  [1 5 0 7 0]
#  [0 4 2 0 0]
#  [0 5 3 0 0]
#  [1 5 3 1 0]
#  [0 5 0 0 0]
#  [1 5 3 7 0]
#  [2 5 2 4 0]
#  [1 5 0 3 0]
#  [1 5 0 0 0]
#  [1 4 3 3 0]
#  [1 5 5 1 0]
#  [2 3 0 0 0]
#  [1 5 0 0 0]
#  [1 5 0 10 5]
#  [0 5 0 4 0]
#  [1 5 0 3 0]
#  [2 5 5 4 0]
#  [1 5 0 0 0]
#  [0 5 0 0 0]
#  [1 5 2 7 0]
#  [1 5 3 3 0]
#  [1 4 0 2 0]
#  [1 5 2 1 0]
#  [1 5 6 4 0]
#  [0 5 2 0 0]
#  [0 4 3 0 0]
#  [2 4 0 4 0]
#  [0 4 3 4 6]
#  [0 5 0 0 0]
#  [1 5 6 4 0]
#  [1 5 5 0 0]
#  [0 5 0 0 0]
#  [1 5 0 4 0]
#  [1 1 3 2 0]
#  [1 5 0 4 0]
#  [1 5 0 0 0]
#  [1 5 2 0 0]
#  [1 5 0 3 0]
#  [0 4 0 0 0]
#  [0 5 0 0 0]
#  [1 5 3 3 0]
#  [1 5 6 4 0]
#  [1 5 0 5 1]
#  [1 5 2 0 0]
#  [1 5 0 9 4]
#  [2 5 2 0 0]
#  [0 5 2 0 0]
#  [2 2 4 4 0]
#  [1 5 1 1 0]
#  [1 5 0 0 0]
#  [1 5 0 3 0]
#  [1 0 0 0 0]
#  [1 5 2 8 3]
#  [1 5 0 1 0]
#  [2 5 4 9 4]
#  [1 5 0 0 0]
#  [1 5 4 1 0]
#  [1 5 0 0 0]
#  [1 5 0 5 1]
#  [2 3 0 6 2]
#  [1 5 0 0 0]]
# [1. 2. 1. 2. 1. 6. 3. 2. 3. 6. 5. 0. 6. 4. 0. 0. 3. 4. 3. 4. 1. 1. 2. 1.
#  0. 1. 6. 2. 4. 0. 0. 6. 4. 5. 1. 4. 6. 1. 0. 5. 1. 5. 6. 4. 1. 6. 3. 0.
#  2. 3. 3. 5. 6. 4. 1. 0. 3. 4. 0. 6. 3. 1. 0. 0. 2. 2. 6. 0. 3. 6. 2. 0.
#  4. 2. 5. 5.]
# [[0 5 0 7 0]
#  [1 5 4 4 0]
#  [1 5 0 0 0]
#  [2 3 0 0 0]
#  [0 5 5 0 0]
#  [3 4 6 3 0]
#  [1 5 5 0 0]
#  [0 5 0 4 0]
#  [1 5 5 0 0]
#  [0 5 4 4 0]
#  [2 5 2 4 0]
#  [1 5 2 0 0]
#  [1 5 4 7 0]
#  [3 5 4 4 0]
#  [3 2 0 4 0]
#  [1 5 0 4 0]
#  [2 5 6 0 0]
#  [1 5 0 9 4]
#  [1 5 3 4 0]
#  [1 5 7 0 0]
#  [0 0 0 0 0]
#  [2 2 0 4 0]
#  [1 0 4 0 0]
#  [1 5 4 1 0]
#  [1 5 0 1 0]
#  [1 5 0 4 0]]
# [1.02162137 1.40757454 2.74054054 4.80324354 4.80324354 4.80324354
#  4.80324354 1.96702691 4.80324354 3.54270282 1.65189173 2.59729727
#  1.17801672 4.80324354 4.39696935 2.28216209 4.80324354 4.80324354
#  2.15506926 1.65189173 4.80324354 4.17297318 4.80324354 1.03270325
#  2.91243245 2.28216209]
# 1.4443475878171899

# %%
# should we be using r2_score?
# how do you do residual plots?

# %%
print(r2_score(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
# Out:
# 0.03379715693992924
# 1.4443475878171899

# %%
# #     # Tomas: correlation analysis to see how your features are correlated to each other
    
# #     # as with any regression you need to minimize the mean square error.
#                                                         ------------------
# #     examples are at : 
# # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html#sklearn.metrics.mean_squared_error
# #     from sklearn.metrics import mean_squared_error
    
# # EMPTY PROCESS DATAFRAME   
    
# #     # accrossed all stocks, what is the average score.
# #     # what is the mean?
# #     # what is the median?
# #     # do we have any outliers that we need to note
# #     # does this work better for same sectors?
