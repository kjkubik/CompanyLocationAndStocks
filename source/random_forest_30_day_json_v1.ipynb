# %%
#dependencies
import warnings
warnings.filterwarnings("ignore")
import json
import pandas as pd
from config import db_password
from sqlalchemy import create_engine
from datetime import datetime, timedelta, date

# %%
# GET Tabled input
# creating database engine
db_name = 'Company_Stocks_DB'
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/{db_name}"
engine = create_engine(db_string)
# read data from PostgreSQL database table and load into Dataframe instance
stock_df = pd.read_sql("select * from \"company_all_star\"", engine);
# sort the dataframe by ticker column
stock_df.sort_values(by=["ticker"])
# Print the DataFrame
stock_df.head()
# ticker, date_val, region, open_val, high_val, low_val, close_val, volume_weight
# Out:
#   ticker    date_val                company_name company_url employee_count  \
# 0    AMD  2020-03-12  Advanced Micro Devices Inc     amd.com         5k-10k
# 1    AMD  2020-03-15  Advanced Micro Devices Inc     amd.com         5k-10k
# 2    AMD  2020-03-16  Advanced Micro Devices Inc     amd.com         5k-10k
# 3    AMD  2020-03-17  Advanced Micro Devices Inc     amd.com         5k-10k
# 4    AMD  2020-03-18  Advanced Micro Devices Inc     amd.com         5k-10k
#
#    revenue      sector    city_name state_name region  ...   latitude  \
# 0  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 1  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 2  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 3  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 4  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                381223.0        4.028436
# 1        41.0812                374962.0        0.946776
# 2        41.1240                434519.0        4.205026
# 3        39.6363                591862.0        1.062215
# 4        40.2337                396388.0        0.657230
#
# [5 rows x 21 columns]

# %%
# save original dataframe as .csv
# stock_df.to_csv("../resources/company_all_star.csv")
# completed

# %%
# save original datafrom as .json
#stock_df.to_json("../resources/company_all_star.json")

# %%
# preserve date column as type object
# stock_df['date'] = stock_df['date_val']

# have the user enter beginning date as yyyy-mm-dd
begin_date = '2022-01-10'
# have the user enter ending date as yyyy-mm-dd
end_date = '2022-03-10'

# Convert the date to datetime64
stock_df['date_val'] = pd.to_datetime(stock_df['date_val'], format='%Y-%m-%d')

begin_df = stock_df.loc[(stock_df['date_val'] >= begin_date)]
end_df = stock_df.loc[(stock_df['date_val'] <= end_date)]

# drop date_val
begin_df.drop(['date_val'], axis=1, inplace=True)
end_df.drop(['date_val'], axis=1, inplace=True)

begin_df.reset_index(drop=True,inplace=True)
begin_df.head()
# Out:
#   ticker                company_name company_url employee_count  revenue  \
# 0    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 1    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 2    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 3    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 4    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
#
#        sector    city_name state_name region country_code   latitude  \
# 0  Technology  Santa Clara         CA      W           US  37.233325
# 1  Technology  Santa Clara         CA      W           US  37.233325
# 2  Technology  Santa Clara         CA      W           US  37.233325
# 3  Technology  Santa Clara         CA      W           US  37.233325
# 4  Technology  Santa Clara         CA      W           US  37.233325
#
#     longitude  open_val  high_val  low_val  close_val      volume  \
# 0 -121.684635   133.450  138.9900   131.59     137.31  77153906.0
# 1 -121.684635   138.585  140.5700   135.77     137.47  69669598.0
# 2 -121.684635   139.440  141.2500   131.81     132.74  76618059.0
# 3 -121.684635   131.680  137.0000   131.43     136.88  71078438.0
# 4 -121.684635   134.500  136.3893   131.59     131.93  56589456.0
#
#    volume_weight  number_of_transactions  percent_change
# 0       136.1279                499284.0        2.892469
# 1       138.0222                458692.0        0.804560
# 2       135.7041                535482.0        4.804934
# 3       135.0553                466893.0        3.948967
# 4       133.7456                426778.0        1.910781

# %%
end_df.reset_index(drop=True,inplace=True)
end_df.head()
# Out:
#   ticker                company_name company_url employee_count  revenue  \
# 0    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 1    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 2    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 3    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 4    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
#
#        sector    city_name state_name region country_code   latitude  \
# 0  Technology  Santa Clara         CA      W           US  37.233325
# 1  Technology  Santa Clara         CA      W           US  37.233325
# 2  Technology  Santa Clara         CA      W           US  37.233325
# 3  Technology  Santa Clara         CA      W           US  37.233325
# 4  Technology  Santa Clara         CA      W           US  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                381223.0        4.028436
# 1        41.0812                374962.0        0.946776
# 2        41.1240                434519.0        4.205026
# 3        39.6363                591862.0        1.062215
# 4        40.2337                396388.0        0.657230

# %%
# merge together the beginning and ending dataframes
merged_df = pd.merge(begin_df, end_df, left_index=True, right_index=True)
merged_df
# Out:
#      ticker_x              company_name_x company_url_x employee_count_x  \
# 0         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 1         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 2         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 3         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 4         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# ...       ...                         ...           ...              ...
# 4279       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 4280       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 4281       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 4282       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 4283       ZS                 Zscaler Inc   zscaler.com            1k-5k
#
#       revenue_x    sector_x  city_name_x state_name_x region_x country_code_x  \
# 0       over-1b  Technology  Santa Clara           CA        W             US
# 1       over-1b  Technology  Santa Clara           CA        W             US
# 2       over-1b  Technology  Santa Clara           CA        W             US
# 3       over-1b  Technology  Santa Clara           CA        W             US
# 4       over-1b  Technology  Santa Clara           CA        W             US
# ...         ...         ...          ...          ...      ...            ...
# 4279  100m-200m  Technology     San Jose           CA        W             US
# 4280  100m-200m  Technology     San Jose           CA        W             US
# 4281  100m-200m  Technology     San Jose           CA        W             US
# 4282  100m-200m  Technology     San Jose           CA        W             US
# 4283  100m-200m  Technology     San Jose           CA        W             US
#
#       ...  latitude_y  longitude_y  open_val_y  high_val_y  low_val_y  \
# 0     ...   37.233325  -121.684635       42.20       43.91     39.600
# 1     ...   37.233325  -121.684635       39.08       43.37     38.510
# 2     ...   37.233325  -121.684635       40.19       42.88     38.300
# 3     ...   37.233325  -121.684635       39.54       41.95     36.750
# 4     ...   37.233325  -121.684635       39.56       41.70     37.690
# ...   ...         ...          ...         ...         ...        ...
# 4279  ...   40.262570   -80.187280      395.71      395.71    379.225
# 4280  ...   40.262570   -80.187280      387.52      395.20    383.010
# 4281  ...   40.262570   -80.187280      398.95      407.78    398.950
# 4282  ...   40.262570   -80.187280      405.14      407.37    402.765
# 4283  ...   40.262570   -80.187280      402.93      405.61    394.020
#
#       close_val_y     volume_y  volume_weight_y  number_of_transactions_y  \
# 0           43.90   86689681.0          41.6701                  381223.0
# 1           38.71   84545868.0          41.0812                  374962.0
# 2           41.88   92741881.0          41.1240                  434519.0
# 3           39.12  106949287.0          39.6363                  591862.0
# 4           39.82   88939024.0          40.2337                  396388.0
# ...           ...          ...              ...                       ...
# 4279       385.38     431244.0         384.8870                   16100.0
# 4280       394.43     350994.0         391.7881                   12501.0
# 4281       403.60     485909.0         404.2643                   14403.0
# 4282       404.61     376352.0         404.8678                   12237.0
# 4283       394.27     320142.0         398.0831                   12581.0
#
#       percent_change_y
# 0             4.028436
# 1             0.946776
# 2             4.205026
# 3             1.062215
# 4             0.657230
# ...                ...
# 4279          2.610498
# 4280          1.783134
# 4281          1.165560
# 4282          0.130819
# 4283          2.149257
#
# [4284 rows x 40 columns]

# %%
# calculate the absolute value of the diffence in the beginning percentage change and the ending percentage change
merged_df['percent_change_difference'] = abs(merged_df['percent_change_y'] - merged_df['percent_change_x'])
merged_df.columns
# Out:
# Index(['ticker_x', 'company_name_x', 'company_url_x', 'employee_count_x',
#        'revenue_x', 'sector_x', 'city_name_x', 'state_name_x', 'region_x',
#        'country_code_x', 'latitude_x', 'longitude_x', 'open_val_x',
#        'high_val_x', 'low_val_x', 'close_val_x', 'volume_x', 'volume_weight_x',
#        'number_of_transactions_x', 'percent_change_x', 'ticker_y',
#        'company_name_y', 'company_url_y', 'employee_count_y', 'revenue_y',
#        'sector_y', 'city_name_y', 'state_name_y', 'region_y', 'country_code_y',
#        'latitude_y', 'longitude_y', 'open_val_y', 'high_val_y', 'low_val_y',
#        'close_val_y', 'volume_y', 'volume_weight_y',
#        'number_of_transactions_y', 'percent_change_y',
#        'percent_change_difference'],
#       dtype='object')

# %%
# drop all *_y's
merged_df.drop(columns = ['ticker_y',
       'company_name_y', 'company_url_y', 'employee_count_y', 'revenue_y',
       'sector_y', 'city_name_y', 'state_name_y', 'region_y', 'country_code_y',
       'latitude_y', 'longitude_y', 'open_val_y', 'high_val_y', 'low_val_y',
       'close_val_y', 'volume_y', 'volume_weight_y',
       'number_of_transactions_y', 'percent_change_y'], axis=1, inplace=True)

# %%
merged_df.set_index("company_name_x").head()
# Out:
#                            ticker_x company_url_x employee_count_x revenue_x  \
# company_name_x
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
#
#                               sector_x  city_name_x state_name_x region_x  \
# company_name_x
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
#
#                            country_code_x  latitude_x  longitude_x  \
# company_name_x
# Advanced Micro Devices Inc             US   37.233325  -121.684635
# Advanced Micro Devices Inc             US   37.233325  -121.684635
# Advanced Micro Devices Inc             US   37.233325  -121.684635
# Advanced Micro Devices Inc             US   37.233325  -121.684635
# Advanced Micro Devices Inc             US   37.233325  -121.684635
#
#                             open_val_x  high_val_x  low_val_x  close_val_x  \
# company_name_x
# Advanced Micro Devices Inc     133.450    138.9900     131.59       137.31
# Advanced Micro Devices Inc     138.585    140.5700     135.77       137.47
# Advanced Micro Devices Inc     139.440    141.2500     131.81       132.74
# Advanced Micro Devices Inc     131.680    137.0000     131.43       136.88
# Advanced Micro Devices Inc     134.500    136.3893     131.59       131.93
#
#                               volume_x  volume_weight_x  \
# company_name_x
# Advanced Micro Devices Inc  77153906.0         136.1279
# Advanced Micro Devices Inc  69669598.0         138.0222
# Advanced Micro Devices Inc  76618059.0         135.7041
# Advanced Micro Devices Inc  71078438.0         135.0553
# Advanced Micro Devices Inc  56589456.0         133.7456
#
#                             number_of_transactions_x  percent_change_x  \
# company_name_x
# Advanced Micro Devices Inc                  499284.0          2.892469
# Advanced Micro Devices Inc                  458692.0          0.804560
# Advanced Micro Devices Inc                  535482.0          4.804934
# Advanced Micro Devices Inc                  466893.0          3.948967
# Advanced Micro Devices Inc                  426778.0          1.910781
#
#                             percent_change_difference
# company_name_x
# Advanced Micro Devices Inc                   1.135967
# Advanced Micro Devices Inc                   0.142215
# Advanced Micro Devices Inc                   0.599908
# Advanced Micro Devices Inc                   2.886752
# Advanced Micro Devices Inc                   1.253551

# %%
merged_df.columns
# Out:
# Index(['ticker_x', 'company_name_x', 'company_url_x', 'employee_count_x',
#        'revenue_x', 'sector_x', 'city_name_x', 'state_name_x', 'region_x',
#        'country_code_x', 'latitude_x', 'longitude_x', 'open_val_x',
#        'high_val_x', 'low_val_x', 'close_val_x', 'volume_x', 'volume_weight_x',
#        'number_of_transactions_x', 'percent_change_x',
#        'percent_change_difference'],
#       dtype='object')

# %%
merged_df['coordinates_x'] = merged_df['latitude_x'].astype('str') + ", " + merged_df['longitude_x'].astype('str')
merged_df.drop(['latitude_x', 'longitude_x'], axis=1, inplace=True)

# %%
merged_df.rename(columns={"ticker_x":"ticker",
                         "company_name_x": "company_name",
                         "company_url_x": "company_url",
                         "employee_count_x": "company_count",
                         "revenue_x": "revenue",
                         "sector_x": "sector",
                         "city_name_x":"city_name",
                         "state_name_x":"state_name",
                         "region_x":"region",
                         "country_code_x":"country_code",
                         "open_val_x":"open_val",
                         "high_val_x":"high_val",
                         "low_val_x":"low_val",
                         "close_val_x":"close_val",
                         "volume_x":"volume",
                         "volume_weight_x":"volume_weight",
                         "number_of_transactions_x":"number_of_transactions",
                         "percent_change_x":"percent_change",
                         "percent_change_difference_x":"percent_change_difference",
                         "coordinates_x":"coordinates"}, inplace=True)

# %%
month_dict = merged_df.to_dict(orient="records")
month_dict[0]
# Out:
# {'ticker': 'AMD',
#  'company_name': 'Advanced Micro Devices Inc',
#  'company_url': 'amd.com',
#  'company_count': '5k-10k',
#  'revenue': 'over-1b',
#  'sector': 'Technology',
#  'city_name': 'Santa Clara',
#  'state_name': 'CA',
#  'region': 'W',
#  'country_code': 'US',
#  'open_val': 133.45,
#  'high_val': 138.99,
#  'low_val': 131.59,
#  'close_val': 137.31,
#  'volume': 77153906.0,
#  'volume_weight': 136.1279,
#  'number_of_transactions': 499284.0,
#  'percent_change': 2.89246908954666,
#  'percent_change_difference': 1.1359669294106798,
#  'coordinates': '37.2333253, -121.6846349'}

# %%
month_json = json.dumps(month_dict, indent=2)

# %%
with open("../resources/random_tree_monthly_stocks.json", "w") as outfile:
    outfile.write(month_json)

# %%
file_path = open("../resources/random_tree_monthly_stocks.json")
rforest_json = json.load(file_path)
rforest_json
# Out:
# [{'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 133.45,
#   'high_val': 138.99,
#   'low_val': 131.59,
#   'close_val': 137.31,
#   'volume': 77153906.0,
#   'volume_weight': 136.1279,
#   'number_of_transactions': 499284.0,
#   'percent_change': 2.89246908954666,
#   'percent_change_difference': 1.1359669294106798,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 138.585,
#   'high_val': 140.57,
#   'low_val': 135.77,
#   'close_val': 137.47,
#   'volume': 69669598.0,
#   'volume_weight': 138.0222,
#   'number_of_transactions': 458692.0,
#   'percent_change': 0.804560378107305,
#   'percent_change_difference': 0.14221546631438708,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 139.44,
#   'high_val': 141.25,
#   'low_val': 131.81,
#   'close_val': 132.74,
#   'volume': 76618059.0,
#   'volume_weight': 135.7041,
#   'number_of_transactions': 535482.0,
#   'percent_change': 4.80493402180148,
#   'percent_change_difference': 0.5999078958995003,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 131.68,
#   'high_val': 137.0,
#   'low_val': 131.43,
#   'close_val': 136.88,
#   'volume': 71078438.0,
#   'volume_weight': 135.0553,
#   'number_of_transactions': 466893.0,
#   'percent_change': 3.94896719319562,
#   'percent_change_difference': 2.88675171519865,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 134.5,
#   'high_val': 136.3893,
#   'low_val': 131.59,
#   'close_val': 131.93,
#   'volume': 56589456.0,
#   'volume_weight': 133.7456,
#   'number_of_transactions': 426778.0,
#   'percent_change': 1.91078066914498,
#   'percent_change_difference': 1.253551144372488,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 133.55,
#   'high_val': 134.57,
#   'low_val': 128.02,
#   'close_val': 128.27,
#   'volume': 68751849.0,
#   'volume_weight': 130.7284,
#   'number_of_transactions': 502518.0,
#   'percent_change': 3.95357543991015,
#   'percent_change_difference': 0.6236348708583401,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 126.04,
#   'high_val': 128.51,
#   'low_val': 121.41,
#   'close_val': 121.89,
#   'volume': 91157293.0,
#   'volume_weight': 125.8506,
#   'number_of_transactions': 698057.0,
#   'percent_change': 3.29260552205649,
#   'percent_change_difference': 0.7815272354981402,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 120.14,
#   'high_val': 125.02,
#   'low_val': 118.39,
#   'close_val': 118.81,
#   'volume': 95685268.0,
#   'volume_weight': 121.3988,
#   'number_of_transactions': 766372.0,
#   'percent_change': 1.10704178458465,
#   'percent_change_difference': 3.84300362867602,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 115.4,
#   'high_val': 116.77,
#   'low_val': 107.5,
#   'close_val': 116.53,
#   'volume': 115401016.0,
#   'volume_weight': 112.3266,
#   'number_of_transactions': 888733.0,
#   'percent_change': 0.979202772963601,
#   'percent_change_difference': 3.6371682464849893,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 114.1,
#   'high_val': 114.82,
#   'low_val': 109.86,
#   'close_val': 111.13,
#   'volume': 85002907.0,
#   'volume_weight': 112.02,
#   'number_of_transactions': 602417.0,
#   'percent_change': 2.60297984224364,
#   'percent_change_difference': 1.15411932769956,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 114.55,
#   'high_val': 117.16,
#   'low_val': 108.63,
#   'close_val': 110.71,
#   'volume': 94302613.0,
#   'volume_weight': 113.1532,
#   'number_of_transactions': 672021.0,
#   'percent_change': 3.35224792666958,
#   'percent_change_difference': 2.790935318724852,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 111.96,
#   'high_val': 112.75,
#   'low_val': 101.94,
#   'close_val': 102.6,
#   'volume': 125954124.0,
#   'volume_weight': 106.2354,
#   'number_of_transactions': 1018135.0,
#   'percent_change': 8.36012861736334,
#   'percent_change_difference': 7.04768153861652,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 101.55,
#   'high_val': 105.4,
#   'low_val': 99.35,
#   'close_val': 105.24,
#   'volume': 98732221.0,
#   'volume_weight': 102.618,
#   'number_of_transactions': 770278.0,
#   'percent_change': 3.63367799113737,
#   'percent_change_difference': 1.4680434486122396,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 107.93,
#   'high_val': 114.31,
#   'low_val': 106.9,
#   'close_val': 114.25,
#   'volume': 97205994.0,
#   'volume_weight': 111.4309,
#   'number_of_transactions': 683688.0,
#   'percent_change': 5.85564717872695,
#   'percent_change_difference': 4.67864400987226,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 116.75,
#   'high_val': 117.26,
#   'low_val': 112.73,
#   'close_val': 116.78,
#   'volume': 122467874.0,
#   'volume_weight': 116.1475,
#   'number_of_transactions': 925900.0,
#   'percent_change': 0.025695931477517,
#   'percent_change_difference': 2.485824805849683,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 129.89,
#   'high_val': 130.06,
#   'low_val': 120.64,
#   'close_val': 122.76,
#   'volume': 180064993.0,
#   'volume_weight': 124.0596,
#   'number_of_transactions': 1254558.0,
#   'percent_change': 5.48926014319808,
#   'percent_change_difference': 1.6292149964712297,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 120.32,
#   'high_val': 125.37,
#   'low_val': 118.816,
#   'close_val': 120.08,
#   'volume': 103585547.0,
#   'volume_weight': 122.1374,
#   'number_of_transactions': 716090.0,
#   'percent_change': 0.199468085106379,
#   'percent_change_difference': 7.0691549397243305,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 120.34,
#   'high_val': 124.96,
#   'low_val': 118.58,
#   'close_val': 123.6,
#   'volume': 86207008.0,
#   'volume_weight': 122.3,
#   'number_of_transactions': 603617.0,
#   'percent_change': 2.70899119162373,
#   'percent_change_difference': 0.15048593255927,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 123.56,
#   'high_val': 127.63,
#   'low_val': 122.785,
#   'close_val': 123.67,
#   'volume': 81672504.0,
#   'volume_weight': 125.4259,
#   'number_of_transactions': 525095.0,
#   'percent_change': 0.0890255746196175,
#   'percent_change_difference': 1.4087901108390823,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 122.38,
#   'high_val': 128.705,
#   'low_val': 122.05,
#   'close_val': 128.23,
#   'volume': 84902753.0,
#   'volume_weight': 125.9646,
#   'number_of_transactions': 566128.0,
#   'percent_change': 4.78019284196764,
#   'percent_change_difference': 2.22228750460612,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 129.6,
#   'high_val': 132.96,
#   'low_val': 127.65,
#   'close_val': 132.85,
#   'volume': 92948862.0,
#   'volume_weight': 130.7954,
#   'number_of_transactions': 618883.0,
#   'percent_change': 2.50771604938272,
#   'percent_change_difference': 2.5882195809040502,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 128.84,
#   'high_val': 131.7589,
#   'low_val': 124.61,
#   'close_val': 125.77,
#   'volume': 108939859.0,
#   'volume_weight': 128.902,
#   'number_of_transactions': 797723.0,
#   'percent_change': 2.38280037255511,
#   'percent_change_difference': 2.7765755248317,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 126.14,
#   'high_val': 127.1699,
#   'low_val': 111.81,
#   'close_val': 113.18,
#   'volume': 164708241.0,
#   'volume_weight': 117.652,
#   'number_of_transactions': 1209307.0,
#   'percent_change': 10.2742983986047,
#   'percent_change_difference': 7.929239772139029,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 115.51,
#   'high_val': 118.37,
#   'low_val': 113.46,
#   'close_val': 114.27,
#   'volume': 135125910.0,
#   'volume_weight': 116.0441,
#   'number_of_transactions': 880606.0,
#   'percent_change': 1.07350012985889,
#   'percent_change_difference': 0.69562067071295,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 117.19,
#   'high_val': 121.88,
#   'low_val': 114.36,
#   'close_val': 121.47,
#   'volume': 144139671.0,
#   'volume_weight': 118.5217,
#   'number_of_transactions': 812307.0,
#   'percent_change': 3.6521887533066,
#   'percent_change_difference': 2.3444293810311,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 119.05,
#   'high_val': 119.54,
#   'low_val': 114.22,
#   'close_val': 117.69,
#   'volume': 119107831.0,
#   'volume_weight': 116.8985,
#   'number_of_transactions': 701937.0,
#   'percent_change': 1.14237715245695,
#   'percent_change_difference': 0.62611159352376,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 116.26,
#   'high_val': 116.98,
#   'low_val': 112.26,
#   'close_val': 112.37,
#   'volume': 98179641.0,
#   'volume_weight': 114.5982,
#   'number_of_transactions': 595580.0,
#   'percent_change': 3.34594873559264,
#   'percent_change_difference': 3.6487788566744896,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 113.9,
#   'high_val': 115.635,
#   'low_val': 109.89,
#   'close_val': 113.83,
#   'volume': 114300071.0,
#   'volume_weight': 112.784,
#   'number_of_transactions': 732539.0,
#   'percent_change': 0.0614574187884174,
#   'percent_change_difference': 1.7779161015175426,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 115.27,
#   'high_val': 119.2,
#   'low_val': 113.61,
#   'close_val': 115.65,
#   'volume': 141648454.0,
#   'volume_weight': 116.2412,
#   'number_of_transactions': 897808.0,
#   'percent_change': 0.32966079639109,
#   'percent_change_difference': 0.9942580032558699,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 117.4,
#   'high_val': 118.65,
#   'low_val': 109.04,
#   'close_val': 109.76,
#   'volume': 120299433.0,
#   'volume_weight': 113.1846,
#   'number_of_transactions': 762482.0,
#   'percent_change': 6.5076660988075,
#   'percent_change_difference': 4.5475935035262,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 104.56,
#   'high_val': 116.96,
#   'low_val': 104.26,
#   'close_val': 116.61,
#   'volume': 142956572.0,
#   'volume_weight': 111.2883,
#   'number_of_transactions': 960187.0,
#   'percent_change': 11.5244835501148,
#   'percent_change_difference': 9.87058382866634,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 117.16,
#   'high_val': 121.23,
#   'low_val': 116.0421,
#   'close_val': 121.06,
#   'volume': 127820983.0,
#   'volume_weight': 119.3594,
#   'number_of_transactions': 802060.0,
#   'percent_change': 3.32878115397747,
#   'percent_change_difference': 0.4421471441804101,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 120.31,
#   'high_val': 124.61,
#   'low_val': 119.2,
#   'close_val': 123.34,
#   'volume': 124666142.0,
#   'volume_weight': 122.2431,
#   'number_of_transactions': 716019.0,
#   'percent_change': 2.51849389078215,
#   'percent_change_difference': 0.92304184603613,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 122.33,
#   'high_val': 122.43,
#   'low_val': 112.8,
#   'close_val': 113.83,
#   'volume': 126552244.0,
#   'volume_weight': 116.8472,
#   'number_of_transactions': 844842.0,
#   'percent_change': 6.94841821303033,
#   'percent_change_difference': 5.00194619356561,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 115.47,
#   'high_val': 119.48,
#   'low_val': 113.31,
#   'close_val': 118.28,
#   'volume': 118054509.0,
#   'volume_weight': 116.7418,
#   'number_of_transactions': 706887.0,
#   'percent_change': 2.43353251926908,
#   'percent_change_difference': 0.10339741059472018,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 118.13,
#   'high_val': 118.26,
#   'low_val': 111.05,
#   'close_val': 111.98,
#   'volume': 123853721.0,
#   'volume_weight': 113.6286,
#   'number_of_transactions': 763902.0,
#   'percent_change': 5.20612884110725,
#   'percent_change_difference': 0.3042595961104695,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 112.0,
#   'high_val': 113.0,
#   'low_val': 106.81,
#   'close_val': 108.41,
#   'volume': 100671339.0,
#   'volume_weight': 109.0619,
#   'number_of_transactions': 674554.0,
#   'percent_change': 3.20535714285715,
#   'percent_change_difference': 0.88456358118767,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 108.53,
#   'high_val': 109.53,
#   'low_val': 102.82,
#   'close_val': 102.95,
#   'volume': 92599972.0,
#   'volume_weight': 105.5087,
#   'number_of_transactions': 659639.0,
#   'percent_change': 5.14143554777481,
#   'percent_change_difference': 4.645441652315052,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 102.81,
#   'high_val': 109.9,
#   'low_val': 100.08,
#   'close_val': 105.53,
#   'volume': 135348316.0,
#   'volume_weight': 105.1526,
#   'number_of_transactions': 845843.0,
#   'percent_change': 2.64565703725318,
#   'percent_change_difference': 0.79415505350106,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 108.41,
#   'high_val': 111.71,
#   'low_val': 106.85,
#   'close_val': 111.05,
#   'volume': 102310329.0,
#   'volume_weight': 109.6319,
#   'number_of_transactions': 602679.0,
#   'percent_change': 2.43519970482428,
#   'percent_change_difference': 0.4409523414494001,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 108.89,
#   'high_val': 109.07,
#   'low_val': 103.07,
#   'close_val': 106.46,
#   'volume': 102557375.0,
#   'volume_weight': 105.3382,
#   'number_of_transactions': 639388.0,
#   'percent_change': 2.23160988153183,
#   'percent_change_difference': 3.1370101562753603,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'AMD',
#   'company_name': 'Advanced Micro Devices Inc',
#   'company_url': 'amd.com',
#   'company_count': '5k-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Santa Clara',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 108.13,
#   'high_val': 108.19,
#   'low_val': 104.08,
#   'close_val': 104.29,
#   'volume': 87584432.0,
#   'volume_weight': 105.9691,
#   'number_of_transactions': 542478.0,
#   'percent_change': 3.5512808656247,
#   'percent_change_difference': 0.8014185552607902,
#   'coordinates': '37.2333253, -121.6846349'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 525.5533,
#   'high_val': 535.18,
#   'low_val': 520.9821,
#   'close_val': 529.89,
#   'volume': 3422161.0,
#   'volume_weight': 529.9001,
#   'number_of_transactions': 101410.0,
#   'percent_change': 0.825168446283174,
#   'percent_change_difference': 2.616726446388916,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 533.09,
#   'high_val': 541.59,
#   'low_val': 529.28,
#   'close_val': 532.37,
#   'volume': 2901791.0,
#   'volume_weight': 533.9129,
#   'number_of_transactions': 81191.0,
#   'percent_change': 0.135061621864981,
#   'percent_change_difference': 4.490658147808719,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 532.22,
#   'high_val': 535.265,
#   'low_val': 516.32,
#   'close_val': 516.9,
#   'volume': 3406500.0,
#   'volume_weight': 520.9379,
#   'number_of_transactions': 88943.0,
#   'percent_change': 2.87850888730225,
#   'percent_change_difference': 1.22809628415146,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 514.49,
#   'high_val': 522.5715,
#   'low_val': 511.27,
#   'close_val': 520.6,
#   'volume': 2659825.0,
#   'volume_weight': 517.6421,
#   'number_of_transactions': 75958.0,
#   'percent_change': 1.18758382087116,
#   'percent_change_difference': 0.47823496674239796,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 510.39,
#   'high_val': 519.39,
#   'low_val': 504.98,
#   'close_val': 513.34,
#   'volume': 3461507.0,
#   'volume_weight': 513.246,
#   'number_of_transactions': 95040.0,
#   'percent_change': 0.577989380669693,
#   'percent_change_difference': 1.407669747846577,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 516.48,
#   'high_val': 528.9179,
#   'low_val': 515.3,
#   'close_val': 516.58,
#   'volume': 2985891.0,
#   'volume_weight': 521.2438,
#   'number_of_transactions': 82988.0,
#   'percent_change': 0.0193618339529164,
#   'percent_change_difference': 0.2635736213963256,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 522.38,
#   'high_val': 532.025,
#   'low_val': 509.64,
#   'close_val': 510.85,
#   'volume': 3208136.0,
#   'volume_weight': 520.6816,
#   'number_of_transactions': 92296.0,
#   'percent_change': 2.20720548259887,
#   'percent_change_difference': 1.3743047502875103,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 508.5,
#   'high_val': 513.8624,
#   'low_val': 499.2701,
#   'close_val': 499.91,
#   'volume': 4276067.0,
#   'volume_weight': 504.9794,
#   'number_of_transactions': 119443.0,
#   'percent_change': 1.68928220255653,
#   'percent_change_difference': 0.9589553813040219,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 491.07,
#   'high_val': 520.43,
#   'low_val': 483.31,
#   'close_val': 519.66,
#   'volume': 7555213.0,
#   'volume_weight': 502.3254,
#   'number_of_transactions': 162344.0,
#   'percent_change': 5.82198057303439,
#   'percent_change_difference': 0.7871653614650294,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 505.51,
#   'high_val': 514.26,
#   'low_val': 500.01,
#   'close_val': 502.72,
#   'volume': 4051522.0,
#   'volume_weight': 504.9497,
#   'number_of_transactions': 102687.0,
#   'percent_change': 0.551917865126301,
#   'percent_change_difference': 0.44301361600754796,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 514.0,
#   'high_val': 520.49,
#   'low_val': 494.22,
#   'close_val': 500.81,
#   'volume': 4449496.0,
#   'volume_weight': 508.3122,
#   'number_of_transactions': 114218.0,
#   'percent_change': 2.56614785992218,
#   'percent_change_difference': 1.59007130489826,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 508.94,
#   'high_val': 513.23,
#   'low_val': 485.62,
#   'close_val': 493.05,
#   'volume': 5830522.0,
#   'volume_weight': 497.4915,
#   'number_of_transactions': 121762.0,
#   'percent_change': 3.12217550202381,
#   'percent_change_difference': 0.20027504531630003,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 494.0901,
#   'high_val': 519.0,
#   'low_val': 480.62,
#   'close_val': 518.16,
#   'volume': 4333427.0,
#   'volume_weight': 506.226,
#   'number_of_transactions': 98440.0,
#   'percent_change': 4.87156087523307,
#   'percent_change_difference': 4.271298260339052,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 518.98,
#   'high_val': 534.94,
#   'low_val': 514.39,
#   'close_val': 534.3,
#   'volume': 3995098.0,
#   'volume_weight': 529.0899,
#   'number_of_transactions': 84554.0,
#   'percent_change': 2.95194419823499,
#   'percent_change_difference': 2.78356253312742,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 536.0,
#   'high_val': 538.77,
#   'low_val': 527.72,
#   'close_val': 535.98,
#   'volume': 2294434.0,
#   'volume_weight': 533.9474,
#   'number_of_transactions': 63307.0,
#   'percent_change': 0.0037313432835787,
#   'percent_change_difference': 1.6129787030813914,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 536.25,
#   'high_val': 540.46,
#   'low_val': 529.3201,
#   'close_val': 533.09,
#   'volume': 2494142.0,
#   'volume_weight': 533.2413,
#   'number_of_transactions': 64869.0,
#   'percent_change': 0.589277389277383,
#   'percent_change_difference': 0.5132173018082841,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 522.87,
#   'high_val': 525.18,
#   'low_val': 508.75,
#   'close_val': 510.83,
#   'volume': 3058710.0,
#   'volume_weight': 514.8938,
#   'number_of_transactions': 76082.0,
#   'percent_change': 2.30267561726625,
#   'percent_change_difference': 2.0950892802215257,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 503.77,
#   'high_val': 519.97,
#   'low_val': 503.77,
#   'close_val': 513.54,
#   'volume': 2583714.0,
#   'volume_weight': 513.6129,
#   'number_of_transactions': 61623.0,
#   'percent_change': 1.93937709669095,
#   'percent_change_difference': 1.320240136090578,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 516.0,
#   'high_val': 516.0,
#   'low_val': 500.95,
#   'close_val': 507.1,
#   'volume': 3120737.0,
#   'volume_weight': 508.5957,
#   'number_of_transactions': 78159.0,
#   'percent_change': 1.72480620155038,
#   'percent_change_difference': 4.77249217785498,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 501.63,
#   'high_val': 513.51,
#   'low_val': 501.07,
#   'close_val': 511.31,
#   'volume': 3205743.0,
#   'volume_weight': 508.7802,
#   'number_of_transactions': 70936.0,
#   'percent_change': 1.92970914817694,
#   'percent_change_difference': 1.510128728596529,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 520.35,
#   'high_val': 522.48,
#   'low_val': 515.06,
#   'close_val': 521.75,
#   'volume': 2542201.0,
#   'volume_weight': 519.2488,
#   'number_of_transactions': 67941.0,
#   'percent_change': 0.269049678101274,
#   'percent_change_difference': 5.290478387683496,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 508.08,
#   'high_val': 514.4799,
#   'low_val': 492.28,
#   'close_val': 495.02,
#   'volume': 4735802.0,
#   'volume_weight': 501.5645,
#   'number_of_transactions': 119962.0,
#   'percent_change': 2.57046134467013,
#   'percent_change_difference': 0.17449411797301995,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 497.92,
#   'high_val': 499.93,
#   'low_val': 472.8952,
#   'close_val': 473.97,
#   'volume': 5026970.0,
#   'volume_weight': 482.1864,
#   'number_of_transactions': 136685.0,
#   'percent_change': 4.81000964010283,
#   'percent_change_difference': 0.8160956043477903,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 473.2,
#   'high_val': 478.57,
#   'low_val': 469.2101,
#   'close_val': 474.01,
#   'volume': 3372122.0,
#   'volume_weight': 474.3433,
#   'number_of_transactions': 84989.0,
#   'percent_change': 0.171174978867287,
#   'percent_change_difference': 2.0901315537960232,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 482.5337,
#   'high_val': 482.5337,
#   'low_val': 472.39,
#   'close_val': 479.5,
#   'volume': 3745338.0,
#   'volume_weight': 477.9062,
#   'number_of_transactions': 77142.0,
#   'percent_change': 0.628702202561191,
#   'percent_change_difference': 0.190666064579804,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 476.485,
#   'high_val': 480.21,
#   'low_val': 467.27,
#   'close_val': 477.7,
#   'volume': 3750472.0,
#   'volume_weight': 474.0233,
#   'number_of_transactions': 81341.0,
#   'percent_change': 0.254992287270318,
#   'percent_change_difference': 0.806889807200572,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 473.14,
#   'high_val': 476.45,
#   'low_val': 456.05,
#   'close_val': 457.71,
#   'volume': 4021128.0,
#   'volume_weight': 462.4589,
#   'number_of_transactions': 98463.0,
#   'percent_change': 3.26119119076806,
#   'percent_change_difference': 2.930369650610001,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 458.69,
#   'high_val': 459.3,
#   'low_val': 441.77,
#   'close_val': 442.56,
#   'volume': 5194162.0,
#   'volume_weight': 446.6922,
#   'number_of_transactions': 131815.0,
#   'percent_change': 3.51653622272123,
#   'percent_change_difference': 3.351912114435157,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 440.35,
#   'high_val': 451.09,
#   'low_val': 435.05,
#   'close_val': 438.4,
#   'volume': 4287637.0,
#   'volume_weight': 441.6249,
#   'number_of_transactions': 106077.0,
#   'percent_change': 0.442829567389587,
#   'percent_change_difference': 1.482692685108133,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 447.78,
#   'high_val': 449.59,
#   'low_val': 428.06,
#   'close_val': 429.45,
#   'volume': 4263021.0,
#   'volume_weight': 436.5083,
#   'number_of_transactions': 88312.0,
#   'percent_change': 4.09352807182098,
#   'percent_change_difference': 1.2199648534301804,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 418.59,
#   'high_val': 465.93,
#   'low_val': 416.8124,
#   'close_val': 463.82,
#   'volume': 6448772.0,
#   'volume_weight': 450.521,
#   'number_of_transactions': 149687.0,
#   'percent_change': 10.8053226307365,
#   'percent_change_difference': 9.60669249375019,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 465.39,
#   'high_val': 468.5199,
#   'low_val': 456.015,
#   'close_val': 465.54,
#   'volume': 2869739.0,
#   'volume_weight': 463.5538,
#   'number_of_transactions': 80493.0,
#   'percent_change': 0.0322310320376532,
#   'percent_change_difference': 3.3428895079816368,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 462.4,
#   'high_val': 468.48,
#   'low_val': 458.86,
#   'close_val': 467.68,
#   'volume': 3302341.0,
#   'volume_weight': 465.0572,
#   'number_of_transactions': 69591.0,
#   'percent_change': 1.14186851211073,
#   'percent_change_difference': 0.882646179109728,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 468.0,
#   'high_val': 479.21,
#   'low_val': 462.92,
#   'close_val': 466.68,
#   'volume': 3352760.0,
#   'volume_weight': 468.6079,
#   'number_of_transactions': 81787.0,
#   'percent_change': 0.282051282051281,
#   'percent_change_difference': 2.552194222248959,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 471.94,
#   'high_val': 477.49,
#   'low_val': 466.04,
#   'close_val': 471.18,
#   'volume': 2948450.0,
#   'volume_weight': 471.9849,
#   'number_of_transactions': 73982.0,
#   'percent_change': 0.161037420011016,
#   'percent_change_difference': 0.06603456992550531,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 475.83,
#   'high_val': 476.05,
#   'low_val': 455.445,
#   'close_val': 459.08,
#   'volume': 2906318.0,
#   'volume_weight': 462.3042,
#   'number_of_transactions': 72353.0,
#   'percent_change': 3.5201647647269,
#   'percent_change_difference': 2.21250074104377,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 455.49,
#   'high_val': 463.52,
#   'low_val': 447.0,
#   'close_val': 452.13,
#   'volume': 2752177.0,
#   'volume_weight': 452.735,
#   'number_of_transactions': 65601.0,
#   'percent_change': 0.737667127708625,
#   'percent_change_difference': 0.20751245641235805,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 456.22,
#   'high_val': 457.68,
#   'low_val': 437.18,
#   'close_val': 437.97,
#   'volume': 3676072.0,
#   'volume_weight': 444.4155,
#   'number_of_transactions': 84417.0,
#   'percent_change': 4.00026303099382,
#   'percent_change_difference': 3.3433561240869105,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 432.51,
#   'high_val': 443.8,
#   'low_val': 421.36,
#   'close_val': 431.53,
#   'volume': 3734842.0,
#   'volume_weight': 432.4705,
#   'number_of_transactions': 93468.0,
#   'percent_change': 0.226584356431069,
#   'percent_change_difference': 0.565718982561577,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 443.8,
#   'high_val': 453.11,
#   'low_val': 438.93,
#   'close_val': 450.87,
#   'volume': 2905656.0,
#   'volume_weight': 447.8637,
#   'number_of_transactions': 67082.0,
#   'percent_change': 1.59305993690852,
#   'percent_change_difference': 5.38563961466098,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 444.68,
#   'high_val': 447.65,
#   'low_val': 433.01,
#   'close_val': 438.95,
#   'volume': 2686310.0,
#   'volume_weight': 437.7568,
#   'number_of_transactions': 66371.0,
#   'percent_change': 1.28856705945849,
#   'percent_change_difference': 1.59638254081957,
#   'coordinates': '37.3361905, -121.890583'},
#  {'ticker': 'ADBE',
#   'company_name': 'Adobe Inc.',
#   'company_url': 'adobe.com',
#   'company_count': 'over-10k',
#   'revenue': '1m-10m',
#   'sector': 'Technology',
#   'city_name': 'San Jose',
#   'state_name': 'CA',
#   'region': 'W',
#   'country_code': 'US',
#   'open_val': 439.66,
#   'high_val': 440.61,
#   'low_val': 415.43,
#   'close_val': 416.38,
#   'volume': 4434498.0,
#   'volume_weight': 422.5279,
#   'number_of_transactions': 107234.0,
#   'percent_change': 5.29500068234545,
#   'percent_change_difference': 0.15665775096434942,
# ...
#   'close_val': 572.16,
#   'volume': 1180979.0,
#   'volume_weight': 577.0271,
#   'number_of_transactions': 30546.0,
#   'percent_change': 2.09445585215606,
#   'percent_change_difference': 2.0750940182031434,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 574.87,
#   'high_val': 579.75,
#   'low_val': 568.82,
#   'close_val': 569.69,
#   'volume': 1105754.0,
#   'volume_weight': 572.6713,
#   'number_of_transactions': 29267.0,
#   'percent_change': 0.901073286134248,
#   'percent_change_difference': 1.3061321964646218,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 580.11,
#   'high_val': 580.67,
#   'low_val': 562.455,
#   'close_val': 577.13,
#   'volume': 1908008.0,
#   'volume_weight': 573.5064,
#   'number_of_transactions': 38831.0,
#   'percent_change': 0.513695678405823,
#   'percent_change_difference': 1.1755865241507069,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 570.22,
#   'high_val': 575.38,
#   'low_val': 560.72,
#   'close_val': 563.54,
#   'volume': 1092668.0,
#   'volume_weight': 565.2345,
#   'number_of_transactions': 27178.0,
#   'percent_change': 1.17147767528324,
#   'percent_change_difference': 4.650502897751149,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 563.98,
#   'high_val': 574.86,
#   'low_val': 549.59,
#   'close_val': 555.0,
#   'volume': 1638668.0,
#   'volume_weight': 559.9155,
#   'number_of_transactions': 36329.0,
#   'percent_change': 1.59225504450513,
#   'percent_change_difference': 1.040337179378829,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 549.85,
#   'high_val': 567.9,
#   'low_val': 549.85,
#   'close_val': 561.03,
#   'volume': 1561072.0,
#   'volume_weight': 561.625,
#   'number_of_transactions': 36366.0,
#   'percent_change': 2.03328180412839,
#   'percent_change_difference': 0.5328660557937899,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 560.62,
#   'high_val': 592.2,
#   'low_val': 560.37,
#   'close_val': 590.47,
#   'volume': 2600684.0,
#   'volume_weight': 583.7945,
#   'number_of_transactions': 51469.0,
#   'percent_change': 5.32446220256145,
#   'percent_change_difference': 2.20228670053764,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 588.99,
#   'high_val': 595.13,
#   'low_val': 584.5,
#   'close_val': 593.34,
#   'volume': 1473429.0,
#   'volume_weight': 591.8616,
#   'number_of_transactions': 35511.0,
#   'percent_change': 0.738552437223047,
#   'percent_change_difference': 4.133008438010023,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 590.73,
#   'high_val': 598.325,
#   'low_val': 587.88,
#   'close_val': 596.89,
#   'volume': 1253077.0,
#   'volume_weight': 593.0801,
#   'number_of_transactions': 33273.0,
#   'percent_change': 1.04277758028202,
#   'percent_change_difference': 1.9091666179529698,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 598.25,
#   'high_val': 603.71,
#   'low_val': 592.34,
#   'close_val': 600.24,
#   'volume': 1074270.0,
#   'volume_weight': 597.789,
#   'number_of_transactions': 27439.0,
#   'percent_change': 0.332636857501046,
#   'percent_change_difference': 0.3289055142174673,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 600.72,
#   'high_val': 621.0,
#   'low_val': 596.04,
#   'close_val': 610.45,
#   'volume': 2232285.0,
#   'volume_weight': 614.1698,
#   'number_of_transactions': 40589.0,
#   'percent_change': 1.61972299906779,
#   'percent_change_difference': 1.030445609790407,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 599.97,
#   'high_val': 613.18,
#   'low_val': 596.95,
#   'close_val': 608.92,
#   'volume': 1389348.0,
#   'volume_weight': 607.1938,
#   'number_of_transactions': 28083.0,
#   'percent_change': 1.49174125372934,
#   'percent_change_difference': 0.81093436353691,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 610.12,
#   'high_val': 613.63,
#   'low_val': 605.85,
#   'close_val': 610.75,
#   'volume': 1359651.0,
#   'volume_weight': 609.6313,
#   'number_of_transactions': 28689.0,
#   'percent_change': 0.10325837540156,
#   'percent_change_difference': 1.8361187212893901,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 612.88,
#   'high_val': 615.84,
#   'low_val': 608.4,
#   'close_val': 609.12,
#   'volume': 1227676.0,
#   'volume_weight': 611.5089,
#   'number_of_transactions': 27674.0,
#   'percent_change': 0.613496932515336,
#   'percent_change_difference': 1.111309269035044,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 613.0,
#   'high_val': 615.0,
#   'low_val': 604.72,
#   'close_val': 614.75,
#   'volume': 1396212.0,
#   'volume_weight': 611.1631,
#   'number_of_transactions': 28661.0,
#   'percent_change': 0.285481239804241,
#   'percent_change_difference': 1.644227908372699,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 607.17,
#   'high_val': 613.085,
#   'low_val': 604.02,
#   'close_val': 606.52,
#   'volume': 1514780.0,
#   'volume_weight': 608.772,
#   'number_of_transactions': 34852.0,
#   'percent_change': 0.107054037584198,
#   'percent_change_difference': 0.161995640517076,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 608.99,
#   'high_val': 614.54,
#   'low_val': 602.51,
#   'close_val': 604.73,
#   'volume': 1517223.0,
#   'volume_weight': 607.7561,
#   'number_of_transactions': 35766.0,
#   'percent_change': 0.699518875515196,
#   'percent_change_difference': 1.8709424691549341,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 605.69,
#   'high_val': 614.5,
#   'low_val': 601.58,
#   'close_val': 607.94,
#   'volume': 2480031.0,
#   'volume_weight': 606.231,
#   'number_of_transactions': 34255.0,
#   'percent_change': 0.37147715828229,
#   'percent_change_difference': 4.43853248182054,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 611.74,
#   'high_val': 615.6,
#   'low_val': 607.86,
#   'close_val': 609.45,
#   'volume': 2564495.0,
#   'volume_weight': 610.9796,
#   'number_of_transactions': 29965.0,
#   'percent_change': 0.374342040736255,
#   'percent_change_difference': 0.203167061868968,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 606.86,
#   'high_val': 612.52,
#   'low_val': 602.7,
#   'close_val': 609.46,
#   'volume': 1388454.0,
#   'volume_weight': 607.4838,
#   'number_of_transactions': 35969.0,
#   'percent_change': 0.428434894374324,
#   'percent_change_difference': 0.200267308186867,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 603.2,
#   'high_val': 606.035,
#   'low_val': 588.39,
#   'close_val': 597.83,
#   'volume': 2109730.0,
#   'volume_weight': 597.8434,
#   'number_of_transactions': 36288.0,
#   'percent_change': 0.890251989389921,
#   'percent_change_difference': 0.635259702119603,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 598.79,
#   'high_val': 605.62,
#   'low_val': 594.57,
#   'close_val': 596.83,
#   'volume': 2786408.0,
#   'volume_weight': 599.1861,
#   'number_of_transactions': 37813.0,
#   'percent_change': 0.327326775664243,
#   'percent_change_difference': 2.9338644151038173,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 599.34,
#   'high_val': 603.15,
#   'low_val': 591.88,
#   'close_val': 595.5,
#   'volume': 1986709.0,
#   'volume_weight': 597.246,
#   'number_of_transactions': 37778.0,
#   'percent_change': 0.640704775252783,
#   'percent_change_difference': 2.875831447468447,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 591.87,
#   'high_val': 592.74,
#   'low_val': 569.39,
#   'close_val': 570.6,
#   'volume': 2774497.0,
#   'volume_weight': 574.7752,
#   'number_of_transactions': 48728.0,
#   'percent_change': 3.59369456130569,
#   'percent_change_difference': 3.150864993916103,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 572.5,
#   'high_val': 586.95,
#   'low_val': 566.05,
#   'close_val': 586.59,
#   'volume': 4139728.0,
#   'volume_weight': 579.4083,
#   'number_of_transactions': 51905.0,
#   'percent_change': 2.46113537117904,
#   'percent_change_difference': 1.6323927006419403,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 587.92,
#   'high_val': 602.02,
#   'low_val': 586.54,
#   'close_val': 601.16,
#   'volume': 1847342.0,
#   'volume_weight': 598.6141,
#   'number_of_transactions': 39783.0,
#   'percent_change': 2.25200707579263,
#   'percent_change_difference': 8.55331555494387,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 593.77,
#   'high_val': 605.4,
#   'low_val': 593.72,
#   'close_val': 601.78,
#   'volume': 2272780.0,
#   'volume_weight': 600.6741,
#   'number_of_transactions': 35009.0,
#   'percent_change': 1.34900719133671,
#   'percent_change_difference': 1.316776159299057,
#   'coordinates': '41.0534302, -73.5387341'},
#  {'ticker': 'CHTR',
#   'company_name': 'Charter Communications Inc',
#   'company_url': 'spectrum.com',
#   'company_count': 'over-10k',
#   'revenue': 'over-1b',
#   'sector': 'Technology',
#   'city_name': 'Stamford',
#   'state_name': 'CT',
#   'region': 'NE',
#   'country_code': 'US',
#   'open_val': 590.99,
#   'high_val': 603.16,
#   'low_val': 589.47,
#   'close_val': 594.74,
#   'volume': 1578566.0,
#   'volume_weight': 595.6843,
#   'number_of_transactions': 38839.0,
#   'percent_change': 0.634528503020356,
#   'percent_change_difference': 0.5073400090903739,
#   'coordinates': '41.0534302, -73.5387341'},
#  ...]
