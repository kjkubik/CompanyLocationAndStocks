# %%
import requests
import datetime
import time
import pandas as pd
from io import open
from numpy import record
import json
import bs4 as bs
import re
from config import url, headers

# %%
# ORIGINAL URL: querystring = {"url":"adobe.com"}

# Create dataframe for URL input
url_df = pd.read_csv("compcom.csv")
print(url_df.head())
# Out:
#   Ticker                          url
# 0   MNST  {"url":"monsterenergy.com"}
# 1   MSFT      {"url":"microsoft.com"}
# 2     MU       {"url":"catalent.com"}
# 3   NFLX        {"url":"netflix.com"}
# 4   NTES   {"url":"neteasegames.com"}

# %%
# OUTPUT FILE
output = open("StockFacts.json", "w", encoding="utf-8")
print(output)
# Out:
# <_io.TextIOWrapper name='StockFacts.json' mode='w' encoding='utf-8'>

# %%
# write header record once
# record = f"ticker, url, revenue, employee_count\n"
# print(record)
# output.write(record)

# %%
# get company revenue and employee_count
with open("StockFacts.json", "w",encoding="utf-8") as outfile:
    for record, row in url_df.iterrows():
            # must do this
            time.sleep(5)
            querystring = json.loads(row['url'])
            response = requests.request("GET", url, headers=headers, params=querystring)
            
            
            outfile.write(response.text)
            print(response.text)
        
        
        
        # DO THIS LATER
#         url_string = row['url']
#         ticker = row['Ticker']
        
############################################################################################        
        
#         company_revenue = response.json()['data']['revenue']
#         company_size = response.json()['data']['size']
        
#         print(f"{ticker},{url_string},{company_revenue},{company_size}\n")
#         record = f"{ticker},{url_string},{company_revenue},{company_size}\n"
# Out:
# {"result":"success","data":{"name":"Monster Energy","alternate_name":null,"domain":"monsterenergy.com","domain_name":"monsterenergy","domain_tld":"com","business_type":null,"monthly_visitors":"10k-50k","phone_number":"(800) 426-7367","revenue":"over-1b","size":"1k-5k","year_founded":2002,"address":"1 monster way","address_name":"Corona","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":33.8410146,"address_lng":-117.52079778811958,"updated_at":"2020-09-24T21:44:19+00:00","description":"Based in Corona, California, Monster Energy is a leading marketer and distributor of energy drinks and alternative beverages.  The company markets and distributes Monster Energy® energy drinks, Monster Energy Extra Strength Nitrous Technology® energy drinks, Java Monster® non-carbonated coffee + energy drinks, M3® Monster Energy® Super Concentrate energy drinks, Monster Rehab® non-carbonated energy drinks with electrolytes, Muscle Monster® Energy Shakes, Übermonster® energy drinks, NOS® energy drinks, Full Throttle® energy drinks, Burn® energy drinks, Mother® energy drinks, BU® energy drinks, Gladiator® energy drinks, Samurai® energy drinks, Nalu® energy drinks, BPM® energy drinks, Power Play® energy drinks, and Relentless® energy drinks.\\\\We offer a comprehensive compensation and benefits package which includes a competitive salary; company-paid medical, dental, vision, long-term disability and life insurance coverage; 401(k) with company match; generous employee discounts; a casual but driven work environment; and the ability to make a real difference as a key contributor to our growth. \\\\Most companies spend their money on ad agencies, TV commercials, radio spots, and billboards to tell you how good their products are. At Monster we choose none of the above. Instead, we support the scene, our bands, our athletes and our fans. We back athletes so they can make a career out of their passion. We promote concert tours, so our favorite bands can visit your home town. We celebrate with our fans and riders by throwing parties and making the coolest events we can think of a reality. \\\\This is the official Linked in company page for Monster Energy a leading marketer and distributor of energy drinks and alternative beverages.\\\\Monster is lifestyle in a can.\\\\\\Monster Energy is an affirmative action and equal opportunity employer.","social_networks":{"angellist":"http://angel.co/monster-beverage-coperation","facebook":"https://www.facebook.com/monsterenergy","linkedin":"https://www.linkedin.com/company/monster-energy_2","twitter":"https://www.twitter.com/monsterenergyjp"},"email_patterns":[{"pattern":"[F].[L]","percentage":99.869},{"pattern":"[F1][L]","percentage":0.0655},{"pattern":"[F1].[L]","percentage":0.0655}],"technologies":[],"technology_categories":[],"industries":["beverages","consumer-goods","consumers","food","fruit","manufacturing","vegetable-markets"]}}
# {"result":"success","data":{"name":"Microsoft","alternate_name":null,"domain":"microsoft.com","domain_name":"microsoft","domain_tld":"com","business_type":null,"monthly_visitors":"over-1b","phone_number":"(503) 443-7070","revenue":"over-1b","size":"over-10k","year_founded":1975,"address":"1 microsoft way","address_name":"Redmond","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":47.6694141,"address_lng":-122.1238767,"updated_at":"2020-09-22T15:49:41+00:00","description":"At Microsoft, our mission is to empower every person and every organization on the planet to achieve more. Our mission is grounded in both the world in which we live and the future we strive to create. Today, we live in a mobile-first, cloud-first world, and the transformation we are driving across our businesses is designed to enable Microsoft and our customers to thrive in this world. \\\\We do business in 170 countries and are made up of 114,000 passionate employees dedicated to fulfilling our mission of helping you and your organization achieve more.\\","social_networks":{"angellist":"http://angel.co/microsoft","facebook":"https://www.facebook.com/MicrosoftIndia?brand_redir=1","linkedin":"https://www.linkedin.com/company/microsoft","twitter":"http://twitter.com/Microsoft"},"email_patterns":[{"pattern":"[F][L1]","percentage":47.204},{"pattern":"[F1][L]","percentage":26.0307},{"pattern":"[F].[L]","percentage":22.9093},{"pattern":"[F][L]","percentage":2.3292},{"pattern":"[F]","percentage":0.7048},{"pattern":"[L]","percentage":0.5309},{"pattern":"[L].[F]","percentage":0.0818},{"pattern":"[L][F1]","percentage":0.04},{"pattern":"[L1][F]","percentage":0.04},{"pattern":"[F1].[L]","percentage":0.0288},{"pattern":"[L][F]","percentage":0.0205},{"pattern":"[F].[L1]","percentage":0.0186},{"pattern":"[F1][L1]","percentage":0.0139},{"pattern":"[F]_[L]","percentage":0.0121},{"pattern":"[F1][M1][L]","percentage":0.0112}],"technologies":["comscore","jquery","kestrel","microsoft-asp-net","microsoft-iis","office-365","windows-server"],"technology_categories":["Calendar & Scheduling","Video Conferencing","analytics","cloud-storage","collaboration","conversion-optimization","dot-net-framework","email-service","javascript-library","operating-system","productivity","web-server"],"industries":["advertising","business-software","cloud-computing","computer-software","computers","consumer-internet","design-tools","developer-tools","electronics","entertainment-products","games","hardware","home-educational-software","information-technology","internet","mobile-phones","prepackaged-software","search","servers","shopping","smartphones","software","tablets","video-games","windows-applications-platforms","windows-operating-system"]}}
# {"result":"success","data":{"name":"Catalent","alternate_name":null,"domain":"catalent.com","domain_name":"catalent","domain_tld":"com","business_type":null,"monthly_visitors":"10m-50m","phone_number":"(732) 537-6200","revenue":"over-1b","size":"over-10k","year_founded":2007,"address":"14 schoolhouse road","address_name":"Somerset","address_postal_code":"08560","address_country_code":"US","address_country":"United States","address_lat":40.2762189,"address_lng":-74.8490528,"updated_at":"2020-09-28T22:05:01+00:00","description":"Catalyst + Talent. Our name combines these ideas. From drug and biologic development services to delivery technologies to supply solutions, we are the catalyst for your success. With over 80 years of experience, we have the deepest expertise, the broadest offerings, and the most innovative technologies to help you get more molecules to market faster, enhance product performance and provide superior, reliable manufacturing and packaging results.\\\\Catalent develops. With our broad range of expert services we drive faster, more efficient development timelines to help you take more molecules to market and create more effective products.\\\\Catalent delivers. As the world leader in drug delivery innovations, we have a proven record of enhancing bioavailability, solubility and permeability, improving ease and route of administration, and increasing patient compliance for better treatments.\\\\Catalent supplies. Globally positioned to serve all your manufacturing and commercial packaging needs, we provide integrated solutions to take your product from design, to clinical trial, to plant, and to pharmacy.\\\\Catalent. More products. Better treatments. Reliably supplied.™\\\\Visit. www.catalent.com/careers to explore career opportunities, or contact us at +1 877 503 9493","social_networks":{"facebook":"http://www.facebook.com/CatalentPharmaSolutions","linkedin":"https://www.linkedin.com/company/catalent-pharma-solutions","twitter":"http://twitter.com/catalentpharma","youtube":"https://youtube.com/user/catalent"},"email_patterns":[{"pattern":"[F].[L]","percentage":98.45},{"pattern":"[L].[F]","percentage":0.4454},{"pattern":"[F1][L]","percentage":0.3919},{"pattern":"[F]","percentage":0.1603},{"pattern":"[L]","percentage":0.1603},{"pattern":"[F1].[L]","percentage":0.1603},{"pattern":"[F][L]","percentage":0.1425},{"pattern":"[F][L1]","percentage":0.0534},{"pattern":"[F]_[L]","percentage":0.0356}],"technologies":["amazon-cloudfront","apache","azure-cdn","crazy-egg","google-analytics","google-font-api","google-tag-manager","jquery","livechat","microsoft-asp-net","microsoft-iis","modernizr","mysql","office-365","openssl","php","red-hat","trackjs","windows-server","wordpress","wp-super-cache"],"technology_categories":["Calendar & Scheduling","Video Conferencing","analytics","caching","cdn","cloud-storage","cms","collaboration","conversion-optimization","database","dot-net-framework","email-service","error-tracking","font-library","heatmap","javascript-library","live-chat","operating-system","productivity","programming-language","ssl","tag-management","web-server","wordpress-plugin"],"industries":["analytical-chemistry","biologics","biotech","clinical-packaging","clinical-supply","diagnostic-substances","drug-delivery","formulation-development","pharmaceutical-supply-chain","pharmaceuticals","respiratory"]}}
# {"result":"success","data":{"name":"Netflix","alternate_name":null,"domain":"netflix.com","domain_name":"netflix","domain_tld":"com","business_type":null,"monthly_visitors":"over-1b","phone_number":"(866) 579-7172","revenue":"over-1b","size":"5k-10k","year_founded":1997,"address":"100 winchester circle","address_name":"Los Gatos","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.226611,"address_lng":-121.9746797,"updated_at":"2020-09-22T15:49:41+00:00","description":"Netflix has been leading the way for digital content since 1997\\\\Netflix is the world's leading Internet television network with over 100 million members in over 190 countries enjoying more than 125 million hours of TV shows and movies per day, including original series, documentaries and feature films. Members can watch as much as they want, anytime, anywhere, on nearly any Internet-connected screen. Members can play, pause and resume watching, all without commercials or commitments.","social_networks":{"angellist":"http://angel.co/netflix","facebook":"https://www.facebook.com/netflix","linkedin":"https://www.linkedin.com/company/netflix","twitter":"http://twitter.com/Netflix"},"email_patterns":[{"pattern":"[F1][L]","percentage":94.2245},{"pattern":"[F][L1]","percentage":3.7854},{"pattern":"[F]","percentage":0.995},{"pattern":"[F][L]","percentage":0.4543},{"pattern":"[F].[L]","percentage":0.2812},{"pattern":"[L]","percentage":0.1514},{"pattern":"[L1][F]","percentage":0.0433},{"pattern":"[F1].[L]","percentage":0.0216},{"pattern":"[F]_[L1]","percentage":0.0216},{"pattern":"[F1][L1]","percentage":0.0216}],"technologies":["bootstrap","g-suite","jquery"],"technology_categories":["Calendar & Scheduling","Video Conferencing","cloud-storage","collaboration","email-service","javascript-library","productivity","ui-framework"],"industries":["consumer-electronics","consumer-internet","entertainment","games","hardware","information-technology","internet","movies"]}}
# {"result":"success","data":{"name":"neoAs","alternate_name":null,"domain":"neteasegames.com","domain_name":"neteasegames","domain_tld":"com","business_type":null,"monthly_visitors":"under-10k","phone_number":null,"revenue":null,"size":null,"year_founded":null,"address":null,"address_name":null,"address_postal_code":null,"address_country_code":null,"address_country":null,"address_lat":null,"address_lng":null,"updated_at":"2020-09-27T10:56:51+00:00","description":"NetEase Games is a leadingprovider of self‐developed PC‐client and mobile games to worldwide users. In partnership with Blizzard Entertainment, Mojang AB (a Microsoft subsidiary) and other global game developers, the company also operates some of the most popular international online games in China. NetEase Games was formally established in 2001 by NetEase, a leading internet technology company in China.","social_networks":{"facebook":"https://facebook.com/neteaseofficial","twitter":"https://twitter.com/neteaseofficial","youtube":"https://youtube.com/channel/uc7fpai77lccwfuc94uhyfgg"},"email_patterns":[],"technologies":["amazon-cloudfront","amazon-s3","apache","google-font-api","jquery","nginx"],"technology_categories":["cdn","font-library","javascript-library","web-server"],"industries":[]}}
# {"result":"success","data":{"name":"NVIDIA","alternate_name":null,"domain":"nvidia.com","domain_name":"nvidia","domain_tld":"com","business_type":null,"monthly_visitors":"100m-500m","phone_number":"(408) 486-2000","revenue":"over-1b","size":"over-10k","year_founded":1993,"address":"2701 san tomas expressway","address_name":"Santa Clara","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3541132,"address_lng":-121.955174,"updated_at":"2020-09-22T15:55:55+00:00","description":"NVIDIA's invention of the GPU in 1999 sparked the growth of the PC gaming market, redefined modern computer graphics, and revolutionized parallel computing. More recently, GPU deep learning ignited modern AI — the next era of computing — with the GPU acting as the brain of computers, robots, and self-driving cars that can perceive and understand the world. Today, NVIDIA is increasingly known as \"the AI computing company.\"","social_networks":{"angellist":"http://angel.co/nvidia","facebook":"http://www.facebook.com/NVIDIA/","linkedin":"https://www.linkedin.com/company/nvidia","twitter":"http://twitter.com/@nvidia"},"email_patterns":[{"pattern":"[F1][L]","percentage":93.7622},{"pattern":"[F][L1]","percentage":3.5942},{"pattern":"[F].[L]","percentage":0.8334},{"pattern":"[L]","percentage":0.573},{"pattern":"[F]","percentage":0.5209},{"pattern":"[F][L]","percentage":0.5079},{"pattern":"[L1][F]","percentage":0.1172},{"pattern":"[F1][L1]","percentage":0.026},{"pattern":"[F1].[L]","percentage":0.013},{"pattern":"[L][F]","percentage":0.013},{"pattern":"[L].[F]","percentage":0.013},{"pattern":"[L][F1]","percentage":0.013},{"pattern":"[F]_[L]","percentage":0.013}],"technologies":["adobe-experience-manager","apache","facebook-social-plugins","font-awesome","google-font-api","google-tag-manager","gsap","handlebars","java","jquery","jquery-ui","lodash","marketo","modernizr","mustache","new-relic"],"technology_categories":["analytics","animation-library","application-performance","cms","email-service","font-library","javascript-library","marketing","marketing-automation","programming-language","social-widget","tag-management","ui-framework","web-server"],"industries":["artificial-intelligence","automotive-technology","cloud-gaming","computer-hardware","consumer-electronics","deep-learning","enterprise-virtualization","gaming","gpu","gpuaccelerated-computing","graphics-processing-units","hardware","high-performance-computing","hpc","information-technology","mobile","parallel-computing","pc-gaming","professional-graphics","robotics","selfdriving-cars","semiconductors","supercomputing","virtual-reality","virtualization","visual-computing","workstations"]}}
# {"result":"success","data":{"name":"NXP Semiconductors","alternate_name":null,"domain":"nxp.com","domain_name":"nxp","domain_tld":"com","business_type":null,"monthly_visitors":"1m-10m","phone_number":null,"revenue":"over-1b","size":"over-10k","year_founded":2006,"address":null,"address_name":"Eindhoven","address_postal_code":null,"address_country_code":"NL","address_country":"Netherlands","address_lat":51.4392648,"address_lng":5.478633,"updated_at":"2020-09-24T12:02:26+00:00","description":"The electronics industry is being driven by four mega trends that are helping shape our society: Energy Efficiency, Connected Devices, Security and Health. Connecting to these trends and enabling Secure Connections for a Smarter World, NXP Semiconductors N.V. (NASDAQ: NXPI) creates solutions that enable Secure Connections for a Smarter World. Building on its expertise in High Performance Mixed Signal electronics, NXP is driving innovation in the application areas Connected Car, Security, Portable & Wearable and Internet of Things. NXP has operations in more than 25 countries, and posted revenue of $5.65 billion in 2014. Find out more at nxp.com.  Additional information can be found by visiting www.nxp.com.","social_networks":{"angellist":"http://angel.co/nxp-semiconductors","facebook":"https://www.facebook.com/pages/NXP-Semiconductors/108346855859456","linkedin":"https://www.linkedin.com/company/nxp-semiconductors","twitter":"https://twitter.com/NXP"},"email_patterns":[{"pattern":"[F].[L]","percentage":98.8356},{"pattern":"[F1].[L]","percentage":0.2541},{"pattern":"[L].[F]","percentage":0.2399},{"pattern":"[L]","percentage":0.1835},{"pattern":"[F].[M].[L]","percentage":0.1411},{"pattern":"[F1][L]","percentage":0.127},{"pattern":"[F]","percentage":0.0565},{"pattern":"[F][L1]","percentage":0.0494},{"pattern":"[F][L]","percentage":0.0353},{"pattern":"[F].[L1]","percentage":0.0212},{"pattern":"[F]_[L]","percentage":0.0212},{"pattern":"[L][F1]","percentage":0.0141}],"technologies":["akamai","apache","azure-cdn","babel","bootstrap","cloudflare","java","jetty","jquery","lodash","nginx"],"technology_categories":["cdn","javascript-compiler","javascript-library","programming-language","ui-framework","web-server"],"industries":["automotive","digital-networking","hardware","identification","information-technology","semiconductors","standard-products","wireless-infrastructure"]}}
# {"result":"success","data":{"name":"Okta","alternate_name":null,"domain":"okta.com","domain_name":"okta","domain_tld":"com","business_type":null,"monthly_visitors":"500m-1b","phone_number":"(888) 722-7871","revenue":"100m-200m","size":"1k-5k","year_founded":2009,"address":"100 1st street","address_name":"San Francisco","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.7790262,"address_lng":-122.419906,"updated_at":"2020-09-22T15:53:23+00:00","description":"Okta is the leading independent provider of identity for the enterprise. The Okta Identity Cloud connects and protects employees of many of the world's largest enterprises. It also securely connects enterprises to their partners, suppliers and customers. With deep integrations to over 5,000 apps, the Okta Identity Cloud enables simple and secure access from any device. \\\\Thousands of customers, including Experian, 20th Century Fox, LinkedIn, Flex, News Corp, Dish Networks, and Adobe trust Okta to work faster, boost revenue and stay secure. \\\\Okta helps customers fulfill their missions faster by making it safe and easy to use the technologies they need to do their most significant work.","social_networks":{"angellist":"http://angel.co/okta","facebook":"http://www.facebook.com/oktaidentity","linkedin":"https://www.linkedin.com/company/okta-inc-","twitter":"http://www.twitter.com/okta"},"email_patterns":[{"pattern":"[F].[L]","percentage":79.23},{"pattern":"[F1][L]","percentage":19.2503},{"pattern":"[F]","percentage":0.8105},{"pattern":"[F]_[L]","percentage":0.304},{"pattern":"[L]","percentage":0.2026},{"pattern":"[F][L1]","percentage":0.2026}],"technologies":["apache","cloudflare","drupal","google-analytics","google-tag-manager","heap","jquery","lodash","mariadb","marketo","new-relic","nginx","pantheon","php","polyfill-io","varnish","vwo"],"technology_categories":["a-b-testing","analytics","application-performance","caching","cdn","cms","database","email-service","heatmap","javascript-library","marketing","marketing-automation","programming-language","push-notifications","session-recording","tag-management","web-hosting","web-server"],"industries":["access-management","cloud","computer-software","idaas","identity-management","mobile-security","mobility-management","saas","single-signon","user-management"]}}
# {"result":"success","data":{"name":"Old Dominion Freight Line","alternate_name":null,"domain":"odfl.com","domain_name":"odfl","domain_tld":"com","business_type":null,"monthly_visitors":"1m-10m","phone_number":null,"revenue":"over-1b","size":"over-10k","year_founded":1934,"address":"500 old dominion way","address_name":"Thomasville","address_postal_code":"27360","address_country_code":"US","address_country":"United States","address_lat":35.8831786,"address_lng":-80.081817,"updated_at":"2020-09-25T04:27:28+00:00","description":"Old Dominion Freight Line, Inc. (NASDAQ: ODFL) is a leading, less-than-truckload (\"LTL\"), union-free company providing premium service to all its customers. OD offers regional, inter-regional and national LTL service. In addition to its core LTL services, the company offers its customers a broad range of logistics services including ground and air expedited transportation, supply chain consulting, transportation management, truckload brokerage, container delivery and warehousing. In addition, Old Dominion offers a consumer product for household moving: OD Household Services. Through strategic partnerships, the company also offers international freight forwarding services throughout the world. Old Dominion's claims ratio and on-time record are among the best in the industry. For 80 years, Old Dominion has been Helping the World Keep Promises.\\\\For career opportunities, visit http://www.odfl.com/Careers/.","social_networks":{"facebook":"https://www.facebook.com/OldDominionFreightLine","instagram":"https://instagram.com/odfl_inc","linkedin":"https://www.linkedin.com/company/old-dominion-freight-line","twitter":"https://twitter.com/odfl_inc"},"email_patterns":[{"pattern":"[F].[L]","percentage":98.4848},{"pattern":"[F1].[L]","percentage":0.7371},{"pattern":"[F1][L]","percentage":0.5324},{"pattern":"[L]","percentage":0.0819},{"pattern":"[F]","percentage":0.041},{"pattern":"[F][L]","percentage":0.041},{"pattern":"[F][L1]","percentage":0.041},{"pattern":"[L][F1]","percentage":0.041}],"technologies":["amazon-cloudfront","amazon-s3","apache","azure-cdn","cloudflare","facebook-social-plugins","google-analytics","google-cloud","google-tag-manager","java","jquery","jquery-ui","lua","microsoft-asp-net","microsoft-iis","nginx","openresty","varnish","windows-server","zurb-foundation"],"technology_categories":["analytics","caching","cdn","cloud-paas","dot-net-framework","javascript-library","operating-system","programming-language","social-widget","tag-management","ui-framework","web-hosting","web-server"],"industries":["home-services","local-services","movers","railroad","shipping-centers","transportation","trucking"]}}
# {"result":"success","data":{"name":"O'reilly Automotive","alternate_name":null,"domain":"oreillyauto.com","domain_name":"oreillyauto","domain_tld":"com","business_type":null,"monthly_visitors":"10m-50m","phone_number":"(541) 736-7472","revenue":"over-1b","size":"over-10k","year_founded":1957,"address":"233 south patterson avenue","address_name":"Springfield","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.2166779,"address_lng":-93.2920373,"updated_at":"2020-09-23T12:55:12+00:00","description":"It started with a father and son – Charles Francis \"C.F.\" and Charles H. \"Chub\" O'Reilly. Together they had the courage and confidence to venture out on their own. Along with 11 others who shared the same desire to offer great customer service and auto parts availability, the doors of O'Reilly Automotive, Inc. opened on Dec. 2, 1957. \\\\Now, more than 60 years later, the 75,000-plus team members at O'Reilly Auto Parts are proud of the company's achievements over the years. \\\\During our early years, we focused on sales and slow and steady growth. At the end of our first year, sales totaled $700,000, and by 1961 volume reached $1.3 million. For the first seven years of operation, there was one store in Springfield, MO, until the second opened in July 1964. In March 1975, annual sales volume rose to $7 million and a 52,000 square-foot facility was built in Springfield for the O'Reilly/Ozark warehouse operation. By that time, the company had nine stores, all located in southwest Missouri. \\\\The long range plans and stability of the company were solidified by a public offering of company stock in April 1993. Since that time, the Company has grown through new store and distribution center openings, as well as numerous mergers and acquisitions. O'Reilly currently operates stores in 47 states, including Alaska and Hawaii, and distribution centers in 27 locations. \\\\Dramatic changes in technology, inventory control, facilities, and sheer size mark the O'Reilly growth and success story. But, it is our spirit of teamwork - how important it was then and how important it remains - that drives our performance. The company's values and culture that started with the original 13 employee/owners remain evident and strong as we expand and develop Team O'Reilly.","social_networks":{"facebook":"https://www.facebook.com/OreillyAutoParts","linkedin":"https://www.linkedin.com/company/o'reilly-auto-parts","twitter":"https://twitter.com/OReillyAuto"},"email_patterns":[{"pattern":"[F1][L]","percentage":99.7123},{"pattern":"[F][L]","percentage":0.1726},{"pattern":"[F].[L]","percentage":0.0384},{"pattern":"[F1].[L]","percentage":0.0384},{"pattern":"[L].[F1]","percentage":0.0192},{"pattern":"[F1][L1]","percentage":0.0192}],"technologies":[],"technology_categories":[],"industries":["auto-parts","automotive","automotive-repair","parking","retail","services","supplies","wholesale"]}}
# {"result":"success","data":{"name":"PACCAR","alternate_name":null,"domain":"paccar.com","domain_name":"paccar","domain_tld":"com","business_type":null,"monthly_visitors":"1m-10m","phone_number":"(425) 468-7877","revenue":"over-1b","size":"over-10k","year_founded":1905,"address":"777 106th avenue northeast","address_name":"Bellevue","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":47.6144219,"address_lng":-122.192337,"updated_at":"2020-09-28T17:37:46+00:00","description":"PACCAR is a global technology leader in the design, manufacture and customer support of premium light-, medium- and heavy-duty trucks under the Kenworth, Peterbilt and DAF nameplates. PACCAR also designs and manufactures advanced diesel engines, provides financial services, information technology, and distributes truck parts related to its principal business.\\\\Kenworth Truck Company builds premium commercial vehicles for sale in the U.S., Canada, Mexico and Australia and for export throughout the world. Peterbilt Motors also designs, manufactures and distributes premium commercial vehicles in the US and Canada. DAF Trucks manufactures trucks in the Netherlands, Belgium, Brasil and the United Kingdom for sale throughout Western and Eastern Europe, and export to Asia, Africa, North and South America.\\\\PACCAR Parts operates a network of parts distribution centers offering aftermarket support to Kenworth, Peterbilt and DAF dealers and customers around the world. Aftermarket support includes customer call centers operating 24 hours a day throughout the year and technologically advanced systems to enhance inventory control and expedite order processing.\\\\PACCAR Financial Services provides finance, lease and insurance services to dealers and customers in 224 countries including a portfolio of more than 175,000 trucks and trailers and total assets in excess of $12 billion. The group includes PACCAR Leasing, a major full-service truck leasing company in North America, with a fleet of over 39,000 vehicles.\\\\Environmental responsibility is one of PACCAR's core values. The company regularly develops new programs to help protect and preserve the environment and PACCAR has established ambitious goals to further reduce emissions and enhance fuel efficiency in its truck models.","social_networks":{"angellist":"http://angel.co/paccar","linkedin":"https://www.linkedin.com/company/paccar","twitter":"https://twitter.com/paccarfinancial"},"email_patterns":[{"pattern":"[F].[L]","percentage":94.8585},{"pattern":"[F1][L]","percentage":4.3788},{"pattern":"[F][L]","percentage":0.3936},{"pattern":"[L].[F]","percentage":0.246},{"pattern":"[F]_[L]","percentage":0.0738},{"pattern":"[L]","percentage":0.0246},{"pattern":"[F].[L1]","percentage":0.0246}],"technologies":["azure-cdn","google-analytics","jquery","microsoft-asp-net","microsoft-iis","modernizr","office-365","windows-server","zurb-foundation"],"technology_categories":["Calendar & Scheduling","Video Conferencing","analytics","cdn","cloud-storage","collaboration","dot-net-framework","email-service","javascript-library","operating-system","productivity","ui-framework","web-server"],"industries":["automotive","car-bodies","corporate-it","daf-trucks","finance","finance-technology","information-technology","kenworth-truck-company","manufacturing","motor-vehicles","paccar-parts"]}}
# {"result":"success","data":{"name":"Palo Alto Networks","alternate_name":null,"domain":"paloaltonetworks.com","domain_name":"paloaltonetworks","domain_tld":"com","business_type":null,"monthly_visitors":"10m-50m","phone_number":"(408) 753-4000","revenue":"200m-1b","size":"5k-10k","year_founded":2005,"address":"3000 tannery way","address_name":"Santa Clara","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3541132,"address_lng":-121.955174,"updated_at":"2020-09-23T13:04:03+00:00","description":"Palo Alto Networks is the next-generation security company, leading a new era in cybersecurity by safely enabling applications and preventing cyber breaches for thousands of organizations worldwide.  Built with an innovative approach and highly differentiated cyber threat prevention capabilities, our game-changing security platform delivers security far superior to legacy or point products, safely enables daily business operations, and protects an organization's most valuable assets.  Find out more at www.paloaltonetworks.com.","social_networks":{"angellist":"http://angel.co/palo-alto-networks","facebook":"http://www.facebook.com/PaloAltoNetworks","linkedin":"https://www.linkedin.com/company/palo-alto-networks","twitter":"http://twitter.com/PaloAltoNtwks","youtube":"https://youtube.com/user/paloaltonetworks"},"email_patterns":[{"pattern":"[F1][L]","percentage":95.8204},{"pattern":"[F].[L]","percentage":3.7124},{"pattern":"[F][L]","percentage":0.2596},{"pattern":"[F]","percentage":0.1298},{"pattern":"[L]","percentage":0.026},{"pattern":"[L][F]","percentage":0.026},{"pattern":"[L1][F]","percentage":0.026}],"technologies":["adobe-experience-manager","akamai","amazon-cloudfront","amazon-s3","apache","azure-cdn","cloudflare","google-analytics","google-cloud","google-tag-manager","java","jquery","microsoft-asp-net","nginx","polyfill-io","ubuntu"],"technology_categories":["analytics","cdn","cloud-paas","cms","dot-net-framework","javascript-library","operating-system","programming-language","tag-management","web-hosting","web-server"],"industries":["communications-hardware","computer","cybersecurity","endpoint-security","enterprise-security-platform","firewall","hardware","information-technology","internet","ips","malware-prevention","network-security","prepackaged-software","security","threat","threat-intelligence","url-filtering"]}}
# {"result":"success","data":{"name":"Paychex","alternate_name":null,"domain":"paychex.com","domain_name":"paychex","domain_tld":"com","business_type":null,"monthly_visitors":"100m-500m","phone_number":"(585) 383-3406","revenue":"over-1b","size":"over-10k","year_founded":1971,"address":"911 panorama trail south","address_name":"Rochester","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":43.157285,"address_lng":-77.615214,"updated_at":"2020-09-22T17:08:21+00:00","description":"Paychex, Inc. (NASDAQ: PAYX) is a leading provider of integrated human capital management solutions for payroll, HR, retirement, and insurance services. By combining its innovative software-as-a-service technology and mobility platform with dedicated, personal service, Paychex empowers small- and medium-sized business owners to focus on the growth and management of their business. Backed by 45 years of industry expertise, Paychex serves approximately 605,000 payroll clients across more than 100 locations and pays one out of every 12 American private sector employees. ","social_networks":{"angellist":"http://angel.co/paychex","facebook":"https://www.facebook.com/Paychex","linkedin":"https://www.linkedin.com/company/paychex","twitter":"http://www.twitter.com/paychex"},"email_patterns":[{"pattern":"[F1][L]","percentage":96.5681},{"pattern":"[F].[L]","percentage":2.0854},{"pattern":"[L1][F]","percentage":0.5911},{"pattern":"[F1][M1][L]","percentage":0.3284},{"pattern":"[F][L]","percentage":0.197},{"pattern":"[F1].[L]","percentage":0.0985},{"pattern":"[L]","percentage":0.0739},{"pattern":"[F]","percentage":0.0328}],"technologies":["acquia-cloud","akka-http","amazon-cloudfront","amazon-ec2","amazon-s3","apache","cloudflare","drupal","express","facebook-social-plugins","google-analytics","google-tag-manager","hotjar","java","jetty","jquery","marketo","new-relic","nginx","node-js","optimizely","php","section-io","varnish"],"technology_categories":["a-b-testing","analytics","application-performance","caching","cdn","cms","conversion-optimization","email-hosting-provider","email-service","feedback-and-survey","heatmap","javascript-library","marketing","marketing-automation","node-js-framework","programming-language","session-recording","social-widget","tag-management","web-server"],"industries":["accountants","benefits-administration","business-insurance","financial-advising","financial-services","group-insurance","human-resources","individual-insurance","insurance","labor","payroll-services","payroll-tax-services","professional-services","retirement-services","tax-services","time","workers-compensation"]}}
# {"result":"success","data":{"name":"Pinduoduo","alternate_name":null,"domain":"pinduoduo.com","domain_name":"pinduoduo","domain_tld":"com","business_type":null,"monthly_visitors":"100m-500m","phone_number":"+86 2 152661300","revenue":"over-1b","size":"1k-5k","year_founded":2015,"address":null,"address_name":"Shanghai","address_postal_code":"200001","address_country_code":"CN","address_country":"China","address_lat":31.2322758,"address_lng":121.4692071,"updated_at":"2020-09-23T06:44:02+00:00","description":"Pinduoduo - Together, More Savings, More Fun","social_networks":{"facebook":"https://facebook.com/pinduoduoinc","linkedin":"https://linkedin.com/company/pinduoduo","twitter":"https://twitter.com/pinduoduoinc"},"email_patterns":[],"technologies":["lua","nginx","openresty"],"technology_categories":["programming-language","web-server"],"industries":["catalog","mail-order-houses"]}}
# {"detail":"No data was returned"}
# {"result":"success","data":{"name":"Pepsi","alternate_name":null,"domain":"pepsico.com","domain_name":"pepsico","domain_tld":"com","business_type":null,"monthly_visitors":"10m-50m","phone_number":null,"revenue":"over-1b","size":"over-10k","year_founded":1965,"address":"700 anderson hill road","address_name":"Town of Harrison","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":41.0195135,"address_lng":-73.71116374834502,"updated_at":"2020-09-25T03:53:54+00:00","description":"PepsiCo is a global food and beverage leader with a product portfolio including 22 brands that generate more than $1 billion each in annual retail sales. Our main businesses – Quaker, Tropicana, Gatorade, Frito-Lay and Pepsi-Cola – make hundreds of enjoyable foods and beverages that are loved throughout the world.\\\\We are focused on delivering sustainable long-term growth while leaving a positive imprint on society and the environment – what we call Performance with Purpose. Our focus includes transforming our portfolio and offering healthier options while making our food system more sustainable and communities more prosperous. In doing so we believe we will pave the way for PepsiCo's future growth and help others thrive.\\\\At PepsiCo, we believe our continued success depends on a diverse workforce and inclusive culture. Our teams reflect the diversity of our communities and consumers. And inclusion is a way of life. In an ever-changing environment, we know that creativity from individuals with varied backgrounds and experiences is critical.\\\\","social_networks":{"angellist":"http://angel.co/pepsi","facebook":"http://www.facebook.com/PepsiCo","instagram":"https://instagram.com/pepsico","linkedin":"https://www.linkedin.com/company/pepsico","twitter":"http://twitter.com/pepsi"},"email_patterns":[{"pattern":"[F].[L]","percentage":99.637},{"pattern":"[L].[F]","percentage":0.0746},{"pattern":"[L]","percentage":0.0729},{"pattern":"[F1][L]","percentage":0.0594},{"pattern":"[F]","percentage":0.0543},{"pattern":"[F1].[L]","percentage":0.0237},{"pattern":"[F][L]","percentage":0.0221},{"pattern":"[F]_[L]","percentage":0.0187},{"pattern":"[F].[L1]","percentage":0.0119}],"technologies":["google-analytics","google-tag-manager","gsap","handlebars","incapsula","jquery","microsoft-asp-net","microsoft-iis","windows-server"],"technology_categories":["analytics","animation-library","cdn","dot-net-framework","javascript-library","operating-system","security","tag-management","web-server"],"industries":["beverages","brand-management","food","fritolay","gatorade","manufacturing","marketing","pepsi","sales","tropicana"]}}
# {"result":"success","data":{"name":"Qualcomm","alternate_name":null,"domain":"qualcomm.com","domain_name":"qualcomm","domain_tld":"com","business_type":null,"monthly_visitors":"10m-50m","phone_number":"(858) 587-1121","revenue":"over-1b","size":"over-10k","year_founded":1985,"address":null,"address_name":"San Diego","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":32.7174202,"address_lng":-117.1627728,"updated_at":"2021-12-14T10:13:55+00:00","description":"Billions, maybe trillions of times a day…\\\\That's how often people around the world likely grab for their smartphone- and all that incredible stuff a phone can do that keeps people reaching for it multiple times a day- Qualcomm invented the stuff that made that stuff possible. \\\\Who is Qualcomm, and what do we do? We are engineers, scientists and business strategists. We come from different countries and diverse cultures, speak different languages and offer unique perspectives. Together, we focus on a single goal—to lead the way to a new era of intelligent, connected devices.\\\\Qualcomm's technologies powered the smartphone revolution by connecting the phone to the Internet, and now we are changing everything about everything else. We pioneered 3G and 4G, propelling mobile to the forefront of the technology world, and now, we are leading the way to 5G that will connect billions more. Our products revolutionize industries from automotive and IoT to healthcare and data-centers, and are allowing millions of devices to connect with each other in new ways never imagined. \\\\We've been called dreamers, inventors, rebels, risk takers, pioneers and geeks.  We dream big. We invent bigger. Most importantly, we often do what many think is impossible in the name of innovation.\\\\For more information, visit https://www.qualcomm.com/.\\\\For Posting Guidelines and Terms, please go to:\\http://bit.ly/1sKRdOT.\\","social_networks":{"angellist":"http://angel.co/qualcomm","facebook":"https://www.facebook.com/QualcommIN","instagram":"https://instagram.com/qualcomm","linkedin":"https://www.linkedin.com/company/qualcomm","twitter":"http://www.twitter.com/Qualcomm","youtube":"https://youtube.com/qualcomm"},"email_patterns":[{"pattern":"[F1][L]","percentage":91.8384},{"pattern":"[F][L1]","percentage":4.0349},{"pattern":"[F].[L]","percentage":1.7994},{"pattern":"[F]","percentage":0.739},{"pattern":"[L]","percentage":0.482},{"pattern":"[L1][F]","percentage":0.3764},{"pattern":"[F][L]","percentage":0.358},{"pattern":"[L][F1]","percentage":0.2984},{"pattern":"[F1][L1]","percentage":0.023},{"pattern":"[F1].[L]","percentage":0.0184},{"pattern":"[L][F]","percentage":0.0138},{"pattern":"[F]_[L]","percentage":0.0138}],"technologies":["amazon-cloudfront","amazon-s3","apache","azure-cdn","drupal","google-tag-manager","gsap","marketo","new-relic","nginx","php","react","tealium","varnish"],"technology_categories":["analytics","animation-library","application-performance","caching","cdn","cms","email-service","javascript-framework","javascript-library","marketing","marketing-automation","programming-language","tag-management","web-server"],"industries":["augmented-reality","display-technology","hardware","information-technology","internet-of-things","location-services","lte","mobile","networking","semiconductors","small-cells","telecommunications","wifi","wireless","wireless-health","wireless-power"]}}
# {"result":"success","data":{"name":"Regeneron","alternate_name":null,"domain":"regeneron.com","domain_name":"regeneron","domain_tld":"com","business_type":null,"monthly_visitors":"100k-500k","phone_number":"(914) 847-7741","revenue":"over-1b","size":"5k-10k","year_founded":1988,"address":"777 old saw mill","address_name":"Town of Greenburgh","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":41.0350625,"address_lng":-73.86485213574096,"updated_at":"2020-09-26T00:55:29+00:00","description":"Get in the Ideas Business. At Regeneron we believe that when the right idea finds the right team, powerful change is possible. As we work together to discover, invent, and develop biopharmaceutical medicines, we're creating whole new ways of thinking about science, manufacturing and commercialization. And whole new ways of thinking about health. So connect with us. Tell us about you. Learn more about our life-changing medicines. And join us, as we build a future we believe in. Please visit www.regeneron.com/social-media-terms for more information on how to engage with Regeneron on social media. \\\\\\An important note about privacy: Regeneron is committed to your privacy and will not ask for sensitive personal information such as social security number, date of birth or bank account details via email or social media. We do not interview candidates on Google Hangouts. Any questions about job listings can be directed to candidatesupport@regeneron.com.","social_networks":{"facebook":"https://www.facebook.com/regeneron","instagram":"https://instagram.com/regeneron","linkedin":"https://www.linkedin.com/company/regeneron-pharmaceuticals","twitter":"http://twitter.com/regeneron"},"email_patterns":[{"pattern":"[F].[L]","percentage":99.299},{"pattern":"[F]","percentage":0.3286},{"pattern":"[L]","percentage":0.1314},{"pattern":"[F][L]","percentage":0.1095},{"pattern":"[F1][L]","percentage":0.0657},{"pattern":"[F1].[L]","percentage":0.0438},{"pattern":"[F][L1]","percentage":0.0219}],"technologies":["apache","bootstrap","cloudflare","drupal","facebook-social-plugins","google-analytics","google-cloud","google-font-api","google-tag-manager","jquery","jquery-ui","nginx","php","varnish"],"technology_categories":["analytics","caching","cdn","cloud-paas","cms","font-library","javascript-library","programming-language","social-widget","tag-management","ui-framework","web-hosting","web-server"],"industries":["biotechnology"]}}
# {"result":"success","data":{"name":"Ross Stores","alternate_name":null,"domain":"rossstores.com","domain_name":"rossstores","domain_tld":"com","business_type":null,"monthly_visitors":"1m-10m","phone_number":"(925) 965-4400","revenue":"over-1b","size":"over-10k","year_founded":1957,"address":"5130 hacienda drive","address_name":"Dublin","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.7021521,"address_lng":-121.9357918,"updated_at":"2020-09-25T01:47:13+00:00","description":"Ross Stores, Inc. website.","social_networks":{"facebook":"https://www.facebook.com/rossdressforless","instagram":"https://instagram.com/rossdressforless","linkedin":"https://www.linkedin.com/company/ross-stores"},"email_patterns":[{"pattern":"[L]","percentage":59.1772},{"pattern":"[L][F]","percentage":16.4557},{"pattern":"[F1].[L]","percentage":11.0759},{"pattern":"[F].[L]","percentage":9.4937},{"pattern":"[F1][L]","percentage":3.1646},{"pattern":"[F]","percentage":0.6329}],"technologies":["amazon-cloudfront","amazon-s3","bootstrap","cloudflare","envoy-proxy","facebook-social-plugins","google-analytics","google-cloud","google-tag-manager","jquery","microsoft-asp-net","microsoft-iis","nginx","windows-server"],"technology_categories":["analytics","cdn","cloud-paas","dot-net-framework","javascript-library","operating-system","reverse-proxy","social-widget","tag-management","ui-framework","web-hosting","web-server"],"industries":["miscellaneous-retail","retail"]}}
# ...
# {"result":"success","data":{"name":"Vertex Pharmaceuticals","alternate_name":null,"domain":"vrtx.com","domain_name":"vrtx","domain_tld":"com","business_type":null,"monthly_visitors":"under-10k","phone_number":"(617) 341-6100","revenue":"over-1b","size":"1k-5k","year_founded":1989,"address":"50 northern avenue","address_name":"Boston","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":42.3602534,"address_lng":-71.0582912,"updated_at":"2020-09-28T15:31:45+00:00","description":"Vertex is a global biotechnology company that invests in scientific innovation to create transformative medicines for people with serious and life-threatening diseases.\\\\We discovered and developed the first medicines to treat the underlying cause of cystic fibrosis (CF), a rare, life-threatening genetic disease. In addition to clinical development programs in CF, Vertex has more than a dozen ongoing research programs focused on the underlying mechanisms of other serious diseases. \\\\Founded in 1989 in Cambridge, Massachusetts, our corporate headquarters is now located in Boston's Innovation District, and our international headquarters is in London, United Kingdom. We currently employ 2,100 people in the United States, Europe, Canada and Australia with nearly two-thirds of our staff dedicated to research and development.\\\\Vertex is consistently recognized as one of the industry's top places to work by Science magazine, The Boston Globe, Boston Business Journal and the San Diego Business Journal. Our research and medicines have also received esteemed recognitions, including the Robert J. Beall Therapeutics Development Award, the Fench Prix Galien and the British Pharmacological Society awards.\\","social_networks":{"angellist":"http://angel.co/vertex-pharmaceuticals","facebook":"https://www.facebook.com/vertexpharmainc","instagram":"https://instagram.com/vertexpharmaceuticals","linkedin":"https://www.linkedin.com/company/vertex-pharmaceuticals","twitter":"http://www.twitter.com/vertexpharma","youtube":"https://youtube.com/channel/ucrnu_qie9exwvqnwkgr1toq/featured"},"email_patterns":[{"pattern":"[F]_[L]","percentage":52.8653},{"pattern":"[F].[L]","percentage":45.6447},{"pattern":"[L]","percentage":0.7736},{"pattern":"[F1][L]","percentage":0.4585},{"pattern":"[F]","percentage":0.086},{"pattern":"[F][L]","percentage":0.086},{"pattern":"[L]_[F]","percentage":0.0573},{"pattern":"[F]-[L]","percentage":0.0287}],"technologies":["amazon-cloudfront","amazon-ecs","amazon-s3","apache","azure-cdn","bootstrap","cloudflare","drupal","google-analytics","google-tag-manager","jquery","lodash","php"],"technology_categories":["analytics","cdn","cms","iaas","javascript-library","programming-language","tag-management","ui-framework","web-server"],"industries":["adrenoleukodystrophy","alpha1-antitrypsin-deficiency","biotechnology","commercial-physical-research","continuous-processing","cystic-fibrosis","life-sciences","pharmaceuticals","polycystic-kidney-disease","sickle-cell-disease","small-molecule","structurebased-drug-design"]}}
# {"result":"success","data":{"name":"Walgreens Boots Alliance","alternate_name":null,"domain":"walgreensbootsalliance.com","domain_name":"walgreensbootsalliance","domain_tld":"com","business_type":null,"monthly_visitors":"10k-50k","phone_number":null,"revenue":null,"size":"over-10k","year_founded":2014,"address":"108 wilmot road","address_name":"Deerfield","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":42.1711365,"address_lng":-87.8445119,"updated_at":"2020-09-28T18:58:11+00:00","description":null,"social_networks":{"instagram":"https://instagram.com/wba_global","linkedin":"https://www.linkedin.com/company/walgreens-boots-alliance","twitter":"https://twitter.com/wba_global"},"email_patterns":[{"pattern":"[F].[L]","percentage":99.0252},{"pattern":"[F][L]","percentage":0.3749},{"pattern":"[F1][L]","percentage":0.2249},{"pattern":"[F]","percentage":0.2},{"pattern":"[F]_[L]","percentage":0.125},{"pattern":"[L]","percentage":0.05}],"technologies":["acquia-cloud","amazon-ec2","apache","drupal","google-analytics","google-font-api","google-tag-manager","jquery","new-relic","nginx","php","polyfill-io","react","varnish"],"technology_categories":["analytics","application-performance","caching","cms","email-hosting-provider","email-service","font-library","javascript-framework","javascript-library","programming-language","tag-management","web-server"],"industries":["pharmaceuticals"]}}
# {"result":"success","data":{"name":"Workday","alternate_name":null,"domain":"workday.com","domain_name":"workday","domain_tld":"com","business_type":null,"monthly_visitors":"10m-50m","phone_number":"(925) 951-9000","revenue":"over-1b","size":"over-10k","year_founded":2005,"address":"6230 stoneridge mall road","address_name":"Pleasanton","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.6624312,"address_lng":-121.8746789,"updated_at":"2020-09-23T13:08:42+00:00","description":"Workday is a leading provider of enterprise cloud applications for finance and human resources. Founded in 2005, Workday delivers financial management, human capital management, and analytics applications designed for the world's largest companies, educational institutions, and government agencies. Organizations ranging from medium-sized businesses to Fortune 50 enterprises have selected Workday.","social_networks":{"angellist":"http://angel.co/workday-1","facebook":"http://www.facebook.com/pages/Workday/118878077237","instagram":"https://instagram.com/workday","linkedin":"https://www.linkedin.com/company/workday","twitter":"http://twitter.com/Workday","youtube":"https://youtube.com/user/workdayvideo"},"email_patterns":[{"pattern":"[F].[L]","percentage":99.4038},{"pattern":"[F1][L]","percentage":0.2087},{"pattern":"[F][L]","percentage":0.1491},{"pattern":"[L]","percentage":0.0894},{"pattern":"[F]","percentage":0.0745},{"pattern":"[F].[L1]","percentage":0.0298},{"pattern":"[F1].[L]","percentage":0.0149},{"pattern":"[L1][F]","percentage":0.0149},{"pattern":"[F]_[L]","percentage":0.0149}],"technologies":["adobe-experience-manager","amazon-cloudfront","amazon-elb","apache","java","jquery","modernizr","nginx","segment"],"technology_categories":["analytics","cdn","cms","javascript-library","load-balancer","programming-language","web-server"],"industries":["computer-software","enterprise-software","expenses","financial-management","grants-management","human-resources","information-technology","payroll","procurement","recruiting","software","time-tracking","workforce-planning-talent-management"]}}
# {"result":"success","data":{"name":"Xcel Energy","alternate_name":null,"domain":"xcelenergy.com","domain_name":"xcelenergy","domain_tld":"com","business_type":null,"monthly_visitors":"10m-50m","phone_number":null,"revenue":null,"size":"over-10k","year_founded":2000,"address":"401 nicollet mall","address_name":"Minneapolis","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":44.9772995,"address_lng":-93.2654692,"updated_at":"2020-09-24T11:16:34+00:00","description":null,"social_networks":{"facebook":"https://www.facebook.com/xcelenergymn","instagram":"https://instagram.com/xcelenergy","linkedin":"https://www.linkedin.com/company/xcel-energy","twitter":"https://twitter.com/xcelenergymn","youtube":"https://youtube.com/xcelenergyvideo"},"email_patterns":[{"pattern":"[F].[L]","percentage":95.4098},{"pattern":"[F].[M1].[L]","percentage":2.2778},{"pattern":"[F1][L]","percentage":1.0354},{"pattern":"[L].[F]","percentage":0.4314},{"pattern":"[L]","percentage":0.2243},{"pattern":"[F]","percentage":0.2071},{"pattern":"[F1].[L]","percentage":0.1553},{"pattern":"[F][L]","percentage":0.1208},{"pattern":"[F][L1]","percentage":0.1035},{"pattern":"[L][F]","percentage":0.0173},{"pattern":"[F]_[L]","percentage":0.0173}],"technologies":["amazon-cloudfront","amazon-ecs","amazon-s3","azure-cdn","google-analytics","google-tag-manager","jquery","jquery-ui","lodash","microsoft-asp-net","microsoft-iis","modernizr","mouse-flow","quantcast","sizmek","varnish","windows-server"],"technology_categories":["advertising","analytics","caching","cdn","conversion-optimization","creative-optimization","dot-net-framework","feedback-and-survey","heatmap","iaas","javascript-library","operating-system","session-recording","tag-management","ui-framework","web-server"],"industries":["utilities"]}}
# {"result":"success","data":{"name":"Zoom Video Communications","alternate_name":null,"domain":"zoom.us","domain_name":"zoom","domain_tld":"us","business_type":null,"monthly_visitors":"over-1b","phone_number":"(888) 799-9666","revenue":"100m-200m","size":"1k-5k","year_founded":2011,"address":"55 almaden boulevard","address_name":"San Jose","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3361905,"address_lng":-121.890583,"updated_at":"2020-09-22T15:49:41+00:00","description":"Zoom unifies cloud video conferencing, simple online meetings, and group messaging into one easy-to-use platform. Our solution offers the best video, audio and screen-sharing experience across Windows PC, Mac, iOS, Android, Zoom Rooms conference room system, and H.323/SIP room systems.\\\\Zoom was founded in 2011 by experienced leaders and engineers from Cisco and WebEx. Every founding engineer has over 10 years of real-time collaboration software experience. Our mission is to develop a people-centric cloud service that transforms the real-time collaboration experience and improves the quality and effectiveness of communications forever. \\\\Zoom has received numerous accolades and awards over the last year including:\\\\- Named New Leader in 2016 Gartner Web Conferencing Magic Quadrant \\- InFlow Analysis Market Compass for Webinar Leader\\- Placed on the Forbes Cloud 100 List\\- JMP Hot 100 Award\\- Aragon Research Hot Vendor Award\\- Let's Do Video Readers' Choice Award\\- Emergence Capital's Emergence Award\\- Frost & Sullivan Entrepreneurial Company of the Year\\- Leader Spot in Aragon Research Globe for Web/Video Conferencing\\- Named Visionary in 2015 Gartner Web Conferencing Magic Quadrant\\- Recognized in Gartner Critical Capabilities for Web Conferencing\\\\Sign up for your free account at http://zoom.us","social_networks":{"angellist":"http://angel.co/zoom-us","facebook":"http://www.facebook.com/zoomwithus","linkedin":"https://www.linkedin.com/company/zoom-video-communications-inc-","twitter":"https://twitter.com/zoom_us"},"email_patterns":[{"pattern":"[F].[L]","percentage":99.4587},{"pattern":"[F1][L]","percentage":0.2706},{"pattern":"[F]","percentage":0.1353},{"pattern":"[F][L]","percentage":0.1353}],"technologies":["bootstrap","g-suite","google-analytics","google-tag-manager","jquery","vue-js"],"technology_categories":["Calendar & Scheduling","Video Conferencing","analytics","cloud-storage","collaboration","email-service","javascript-framework","javascript-library","productivity","tag-management","ui-framework"],"industries":["audio-conferencing","cloud-meetings","information-technology","mobile-collaboration","online-meetings","services","video-conferencing","web-conferencing"]}}
# {"result":"success","data":{"name":"Zscaler","alternate_name":null,"domain":"zscaler.com","domain_name":"zscaler","domain_tld":"com","business_type":null,"monthly_visitors":"50m-100m","phone_number":"(408) 533-0288","revenue":"100m-200m","size":"1k-5k","year_founded":2008,"address":"110 rose orchard way","address_name":"San Jose","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3361905,"address_lng":-121.890583,"updated_at":"2020-09-24T08:13:14+00:00","description":"Zscaler enables the world's leading organizations to securely transform their networks and applications for a mobile and cloud first world. Its flagship services, Zscaler Internet Access and Zscaler Private Access, create fast, secure connections between users and applications, regardless of device, location, or network. Zscaler services are 100% cloud-delivered and offer the simplicity, enhanced security, and improved user experience that traditional appliances or hybrid solutions are unable to match. Used in more than 185 countries, Zscaler operates the world's largest cloud security platform, protecting thousands of enterprises and government agencies from cyberattacks and data loss. \\\\\\Stay Connected:\\LinkedIn: https://www.linkedin.com/company/zscaler\\Twitter:  https://www.twitter.com/zscaler\\Facebook:  https://www.facebook.com/Zscaler/","social_networks":{"angellist":"http://angel.co/zscaler","facebook":"https://www.facebook.com/Zscaler?ref=ts","linkedin":"https://www.linkedin.com/company/zscaler","twitter":"http://www.twitter.com/zscaler","youtube":"https://youtube.com/user/zscalermarketing"},"email_patterns":[{"pattern":"[F1][L]","percentage":93.964},{"pattern":"[F].[L]","percentage":4.1441},{"pattern":"[F]","percentage":1.5315},{"pattern":"[L]","percentage":0.1802},{"pattern":"[F][L]","percentage":0.1802}],"technologies":["acquia-cloud","adroll","akka-http","amazon-ec2","amazon-ecs","amazon-s3","apache","apache-traffic-server","azure-cdn","bootstrap","cloudflare","drupal","facebook-social-plugins","google-analytics","google-cloud","google-font-api","google-tag-manager","jquery","kestrel","marketo","microsoft-asp-net","microsoft-iis","mouse-flow","new-relic","nginx","openssl","php","ubuntu","unix","varnish","windows-server"],"technology_categories":["advertising","analytics","application-performance","caching","cdn","cloud-paas","cms","conversion-optimization","dot-net-framework","email-hosting-provider","email-service","feedback-and-survey","font-library","heatmap","iaas","javascript-library","marketing","marketing-automation","operating-system","programming-language","retargeting","session-recording","social-widget","ssl","tag-management","ui-framework","web-hosting","web-server"],"industries":["advanced-persistent-threat-protection","bandwidth-management","big-data","cloud-internet-security","computer","consumer-internet","data-loss-prevention","data-security","email","enterprise-software","information-technology","internet","malware-analysis","mobile","network-security","next-generation-firewall","protection","security-research","software","ssl-inspection","web-security"]}}

# %%
type(response)
# Out:
# requests.models.Response

# %%
outfile.close()
print("We have the company data we need.")
# Out:
# We have the company data we need.
