# %%
# KERNEL: mlenv

# Import dependencies
import warnings
warnings.filterwarnings("ignore")

# %%
# pip install psycopg2

# %%
#dependencies
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.model_selection import train_test_split
from sqlalchemy import create_engine
from config import db_password

# %%
# # GET Tabled input
# # creating database engine
# db_name = 'Company_Stocks_DB'
# db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/{db_name}"
# engine = create_engine(db_string)
# # read data from PostgreSQL database table and load into Dataframe instance
# stock_df = pd.read_sql("select * from \"view_company_all_star\"", engine);
# # Print the DataFrame
# stock_df.head()

# %%
# Test Data for Initial Model
stock_df = pd.read_csv("../Queries/Testing_Files/company_all_star.csv")
stock_df.head()
# Out:
#   ticker        date                company_name            url  \
# 0    AMD  2020-03-12  Advanced Micro Devices Inc  {url:amd.com}
# 1    AMD  2020-03-15  Advanced Micro Devices Inc  {url:amd.com}
# 2    AMD  2020-03-16  Advanced Micro Devices Inc  {url:amd.com}
# 3    AMD  2020-03-17  Advanced Micro Devices Inc  {url:amd.com}
# 4    AMD  2020-03-18  Advanced Micro Devices Inc  {url:amd.com}
#
#   employee_count  revenue sector    city_name state_name country   latitude  \
# 0         5k-10k  over-1b    TBD  Santa Clara         CA      US  37.233325
# 1         5k-10k  over-1b    TBD  Santa Clara         CA      US  37.233325
# 2         5k-10k  over-1b    TBD  Santa Clara         CA      US  37.233325
# 3         5k-10k  over-1b    TBD  Santa Clara         CA      US  37.233325
# 4         5k-10k  over-1b    TBD  Santa Clara         CA      US  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                  381223        4.028436
# 1        41.0812                  374962        0.946776
# 2        41.1240                  434519        4.205026
# 3        39.6363                  591862        1.062215
# 4        40.2337                  396388        0.657230

# %%
# check dtypes
stock_df.dtypes
# Out:
# ticker                     object
# date                       object
# company_name               object
# url                        object
# employee_count             object
# revenue                    object
# sector                     object
# city_name                  object
# state_name                 object
# country                    object
# latitude                  float64
# longitude                 float64
# open_val                  float64
# high_val                  float64
# low_val                   float64
# close_val                 float64
# volume                    float64
# volume_weight             float64
# number_of_transactions      int64
# percent_change            float64
# dtype: object

# %%
# training model needs to be "int64" for it to be fit, converted all float64s
stock_df[[
    "latitude", 
    "longitude", 
    "open_val", 
    "high_val", 
    "low_val", 
    "close_val", 
    "volume",
    "volume_weight",
    "percent_change"]] = stock_df[[
                                "latitude", 
                                "longitude",
                                "open_val", 
                                "high_val", 
                                "low_val", 
                                "close_val", 
                                "volume",
                                "volume_weight",
                                "percent_change"
                                ]].astype("int")

# %%
# verify .astype() changes
stock_df.dtypes
# Out:
# ticker                    object
# date                      object
# company_name              object
# url                       object
# employee_count            object
# revenue                   object
# sector                    object
# city_name                 object
# state_name                object
# country                   object
# latitude                   int64
# longitude                  int64
# open_val                   int64
# high_val                   int64
# low_val                    int64
# close_val                  int64
# volume                     int64
# volume_weight              int64
# number_of_transactions     int64
# percent_change             int64
# dtype: object

# %%
# need help with which features are to be used and which to drop

# %%
stock_AMD = stock_df.loc[stock_df["ticker"] == "AMD"]
stock_AMD
# Out:
#     ticker        date                company_name            url  \
# 0      AMD  2020-03-12  Advanced Micro Devices Inc  {url:amd.com}
# 1      AMD  2020-03-15  Advanced Micro Devices Inc  {url:amd.com}
# 2      AMD  2020-03-16  Advanced Micro Devices Inc  {url:amd.com}
# 3      AMD  2020-03-17  Advanced Micro Devices Inc  {url:amd.com}
# 4      AMD  2020-03-18  Advanced Micro Devices Inc  {url:amd.com}
# ..     ...         ...                         ...            ...
# 499    AMD  2022-03-06  Advanced Micro Devices Inc  {url:amd.com}
# 500    AMD  2022-03-07  Advanced Micro Devices Inc  {url:amd.com}
# 501    AMD  2022-03-08  Advanced Micro Devices Inc  {url:amd.com}
# 502    AMD  2022-03-09  Advanced Micro Devices Inc  {url:amd.com}
# 503    AMD  2022-03-10  Advanced Micro Devices Inc  {url:amd.com}
#
#     employee_count  revenue sector    city_name state_name country  latitude  \
# 0           5k-10k  over-1b    TBD  Santa Clara         CA      US        37
# 1           5k-10k  over-1b    TBD  Santa Clara         CA      US        37
# 2           5k-10k  over-1b    TBD  Santa Clara         CA      US        37
# 3           5k-10k  over-1b    TBD  Santa Clara         CA      US        37
# 4           5k-10k  over-1b    TBD  Santa Clara         CA      US        37
# ..             ...      ...    ...          ...        ...     ...       ...
# 499         5k-10k  over-1b    TBD  Santa Clara         CA      US        37
# 500         5k-10k  over-1b    TBD  Santa Clara         CA      US        37
# 501         5k-10k  over-1b    TBD  Santa Clara         CA      US        37
# 502         5k-10k  over-1b    TBD  Santa Clara         CA      US        37
# 503         5k-10k  over-1b    TBD  Santa Clara         CA      US        37
#
#      longitude  open_val  high_val  low_val  close_val     volume  \
# 0         -121        42        43       39         43   86689681
# 1         -121        39        43       38         38   84545868
# 2         -121        40        42       38         41   92741881
# 3         -121        39        41       36         39  106949287
# 4         -121        39        41       37         39   88939024
# ..         ...       ...       ...      ...        ...        ...
# 499       -121       108       109      102        102   92599972
# 500       -121       102       109      100        105  135348316
# 501       -121       108       111      106        111  102310329
# 502       -121       108       109      103        106  102557375
# 503       -121       108       108      104        104   87584432
#
#      volume_weight  number_of_transactions  percent_change
# 0               41                  381223               4
# 1               41                  374962               0
# 2               41                  434519               4
# 3               39                  591862               1
# 4               40                  396388               0
# ..             ...                     ...             ...
# 499            105                  659639               5
# 500            105                  845843               2
# 501            109                  602679               2
# 502            105                  639388               2
# 503            105                  542478               3
#
# [504 rows x 20 columns]

# %%
# Create our features 
X = stock_AMD.drop("ticker", axis=1)
X = pd.get_dummies(X)

# Target 
y = stock_AMD["ticker"]

# need to combine ticker and date values into one column in format below
# "AMD 03.17.2022" 

# THEN

# DROP long, lat, company_name, url, ticker & date (once columns are combined)
# bucketing for employee_count and revenue

# %%
# One dataset for geolocation and another for stock behaviour? run each through the model?

# for each record in the the dataframe:
#     move records ticker into new_ticker
#     if new_ticker = prev_ticker:
#         move the ticker value to previous value
#         and...
#         move the record to the processing_dataframe
#     else: # when the new_ticker and the previous_ticker aren't the same,
#           # we have all records in the processing_df for a given ticker
#         call the function that will do the Gradient Boosting Decision Tree Algorithm (GBDT)
# white_check_mark
# eyes
# raised_hands::skin-tone-4





# 9:01
# you have to us the CSV file with only the tickers in it
# New
# 9:03
# # you have to make all the columns a number
# # what can you use to do this? I forget
# #after you have all columns as numbers, then do the following:
# #sort the dataframe by ticker column
# #prime prev_ticker with first record's ticker value in the datafrome
# for each record in the the dataframe:
#     move records ticker into new_ticker
#     if new_ticker = prev_ticker:
#         move the ticker value to previous value
#         and...
#         move the record to the processing_dataframe
#     else: # when the new_ticker and the previous_ticker aren't the same,
#           # we have all records in the processing_df for a given ticker
#         call the function that will do the Gradient Boosting Decision Tree Algorithm (GBDT)

# %%
# FOR LOOP
# prime previous ticker as variable: 

prev_ticker = stock_df[ticker]
    for record in stock_df:
        new_ticker = stock_df[ticker]
        
        if (new_ticker == prev_ticker):
            prev_ticker = stock_df[ticker]
            processing_df.append(record)
        else
            def model_random_forest(processing_df):

# %%
X.describe()
# Out:
#        latitude  longitude    open_val    high_val     low_val   close_val  \
# count     504.0      504.0  504.000000  504.000000  504.000000  504.000000
# mean       37.0     -121.0   89.797619   91.535714   87.827381   89.682540
# std         0.0        0.0   26.974967   27.592294   26.210419   26.900938
# min        37.0     -121.0   39.000000   41.000000   36.000000   38.000000
# 25%        37.0     -121.0   77.000000   78.000000   76.000000   77.000000
# 50%        37.0     -121.0   85.000000   87.000000   83.500000   85.000000
# 75%        37.0     -121.0  106.000000  108.000000  104.000000  106.000000
# max        37.0     -121.0  163.000000  164.000000  156.000000  161.000000
#
#              volume  volume_weight  number_of_transactions  percent_change  \
# count  5.040000e+02     504.000000            5.040000e+02      504.000000
# mean   5.944117e+07      89.720238            3.793248e+05        1.640873
# std    2.970768e+07      26.865601            1.805965e+05        1.834070
# min    1.670591e+07      39.000000            1.218390e+05        0.000000
# 25%    3.932777e+07      77.000000            2.589885e+05        0.000000
# 50%    5.126691e+07      85.000000            3.302930e+05        1.000000
# 75%    6.965402e+07     106.000000            4.383512e+05        3.000000
# max    2.253687e+08     159.000000            1.381840e+06       11.000000
#
#        ...  date_2022-03-09  date_2022-03-10  \
# count  ...       504.000000       504.000000
# mean   ...         0.001984         0.001984
# std    ...         0.044544         0.044544
# min    ...         0.000000         0.000000
# 25%    ...         0.000000         0.000000
# 50%    ...         0.000000         0.000000
# 75%    ...         0.000000         0.000000
# max    ...         1.000000         1.000000
#
#        company_name_Advanced Micro Devices Inc  url_{url:amd.com}  \
# count                                    504.0              504.0
# mean                                       1.0                1.0
# std                                        0.0                0.0
# min                                        1.0                1.0
# 25%                                        1.0                1.0
# 50%                                        1.0                1.0
# 75%                                        1.0                1.0
# max                                        1.0                1.0
#
#        employee_count_5k-10k  revenue_over-1b  sector_TBD  \
# count                  504.0            504.0       504.0
# mean                     1.0              1.0         1.0
# std                      0.0              0.0         0.0
# min                      1.0              1.0         1.0
# 25%                      1.0              1.0         1.0
# 50%                      1.0              1.0         1.0
# 75%                      1.0              1.0         1.0
# max                      1.0              1.0         1.0
#
#        city_name_Santa Clara  state_name_CA  country_US
# count                  504.0          504.0       504.0
# mean                     1.0            1.0         1.0
# std                      0.0            0.0         0.0
# min                      1.0            1.0         1.0
# 25%                      1.0            1.0         1.0
# 50%                      1.0            1.0         1.0
# 75%                      1.0            1.0         1.0
# max                      1.0            1.0         1.0
#
# [8 rows x 522 columns]

# %%
y.value_counts()
# second class is date
# Out:
# AMD    504
# Name: ticker, dtype: int64

# %%
np.unique(y)
# Out:
# array(['AMD'], dtype=object)

# %%
# train the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# random forest classfier
# n_estimator default at 100
random_forest = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
random_forest.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/s0/4pw78f5x71s0c1tjvk4mtcyr0000gn/T/ipykernel_67546/2231655482.py in <module>
#       2 # n_estimator default at 100
#       3 random_forest = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
# ----> 4 random_forest.fit(X_train, y_train)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/imblearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     564                     n_samples_bootstrap=n_samples_bootstrap,
#     565                 )
# --> 566                 for i, (s, t) in enumerate(zip(samplers, trees))
#     567             )
#     568             samplers, trees = zip(*samplers_trees)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/imblearn/ensemble/_forest.py in _local_parallel_build_trees(sampler, tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#      55 ):
#      56     # resample before to fit the tree
# ---> 57     X_resampled, y_resampled = sampler.fit_resample(X, y)
#      58     if sample_weight is not None:
#      59         sample_weight = _safe_indexing(sample_weight, sampler.sample_indices_)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/imblearn/base.py in fit_resample(self, X, y)
#      78
#      79         self.sampling_strategy_ = check_sampling_strategy(
# ---> 80             self.sampling_strategy, y, self._sampling_type
#      81         )
#      82
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/imblearn/utils/_validation.py in check_sampling_strategy(sampling_strategy, y, sampling_type, **kwargs)
#     499     if np.unique(y).size <= 1:
#     500         raise ValueError(
# --> 501             f"The target 'y' needs to have more than 1 class. "
#     502             f"Got {np.unique(y).size} class instead"
#     503         )
#
# ValueError: The target 'y' needs to have more than 1 class. Got 1 class instead

# %%
# confusion matrix
# this matrix is gigantic
y_pred = random_forest.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/s0/4pw78f5x71s0c1tjvk4mtcyr0000gn/T/ipykernel_67546/4009485509.py in <module>
#       1 # confusion matrix
#       2 # this matrix is gigantic
# ----> 3 y_pred = random_forest.predict(X_test)
#       4 confusion_matrix(y_test, y_pred)
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     809
#     810         if self.n_outputs_ == 1:
# --> 811             return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#     812
#     813         else:
#
# AttributeError: 'list' object has no attribute 'take'

# %%
balanced_accuracy_score(y_test, y_pred)
# store score (metrics) THEN
# empty processing_df data frame to star the for loop again

# %%
print(classification_report_imbalanced(y_test, y_pred))

# %%
sorted(zip(X.columns, random_forest.feature_importances_), reverse=True)
