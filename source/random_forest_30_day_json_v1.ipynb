# %%
#dependencies
import warnings
warnings.filterwarnings("ignore")
import json
import pandas as pd
from config import db_password
from sqlalchemy import create_engine
from datetime import datetime, timedelta, date

# %%
# GET Tabled input
# creating database engine
db_name = 'Company_Stocks_DB'
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/{db_name}"
engine = create_engine(db_string)
# read data from PostgreSQL database table and load into Dataframe instance
stock_df = pd.read_sql("select * from \"company_all_star\"", engine);
# sort the dataframe by ticker column
stock_df.sort_values(by=["ticker"])
# Print the DataFrame
stock_df.head()
# ticker, date_val, region, open_val, high_val, low_val, close_val, volume_weight
# Out:
#   ticker    date_val                company_name company_url employee_count  \
# 0    AMD  2020-03-12  Advanced Micro Devices Inc     amd.com         5k-10k
# 1    AMD  2020-03-15  Advanced Micro Devices Inc     amd.com         5k-10k
# 2    AMD  2020-03-16  Advanced Micro Devices Inc     amd.com         5k-10k
# 3    AMD  2020-03-17  Advanced Micro Devices Inc     amd.com         5k-10k
# 4    AMD  2020-03-18  Advanced Micro Devices Inc     amd.com         5k-10k
#
#    revenue      sector    city_name state_name region  ...   latitude  \
# 0  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 1  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 2  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 3  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 4  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                381223.0        4.028436
# 1        41.0812                374962.0        0.946776
# 2        41.1240                434519.0        4.205026
# 3        39.6363                591862.0        1.062215
# 4        40.2337                396388.0        0.657230
#
# [5 rows x 21 columns]

# %%
# save original dataframe as .csv
# stock_df.to_csv("../resources/company_all_star.csv")
# completed

# %%
# save original datafrom as .json
#stock_df.to_json("../resources/company_all_star.json")

# %%
# preserve date column as type object
# stock_df['date'] = stock_df['date_val']

# have the user enter beginning date as yyyy-mm-dd
begin_date = '2022-02-10'
# have the user enter ending date as yyyy-mm-dd
end_date = '2022-03-10'

# Convert the date to datetime64
stock_df['date_val'] = pd.to_datetime(stock_df['date_val'], format='%Y-%m-%d')

begin_df = stock_df.loc[(stock_df['date_val'] >= begin_date)]
end_df = stock_df.loc[(stock_df['date_val'] <= end_date)]

# drop date_val
begin_df.drop(['date_val'], axis=1, inplace=True)
end_df.drop(['date_val'], axis=1, inplace=True)

begin_df.reset_index(drop=True,inplace=True)
begin_df.head()
# Out:
#   ticker                company_name company_url employee_count  revenue  \
# 0    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 1    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 2    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 3    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 4    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
#
#        sector    city_name state_name region country_code   latitude  \
# 0  Technology  Santa Clara         CA      W           US  37.233325
# 1  Technology  Santa Clara         CA      W           US  37.233325
# 2  Technology  Santa Clara         CA      W           US  37.233325
# 3  Technology  Santa Clara         CA      W           US  37.233325
# 4  Technology  Santa Clara         CA      W           US  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635    126.14  127.1699   111.81     113.18  164708241.0
# 1 -121.684635    115.51  118.3700   113.46     114.27  135125910.0
# 2 -121.684635    117.19  121.8800   114.36     121.47  144139671.0
# 3 -121.684635    119.05  119.5400   114.22     117.69  119107831.0
# 4 -121.684635    116.26  116.9800   112.26     112.37   98179641.0
#
#    volume_weight  number_of_transactions  percent_change
# 0       117.6520               1209307.0       10.274298
# 1       116.0441                880606.0        1.073500
# 2       118.5217                812307.0        3.652189
# 3       116.8985                701937.0        1.142377
# 4       114.5982                595580.0        3.345949

# %%
end_df.reset_index(drop=True,inplace=True)
end_df.head()
# Out:
#   ticker                company_name company_url employee_count  revenue  \
# 0    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 1    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 2    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 3    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 4    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
#
#        sector    city_name state_name region country_code   latitude  \
# 0  Technology  Santa Clara         CA      W           US  37.233325
# 1  Technology  Santa Clara         CA      W           US  37.233325
# 2  Technology  Santa Clara         CA      W           US  37.233325
# 3  Technology  Santa Clara         CA      W           US  37.233325
# 4  Technology  Santa Clara         CA      W           US  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                381223.0        4.028436
# 1        41.0812                374962.0        0.946776
# 2        41.1240                434519.0        4.205026
# 3        39.6363                591862.0        1.062215
# 4        40.2337                396388.0        0.657230

# %%
# merge together the beginning and ending dataframes
merged_df = pd.merge(begin_df, end_df, left_index=True, right_index=True)
merged_df
# Out:
#      ticker_x              company_name_x company_url_x employee_count_x  \
# 0         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 1         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 2         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 3         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 4         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# ...       ...                         ...           ...              ...
# 2035       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 2036       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 2037       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 2038       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 2039       ZS                 Zscaler Inc   zscaler.com            1k-5k
#
#       revenue_x    sector_x  city_name_x state_name_x region_x country_code_x  \
# 0       over-1b  Technology  Santa Clara           CA        W             US
# 1       over-1b  Technology  Santa Clara           CA        W             US
# 2       over-1b  Technology  Santa Clara           CA        W             US
# 3       over-1b  Technology  Santa Clara           CA        W             US
# 4       over-1b  Technology  Santa Clara           CA        W             US
# ...         ...         ...          ...          ...      ...            ...
# 2035  100m-200m  Technology     San Jose           CA        W             US
# 2036  100m-200m  Technology     San Jose           CA        W             US
# 2037  100m-200m  Technology     San Jose           CA        W             US
# 2038  100m-200m  Technology     San Jose           CA        W             US
# 2039  100m-200m  Technology     San Jose           CA        W             US
#
#       ...  latitude_y  longitude_y  open_val_y  high_val_y  low_val_y  \
# 0     ...   37.233325  -121.684635       42.20     43.9100      39.60
# 1     ...   37.233325  -121.684635       39.08     43.3700      38.51
# 2     ...   37.233325  -121.684635       40.19     42.8800      38.30
# 3     ...   37.233325  -121.684635       39.54     41.9500      36.75
# 4     ...   37.233325  -121.684635       39.56     41.7000      37.69
# ...   ...         ...          ...         ...         ...        ...
# 2035  ...   47.603832  -122.330062     3157.00   3208.5420    3155.00
# 2036  ...   47.603832  -122.330062     3180.00   3190.6400    3142.20
# 2037  ...   47.603832  -122.330062     3148.01   3156.3841    3110.00
# 2038  ...   47.603832  -122.330062     3120.00   3142.1418    3086.00
# 2039  ...   47.603832  -122.330062     3128.44   3189.9500    3122.08
#
#       close_val_y     volume_y  volume_weight_y  number_of_transactions_y  \
# 0           43.90   86689681.0          41.6701                  381223.0
# 1           38.71   84545868.0          41.0812                  374962.0
# 2           41.88   92741881.0          41.1240                  434519.0
# 3           39.12  106949287.0          39.6363                  591862.0
# 4           39.82   88939024.0          40.2337                  396388.0
# ...           ...          ...              ...                       ...
# 2035      3162.16    3514545.0        3183.9906                  166748.0
# 2036      3182.70    3514954.0        3166.2416                  190280.0
# 2037      3114.21    3654095.0        3131.1142                  211079.0
# 2038      3120.83    3484582.0        3116.6404                  192771.0
# 2039      3165.89    3317494.0        3167.1571                  166014.0
#
#       percent_change_y
# 0             4.028436
# 1             0.946776
# 2             4.205026
# 3             1.062215
# 4             0.657230
# ...                ...
# 2035          0.163446
# 2036          0.084906
# 2037          1.073694
# 2038          0.026603
# 2039          1.197082
#
# [2040 rows x 40 columns]

# %%
# calculate the absolute value of the diffence in the beginning percentage change and the ending percentage change
merged_df['percent_change_difference'] = abs(merged_df['percent_change_y'] - merged_df['percent_change_x'])
merged_df.columns
# Out:
# Index(['ticker_x', 'company_name_x', 'company_url_x', 'employee_count_x',
#        'revenue_x', 'sector_x', 'city_name_x', 'state_name_x', 'region_x',
#        'country_code_x', 'latitude_x', 'longitude_x', 'open_val_x',
#        'high_val_x', 'low_val_x', 'close_val_x', 'volume_x', 'volume_weight_x',
#        'number_of_transactions_x', 'percent_change_x', 'ticker_y',
#        'company_name_y', 'company_url_y', 'employee_count_y', 'revenue_y',
#        'sector_y', 'city_name_y', 'state_name_y', 'region_y', 'country_code_y',
#        'latitude_y', 'longitude_y', 'open_val_y', 'high_val_y', 'low_val_y',
#        'close_val_y', 'volume_y', 'volume_weight_y',
#        'number_of_transactions_y', 'percent_change_y',
#        'percent_change_difference'],
#       dtype='object')

# %%
# drop all *_y's
merged_df.drop(columns = ['ticker_y',
       'company_name_y', 'company_url_y', 'employee_count_y', 'revenue_y',
       'sector_y', 'city_name_y', 'state_name_y', 'region_y', 'country_code_y',
        'open_val_y', 'high_val_y', 'low_val_y',
       'close_val_y', 'volume_y', 'volume_weight_y',
       'number_of_transactions_y', 'percent_change_y'], axis=1, inplace=True)

# %%
merged_df.set_index("company_name_x").head()
# Out:
#                            ticker_x company_url_x employee_count_x revenue_x  \
# company_name_x
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
#
#                               sector_x  city_name_x state_name_x region_x  \
# company_name_x
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
#
#                            country_code_x  latitude_x  ...  high_val_x  \
# company_name_x                                         ...
# Advanced Micro Devices Inc             US   37.233325  ...    127.1699
# Advanced Micro Devices Inc             US   37.233325  ...    118.3700
# Advanced Micro Devices Inc             US   37.233325  ...    121.8800
# Advanced Micro Devices Inc             US   37.233325  ...    119.5400
# Advanced Micro Devices Inc             US   37.233325  ...    116.9800
#
#                             low_val_x  close_val_x     volume_x  \
# company_name_x
# Advanced Micro Devices Inc     111.81       113.18  164708241.0
# Advanced Micro Devices Inc     113.46       114.27  135125910.0
# Advanced Micro Devices Inc     114.36       121.47  144139671.0
# Advanced Micro Devices Inc     114.22       117.69  119107831.0
# Advanced Micro Devices Inc     112.26       112.37   98179641.0
#
#                             volume_weight_x  number_of_transactions_x  \
# company_name_x
# Advanced Micro Devices Inc         117.6520                 1209307.0
# Advanced Micro Devices Inc         116.0441                  880606.0
# Advanced Micro Devices Inc         118.5217                  812307.0
# Advanced Micro Devices Inc         116.8985                  701937.0
# Advanced Micro Devices Inc         114.5982                  595580.0
#
#                             percent_change_x  latitude_y  longitude_y  \
# company_name_x
# Advanced Micro Devices Inc         10.274298   37.233325  -121.684635
# Advanced Micro Devices Inc          1.073500   37.233325  -121.684635
# Advanced Micro Devices Inc          3.652189   37.233325  -121.684635
# Advanced Micro Devices Inc          1.142377   37.233325  -121.684635
# Advanced Micro Devices Inc          3.345949   37.233325  -121.684635
#
#                             percent_change_difference
# company_name_x
# Advanced Micro Devices Inc                   6.245862
# Advanced Micro Devices Inc                   0.126724
# Advanced Micro Devices Inc                   0.552837
# Advanced Micro Devices Inc                   0.080162
# Advanced Micro Devices Inc                   2.688719
#
# [5 rows x 22 columns]

# %%
merged_df.columns
# Out:
# Index(['ticker_x', 'company_name_x', 'company_url_x', 'employee_count_x',
#        'revenue_x', 'sector_x', 'city_name_x', 'state_name_x', 'region_x',
#        'country_code_x', 'latitude_x', 'longitude_x', 'open_val_x',
#        'high_val_x', 'low_val_x', 'close_val_x', 'volume_x', 'volume_weight_x',
#        'number_of_transactions_x', 'percent_change_x', 'latitude_y',
#        'longitude_y', 'percent_change_difference'],
#       dtype='object')

# %%
# merged_df['coordinates_x'] = merged_df['latitude_x'].astype('str') + ", " + merged_df['longitude_x'].astype('str')
# merged_df.drop(['latitude_x', 'longitude_x'], axis=1, inplace=True)

# %%
merged_df.rename(columns={"ticker_x":"ticker",
                         "company_name_x": "company_name",
                         "company_url_x": "company_url",
                         "employee_count_x": "company_count",
                         "revenue_x": "revenue",
                         "sector_x": "sector",
                         "city_name_x":"city_name",
                         "state_name_x":"state_name",
                         "region_x":"region",
                         "country_code_x":"country_code",
                         "open_val_x":"open_val",
                         "high_val_x":"high_val",
                         "low_val_x":"low_val",
                         "close_val_x":"close_val",
                         "volume_x":"volume",
                         "volume_weight_x":"volume_weight",
                         "number_of_transactions_x":"number_of_transactions",
                         "percent_change_x":"percent_change",
                         "percent_change_difference_x":"percent_change_difference",
                         "latitude_x":"latitude",
                         "longitude_x":"longitude"}, inplace=True)

# %%
# month_dict = merged_df.to_dict(orient="records")
# month_dict[0]

merged_df.columns
# Out:
# Index(['ticker', 'company_name', 'company_url', 'company_count', 'revenue',
#        'sector', 'city_name', 'state_name', 'region', 'country_code',
#        'latitude', 'longitude', 'open_val', 'high_val', 'low_val', 'close_val',
#        'volume', 'volume_weight', 'number_of_transactions', 'percent_change',
#        'latitude_y', 'longitude_y', 'percent_change_difference'],
#       dtype='object')

# %%
def df_to_geojson(merged_df, properties, lat='latitude', long='longitude', pc='percent_change', location='city_name', state='state_name'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in merged_df.iterrows():
        feature = {'type':'Feature',
                   'properties':{'mag':[row[pc]], 'place':[row[location]]},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[long],row[lat]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
cols = ['company_name', 'city_name', 
        'state_name', 'region', 'country_code', 
        'percent_change', 'longitude','latitude']
geojson = df_to_geojson(merged_df, cols)

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'mag': [10.2742983986047],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 10.2742983986047,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.07350012985889],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.07350012985889,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.6521887533066],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.6521887533066,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.14237715245695],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.14237715245695,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.34594873559264],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.34594873559264,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0614574187884174],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0614574187884174,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.32966079639109],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.32966079639109,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.5076660988075],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 6.5076660988075,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [11.5244835501148],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 11.5244835501148,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.32878115397747],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.32878115397747,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.51849389078215],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.51849389078215,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.94841821303033],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 6.94841821303033,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.43353251926908],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.43353251926908,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.20612884110725],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.20612884110725,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.20535714285715],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.20535714285715,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.14143554777481],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.14143554777481,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.64565703725318],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.64565703725318,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.43519970482428],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.43519970482428,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.23160988153183],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.23160988153183,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.5512808656247],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.5512808656247,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.81000964010283],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.81000964010283,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.171174978867287],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.171174978867287,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.628702202561191],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.628702202561191,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.254992287270318],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.254992287270318,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.26119119076806],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.26119119076806,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.51653622272123],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.51653622272123,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.442829567389587],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.442829567389587,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.09352807182098],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.09352807182098,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [10.8053226307365],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 10.8053226307365,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0322310320376532],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0322310320376532,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.14186851211073],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.14186851211073,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.282051282051281],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.282051282051281,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.161037420011016],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.161037420011016,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.5201647647269],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.5201647647269,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.737667127708625],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.737667127708625,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.00026303099382],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.00026303099382,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.226584356431069],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.226584356431069,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.59305993690852],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.59305993690852,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.28856705945849],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.28856705945849,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.29500068234545],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.29500068234545,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.00756665242511],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.00756665242511,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.81840004801056],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.81840004801056,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.13486005089059],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.13486005089059,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.68044532936986],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.68044532936986,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.70308274743105],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.70308274743105,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.97348274714301],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.97348274714301,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.00278859001916],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.00278859001916,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [9.57632736696198],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 9.57632736696198,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [12.002830856334],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 12.002830856334,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.61835991460504],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.61835991460504,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.280277374617],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.280277374617,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.318873314289504],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.318873314289504,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.31190975865688],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.31190975865688,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.1937725004737],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.1937725004737,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.35252371161373],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.35252371161373,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [9.24827586206896],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 9.24827586206896,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [7.97690496087518],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 7.97690496087518,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.98033418139311],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.98033418139311,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.53105632832944],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.53105632832944,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.83273859728801],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.83273859728801,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.64888905711798],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 3.64888905711798,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.95195189313066],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 0.95195189313066,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.57087378640777],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 2.57087378640777,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0399110553623423],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 0.0399110553623423,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.69474674190515],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 3.69474674190515,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.06739678193758],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 1.06739678193758,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.314682475231446],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 0.314682475231446,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.75421594503656],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 2.75421594503656,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [8.65807332792693],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 8.65807332792693,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.25442010232907],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 1.25442010232907,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.49224113981823],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 1.49224113981823,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.52536709059815],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 1.52536709059815,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.78751707346043],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 1.78751707346043,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.74242847452217],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 4.74242847452217,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.1694258393361],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 2.1694258393361,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.12715517241379],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 6.12715517241379,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.48604651162791],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 3.48604651162791,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.03822538202299],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 2.03822538202299,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.424965559109906],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 0.424965559109906,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [8.55623516523644],
#     'place': ['Tempe'],
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 8.55623516523644,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.0613241853407],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 3.0613241853407,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.25105600622072],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 2.25105600622072,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.694772707805251],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 0.694772707805251,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.48276050208454],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 1.48276050208454,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.20903468946416],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 2.20903468946416,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.86367158736843],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 1.86367158736843,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.186737640260913],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 0.186737640260913,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.49949060504252],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 4.49949060504252,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [8.23849110574774],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 8.23849110574774,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.15111258718034],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 2.15111258718034,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.746596686895202],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 0.746596686895202,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.04136316762968],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 1.04136316762968,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.797817685234909],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 0.797817685234909,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.6689539280213],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 3.6689539280213,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.0315373167798],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 1.0315373167798,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.49388594196372],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 5.49388594196372,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.489451908972192],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 0.489451908972192,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.158422939068103],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 0.158422939068103,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.777362116896046],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 0.777362116896046,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.70768078783482],
#     'place': ['Seattle'],
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 2.70768078783482,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.140031507089104],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.140031507089104,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.03261109394996],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.03261109394996,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.471111111111112],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.471111111111112,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.362464760370521],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.362464760370521,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0903016073686189],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0903016073686189,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0905100239851512],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0905100239851512,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.294437398079365],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.294437398079365,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.754445841566376],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.754445841566376,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.155300781071577],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.155300781071577,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.04054114791676],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.04054114791676,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.09360353524081],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.09360353524081,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0310724431818152],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0310724431818152,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.57749733380733],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.57749733380733,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.762300762300758],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.762300762300758,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.957954052882535],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.957954052882535,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.32733797397208],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.32733797397208,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.17808043445725],
#     'place': ['Thousand Oaks'],
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
# ...
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.709515859766284,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.55136268343814],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.55136268343814,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.353724511027871],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.353724511027871,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.605933974091097],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.605933974091097,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.48971638882875],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.48971638882875,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.15120655302192],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.15120655302192,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.42369020501139],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 6.42369020501139,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.66204986149585],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.66204986149585,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.48936170212767],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.48936170212767,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.51451409339503],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.51451409339503,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.84090909090908],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.84090909090908,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.518887505188875],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.518887505188875,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.47772852016045],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.47772852016045,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.677012811165509],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.677012811165509,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.398406374501987],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.398406374501987,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.61123734765543],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.61123734765543,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.33220554028336],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.33220554028336,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.79957582184518],
#     'place': ['Mountain View'],
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.79957582184518,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.28545909253305],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.28545909253305,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.32241578692133],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.32241578692133,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.8521962286607],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.8521962286607,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.414472308306548],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.414472308306548,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.17887173215104],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.17887173215104,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.31427882538503],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.31427882538503,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.691767549434291],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.691767549434291,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.06393445955561],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.06393445955561,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [8.54366812227074],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 8.54366812227074,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.377281325085624],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.377281325085624,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.933505972767515],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.933505972767515,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.58570138407578],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.58570138407578,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.94211094871957],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.94211094871957,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.56013465265735],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.56013465265735,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.24466345234808],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.24466345234808,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.77958726465901],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.77958726465901,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.862167278698988],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.862167278698988,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.80949877322117],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.80949877322117,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.69075301532109],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.69075301532109,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.98846078195686],
#     'place': ['Mountain View'],
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.98846078195686,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   ...]}

# %%
#month_json = json.dumps(month_dict, indent=2)

# %%
with open("../resources/daily_stock_map.geojson", "w") as outfile:
    json.dump(geojson, outfile)

# %%
# file_path = open("../resources/random_tree_monthly_stocks.json")
# rforest_json = json.load(file_path)
# rforest_json
