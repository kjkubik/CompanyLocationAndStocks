# %%
import json
import pandas as pd

# %%
stock_df = pd.read_csv("../resources/company_all_star.csv")
stock_df.head()
# Out:
#    Unnamed: 0 ticker    date_val                company_name company_url  \
# 0           0    AMD  2020-03-12  Advanced Micro Devices Inc     amd.com
# 1           1    AMD  2020-03-15  Advanced Micro Devices Inc     amd.com
# 2           2    AMD  2020-03-16  Advanced Micro Devices Inc     amd.com
# 3           3    AMD  2020-03-17  Advanced Micro Devices Inc     amd.com
# 4           4    AMD  2020-03-18  Advanced Micro Devices Inc     amd.com
#
#   employee_count  revenue      sector    city_name state_name  ...   latitude  \
# 0         5k-10k  over-1b  Technology  Santa Clara         CA  ...  37.233325
# 1         5k-10k  over-1b  Technology  Santa Clara         CA  ...  37.233325
# 2         5k-10k  over-1b  Technology  Santa Clara         CA  ...  37.233325
# 3         5k-10k  over-1b  Technology  Santa Clara         CA  ...  37.233325
# 4         5k-10k  over-1b  Technology  Santa Clara         CA  ...  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                381223.0        4.028436
# 1        41.0812                374962.0        0.946776
# 2        41.1240                434519.0        4.205026
# 3        39.6363                591862.0        1.062215
# 4        40.2337                396388.0        0.657230
#
# [5 rows x 22 columns]

# %%
# save original dataframe as .csv
# stock_df.to_csv("../resources/company_all_star.csv")
# completed

# %%
#"geometry":{"type":"Point","coordinates":[-145.39,63.339,24.2]},"id":"ak022438ahl4"},

# %%
stock_df.columns
# Out:
# Index(['Unnamed: 0', 'ticker', 'date_val', 'company_name', 'company_url',
#        'employee_count', 'revenue', 'sector', 'city_name', 'state_name',
#        'region', 'country_code', 'latitude', 'longitude', 'open_val',
#        'high_val', 'low_val', 'close_val', 'volume', 'volume_weight',
#        'number_of_transactions', 'percent_change'],
#       dtype='object')

# %%
stock_df.drop(columns=['Unnamed: 0', 'ticker','company_url','revenue','employee_count',
                       'open_val','high_val','low_val', 'close_val',
                       'volume','volume_weight','number_of_transactions',
                        ], axis=1, inplace=True)
stock_df = stock_df.drop_duplicates(subset="company_name")
stock_df.reset_index(inplace=True)
stock_df.drop(columns="index", axis=1, inplace=True)
stock_df.head()
# Out:
#      date_val                         company_name      sector      city_name  \
# 0  2020-03-12           Advanced Micro Devices Inc  Technology    Santa Clara
# 1  2020-03-12                           Adobe Inc.  Technology       San Jose
# 2  2020-06-02  American Electric Power Company Inc      Energy       Columbus
# 3  2020-12-09                           Airbnb Inc  Technology  San Francisco
# 4  2020-03-12                 Align Technology Inc  Technology          Tempe
#
#   state_name region country_code   latitude   longitude  percent_change
# 0         CA      W           US  37.233325 -121.684635        4.028436
# 1         CA      W           US  37.336191 -121.890583        7.229609
# 2         OH     MW           US  39.962260  -83.000707        0.787858
# 3         CA      W           US  37.779026 -122.419906        0.883562
# 4         AZ     SW           US  33.425506 -111.940009        3.094737

# %%
stock_df.set_index("company_name").head()
# Out:
#                                        date_val      sector      city_name  \
# company_name
# Advanced Micro Devices Inc           2020-03-12  Technology    Santa Clara
# Adobe Inc.                           2020-03-12  Technology       San Jose
# American Electric Power Company Inc  2020-06-02      Energy       Columbus
# Airbnb Inc                           2020-12-09  Technology  San Francisco
# Align Technology Inc                 2020-03-12  Technology          Tempe
#
#                                     state_name region country_code   latitude  \
# company_name
# Advanced Micro Devices Inc                  CA      W           US  37.233325
# Adobe Inc.                                  CA      W           US  37.336191
# American Electric Power Company Inc         OH     MW           US  39.962260
# Airbnb Inc                                  CA      W           US  37.779026
# Align Technology Inc                        AZ     SW           US  33.425506
#
#                                       longitude  percent_change
# company_name
# Advanced Micro Devices Inc          -121.684635        4.028436
# Adobe Inc.                          -121.890583        7.229609
# American Electric Power Company Inc  -83.000707        0.787858
# Airbnb Inc                          -122.419906        0.883562
# Align Technology Inc                -111.940009        3.094737

# %%
# stock_df['coordinates'] = stock_df['latitude'].astype('str') + ", " + stock_df['longitude'].astype('str')
# stock_df.drop(['latitude', 'longitude'], axis=1, inplace=True)

# %%
stock_df.head()
# Out:
#      date_val                         company_name      sector      city_name  \
# 0  2020-03-12           Advanced Micro Devices Inc  Technology    Santa Clara
# 1  2020-03-12                           Adobe Inc.  Technology       San Jose
# 2  2020-06-02  American Electric Power Company Inc      Energy       Columbus
# 3  2020-12-09                           Airbnb Inc  Technology  San Francisco
# 4  2020-03-12                 Align Technology Inc  Technology          Tempe
#
#   state_name region country_code   latitude   longitude  percent_change
# 0         CA      W           US  37.233325 -121.684635        4.028436
# 1         CA      W           US  37.336191 -121.890583        7.229609
# 2         OH     MW           US  39.962260  -83.000707        0.787858
# 3         CA      W           US  37.779026 -122.419906        0.883562
# 4         AZ     SW           US  33.425506 -111.940009        3.094737

# %%
# def df_to_geojson(stock_df, properties, lat='latitude', long='longitude', pc='percent_change', location='city_name' + ', ' + 'state_name'):
def df_to_geojson(stock_df, properties, lat='latitude', long='longitude', pc='percent_change', location='city_name', state='state_name'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in stock_df.iterrows():
        feature = {'type':'Feature',
                   'properties':{'mag':[row[pc]], 'place':[row[location]]},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[long],row[lat]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
cols = ['date_val', 'company_name', 'city_name', 'state_name', 'sector', 'region', 'country_code', 'percent_change', 'longitude', 'latitude']
geojson = df_to_geojson(stock_df, cols)

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'mag': [4.02843601895734],
#     'place': ['Santa Clara'],
#     'date_val': '2020-03-12',
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.02843601895734,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [7.22960879570442],
#     'place': ['San Jose'],
#     'date_val': '2020-03-12',
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 7.22960879570442,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.787857722164283],
#     'place': ['Columbus'],
#     'date_val': '2020-06-02',
#     'company_name': 'American Electric Power Company Inc',
#     'city_name': 'Columbus',
#     'state_name': 'OH',
#     'sector': 'Energy',
#     'region': 'MW',
#     'country_code': 'US',
#     'percent_change': 0.787857722164283,
#     'longitude': -83.0007065,
#     'latitude': 39.9622601},
#    'geometry': {'type': 'Point', 'coordinates': [-83.0007065, 39.9622601]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.883561643835611],
#     'place': ['San Francisco'],
#     'date_val': '2020-12-09',
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.883561643835611,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.09473684210526],
#     'place': ['Tempe'],
#     'date_val': '2020-03-12',
#     'company_name': 'Align Technology Inc',
#     'city_name': 'Tempe',
#     'state_name': 'AZ',
#     'sector': 'Technology',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 3.09473684210526,
#     'longitude': -111.9400091,
#     'latitude': 33.4255056},
#    'geometry': {'type': 'Point', 'coordinates': [-111.9400091, 33.4255056]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.70940170940171],
#     'place': ['Seattle'],
#     'date_val': '2020-03-12',
#     'company_name': 'Amazon.com Inc',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'sector': 'Technology',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 1.70940170940171,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.50295109612142],
#     'place': ['Thousand Oaks'],
#     'date_val': '2020-03-12',
#     'company_name': 'Amgen Inc',
#     'city_name': 'Thousand Oaks',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 6.50295109612142,
#     'longitude': -118.8375937,
#     'latitude': 34.1705609},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8375937, 34.1705609]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.17495784148399],
#     'place': ['Norwood'],
#     'date_val': '2020-03-12',
#     'company_name': 'Analog Devices Inc',
#     'city_name': 'Norwood',
#     'state_name': 'MA',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 5.17495784148399,
#     'longitude': -71.1994976,
#     'latitude': 42.194543},
#    'geometry': {'type': 'Point', 'coordinates': [-71.1994976, 42.194543]}},
#   {'type': 'Feature',
#    'properties': {'mag': [9.49767441860465],
#     'place': ['Canonsburg'],
#     'date_val': '2020-03-12',
#     'company_name': 'ANSYS Inc',
#     'city_name': 'Canonsburg',
#     'state_name': 'PA',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 9.49767441860465,
#     'longitude': -80.1872797,
#     'latitude': 40.2625702},
#    'geometry': {'type': 'Point', 'coordinates': [-80.1872797, 40.2625702]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.93789875042472],
#     'place': ['Capertino'],
#     'date_val': '2020-03-12',
#     'company_name': 'Apple Inc',
#     'city_name': 'Capertino',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.93789875042472,
#     'longitude': -115.245979,
#     'latitude': 36.167269},
#    'geometry': {'type': 'Point', 'coordinates': [-115.245979, 36.167269]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.56133141565646],
#     'place': ['Santa Clara'],
#     'date_val': '2020-03-12',
#     'company_name': 'Applied Materials Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.56133141565646,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0427915661713272],
#     'place': ['Veldhoven'],
#     'date_val': '2020-03-12',
#     'company_name': 'ASML Holding NV',
#     'city_name': 'Veldhoven',
#     'state_name': 'NL',
#     'sector': 'Technology',
#     'region': 'NL',
#     'country_code': 'Netherlands',
#     'percent_change': 0.0427915661713272,
#     'longitude': 5.392731058,
#     'latitude': 51.40770635},
#    'geometry': {'type': 'Point', 'coordinates': [5.392731058, 51.40770635]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.02119758626025],
#     'place': ['Sydney'],
#     'date_val': '2020-03-12',
#     'company_name': 'Atlassian Corporation PLC',
#     'city_name': 'Sydney',
#     'state_name': 'AUS',
#     'sector': 'Technology',
#     'region': 'AU',
#     'country_code': 'Australia',
#     'percent_change': 1.02119758626025,
#     'longitude': 150.9983167,
#     'latitude': -33.91840985},
#    'geometry': {'type': 'Point', 'coordinates': [150.9983167, -33.91840985]}},
#   {'type': 'Feature',
#    'properties': {'mag': [8.23972602739726],
#     'place': ['San Rafael'],
#     'date_val': '2020-03-12',
#     'company_name': 'Autodesk Inc',
#     'city_name': 'San Rafael',
#     'state_name': 'CA',
#     'sector': 'Healthcare',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 8.23972602739726,
#     'longitude': -122.5310874,
#     'latitude': 37.9735346},
#    'geometry': {'type': 'Point', 'coordinates': [-122.5310874, 37.9735346]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.57894736842105],
#     'place': ['San Monica'],
#     'date_val': '2020-03-12',
#     'company_name': 'Activision Blizzard Inc',
#     'city_name': 'San Monica',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.57894736842105,
#     'longitude': -118.3845421,
#     'latitude': 34.084745},
#    'geometry': {'type': 'Point', 'coordinates': [-118.3845421, 34.084745]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.48215198189648],
#     'place': ['Roseland'],
#     'date_val': '2020-03-12',
#     'company_name': 'Automatic Data Processing Inc',
#     'city_name': 'Roseland',
#     'state_name': 'NJ',
#     'sector': 'Consumer Discretionary',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 5.48215198189648,
#     'longitude': -74.2937595,
#     'latitude': 40.8206555},
#    'geometry': {'type': 'Point', 'coordinates': [-74.2937595, 40.8206555]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.70796247293722],
#     'place': ['Cambridge'],
#     'date_val': '2020-03-12',
#     'company_name': 'AstraZeneca PLC',
#     'city_name': 'Cambridge',
#     'state_name': 'UK',
#     'sector': 'Healthcare',
#     'region': 'GB',
#     'country_code': 'UK',
#     'percent_change': 1.70796247293722,
#     'longitude': 0.1186637,
#     'latitude': 52.2055314},
#    'geometry': {'type': 'Point', 'coordinates': [0.1186637, 52.2055314]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.86465932019246],
#     'place': ['San Jose'],
#     'date_val': '2020-03-12',
#     'company_name': 'Broadcom Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.86465932019246,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.22118231305509],
#     'place': ['Beijing'],
#     'date_val': '2020-03-12',
#     'company_name': 'Baidu Inc',
#     'city_name': 'Beijing',
#     'state_name': 'CN',
#     'sector': 'Technology',
#     'region': 'CH',
#     'country_code': 'CH',
#     'percent_change': 4.22118231305509,
#     'longitude': 116.3912757,
#     'latitude': 39.906217},
#    'geometry': {'type': 'Point', 'coordinates': [116.3912757, 39.906217]}},
#   {'type': 'Feature',
#    'properties': {'mag': [9.33939958443792],
#     'place': ['Cambridge'],
#     'date_val': '2020-03-12',
#     'company_name': 'Biogen Inc',
#     'city_name': 'Cambridge',
#     'state_name': 'MA',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 9.33939958443792,
#     'longitude': -71.1056157,
#     'latitude': 42.3750997},
#    'geometry': {'type': 'Point', 'coordinates': [-71.1056157, 42.3750997]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.625],
#     'place': ['Novato'],
#     'date_val': '2020-03-12',
#     'company_name': 'Biomarin Pharmaceutical Inc',
#     'city_name': 'Novato',
#     'state_name': 'CA',
#     'sector': 'Healthcare',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.625,
#     'longitude': -122.5681191,
#     'latitude': 38.1061979},
#    'geometry': {'type': 'Point', 'coordinates': [-122.5681191, 38.1061979]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.32330939557151],
#     'place': ['Norwalk'],
#     'date_val': '2020-03-12',
#     'company_name': 'Booking Holdings Inc',
#     'city_name': 'Norwalk',
#     'state_name': 'CT',
#     'sector': 'Healthcare',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 6.32330939557151,
#     'longitude': -73.4078968,
#     'latitude': 41.1175966},
#    'geometry': {'type': 'Point', 'coordinates': [-73.4078968, 41.1175966]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.38124156545209],
#     'place': ['San Jose'],
#     'date_val': '2020-03-12',
#     'company_name': 'Cadence Design Systems Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.38124156545209,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.72684106790897],
#     'place': ['Stamford'],
#     'date_val': '2020-03-12',
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'sector': 'Technology',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 1.72684106790897,
#     'longitude': -73.5387341,
#     'latitude': 41.0534302},
#    'geometry': {'type': 'Point', 'coordinates': [-73.5387341, 41.0534302]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.25730508239857],
#     'place': ['Dallas'],
#     'date_val': '2020-03-12',
#     'company_name': 'Copart Inc',
#     'city_name': 'Dallas',
#     'state_name': 'TX',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 2.25730508239857,
#     'longitude': -96.7968559,
#     'latitude': 32.7762719},
#    'geometry': {'type': 'Point', 'coordinates': [-96.7968559, 32.7762719]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.877192982456144],
#     'place': ['Austin'],
#     'date_val': '2020-03-12',
#     'company_name': 'CrowdStrike Holdings Inc',
#     'city_name': 'Austin',
#     'state_name': 'TX',
#     'sector': 'Industrials',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 0.877192982456144,
#     'longitude': -97.7436995,
#     'latitude': 30.2711286},
#    'geometry': {'type': 'Point', 'coordinates': [-97.7436995, 30.2711286]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.42872454448018],
#     'place': ['Cincinnati'],
#     'date_val': '2020-03-12',
#     'company_name': 'Cintas Corp',
#     'city_name': 'Cincinnati',
#     'state_name': 'OH',
#     'sector': 'Consumer Staples',
#     'region': 'MW',
#     'country_code': 'US',
#     'percent_change': 4.42872454448018,
#     'longitude': -84.5124602,
#     'latitude': 39.1014537},
#    'geometry': {'type': 'Point', 'coordinates': [-84.5124602, 39.1014537]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.99260943718022],
#     'place': ['San Jose'],
#     'date_val': '2020-03-12',
#     'company_name': 'Cisco Systems Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 6.99260943718022,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [8.55644493513663],
#     'place': ['Tupelo'],
#     'date_val': '2020-03-12',
#     'company_name': 'Comcast Corp',
#     'city_name': 'Tupelo',
#     'state_name': 'MS',
#     'sector': 'Communication Services',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 8.55644493513663,
#     'longitude': -88.7033859,
#     'latitude': 34.2576067},
#    'geometry': {'type': 'Point', 'coordinates': [-88.7033859, 34.2576067]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.65325624069522],
#     'place': ['Issaquah'],
#     'date_val': '2020-03-12',
#     'company_name': 'Costco Wholesale Corp',
#     'city_name': 'Issaquah',
#     'state_name': 'WA',
#     'sector': 'Consumer Discretionary',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 4.65325624069522,
#     'longitude': -122.0432974,
#     'latitude': 47.5348778},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0432974, 47.5348778]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.54867707730456],
#     'place': ['Jacksonville'],
#     'date_val': '2020-03-12',
#     'company_name': 'CSX Corp',
#     'city_name': 'Jacksonville',
#     'state_name': 'FL',
#     'sector': 'Communication Services',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 2.54867707730456,
#     'longitude': -81.655651,
#     'latitude': 30.3321838},
#    'geometry': {'type': 'Point', 'coordinates': [-81.655651, 30.3321838]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.95698508041077],
#     'place': ['Teaneck'],
#     'date_val': '2020-03-12',
#     'company_name': 'Cognizant Technology Solutions Corp',
#     'city_name': 'Teaneck',
#     'state_name': 'NJ',
#     'sector': 'Industrials',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 1.95698508041077,
#     'longitude': -74.0072568,
#     'latitude': 40.8860164},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0072568, 40.8860164]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.05555555555556],
#     'place': ['New York'],
#     'date_val': '2020-03-12',
#     'company_name': 'Datadog Inc',
#     'city_name': 'New York',
#     'state_name': 'NY',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 2.05555555555556,
#     'longitude': -74.0060152,
#     'latitude': 40.7127281},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0060152, 40.7127281]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.06584910690482],
#     'place': ['San Francisco'],
#     'date_val': '2020-03-12',
#     'company_name': 'DocuSign Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.06584910690482,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.79868913857677],
#     'place': ['San Diego'],
#     'date_val': '2020-03-12',
#     'company_name': 'Dexcom Inc',
#     'city_name': 'San Diego',
#     'state_name': 'CA',
#     'sector': 'Healthcare',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.79868913857677,
#     'longitude': -117.1627728,
#     'latitude': 32.7174202},
#    'geometry': {'type': 'Point', 'coordinates': [-117.1627728, 32.7174202]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.0073740270381],
#     'place': ['Chesapeake'],
#     'date_val': '2020-03-12',
#     'company_name': 'Dollar Tree Inc',
#     'city_name': 'Chesapeake',
#     'state_name': 'VA',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 2.0073740270381,
#     'longitude': -76.2466798,
#     'latitude': 36.7183708},
#    'geometry': {'type': 'Point', 'coordinates': [-76.2466798, 36.7183708]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.70143812031597],
#     'place': ['Redwood City'],
#     'date_val': '2020-03-12',
#     'company_name': 'Electronic Arts',
#     'city_name': 'Redwood City',
#     'state_name': 'CA',
#     'sector': 'Consumer Staples',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.70143812031597,
#     'longitude': -122.232523,
#     'latitude': 37.4863239},
#    'geometry': {'type': 'Point', 'coordinates': [-122.232523, 37.4863239]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.62083936324166],
#     'place': ['San Jose'],
#     'date_val': '2020-03-12',
#     'company_name': 'eBay Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.62083936324166,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.580873401562287],
#     'place': ['Chicago'],
#     'date_val': '2020-03-12',
#     'company_name': 'Exelon Corp',
#     'city_name': 'Chicago',
#     'state_name': 'IL',
#     'sector': 'Technology',
#     'region': 'MW',
#     'country_code': 'US',
#     'percent_change': 0.580873401562287,
#     'longitude': -87.6244212,
#     'latitude': 41.8755616},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6244212, 41.8755616]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.93292682926831],
#     'place': ['Winona'],
#     'date_val': '2020-03-12',
#     'company_name': 'Fastenal Co',
#     'city_name': 'Winona',
#     'state_name': 'MN',
#     'sector': 'Industrials',
#     'region': 'MW',
#     'country_code': 'US',
#     'percent_change': 3.93292682926831,
#     'longitude': -91.7807784,
#     'latitude': 43.9582272},
#    'geometry': {'type': 'Point', 'coordinates': [-91.7807784, 43.9582272]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.12768299394607],
#     'place': ['Menlo Park'],
#     'date_val': '2020-03-12',
#     'company_name': 'Meta Platforms Inc',
#     'city_name': 'Menlo Park',
#     'state_name': 'CA',
#     'sector': 'Industrials',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.12768299394607,
#     'longitude': -122.1779927,
#     'latitude': 37.4519671},
#    'geometry': {'type': 'Point', 'coordinates': [-122.1779927, 37.4519671]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.25479233226838],
#     'place': ['Brookfield'],
#     'date_val': '2020-03-12',
#     'company_name': 'Fiserv Inc',
#     'city_name': 'Brookfield',
#     'state_name': 'WI',
#     'sector': 'Technology',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 3.25479233226838,
#     'longitude': -88.1064787,
#     'latitude': 43.0605671},
#    'geometry': {'type': 'Point', 'coordinates': [-88.1064787, 43.0605671]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.64563408272264],
#     'place': ['Sunnyvale'],
#     'date_val': '2020-03-12',
#     'company_name': 'Fortinet Inc',
#     'city_name': 'Sunnyvale',
#     'state_name': 'CA',
#     'sector': 'Financials',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.64563408272264,
#     'longitude': -122.036349,
#     'latitude': 37.3688301},
#    'geometry': {'type': 'Point', 'coordinates': [-122.036349, 37.3688301]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.64048380369805],
#     'place': ['Foster City'],
#     'date_val': '2020-03-12',
#     'company_name': 'Gilead Sciences Inc',
#     'city_name': 'Foster City',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.64048380369805,
#     'longitude': -122.2688522,
#     'latitude': 37.5600336},
#    'geometry': {'type': 'Point', 'coordinates': [-122.2688522, 37.5600336]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.45462256149279],
#     'place': ['Mountain View'],
#     'date_val': '2020-03-12',
#     'company_name': 'Alphabet Class C',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'sector': 'Healthcare',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.45462256149279,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.34300717452914],
#     'place': ['Mountain View'],
#     'date_val': '2020-03-12',
#     'company_name': 'Alphabet Class A',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.34300717452914,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.1072810411537],
#     'place': ['Charlotte'],
#     'date_val': '2020-03-12',
#     'company_name': 'Honeywell International Inc',
#     'city_name': 'Charlotte',
#     'state_name': 'NC',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 5.1072810411537,
#     'longitude': -80.8430827,
#     'latitude': 35.2272086},
#    'geometry': {'type': 'Point', 'coordinates': [-80.8430827, 35.2272086]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.344041629037118],
#     'place': ['San Diego'],
#     'date_val': '2020-03-12',
#     'company_name': 'Illumina Inc',
#     'city_name': 'San Diego',
#     'state_name': 'CA',
#     'sector': 'Healthcare',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.344041629037118,
#     'longitude': -117.1627728,
#     'latitude': 32.7174202},
#    'geometry': {'type': 'Point', 'coordinates': [-117.1627728, 32.7174202]}},
#   {'type': 'Feature',
#    'properties': {'mag': [12.7849150435143],
#     'place': ['Mountain View'],
#     'date_val': '2020-03-12',
#     'company_name': 'Intel Corp',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 12.7849150435143,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.5],
#     'place': ['Mountain View'],
#     'date_val': '2020-03-12',
#     'company_name': 'Intuit Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.5,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.47480314515891],
#     'place': ['Sunnyvale'],
#     'date_val': '2020-03-12',
#     'company_name': 'Intuitive Surgical Inc',
#     'city_name': 'Sunnyvale',
#     'state_name': 'CA',
#     'sector': 'Healthcare',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.47480314515891,
#     'longitude': -122.036349,
#     'latitude': 37.3688301},
#    'geometry': {'type': 'Point', 'coordinates': [-122.036349, 37.3688301]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.28790786948176],
#     'place': ['Wilmington'],
#     'date_val': '2020-03-12',
#     'company_name': 'Marvell Technology Inc',
#     'city_name': 'Wilmington',
#     'state_name': 'DE',
#     'sector': 'Consumer Staples',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.28790786948176,
#     'longitude': -75.546589,
#     'latitude': 39.7459468},
#    'geometry': {'type': 'Point', 'coordinates': [-75.546589, 39.7459468]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.37764362859841],
#     'place': ['Westbrook'],
#     'date_val': '2020-03-12',
#     'company_name': 'IDEXX Laboratories Inc',
#     'city_name': 'Westbrook',
#     'state_name': 'ME',
#     'sector': 'Industrials',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 4.37764362859841,
#     'longitude': -70.3663874,
#     'latitude': 43.6763036},
#    'geometry': {'type': 'Point', 'coordinates': [-70.3663874, 43.6763036]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.16995854669592],
#     'place': ['Westbrook'],
#     'date_val': '2020-03-12',
#     'company_name': 'JD.Com Inc',
#     'city_name': 'Westbrook',
#     'state_name': 'ME',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 3.16995854669592,
#     'longitude': -70.3663874,
#     'latitude': 43.6763036},
#    'geometry': {'type': 'Point', 'coordinates': [-70.3663874, 43.6763036]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.17894736842106],
#     'place': ['Plano'],
#     'date_val': '2020-03-12',
#     'company_name': 'Keurig Dr Pepper Inc',
#     'city_name': 'Plano',
#     'state_name': 'TX',
#     'sector': 'Healthcare',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 1.17894736842106,
#     'longitude': -96.6925096,
#     'latitude': 33.0136764},
#    'geometry': {'type': 'Point', 'coordinates': [-96.6925096, 33.0136764]}},
#   {'type': 'Feature',
#    'properties': {'mag': [9.44887818099685],
#     'place': ['Milpitas'],
#     'date_val': '2020-03-12',
#     'company_name': 'KLA Corp',
#     'city_name': 'Milpitas',
#     'state_name': 'CA',
#     'sector': 'Consumer Staples',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 9.44887818099685,
#     'longitude': -121.9069256,
#     'latitude': 37.4282771},
#    'geometry': {'type': 'Point', 'coordinates': [-121.9069256, 37.4282771]}},
#   {'type': 'Feature',
#    'properties': {'mag': [12.8531073446328],
#     'place': ['Chicago'],
#     'date_val': '2020-03-12',
#     'company_name': 'Kraft Heinz Co',
#     'city_name': 'Chicago',
#     'state_name': 'IL',
#     'sector': 'Consumer Discretionary',
#     'region': 'MW',
#     'country_code': 'US',
#     'percent_change': 12.8531073446328,
#     'longitude': -87.6244212,
#     'latitude': 41.8755616},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6244212, 41.8755616]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.06299212598424],
#     'place': ['Fremont'],
#     'date_val': '2020-03-12',
#     'company_name': 'Lam Research Corp',
#     'city_name': 'Fremont',
#     'state_name': 'CA',
#     'sector': 'Consumer Staples',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.06299212598424,
#     'longitude': -121.988571,
#     'latitude': 37.5482697},
#    'geometry': {'type': 'Point', 'coordinates': [-121.988571, 37.5482697]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.29952456418384],
#     'place': ['Newark'],
#     'date_val': '2021-07-25',
#     'company_name': 'Lucid Group Inc',
#     'city_name': 'Newark',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 6.29952456418384,
#     'longitude': -122.0402399,
#     'latitude': 37.5296593},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0402399, 37.5296593]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.48322910744741],
#     'place': ['Vancouver'],
#     'date_val': '2020-03-12',
#     'company_name': 'Lululemon Athletica Inc',
#     'city_name': 'Vancouver',
#     'state_name': 'CAN',
#     'sector': 'Technology',
#     'region': 'CA',
#     'country_code': 'CA',
#     'percent_change': 0.48322910744741,
#     'longitude': -122.7740237,
#     'latitude': 49.1566925},
#    'geometry': {'type': 'Point', 'coordinates': [-122.7740237, 49.1566925]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.235765207791498],
#     'place': ['Buenos Aires'],
#     'date_val': '2020-03-12',
#     'company_name': 'Mercadolibre Inc',
#     'city_name': 'Buenos Aires',
#     'state_name': 'AR',
#     'sector': 'Consumer Discretionary',
#     'region': 'SE',
#     'country_code': 'Argentina',
#     'percent_change': 0.235765207791498,
#     'longitude': -58.4370894,
#     'latitude': -34.6075682},
#    'geometry': {'type': 'Point', 'coordinates': [-58.4370894, -34.6075682]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.66720961009875],
#     'place': ['Washington'],
#     'date_val': '2020-03-12',
#     'company_name': 'Marriott International Inc',
#     'city_name': 'Washington',
#     'state_name': 'D.C.',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 2.66720961009875,
#     'longitude': -77.0350922,
#     'latitude': 38.9074322},
#    'geometry': {'type': 'Point', 'coordinates': [-77.0350922, 38.9074322]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.46014995181799],
#     'place': ['Dallas'],
#     'date_val': '2020-03-12',
#     'company_name': 'Match Group Inc',
#     'city_name': 'Dallas',
#     'state_name': 'TX',
#     'sector': 'Consumer Staples',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 1.46014995181799,
#     'longitude': -96.7968559,
#     'latitude': 32.7762719},
#    'geometry': {'type': 'Point', 'coordinates': [-96.7968559, 32.7762719]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.82397003745318],
#     'place': ['Chandler'],
#     'date_val': '2020-03-12',
#     'company_name': 'Microchip Technology Inc',
#     'city_name': 'Chandler',
#     'state_name': 'AZ',
#     'sector': 'Consumer Discretionary',
#     'region': 'SW',
#     'country_code': 'US',
#     'percent_change': 4.82397003745318,
#     'longitude': -111.84125,
#     'latitude': 33.3061605},
#    'geometry': {'type': 'Point', 'coordinates': [-111.84125, 33.3061605]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.57856567284448],
#     'place': ['Chicago'],
#     'date_val': '2020-03-12',
#     'company_name': 'Mondelez International Inc',
#     'city_name': 'Chicago',
#     'state_name': 'IL',
#     'sector': 'Technology',
#     'region': 'MW',
#     'country_code': 'US',
#     'percent_change': 2.57856567284448,
#     'longitude': -87.6244212,
#     'latitude': 41.8755616},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6244212, 41.8755616]}},
#   {'type': 'Feature',
#    'properties': {'mag': [7.39130434782608],
#     'place': ['Cambridge'],
#     'date_val': '2020-03-12',
#     'company_name': 'Moderna Inc',
#     'city_name': 'Cambridge',
#     'state_name': 'MA',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 7.39130434782608,
#     'longitude': -71.1056157,
#     'latitude': 42.3750997},
#    'geometry': {'type': 'Point', 'coordinates': [-71.1056157, 42.3750997]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.33110367892977],
#     'place': ['Corona'],
#     'date_val': '2020-03-12',
#     'company_name': 'Monster Beverage Corp',
#     'city_name': 'Corona',
#     'state_name': 'CA',
#     'sector': 'Communication Services',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.33110367892977,
#     'longitude': -117.5664449,
#     'latitude': 33.8752945},
#    'geometry': {'type': 'Point', 'coordinates': [-117.5664449, 33.8752945]}},
#   {'type': 'Feature',
#    'properties': {'mag': [7.6813559322034],
#     'place': ['Redmond'],
#     'date_val': '2020-03-12',
#     'company_name': 'Microsoft Corp',
#     'city_name': 'Redmond',
#     'state_name': 'WA',
#     'sector': 'Healthcare',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 7.6813559322034,
#     'longitude': -122.1238767,
#     'latitude': 47.6694141},
#    'geometry': {'type': 'Point', 'coordinates': [-122.1238767, 47.6694141]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.41592494587443],
#     'place': ['Boise'],
#     'date_val': '2020-03-12',
#     'company_name': 'Micron Technology Inc',
#     'city_name': 'Boise',
#     'state_name': 'ID',
#     'sector': 'Technology',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 3.41592494587443,
#     'longitude': -116.200886,
#     'latitude': 43.6166163},
#    'geometry': {'type': 'Point', 'coordinates': [-116.200886, 43.6166163]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.75032525490909],
#     'place': ['Los Gatos'],
#     'date_val': '2020-03-12',
#     'company_name': 'Netflix Inc',
#     'city_name': 'Los Gatos',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.75032525490909,
#     'longitude': -121.9746797,
#     'latitude': 37.226611},
#    'geometry': {'type': 'Point', 'coordinates': [-121.9746797, 37.226611]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.72348003052658],
#     'place': ['Hangzhou'],
#     'date_val': '2020-03-12',
#     'company_name': 'NetEase Inc',
#     'city_name': 'Hangzhou',
#     'state_name': 'CN',
#     'sector': 'Technology',
#     'region': 'CH',
#     'country_code': 'CN',
#     'percent_change': 1.72348003052658,
#     'longitude': 120.2052342,
#     'latitude': 30.2489634},
#    'geometry': {'type': 'Point', 'coordinates': [120.2052342, 30.2489634]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.48590021691974],
#     'place': ['Santa Clara'],
#     'date_val': '2020-03-12',
#     'company_name': 'NVIDIA Corp',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.48590021691974,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.47916666666666],
#     'place': ['Eindhoven'],
#     'date_val': '2020-03-12',
#     'company_name': 'NXP Semiconductors NV',
#     'city_name': 'Eindhoven',
#     'state_name': 'NL',
#     'sector': 'Technology',
#     'region': 'NL',
#     'country_code': 'Netherlands',
#     'percent_change': 0.47916666666666,
#     'longitude': 5.478633,
#     'latitude': 51.4392648},
#    'geometry': {'type': 'Point', 'coordinates': [5.478633, 51.4392648]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.7289211242067],
#     'place': ['San Francisco'],
#     'date_val': '2020-03-12',
#     'company_name': 'Okta Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.7289211242067,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.23157831527666],
#     'place': ['Thomasville'],
#     'date_val': '2020-03-12',
#     'company_name': 'Old Dominion Freight Line Inc',
#     'city_name': 'Thomasville',
#     'state_name': 'NC',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 3.23157831527666,
#     'longitude': -80.081817,
#     'latitude': 35.8831786},
#    'geometry': {'type': 'Point', 'coordinates': [-80.081817, 35.8831786]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.99418604651163],
#     'place': ['Springfield'],
#     'date_val': '2020-03-12',
#     'company_name': 'O’Reilly Automotive Inc',
#     'city_name': 'Springfield',
#     'state_name': 'MO',
#     'sector': 'Industrials',
#     'region': 'MW',
#     'country_code': 'US',
#     'percent_change': 2.99418604651163,
#     'longitude': -93.2920373,
#     'latitude': 37.2166779},
#    'geometry': {'type': 'Point', 'coordinates': [-93.2920373, 37.2166779]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.61050754013296],
#     'place': ['Bellevue'],
#     'date_val': '2020-03-12',
#     'company_name': 'Paccar Inc',
#     'city_name': 'Bellevue',
#     'state_name': 'WA',
#     'sector': 'Technology',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 5.61050754013296,
#     'longitude': -122.192337,
#     'latitude': 47.6144219},
#    'geometry': {'type': 'Point', 'coordinates': [-122.192337, 47.6144219]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.92679614287655],
#     'place': ['Santa Clara'],
#     'date_val': '2020-03-12',
#     'company_name': 'Palo Alto Networks Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'sector': 'Consumer Discretionary',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.92679614287655,
#     'longitude': -121.6846349,
#     'latitude': 37.2333253},
#    'geometry': {'type': 'Point', 'coordinates': [-121.6846349, 37.2333253]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.62440843252545],
#     'place': ['Rochester'],
#     'date_val': '2020-03-12',
#     'company_name': 'Paychex Inc',
#     'city_name': 'Rochester',
#     'state_name': 'NY',
#     'sector': 'Industrials',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 2.62440843252545,
#     'longitude': -77.615214,
#     'latitude': 43.157285},
#    'geometry': {'type': 'Point', 'coordinates': [-77.615214, 43.157285]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.14492753623189],
#     'place': ['Shanghai'],
#     'date_val': '2020-03-12',
#     'company_name': 'Pinduoduo Inc',
#     'city_name': 'Shanghai',
#     'state_name': 'CN',
#     'sector': 'Industrials',
#     'region': 'CH',
#     'country_code': 'CH',
#     'percent_change': 2.14492753623189,
#     'longitude': 121.4692071,
#     'latitude': 31.2322758},
#    'geometry': {'type': 'Point', 'coordinates': [121.4692071, 31.2322758]}},
#   {'type': 'Feature',
#    'properties': {'mag': [9.58018304814963],
#     'place': ['San Jose'],
#     'date_val': '2020-03-12',
#     'company_name': 'PayPal Holdings Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'sector': 'Financials',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 9.58018304814963,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.6098773616175],
#     'place': ['Harrison'],
#     'date_val': '2020-03-12',
#     'company_name': 'PepsiCo Inc.',
#     'city_name': 'Harrison',
#     'state_name': 'NY',
#     'sector': 'Consumer Discretionary',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 5.6098773616175,
#     'longitude': -73.71116375,
#     'latitude': 41.0195135},
#    'geometry': {'type': 'Point', 'coordinates': [-73.71116375, 41.0195135]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.50463613374543],
#     'place': ['San Diego'],
#     'date_val': '2020-03-12',
#     'company_name': 'Qualcomm Inc',
#     'city_name': 'San Diego',
#     'state_name': 'CA',
#     'sector': 'Consumer Staples',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 6.50463613374543,
#     'longitude': -117.1627728,
#     'latitude': 32.7174202},
#    'geometry': {'type': 'Point', 'coordinates': [-117.1627728, 32.7174202]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.37586759209824],
#     'place': ['Dallas'],
#     'date_val': '2020-04-30',
#     'company_name': 'Texas Instruments Inc',
#     'city_name': 'Dallas',
#     'state_name': 'TX',
#     'sector': 'Communication Services',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 2.37586759209824,
#     'longitude': -96.7968559,
#     'latitude': 32.7762719},
#    'geometry': {'type': 'Point', 'coordinates': [-96.7968559, 32.7762719]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.61562661513225],
#     'place': ['Tarrytown'],
#     'date_val': '2020-03-12',
#     'company_name': 'Regeneron Pharmaceuticals Inc',
#     'city_name': 'Tarrytown',
#     'state_name': 'NY',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 4.61562661513225,
#     'longitude': -73.86732932,
#     'latitude': 41.065586},
#    'geometry': {'type': 'Point', 'coordinates': [-73.86732932, 41.065586]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.92795147966119],
#     'place': ['San Bruno'],
#     'date_val': '2020-03-12',
#     'company_name': 'Ross Stores Inc',
#     'city_name': 'San Bruno',
#     'state_name': 'CA',
#     'sector': 'Healthcare',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.92795147966119,
#     'longitude': -122.4332435,
#     'latitude': 37.6261715},
#    'geometry': {'type': 'Point', 'coordinates': [-122.4332435, 37.6261715]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.07612456747405],
#     'place': ['New York'],
#     'date_val': '2020-03-12',
#     'company_name': 'Sirius XM Holdings Inc',
#     'city_name': 'New York',
#     'state_name': 'NY',
#     'sector': 'Healthcare',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 2.07612456747405,
#     'longitude': -74.0060152,
#     'latitude': 40.7127281},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0060152, 40.7127281]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.69290169290169],
#     'place': ['Bothell'],
#     'date_val': '2020-03-12',
#     'company_name': 'Seagen Inc',
#     'city_name': 'Bothell',
#     'state_name': 'WA',
#     'sector': 'Communication Services',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 1.69290169290169,
#     'longitude': -122.2068288,
#     'latitude': 47.7598697},
#    'geometry': {'type': 'Point', 'coordinates': [-122.2068288, 47.7598697]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.31937725393614],
#     'place': ['San Francisco'],
#     'date_val': '2020-03-12',
#     'company_name': 'Splunk Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.31937725393614,
#     'longitude': -122.419906,
#     'latitude': 37.7790262},
#    'geometry': {'type': 'Point', 'coordinates': [-122.419906, 37.7790262]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.09398715703445],
#     'place': ['Irvine'],
#     'date_val': '2020-03-12',
#     'company_name': 'Skyworks Solutions Inc',
#     'city_name': 'Irvine',
#     'state_name': 'CA',
#     'sector': 'Consumer Discretionary',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.09398715703445,
#     'longitude': -117.8259819,
#     'latitude': 33.6856969},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8259819, 33.6856969]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.5041888804265],
#     'place': ['Seattle'],
#     'date_val': '2020-03-12',
#     'company_name': 'Starbucks Corp',
#     'city_name': 'Seattle',
#     'state_name': 'WA',
#     'sector': 'Consumer Discretionary',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 6.5041888804265,
#     'longitude': -122.3300624,
#     'latitude': 47.6038321},
#    'geometry': {'type': 'Point', 'coordinates': [-122.3300624, 47.6038321]}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.9788647826435],
#     'place': ['Mountain View'],
#     'date_val': '2020-03-12',
#     'company_name': 'Synopsys Inc',
#     'city_name': 'Mountain View',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.9788647826435,
#     'longitude': -122.0832101,
#     'latitude': 37.3893889},
#    'geometry': {'type': 'Point', 'coordinates': [-122.0832101, 37.3893889]}},
#   {'type': 'Feature',
#    'properties': {'mag': [8.13109243697479],
#     'place': ['Austin'],
#     'date_val': '2020-03-12',
#     'company_name': 'Tesla Inc',
#     'city_name': 'Austin',
#     'state_name': 'TX',
#     'sector': 'Technology',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 8.13109243697479,
#     'longitude': -97.7436995,
#     'latitude': 30.2711286},
#    'geometry': {'type': 'Point', 'coordinates': [-97.7436995, 30.2711286]}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.53774173424828],
#     'place': ['Bellevue'],
#     'date_val': '2020-03-12',
#     'company_name': 'T-Mobile US Inc',
#     'city_name': 'Bellevue',
#     'state_name': 'WA',
#     'sector': 'Consumer Discretionary',
#     'region': 'NW',
#     'country_code': 'US',
#     'percent_change': 6.53774173424828,
#     'longitude': -122.192337,
#     'latitude': 47.6144219},
#    'geometry': {'type': 'Point', 'coordinates': [-122.192337, 47.6144219]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.99626286437072],
#     'place': ['Reston'],
#     'date_val': '2020-03-12',
#     'company_name': 'Verisign Inc',
#     'city_name': 'Reston',
#     'state_name': 'VA',
#     'sector': 'Industrials',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 4.99626286437072,
#     'longitude': -77.3579805,
#     'latitude': 38.9583737},
#    'geometry': {'type': 'Point', 'coordinates': [-77.3579805, 38.9583737]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.220249156858711],
#     'place': ['Jersey City'],
#     'date_val': '2020-03-12',
#     'company_name': 'Verisk Analytics Inc',
#     'city_name': 'Jersey City',
#     'state_name': 'NJ',
#     'sector': 'Technology',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.220249156858711,
#     'longitude': -74.047455,
#     'latitude': 40.7215682},
#    'geometry': {'type': 'Point', 'coordinates': [-74.047455, 40.7215682]}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.20515052925813],
#     'place': ['Boston'],
#     'date_val': '2020-03-12',
#     'company_name': 'Vertex Pharmaceuticals Inc',
#     'city_name': 'Boston',
#     'state_name': 'MA',
#     'sector': 'Healthcare',
#     'region': 'SE',
#     'country_code': 'US',
#     'percent_change': 1.20515052925813,
#     'longitude': -71.0582912,
#     'latitude': 42.3602534},
#    'geometry': {'type': 'Point', 'coordinates': [-71.0582912, 42.3602534]}},
#   {'type': 'Feature',
#    'properties': {'mag': [8.12265917602996],
#     'place': ['Chicago'],
#     'date_val': '2020-03-12',
#     'company_name': 'Walgreens Boots Alliance Inc',
#     'city_name': 'Chicago',
#     'state_name': 'IL',
#     'sector': 'Healthcare',
#     'region': 'MW',
#     'country_code': 'US',
#     'percent_change': 8.12265917602996,
#     'longitude': -87.6244212,
#     'latitude': 41.8755616},
#    'geometry': {'type': 'Point', 'coordinates': [-87.6244212, 41.8755616]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.430123204782389],
#     'place': ['Pleasanton'],
#     'date_val': '2020-03-12',
#     'company_name': 'Workday Inc',
#     'city_name': 'Pleasanton',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.430123204782389,
#     'longitude': -121.8746789,
#     'latitude': 37.6624312},
#    'geometry': {'type': 'Point', 'coordinates': [-121.8746789, 37.6624312]}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.98151460942159],
#     'place': ['Minneapolis'],
#     'date_val': '2020-04-28',
#     'company_name': 'Xcel Energy Inc',
#     'city_name': 'Minneapolis',
#     'state_name': 'MN',
#     'sector': 'Utilities',
#     'region': 'MW',
#     'country_code': 'US',
#     'percent_change': 2.98151460942159,
#     'longitude': -93.2654692,
#     'latitude': 44.9772995},
#    'geometry': {'type': 'Point', 'coordinates': [-93.2654692, 44.9772995]}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.89380530973451],
#     'place': ['San Jose'],
#     'date_val': '2020-03-12',
#     'company_name': 'Zoom Video Communications Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.89380530973451,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.166825548141087],
#     'place': ['San Jose'],
#     'date_val': '2020-03-12',
#     'company_name': 'Zscaler Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'sector': 'Technology',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.166825548141087,
#     'longitude': -121.890583,
#     'latitude': 37.3361905},
#    'geometry': {'type': 'Point', 'coordinates': [-121.890583, 37.3361905]}}]}

# %%
with open('../resources/monthly_json_new3.json', 'w') as f:
    json.dump(geojson, f)
