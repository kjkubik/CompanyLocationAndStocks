# %%
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime, timedelta
from functools import partial
import numpy as np
import psycopg2
import pandas as pd
from sqlalchemy import create_engine
from config import db_password
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

#import necessary libraries 
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols


#from joblib import Parallel, delayed, Model 
#from collections import Counter <--????
#from sklearn.metrics import confusion_matrix
#from imblearn.metrics import classification_report_imbalanced

# %%
# GET Tabled input

# creating database engine
db_name = 'Company_Stock_DB'
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/{db_name}"
engine = create_engine(db_string)

# read data from PostgreSQL database table and load into Dataframe instance
stock_df = pd.read_sql("select * from \"company_all_star\"", engine);

#sort the dataframe by ticker column
stock_df.sort_values(by=['ticker'])

# Print the DataFrame
stock_df.head()
# Out:
#   ticker    date_val                company_name company_url employee_count  \
# 0    AMD  2020-03-12  Advanced Micro Devices Inc     amd.com         5k-10k
# 1    AMD  2020-03-15  Advanced Micro Devices Inc     amd.com         5k-10k
# 2    AMD  2020-03-16  Advanced Micro Devices Inc     amd.com         5k-10k
# 3    AMD  2020-03-17  Advanced Micro Devices Inc     amd.com         5k-10k
# 4    AMD  2020-03-18  Advanced Micro Devices Inc     amd.com         5k-10k
#
#    revenue      sector    city_name state_name region  ...   latitude  \
# 0  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 1  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 2  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 3  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 4  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                381223.0        4.028436
# 1        41.0812                374962.0        0.946776
# 2        41.1240                434519.0        4.205026
# 3        39.6363                591862.0        1.062215
# 4        40.2337                396388.0        0.657230
#
# [5 rows x 21 columns]

# %%
# check dtypes
stock_df.dtypes
# Out:
# ticker                     object
# date_val                   object
# company_name               object
# company_url                object
# employee_count             object
# revenue                    object
# sector                     object
# city_name                  object
# state_name                 object
# region                     object
# country_code               object
# latitude                  float64
# longitude                 float64
# open_val                  float64
# high_val                  float64
# low_val                   float64
# close_val                 float64
# volume                    float64
# volume_weight             float64
# number_of_transactions    float64
# percent_change            float64
# dtype: object

# %%
# preserve date column as type object
stock_df['date'] = stock_df['date_val']

# have the user enter beginning date as yyyy-mm-dd
begin_date = '2022-03-08'
# have the user enter ending date as yyyy-mm-dd
end_date = '2022-03-10'

# Convert the date to datetime64
stock_df['date_val'] = pd.to_datetime(stock_df['date_val'], format='%Y-%m-%d')

stock_df = stock_df.loc[(stock_df['date_val'] >= begin_date)
                     & (stock_df['date_val'] <= end_date)]

# drop throw-aways 
stock_df.drop(["employee_count", "revenue", "longitude", "latitude", "company_name", "company_url", "date_val"], axis=1, inplace=True)

stock_df
# Out:
#       ticker                  sector      city_name state_name region  \
# 501      AMD              Technology    Santa Clara         CA      W
# 502      AMD              Technology    Santa Clara         CA      W
# 503      AMD              Technology    Santa Clara         CA      W
# 1006    ADBE              Technology       San Jose         CA      W
# 1007    ADBE              Technology       San Jose         CA      W
# 1008    ADBE              Technology       San Jose         CA      W
# 1321    ABNB              Technology  San Francisco         CA      W
# 1322    ABNB              Technology  San Francisco         CA      W
# 1323    ABNB              Technology  San Francisco         CA      W
# 1825    ALGN              Technology          Tempe         AZ     SW
# 1826    ALGN              Technology          Tempe         AZ     SW
# 1827    ALGN              Technology          Tempe         AZ     SW
# 2329    AMZN              Technology        Seattle         WA     NW
# 2330    AMZN              Technology        Seattle         WA     NW
# 2331    AMZN              Technology        Seattle         WA     NW
# 2833    AMGN              Technology  Thousand Oaks         CA      W
# 2834    AMGN              Technology  Thousand Oaks         CA      W
# 2835    AMGN              Technology  Thousand Oaks         CA      W
# 3336     AEP                  Energy       Columbus         OH     MW
# 3337     AEP                  Energy       Columbus         OH     MW
# 3338     AEP                  Energy       Columbus         OH     MW
# 3840     ADI              Technology        Norwood         MA     SE
# 3841     ADI              Technology        Norwood         MA     SE
# 3842     ADI              Technology        Norwood         MA     SE
# 4344    ANSS              Technology     Canonsburg         PA     SE
# 4345    ANSS              Technology     Canonsburg         PA     SE
# 4346    ANSS              Technology     Canonsburg         PA     SE
# 4848    AAPL              Technology      Capertino         CA      W
# 4849    AAPL              Technology      Capertino         CA      W
# 4850    AAPL              Technology      Capertino         CA      W
# 5352    AMAT              Technology    Santa Clara         CA      W
# 5353    AMAT              Technology    Santa Clara         CA      W
# 5354    AMAT              Technology    Santa Clara         CA      W
# 5856    ASML              Technology      Veldhoven         NL     NL
# 5857    ASML              Technology      Veldhoven         NL     NL
# 5858    ASML              Technology      Veldhoven         NL     NL
# 6360    TEAM              Technology         Sydney        AUS     AU
# 6361    TEAM              Technology         Sydney        AUS     AU
# 6362    TEAM              Technology         Sydney        AUS     AU
# 6864    ADSK              Healthcare     San Rafael         CA      W
# 6865    ADSK              Healthcare     San Rafael         CA      W
# 6866    ADSK              Healthcare     San Rafael         CA      W
# 7368    ATVI              Technology     San Monica         CA      W
# 7369    ATVI              Technology     San Monica         CA      W
# 7370    ATVI              Technology     San Monica         CA      W
# 7872     ADP  Consumer Discretionary       Roseland         NJ     NE
# 7873     ADP  Consumer Discretionary       Roseland         NJ     NE
# 7874     ADP  Consumer Discretionary       Roseland         NJ     NE
# 8376     AZN              Healthcare      Cambridge         UK     GB
# 8377     AZN              Healthcare      Cambridge         UK     GB
# 8378     AZN              Healthcare      Cambridge         UK     GB
# 8880    AVGO              Technology       San Jose         CA      W
# 8881    AVGO              Technology       San Jose         CA      W
# 8882    AVGO              Technology       San Jose         CA      W
# 9384    BIDU              Technology        Beijing         CN     CH
# 9385    BIDU              Technology        Beijing         CN     CH
# 9386    BIDU              Technology        Beijing         CN     CH
# 9887    BIIB              Technology      Cambridge         MA     SE
# 9888    BIIB              Technology      Cambridge         MA     SE
# 9889    BIIB              Technology      Cambridge         MA     SE
# 10391   BMRN              Healthcare         Novato         CA      W
# 10392   BMRN              Healthcare         Novato         CA      W
# 10393   BMRN              Healthcare         Novato         CA      W
# 10895   BKNG              Healthcare        Norwalk         CT     NE
# 10896   BKNG              Healthcare        Norwalk         CT     NE
# 10897   BKNG              Healthcare        Norwalk         CT     NE
# 11399   CDNS              Technology       San Jose         CA      W
# 11400   CDNS              Technology       San Jose         CA      W
# 11401   CDNS              Technology       San Jose         CA      W
# 11903   CHTR              Technology       Stamford         CT     NE
# 11904   CHTR              Technology       Stamford         CT     NE
# 11905   CHTR              Technology       Stamford         CT     NE
# 12407   CPRT              Technology         Dallas         TX     SE
# 12408   CPRT              Technology         Dallas         TX     SE
# 12409   CPRT              Technology         Dallas         TX     SE
# 12911   CRWD             Industrials         Austin         TX     SE
# 12912   CRWD             Industrials         Austin         TX     SE
# 12913   CRWD             Industrials         Austin         TX     SE
# 13415   CTAS        Consumer Staples     Cincinnati         OH     MW
# 13416   CTAS        Consumer Staples     Cincinnati         OH     MW
# 13417   CTAS        Consumer Staples     Cincinnati         OH     MW
# 13919   CSCO              Technology       San Jose         CA      W
# 13920   CSCO              Technology       San Jose         CA      W
# 13921   CSCO              Technology       San Jose         CA      W
# 14423  CMCSA  Communication Services         Tupelo         MS     SE
# 14424  CMCSA  Communication Services         Tupelo         MS     SE
# 14425  CMCSA  Communication Services         Tupelo         MS     SE
# 14927   COST  Consumer Discretionary       Issaquah         WA     NW
# 14928   COST  Consumer Discretionary       Issaquah         WA     NW
# 14929   COST  Consumer Discretionary       Issaquah         WA     NW
# 15431    CSX  Communication Services   Jacksonville         FL     SE
# 15432    CSX  Communication Services   Jacksonville         FL     SE
# 15433    CSX  Communication Services   Jacksonville         FL     SE
# 15935   CTSH             Industrials        Teaneck         NJ     NE
# 15936   CTSH             Industrials        Teaneck         NJ     NE
# 15937   CTSH             Industrials        Teaneck         NJ     NE
# 16439   DDOG              Technology       New York         NY     SE
# 16440   DDOG              Technology       New York         NY     SE
# 16441   DDOG              Technology       New York         NY     SE
# 16943   DOCU              Technology  San Francisco         CA      W
# 16944   DOCU              Technology  San Francisco         CA      W
# 16945   DOCU              Technology  San Francisco         CA      W
# 17447   DXCM              Healthcare      San Diego         CA      W
# 17448   DXCM              Healthcare      San Diego         CA      W
# 17449   DXCM              Healthcare      San Diego         CA      W
# 17951   DLTR              Technology     Chesapeake         VA     SE
# 17952   DLTR              Technology     Chesapeake         VA     SE
# 17953   DLTR              Technology     Chesapeake         VA     SE
# 18455     EA        Consumer Staples   Redwood City         CA      W
# 18456     EA        Consumer Staples   Redwood City         CA      W
# 18457     EA        Consumer Staples   Redwood City         CA      W
# 18959   EBAY              Technology       San Jose         CA      W
# 29039   LRCX        Consumer Staples        Fremont         CA      W
# 29040   LRCX        Consumer Staples        Fremont         CA      W
# 29041   LRCX        Consumer Staples        Fremont         CA      W
# 29199   LCID              Technology         Newark         CA      W
# 29200   LCID              Technology         Newark         CA      W
# 29201   LCID              Technology         Newark         CA      W
# 29703   LULU              Technology      Vancouver        CAN     CA
# 29704   LULU              Technology      Vancouver        CAN     CA
# 29705   LULU              Technology      Vancouver        CAN     CA
# 30207   MELI  Consumer Discretionary   Buenos Aires         AR     SE
# 30208   MELI  Consumer Discretionary   Buenos Aires         AR     SE
# 30209   MELI  Consumer Discretionary   Buenos Aires         AR     SE
# 30711    MAR              Technology     Washington       D.C.     SE
# 30712    MAR              Technology     Washington       D.C.     SE
# 30713    MAR              Technology     Washington       D.C.     SE
# 31215   MTCH        Consumer Staples         Dallas         TX     SE
# 31216   MTCH        Consumer Staples         Dallas         TX     SE
# 31217   MTCH        Consumer Staples         Dallas         TX     SE
# 31719   MCHP  Consumer Discretionary       Chandler         AZ     SW
# 31720   MCHP  Consumer Discretionary       Chandler         AZ     SW
# 31721   MCHP  Consumer Discretionary       Chandler         AZ     SW
# 32223   MDLZ              Technology        Chicago         IL     MW
# 32224   MDLZ              Technology        Chicago         IL     MW
# 32225   MDLZ              Technology        Chicago         IL     MW
# 32727   MRNA              Technology      Cambridge         MA     SE
# 32728   MRNA              Technology      Cambridge         MA     SE
# 32729   MRNA              Technology      Cambridge         MA     SE
# 33231   MNST  Communication Services         Corona         CA      W
# 33232   MNST  Communication Services         Corona         CA      W
# 33233   MNST  Communication Services         Corona         CA      W
# 33735   MSFT              Healthcare        Redmond         WA     NW
# 33736   MSFT              Healthcare        Redmond         WA     NW
# 33737   MSFT              Healthcare        Redmond         WA     NW
# 34239     MU              Technology          Boise         ID     NW
# 34240     MU              Technology          Boise         ID     NW
# 34241     MU              Technology          Boise         ID     NW
# 34743   NFLX              Technology      Los Gatos         CA      W
# 34744   NFLX              Technology      Los Gatos         CA      W
# 34745   NFLX              Technology      Los Gatos         CA      W
# 35247   NTES              Technology       Hangzhou         CN     CH
# 35248   NTES              Technology       Hangzhou         CN     CH
# 35249   NTES              Technology       Hangzhou         CN     CH
# 35751   NVDA              Technology    Santa Clara         CA      W
# 35752   NVDA              Technology    Santa Clara         CA      W
# 35753   NVDA              Technology    Santa Clara         CA      W
# 36255   NXPI              Technology      Eindhoven         NL     NL
# 36256   NXPI              Technology      Eindhoven         NL     NL
# 36257   NXPI              Technology      Eindhoven         NL     NL
# 36759   OKTA              Technology  San Francisco         CA      W
# 36760   OKTA              Technology  San Francisco         CA      W
# 36761   OKTA              Technology  San Francisco         CA      W
# 37263   ODFL              Technology    Thomasville         NC     SE
# 37264   ODFL              Technology    Thomasville         NC     SE
# 37265   ODFL              Technology    Thomasville         NC     SE
# 37767   ORLY             Industrials    Springfield         MO     MW
# 37768   ORLY             Industrials    Springfield         MO     MW
# 37769   ORLY             Industrials    Springfield         MO     MW
# 38271   PCAR              Technology       Bellevue         WA     NW
# 38272   PCAR              Technology       Bellevue         WA     NW
# 38273   PCAR              Technology       Bellevue         WA     NW
# 38775   PANW  Consumer Discretionary    Santa Clara         CA      W
# 38776   PANW  Consumer Discretionary    Santa Clara         CA      W
# 38777   PANW  Consumer Discretionary    Santa Clara         CA      W
# 39279   PAYX             Industrials      Rochester         NY     SE
# 39280   PAYX             Industrials      Rochester         NY     SE
# 39281   PAYX             Industrials      Rochester         NY     SE
# 39783    PDD             Industrials       Shanghai         CN     CH
# 39784    PDD             Industrials       Shanghai         CN     CH
# 39785    PDD             Industrials       Shanghai         CN     CH
# 40287   PYPL              Financials       San Jose         CA      W
# 40288   PYPL              Financials       San Jose         CA      W
# 40289   PYPL              Financials       San Jose         CA      W
# 40791    PEP  Consumer Discretionary       Harrison         NY     SE
# 40792    PEP  Consumer Discretionary       Harrison         NY     SE
# 40793    PEP  Consumer Discretionary       Harrison         NY     SE
# 41296   QCOM        Consumer Staples      San Diego         CA      W
# 41297   QCOM        Consumer Staples      San Diego         CA      W
# 41298   QCOM        Consumer Staples      San Diego         CA      W
# 41800   REGN              Technology      Tarrytown         NY     SE
# 41801   REGN              Technology      Tarrytown         NY     SE
# 41802   REGN              Technology      Tarrytown         NY     SE
# 42304   ROST              Healthcare      San Bruno         CA      W
# 42305   ROST              Healthcare      San Bruno         CA      W
# 42306   ROST              Healthcare      San Bruno         CA      W
# 42808   SIRI              Healthcare       New York         NY     SE
# 42809   SIRI              Healthcare       New York         NY     SE
# 42810   SIRI              Healthcare       New York         NY     SE
# 43312   SGEN  Communication Services        Bothell         WA     NW
# 43313   SGEN  Communication Services        Bothell         WA     NW
# 43314   SGEN  Communication Services        Bothell         WA     NW
# 43816   SPLK              Technology  San Francisco         CA      W
# 43817   SPLK              Technology  San Francisco         CA      W
# 43818   SPLK              Technology  San Francisco         CA      W
# 44320   SWKS  Consumer Discretionary         Irvine         CA      W
# 44321   SWKS  Consumer Discretionary         Irvine         CA      W
# 44322   SWKS  Consumer Discretionary         Irvine         CA      W
# 44824   SBUX  Consumer Discretionary        Seattle         WA     NW
# 44825   SBUX  Consumer Discretionary        Seattle         WA     NW
# 44826   SBUX  Consumer Discretionary        Seattle         WA     NW
# 45328   SNPS              Technology  Mountain View         CA      W
# 45329   SNPS              Technology  Mountain View         CA      W
# 45330   SNPS              Technology  Mountain View         CA      W
# 45832   TSLA              Technology         Austin         TX     SE
# 45833   TSLA              Technology         Austin         TX     SE
# 45834   TSLA              Technology         Austin         TX     SE
# 46335    TXN  Communication Services         Dallas         TX     SE
# 46336    TXN  Communication Services         Dallas         TX     SE
# 46337    TXN  Communication Services         Dallas         TX     SE
# 46839   TMUS  Consumer Discretionary       Bellevue         WA     NW
# 46840   TMUS  Consumer Discretionary       Bellevue         WA     NW
# 46841   TMUS  Consumer Discretionary       Bellevue         WA     NW
# 47343   VRSN             Industrials         Reston         VA     SE
# 47344   VRSN             Industrials         Reston         VA     SE
# 47345   VRSN             Industrials         Reston         VA     SE
# city_name                  object
# state_name                 object
# region                     object
# country_code               object
# open_val                  float64
# high_val                  float64
# low_val                   float64
# close_val                 float64
# volume                    float64
# volume_weight             float64
# number_of_transactions    float64
# percent_change            float64
# date                       object
# dtype: object

# %%
# drop fields that will not be used to represent a period of time
stock_df.drop(columns = ['open_val', 'high_val', 'low_val', 'close_val', 'number_of_transactions'], axis=1, inplace=True)
pd.set_option('display.max_rows', None)
stock_df
# Out:
#       ticker                  sector      city_name state_name region  \
# 501      AMD              Technology    Santa Clara         CA      W
# 502      AMD              Technology    Santa Clara         CA      W
# 503      AMD              Technology    Santa Clara         CA      W
# 1006    ADBE              Technology       San Jose         CA      W
# 1007    ADBE              Technology       San Jose         CA      W
# 1008    ADBE              Technology       San Jose         CA      W
# 1321    ABNB              Technology  San Francisco         CA      W
# 1322    ABNB              Technology  San Francisco         CA      W
# 1323    ABNB              Technology  San Francisco         CA      W
# 1825    ALGN              Technology          Tempe         AZ     SW
# 1826    ALGN              Technology          Tempe         AZ     SW
# 1827    ALGN              Technology          Tempe         AZ     SW
# 2329    AMZN              Technology        Seattle         WA     NW
# 2330    AMZN              Technology        Seattle         WA     NW
# 2331    AMZN              Technology        Seattle         WA     NW
# 2833    AMGN              Technology  Thousand Oaks         CA      W
# 2834    AMGN              Technology  Thousand Oaks         CA      W
# 2835    AMGN              Technology  Thousand Oaks         CA      W
# 3336     AEP                  Energy       Columbus         OH     MW
# 3337     AEP                  Energy       Columbus         OH     MW
# 3338     AEP                  Energy       Columbus         OH     MW
# 3840     ADI              Technology        Norwood         MA     SE
# 3841     ADI              Technology        Norwood         MA     SE
# 3842     ADI              Technology        Norwood         MA     SE
# 4344    ANSS              Technology     Canonsburg         PA     SE
# 4345    ANSS              Technology     Canonsburg         PA     SE
# 4346    ANSS              Technology     Canonsburg         PA     SE
# 4848    AAPL              Technology      Capertino         CA      W
# 4849    AAPL              Technology      Capertino         CA      W
# 4850    AAPL              Technology      Capertino         CA      W
# 5352    AMAT              Technology    Santa Clara         CA      W
# 5353    AMAT              Technology    Santa Clara         CA      W
# 5354    AMAT              Technology    Santa Clara         CA      W
# 5856    ASML              Technology      Veldhoven         NL     NL
# 5857    ASML              Technology      Veldhoven         NL     NL
# 5858    ASML              Technology      Veldhoven         NL     NL
# 6360    TEAM              Technology         Sydney        AUS     AU
# 6361    TEAM              Technology         Sydney        AUS     AU
# 6362    TEAM              Technology         Sydney        AUS     AU
# 6864    ADSK              Healthcare     San Rafael         CA      W
# 6865    ADSK              Healthcare     San Rafael         CA      W
# 6866    ADSK              Healthcare     San Rafael         CA      W
# 7368    ATVI              Technology     San Monica         CA      W
# 7369    ATVI              Technology     San Monica         CA      W
# 7370    ATVI              Technology     San Monica         CA      W
# 7872     ADP  Consumer Discretionary       Roseland         NJ     NE
# 7873     ADP  Consumer Discretionary       Roseland         NJ     NE
# 7874     ADP  Consumer Discretionary       Roseland         NJ     NE
# 8376     AZN              Healthcare      Cambridge         UK     GB
# 8377     AZN              Healthcare      Cambridge         UK     GB
# 28535    KHC  Consumer Discretionary        Chicago         IL     MW
# 28536    KHC  Consumer Discretionary        Chicago         IL     MW
# 28537    KHC  Consumer Discretionary        Chicago         IL     MW
# 29039   LRCX        Consumer Staples        Fremont         CA      W
# 29040   LRCX        Consumer Staples        Fremont         CA      W
# 29041   LRCX        Consumer Staples        Fremont         CA      W
# 29199   LCID              Technology         Newark         CA      W
# 29200   LCID              Technology         Newark         CA      W
# 29201   LCID              Technology         Newark         CA      W
# 29703   LULU              Technology      Vancouver        CAN     CA
# 29704   LULU              Technology      Vancouver        CAN     CA
# 29705   LULU              Technology      Vancouver        CAN     CA
# 30207   MELI  Consumer Discretionary   Buenos Aires         AR     SE
# 30208   MELI  Consumer Discretionary   Buenos Aires         AR     SE
# 30209   MELI  Consumer Discretionary   Buenos Aires         AR     SE
# 30711    MAR              Technology     Washington       D.C.     SE
# 30712    MAR              Technology     Washington       D.C.     SE
# 30713    MAR              Technology     Washington       D.C.     SE
# 31215   MTCH        Consumer Staples         Dallas         TX     SE
# 31216   MTCH        Consumer Staples         Dallas         TX     SE
# 31217   MTCH        Consumer Staples         Dallas         TX     SE
# 31719   MCHP  Consumer Discretionary       Chandler         AZ     SW
# 31720   MCHP  Consumer Discretionary       Chandler         AZ     SW
# 31721   MCHP  Consumer Discretionary       Chandler         AZ     SW
# 32223   MDLZ              Technology        Chicago         IL     MW
# 32224   MDLZ              Technology        Chicago         IL     MW
# 32225   MDLZ              Technology        Chicago         IL     MW
# 32727   MRNA              Technology      Cambridge         MA     SE
# 32728   MRNA              Technology      Cambridge         MA     SE
# 32729   MRNA              Technology      Cambridge         MA     SE
# 33231   MNST  Communication Services         Corona         CA      W
# 33232   MNST  Communication Services         Corona         CA      W
# 33233   MNST  Communication Services         Corona         CA      W
# 33735   MSFT              Healthcare        Redmond         WA     NW
# 33736   MSFT              Healthcare        Redmond         WA     NW
# 33737   MSFT              Healthcare        Redmond         WA     NW
# 34239     MU              Technology          Boise         ID     NW
# 34240     MU              Technology          Boise         ID     NW
# 34241     MU              Technology          Boise         ID     NW
# 34743   NFLX              Technology      Los Gatos         CA      W
# 34744   NFLX              Technology      Los Gatos         CA      W
# 34745   NFLX              Technology      Los Gatos         CA      W
# 35247   NTES              Technology       Hangzhou         CN     CH
# 35248   NTES              Technology       Hangzhou         CN     CH
# 35249   NTES              Technology       Hangzhou         CN     CH
# 35751   NVDA              Technology    Santa Clara         CA      W
# 35752   NVDA              Technology    Santa Clara         CA      W
# 35753   NVDA              Technology    Santa Clara         CA      W
# 36255   NXPI              Technology      Eindhoven         NL     NL
# 36256   NXPI              Technology      Eindhoven         NL     NL
# 36257   NXPI              Technology      Eindhoven         NL     NL
# 36759   OKTA              Technology  San Francisco         CA      W
# 36760   OKTA              Technology  San Francisco         CA      W
# 36761   OKTA              Technology  San Francisco         CA      W
# 37263   ODFL              Technology    Thomasville         NC     SE
# 37264   ODFL              Technology    Thomasville         NC     SE
# 37265   ODFL              Technology    Thomasville         NC     SE
# 37767   ORLY             Industrials    Springfield         MO     MW
# 37768   ORLY             Industrials    Springfield         MO     MW
# 37769   ORLY             Industrials    Springfield         MO     MW
# 38271   PCAR              Technology       Bellevue         WA     NW
# 38272   PCAR              Technology       Bellevue         WA     NW
# 38273   PCAR              Technology       Bellevue         WA     NW
# 38775   PANW  Consumer Discretionary    Santa Clara         CA      W
# 38776   PANW  Consumer Discretionary    Santa Clara         CA      W
# 38777   PANW  Consumer Discretionary    Santa Clara         CA      W
# 39279   PAYX             Industrials      Rochester         NY     SE
# 39280   PAYX             Industrials      Rochester         NY     SE
# 39281   PAYX             Industrials      Rochester         NY     SE
# 39783    PDD             Industrials       Shanghai         CN     CH
# 39784    PDD             Industrials       Shanghai         CN     CH
# 39785    PDD             Industrials       Shanghai         CN     CH
# 40287   PYPL              Financials       San Jose         CA      W
# 40288   PYPL              Financials       San Jose         CA      W
# 40289   PYPL              Financials       San Jose         CA      W
# 40791    PEP  Consumer Discretionary       Harrison         NY     SE
# 40792    PEP  Consumer Discretionary       Harrison         NY     SE
# 40793    PEP  Consumer Discretionary       Harrison         NY     SE
# 41296   QCOM        Consumer Staples      San Diego         CA      W
# 41297   QCOM        Consumer Staples      San Diego         CA      W
# 41298   QCOM        Consumer Staples      San Diego         CA      W
# 41800   REGN              Technology      Tarrytown         NY     SE
# 41801   REGN              Technology      Tarrytown         NY     SE
# 41802   REGN              Technology      Tarrytown         NY     SE
# 42304   ROST              Healthcare      San Bruno         CA      W
# 42305   ROST              Healthcare      San Bruno         CA      W
# 42306   ROST              Healthcare      San Bruno         CA      W
# 42808   SIRI              Healthcare       New York         NY     SE
# 42809   SIRI              Healthcare       New York         NY     SE
# 42810   SIRI              Healthcare       New York         NY     SE
# 43312   SGEN  Communication Services        Bothell         WA     NW
# 43313   SGEN  Communication Services        Bothell         WA     NW
# 43314   SGEN  Communication Services        Bothell         WA     NW
# 43816   SPLK              Technology  San Francisco         CA      W
# 43817   SPLK              Technology  San Francisco         CA      W
# 43818   SPLK              Technology  San Francisco         CA      W
# 44320   SWKS  Consumer Discretionary         Irvine         CA      W
# 44321   SWKS  Consumer Discretionary         Irvine         CA      W
# 44322   SWKS  Consumer Discretionary         Irvine         CA      W
# 44824   SBUX  Consumer Discretionary        Seattle         WA     NW
# 44825   SBUX  Consumer Discretionary        Seattle         WA     NW
# 44826   SBUX  Consumer Discretionary        Seattle         WA     NW
# 45328   SNPS              Technology  Mountain View         CA      W
# 45329   SNPS              Technology  Mountain View         CA      W
# 45330   SNPS              Technology  Mountain View         CA      W
# 45832   TSLA              Technology         Austin         TX     SE
# 45833   TSLA              Technology         Austin         TX     SE
# 45834   TSLA              Technology         Austin         TX     SE
# 46335    TXN  Communication Services         Dallas         TX     SE
# 46336    TXN  Communication Services         Dallas         TX     SE
# 46337    TXN  Communication Services         Dallas         TX     SE
# 46839   TMUS  Consumer Discretionary       Bellevue         WA     NW
# 46840   TMUS  Consumer Discretionary       Bellevue         WA     NW
# 46841   TMUS  Consumer Discretionary       Bellevue         WA     NW
# 47345           US     438066.0       205.8594        3.168279  2022-03-10
# 47847           US    1419459.0       186.6740        0.096026  2022-03-08
# 47848           US    1247375.0       184.6647        0.165280  2022-03-09
# 47849           US    1371564.0       183.5925        1.690339  2022-03-10
# 48351           US    1379009.0       238.6797        0.528045  2022-03-08
# 48352           US    1080110.0       239.5513        2.878891  2022-03-09
# 48353           US    1374036.0       239.6352        2.522671  2022-03-10
# 48855           US    5408382.0        48.1664        0.803958  2022-03-08
# 48856           US    4999822.0        47.7198        0.877193  2022-03-09
# 48857           US    5737993.0        47.9174        2.023957  2022-03-10
# 49360           US    2392043.0       233.0048        3.897317  2022-03-08
# 49361           US    1478994.0       229.0807        0.070086  2022-03-09
# 49362           US    1789032.0       226.1950        2.796266  2022-03-10
# 49863           US    2866881.0        69.9416        0.922117  2022-03-08
# 49864           US    1945242.0        69.9773        1.197173  2022-03-09
# 49865           US    3031491.0        70.4602        0.817477  2022-03-10
# 50367           US    6427507.0       109.3114        2.467811  2022-03-08
# 50368           US    5030777.0       103.3206        2.366892  2022-03-09
# 50369           US    6454629.0        99.6973        5.179745  2022-03-10
# 50871           US    3050554.0       209.3268        4.174843  2022-03-08
# 50872           US    2305091.0       208.7971        1.753642  2022-03-09
# 50873           US    1893573.0       202.9376        4.682021  2022-03-10

# %%
# get first stock ticker in first row
prev_ticker = stock_df.iat[0,0]
print (prev_ticker)

i = 0
new_ticker_flag = 'yes'
process_list=[]
process_list_v=[]

for rec in stock_df.iterrows():
# for rec in stock_df:
    new_ticker = stock_df['ticker']
    new_ticker = new_ticker.iloc[i]
    print("previous ticker and new ticker: ", prev_ticker, "and", new_ticker)

    if (prev_ticker == new_ticker):
        if (new_ticker_flag == 'yes'):
            new_ticker_flag = 'no'
            begin_v = stock_df['volume']
            begin_vw = stock_df['volume_weight']
            begin_vw = begin_vw.iloc[i]
            begin_v = begin_v.iloc[i]
            print("begin_vw: ", begin_vw)
            print("begin_v: ", begin_v)

        else:
            last_vw = stock_df['volume_weight']
            last_v = stock_df['volume']
            last_vw = last_vw.iloc[i]
            last_v = last_v.iloc[i]
            print("last_vw: ", last_vw)
            print("last_v: ", last_v)
            
    else:
            print ("new")
            vw_average = 100 - (last_vw/begin_vw) * 100
            v_average = 100 - (last_v/begin_v) * 100
            print("vwa: ", vw_average)
            print("v: ", v_average)
            # append to the pro
            
            process_list.append(vw_average)
            process_list_v.append(v_average)
            
            prev_ticker = new_ticker
            new_ticker_flag == 'yes'
            begin_vw = stock_df['volume_weight']
            begin_v = stock_df['volume']
            begin_vw = begin_vw.iloc[i]
            begin_v = begin_v.iloc[i]
            print("begin_vw: ", begin_vw)
            print("begin_v: ", begin_v)
            
    i=i+1
    
# account for the last record in the dataframe
# vw_average = 100 - (last_vw/begin_vw) * 100
# print("vwa: ", vw_average)       
# process_list.append(vw_average)
vw_average = 100 - (last_vw/begin_vw) * 100
v_average = 100 - (last_v/begin_v) * 100
process_list.append(vw_average)
process_list_v.append(v_average)   

# v_average = 100 - (last_v/begin_v) * 100
# print("v: ", v_average)       
# process_list.append(v_average)

#     new_ticker = stock_df['ticker']
#     new_ticker = new_ticker.head(1)
#     print(new_ticker)
#     if prev_ticker == new_ticker: 
#         print ("good")

#creating records containing the differences between the beginning and ending date volume and volume_weight for each stock
# so that we only have one record for each stock. drop volume and weight and percent change (???)

# move beginning volume

# move ending volume

# volume percent change (end/begin) * 100

# move beginning volume weight

# move ending volume weight

# volume weight percent change (end/begin) * 100

#stock_df

# add the columns to the processing dataframe (creating a new dataframe)
# this new dataframe will have ticket, employee_count, revenue, sector, city_name,
# Out:
# AMD
# previous ticker and new ticker:  AMD and AMD
# begin_vw:  109.6319
# begin_v:  102310329.0
# previous ticker and new ticker:  AMD and AMD
# last_vw:  105.3382
# last_v:  102557375.0
# previous ticker and new ticker:  AMD and AMD
# last_vw:  105.9691
# last_v:  87584432.0
# previous ticker and new ticker:  AMD and ADBE
# new
# vwa:  3.340998377297126
# v:  14.393362961426888
# begin_vw:  447.8637
# begin_v:  2905656.0
# previous ticker and new ticker:  ADBE and ADBE
# last_vw:  437.7568
# last_v:  2686310.0
# previous ticker and new ticker:  ADBE and ADBE
# last_vw:  422.5279
# last_v:  4434498.0
# previous ticker and new ticker:  ADBE and ABNB
# new
# vwa:  5.657033601964173
# v:  -52.616070174858976
# begin_vw:  148.5454
# begin_v:  7023908.0
# previous ticker and new ticker:  ABNB and ABNB
# last_vw:  149.8916
# last_v:  5302511.0
# previous ticker and new ticker:  ABNB and ABNB
# last_vw:  147.8527
# last_v:  4577255.0
# previous ticker and new ticker:  ABNB and ALGN
# new
# vwa:  0.46632208065682335
# v:  34.8332153553264
# begin_vw:  438.9188
# begin_v:  694358.0
# previous ticker and new ticker:  ALGN and ALGN
# last_vw:  427.7159
# last_v:  532709.0
# previous ticker and new ticker:  ALGN and ALGN
# last_vw:  409.9722
# last_v:  957114.0
# previous ticker and new ticker:  ALGN and AMZN
# new
# vwa:  6.594978387802016
# v:  -37.84157451919614
# begin_vw:  2821.5439
# begin_v:  4132233.0
# previous ticker and new ticker:  AMZN and AMZN
# last_vw:  2930.5557
# last_v:  6753145.0
# previous ticker and new ticker:  AMZN and AMZN
# last_vw:  2946.3903
# last_v:  3437028.0
# previous ticker and new ticker:  AMZN and AMGN
# new
# vwa:  -4.424754830148132
# v:  16.823954505953566
# begin_vw:  231.8198
# begin_v:  2640854.0
# previous ticker and new ticker:  AMGN and AMGN
# last_vw:  227.5793
# last_v:  3957273.0
# previous ticker and new ticker:  AMGN and AMGN
# last_vw:  228.6386
# last_v:  2667024.0
# previous ticker and new ticker:  AMGN and AEP
# new
# vwa:  1.3722727739390592
# v:  -0.9909673158758494
# begin_vw:  95.0679
# begin_v:  3006258.0
# previous ticker and new ticker:  AEP and AEP
# last_vw:  95.5087
# last_v:  2897953.0
# previous ticker and new ticker:  AEP and AEP
# last_vw:  95.8241
# last_v:  2254945.0
# previous ticker and new ticker:  AEP and ADI
# new
# vwa:  -0.7954314758188588
# v:  24.991634117896737
# begin_vw:  153.5888
# begin_v:  3046254.0
# previous ticker and new ticker:  ADI and ADI
# last_vw:  150.1401
# last_v:  4035714.0
# previous ticker and new ticker:  ADI and ADI
# last_vw:  149.4415
# last_v:  3964265.0
# previous ticker and new ticker:  ADI and ANSS
# new
# vwa:  2.7002619982707046
# v:  -30.13573392107159
# begin_vw:  310.8922
# begin_v:  404751.0
# previous ticker and new ticker:  ANSS and ANSS
# last_vw:  301.8731
# last_v:  452440.0
# previous ticker and new ticker:  ANSS and ANSS
# last_vw:  298.0095
# last_v:  691956.0
# previous ticker and new ticker:  ANSS and AAPL
# new
# vwa:  4.143783600875167
# v:  -70.9584411156489
# begin_vw:  161.9446
# begin_v:  91445405.0
# previous ticker and new ticker:  AAPL and AAPL
# last_vw:  158.0284
# last_v:  105342033.0
# previous ticker and new ticker:  AAPL and AAPL
# last_vw:  156.1598
# last_v:  96917302.0
# previous ticker and new ticker:  AAPL and AMAT
# new
# vwa:  3.5720857626620557
# v:  -5.983785625969944
# begin_vw:  128.1947
# begin_v:  7623175.0
# previous ticker and new ticker:  AMAT and AMAT
# last_vw:  124.5674
# last_v:  5604387.0
# previous ticker and new ticker:  AMAT and AMAT
# last_vw:  125.9169
# last_v:  6015969.0
# previous ticker and new ticker:  AMAT and ASML
# new
# vwa:  1.7768285272324107
# v:  21.08315760821442
# begin_vw:  614.6359
# begin_v:  1593366.0
# previous ticker and new ticker:  ASML and ASML
# last_vw:  601.0389
# last_v:  735546.0
# previous ticker and new ticker:  ASML and ASML
# last_vw:  595.6976
# last_v:  818991.0
# previous ticker and new ticker:  ASML and TEAM
# new
# vwa:  3.081222557940393
# v:  48.59994502204766
# begin_vw:  260.458
# begin_v:  2614939.0
# previous ticker and new ticker:  TEAM and TEAM
# last_vw:  256.1528
# last_v:  1684942.0
# previous ticker and new ticker:  TEAM and TEAM
# last_vw:  248.8555
# last_v:  1466375.0
# previous ticker and new ticker:  TEAM and ADSK
# new
# vwa:  4.454652957482594
# v:  43.92316608532742
# begin_vw:  205.2018
# begin_v:  1850028.0
# previous ticker and new ticker:  ADSK and ADSK
# last_vw:  199.9849
# last_v:  1458925.0
# previous ticker and new ticker:  ADSK and ADSK
# last_vw:  195.0114
# last_v:  1987062.0
# previous ticker and new ticker:  ADSK and ATVI
# new
# vwa:  4.966038309605452
# v:  -7.407131135312554
# begin_vw:  80.9645
# begin_v:  9914482.0
# previous ticker and new ticker:  ATVI and ATVI
# last_vw:  80.813
# last_v:  6981412.0
# previous ticker and new ticker:  ATVI and ATVI
# last_vw:  80.4348
# last_v:  10714298.0
# previous ticker and new ticker:  ATVI and ADP
# new
# vwa:  0.6542373509377626
# v:  -8.067148641754557
# begin_vw:  209.3495
# begin_v:  1791687.0
# previous ticker and new ticker:  ADP and ADP
# last_vw:  207.7212
# last_v:  2399303.0
# previous ticker and new ticker:  ADP and ADP
# last_vw:  208.5401
# last_v:  1664796.0
# previous ticker and new ticker:  ADP and AZN
# new
# vwa:  0.38662619208548676
# v:  7.082207997267375
# begin_vw:  59.9165
# begin_v:  9256766.0
# previous ticker and new ticker:  AZN and AZN
# last_vw:  60.6449
# last_v:  6667621.0
# previous ticker and new ticker:  AZN and AZN
# last_vw:  60.5447
# last_v:  6342213.0
# previous ticker and new ticker:  AZN and AVGO
# new
# vwa:  -1.0484591055886199
# v:  31.485650604109466
# begin_vw:  595.6417
# begin_v:  2256049.0
# previous ticker and new ticker:  AVGO and AVGO
# last_vw:  584.2682
# last_v:  1932364.0
# previous ticker and new ticker:  AVGO and AVGO
# last_vw:  582.1116
# last_v:  1981534.0
# previous ticker and new ticker:  AVGO and BIDU
# new
# vwa:  2.271516584550753
# v:  12.167953798875814
# begin_vw:  143.0105
# begin_v:  3303007.0
# previous ticker and new ticker:  BIDU and BIDU
# last_vw:  135.0444
# last_v:  4452305.0
# previous ticker and new ticker:  BIDU and BIDU
# last_vw:  123.212
# last_v:  7837318.0
# previous ticker and new ticker:  BIDU and BIIB
# new
# vwa:  13.844088371133594
# v:  -137.27827400910746
# begin_vw:  204.3033
# begin_v:  1236890.0
# previous ticker and new ticker:  BIIB and BIIB
# last_vw:  198.5026
# last_v:  1166270.0
# previous ticker and new ticker:  BIIB and BIIB
# last_vw:  199.0211
# last_v:  787917.0
# previous ticker and new ticker:  BIIB and BMRN
# new
# vwa:  2.585469740332144
# v:  36.29853907784848
# begin_vw:  78.6484
# begin_v:  1583428.0
# previous ticker and new ticker:  BMRN and BMRN
# last_vw:  77.6476
# last_v:  821615.0
# previous ticker and new ticker:  BMRN and BMRN
# last_vw:  76.5255
# last_v:  842813.0
# previous ticker and new ticker:  BMRN and BKNG
# new
# vwa:  2.6992284649147393
# v:  46.77288768418899
# begin_vw:  2049.4691
# begin_v:  776359.0
# previous ticker and new ticker:  BKNG and BKNG
# last_vw:  2028.467
# last_v:  638530.0
# previous ticker and new ticker:  BKNG and BKNG
# last_vw:  2030.8021
# last_v:  360797.0
# previous ticker and new ticker:  BKNG and CDNS
# new
# vwa:  0.9108212463412997
# v:  53.527040969448414
# begin_vw:  150.3021
# begin_v:  2086904.0
# previous ticker and new ticker:  CDNS and CDNS
# last_vw:  148.147
# last_v:  1603218.0
# previous ticker and new ticker:  CDNS and CDNS
# last_vw:  146.3686
# last_v:  1382365.0
# previous ticker and new ticker:  CDNS and CHTR
# new
# vwa:  2.6170625693187333
# v:  33.76001004358609
# begin_vw:  561.2489
# begin_v:  1212273.0
# previous ticker and new ticker:  CHTR and CHTR
# last_vw:  561.1658
# last_v:  1537737.0
# previous ticker and new ticker:  CHTR and CHTR
# last_vw:  567.4888
# last_v:  1788310.0
# previous ticker and new ticker:  CHTR and CPRT
# new
# vwa:  -1.1117883705428824
# v:  -47.51710217088066
# begin_vw:  114.6927
# begin_v:  2624716.0
# previous ticker and new ticker:  CPRT and CPRT
# last_vw:  115.1458
# last_v:  1924115.0
# previous ticker and new ticker:  CPRT and CPRT
# last_vw:  115.7932
# last_v:  1867003.0
# previous ticker and new ticker:  CPRT and CRWD
# new
# vwa:  -0.959520527461649
# v:  28.86838042668235
# begin_vw:  171.3546
# begin_v:  9287180.0
# previous ticker and new ticker:  CRWD and CRWD
# last_vw:  191.8395
# last_v:  24135352.0
# previous ticker and new ticker:  CRWD and CRWD
# last_vw:  193.156
# last_v:  7983054.0
# previous ticker and new ticker:  CRWD and CTAS
# new
# vwa:  -12.722973296310698
# v:  14.042217336155858
# begin_vw:  373.3328
# begin_v:  460652.0
# previous ticker and new ticker:  CTAS and CTAS
# last_vw:  368.7097
# last_v:  487435.0
# previous ticker and new ticker:  CTAS and CTAS
# last_vw:  370.587
# last_v:  371905.0
# previous ticker and new ticker:  CTAS and CSCO
# new
# vwa:  0.7354831935474238
# v:  19.26551930741644
# begin_vw:  55.738
# begin_v:  19150856.0
# previous ticker and new ticker:  CSCO and CSCO
# last_vw:  54.6294
# last_v:  18550934.0
# previous ticker and new ticker:  CSCO and CSCO
# last_vw:  55.0892
# last_v:  20330307.0
# previous ticker and new ticker:  CSCO and CMCSA
# new
# vwa:  1.1640173669668883
# v:  -6.158737760860404
# begin_vw:  46.3043
# begin_v:  20113718.0
# previous ticker and new ticker:  CMCSA and CMCSA
# last_vw:  45.3313
# last_v:  18179456.0
# previous ticker and new ticker:  CMCSA and CMCSA
# last_vw:  45.3243
# last_v:  19584780.0
# previous ticker and new ticker:  CMCSA and COST
# new
# vwa:  2.116434110870898
# v:  2.6297375751216094
# begin_vw:  525.2468
# begin_v:  2789706.0
# previous ticker and new ticker:  COST and COST
# last_vw:  527.6596
# last_v:  1777660.0
# previous ticker and new ticker:  COST and COST
# last_vw:  532.3424
# last_v:  1735112.0
# previous ticker and new ticker:  COST and CSX
# new
# vwa:  -1.3509078018181242
# v:  37.80305164773635
# begin_vw:  34.6627
# begin_v:  21741832.0
# previous ticker and new ticker:  CSX and CSX
# last_vw:  34.833
# last_v:  24267691.0
# previous ticker and new ticker:  CSX and CSX
# last_vw:  34.9849
# last_v:  21957297.0
# previous ticker and new ticker:  CSX and CTSH
# new
# vwa:  -0.9295294365413014
# v:  -0.9910158444789801
# begin_vw:  88.5163
# begin_v:  4135694.0
# previous ticker and new ticker:  CTSH and CTSH
# last_vw:  87.1445
# last_v:  2363514.0
# previous ticker and new ticker:  CTSH and CTSH
# last_vw:  88.5223
# last_v:  3576086.0
# previous ticker and new ticker:  CTSH and DDOG
# new
# vwa:  -0.006778412563562597
# v:  13.531175178821258
# begin_vw:  139.3596
# begin_v:  6419730.0
# previous ticker and new ticker:  DDOG and DDOG
# last_vw:  139.1711
# last_v:  3091661.0
# previous ticker and new ticker:  DDOG and DDOG
# last_vw:  130.0496
# last_v:  4354633.0
# previous ticker and new ticker:  DDOG and DOCU
# new
# vwa:  6.680558784611904
# v:  32.16797279636371
# begin_vw:  98.2739
# begin_v:  5174835.0
# previous ticker and new ticker:  DOCU and DOCU
# last_vw:  88.3931
# last_v:  11491126.0
# previous ticker and new ticker:  DOCU and DOCU
# last_vw:  74.0216
# last_v:  44966816.0
# previous ticker and new ticker:  DOCU and DXCM
# new
# vwa:  24.678271646897088
# v:  -768.9516863822711
# begin_vw:  407.0818
# begin_v:  1055306.0
# previous ticker and new ticker:  DXCM and DXCM
# last_vw:  404.807
# last_v:  634775.0
# previous ticker and new ticker:  DXCM and DXCM
# last_vw:  396.9054
# last_v:  607547.0
# previous ticker and new ticker:  DXCM and DLTR
# new
# vwa:  2.499841555186208
# v:  42.42930486512917
# begin_vw:  148.2673
# begin_v:  6167252.0
# previous ticker and new ticker:  DLTR and DLTR
# last_vw:  147.4767
# last_v:  2537913.0
# previous ticker and new ticker:  DLTR and DLTR
# last_vw:  147.3746
# last_v:  1682512.0
# previous ticker and new ticker:  DLTR and EA
# new
# vwa:  0.6020882554683453
# v:  72.71861114155867
# begin_vw:  125.1684
# begin_v:  2139504.0
# previous ticker and new ticker:  EA and EA
# last_vw:  123.7974
# last_v:  1222004.0
# previous ticker and new ticker:  EA and EA
# last_vw:  122.9628
# last_v:  1195222.0
# previous ticker and new ticker:  EA and EBAY
# new
# vwa:  1.7621060906746493
# v:  44.13555665238298
# begin_vw:  53.0511
# begin_v:  10250423.0
# previous ticker and new ticker:  EBAY and EBAY
# last_vw:  53.0869
# last_v:  18926205.0
# previous ticker and new ticker:  EBAY and EBAY
# last_vw:  50.9199
# last_v:  9217656.0
# previous ticker and new ticker:  EBAY and EXC
# new
# vwa:  4.017258831579369
# v:  10.075359816858281
# begin_vw:  43.5758
# begin_v:  8573141.0
# previous ticker and new ticker:  EXC and EXC
# last_vw:  43.53
# last_v:  9859163.0
# previous ticker and new ticker:  EXC and EXC
# last_vw:  43.8972
# last_v:  6407446.0
# previous ticker and new ticker:  EXC and FAST
# new
# vwa:  -0.7375653459029934
# v:  25.26139486099669
# begin_vw:  54.6028
# begin_v:  3616368.0
# previous ticker and new ticker:  FAST and FAST
# last_vw:  54.2348
# last_v:  2401261.0
# previous ticker and new ticker:  FAST and FAST
# last_vw:  54.3752
# last_v:  2446355.0
# previous ticker and new ticker:  FAST and FB
# new
# vwa:  0.4168284410323366
# v:  32.35326161496839
# begin_vw:  196.9614
# begin_v:  31894695.0
# previous ticker and new ticker:  FB and FB
# last_vw:  193.9663
# last_v:  24852975.0
# previous ticker and new ticker:  FB and FB
# last_vw:  189.4396
# last_v:  34694534.0
# previous ticker and new ticker:  FB and FISV
# new
# vwa:  3.8189208646973327
# v:  -8.778384618507886
# begin_vw:  96.1614
# begin_v:  4452408.0
# previous ticker and new ticker:  FISV and FISV
# last_vw:  94.8574
# last_v:  2764771.0
# previous ticker and new ticker:  FISV and FISV
# last_vw:  94.8533
# last_v:  2720970.0
# previous ticker and new ticker:  FISV and FTNT
# new
# vwa:  1.3603171334859923
# v:  38.88767606203205
# begin_vw:  283.2592
# begin_v:  2198856.0
# previous ticker and new ticker:  FTNT and FTNT
# last_vw:  283.9637
# last_v:  1467666.0
# previous ticker and new ticker:  FTNT and FTNT
# last_vw:  282.1387
# last_v:  1369052.0
# previous ticker and new ticker:  FTNT and GILD
# new
# vwa:  0.39557408903225166
# v:  37.737987389806335
# begin_vw:  59.3244
# begin_v:  13678135.0
# previous ticker and new ticker:  GILD and GILD
# last_vw:  57.8358
# last_v:  13243687.0
# previous ticker and new ticker:  GILD and GILD
# last_vw:  58.4238
# last_v:  13007627.0
# previous ticker and new ticker:  GILD and GOOG
# new
# vwa:  1.5180937354612922
# v:  4.902042566475615
# begin_vw:  2650.3074
# begin_v:  1612872.0
# previous ticker and new ticker:  GOOG and GOOG
# last_vw:  2649.0884
# last_v:  1213260.0
# previous ticker and new ticker:  GOOG and GOOG
# last_vw:  2637.3465
# last_v:  1329990.0
# previous ticker and new ticker:  GOOG and GOOGL
# new
# vwa:  0.489033838112519
# v:  17.53902355549603
# begin_vw:  2643.6693
# begin_v:  1851270.0
# previous ticker and new ticker:  GOOGL and GOOGL
# last_vw:  2640.1379
# last_v:  1355070.0
# previous ticker and new ticker:  GOOGL and GOOGL
# last_vw:  2626.3924
# last_v:  1576322.0
# previous ticker and new ticker:  GOOGL and HON
# new
# vwa:  0.6535197121667125
# v:  14.851858453926226
# begin_vw:  185.6762
# begin_v:  2899407.0
# previous ticker and new ticker:  HON and HON
# last_vw:  184.1054
# last_v:  2455436.0
# previous ticker and new ticker:  HON and HON
# last_vw:  183.66
# last_v:  2725571.0
# previous ticker and new ticker:  HON and ILMN
# new
# vwa:  1.0858688404868246
# v:  5.995570818446666
# begin_vw:  324.633
# begin_v:  873582.0
# previous ticker and new ticker:  ILMN and ILMN
# last_vw:  315.4683
# last_v:  768526.0
# previous ticker and new ticker:  ILMN and ILMN
# last_vw:  308.8718
# last_v:  642681.0
# previous ticker and new ticker:  ILMN and INTC
# new
# vwa:  4.85508250855581
# v:  26.43151988021731
# begin_vw:  47.5889
# begin_v:  36076458.0
# previous ticker and new ticker:  INTC and INTC
# last_vw:  46.5762
# last_v:  36455953.0
# previous ticker and new ticker:  INTC and INTC
# last_vw:  46.2802
# last_v:  27082085.0
# previous ticker and new ticker:  INTC and INTU
# new
# vwa:  2.750011031984357
# v:  24.93141926516178
# begin_vw:  463.3738
# begin_v:  1950593.0
# previous ticker and new ticker:  INTU and INTU
# last_vw:  450.4148
# last_v:  1756284.0
# previous ticker and new ticker:  INTU and INTU
# last_vw:  443.7956
# last_v:  2303338.0
# previous ticker and new ticker:  INTU and ISRG
# new
# vwa:  4.225141775387399
# v:  -18.083987792430307
# begin_vw:  277.0114
# begin_v:  2080804.0
# previous ticker and new ticker:  ISRG and ISRG
# last_vw:  274.4961
# last_v:  1331160.0
# previous ticker and new ticker:  ISRG and ISRG
# last_vw:  276.1064
# last_v:  1842068.0
# previous ticker and new ticker:  ISRG and MRVL
# new
# vwa:  0.3267013559730714
# v:  11.473257452407807
# begin_vw:  66.578
# begin_v:  10367602.0
# previous ticker and new ticker:  MRVL and MRVL
# last_vw:  65.2805
# last_v:  7677751.0
# previous ticker and new ticker:  MRVL and MRVL
# last_vw:  64.1245
# last_v:  6971974.0
# previous ticker and new ticker:  MRVL and IDXX
# new
# vwa:  3.685151251164058
# v:  32.752298940487876
# begin_vw:  527.6219
# begin_v:  558578.0
# previous ticker and new ticker:  IDXX and IDXX
# last_vw:  520.0078
# last_v:  525296.0
# previous ticker and new ticker:  IDXX and IDXX
# last_vw:  506.76
# last_v:  334124.0
# previous ticker and new ticker:  IDXX and JD
# new
# vwa:  3.95394884101664
# v:  40.1831078202149
# begin_vw:  61.8761
# begin_v:  9487275.0
# previous ticker and new ticker:  JD and JD
# last_vw:  52.8668
# last_v:  55348139.0
# previous ticker and new ticker:  JD and JD
# last_vw:  49.7949
# last_v:  32963038.0
# previous ticker and new ticker:  JD and KDP
# new
# vwa:  19.524824609178665
# v:  -247.44474045497788
# begin_vw:  37.5559
# begin_v:  9897116.0
# previous ticker and new ticker:  KDP and KDP
# last_vw:  37.0888
# last_v:  8174470.0
# previous ticker and new ticker:  KDP and KDP
# last_vw:  37.0816
# last_v:  6844868.0
# previous ticker and new ticker:  KDP and KLAC
# new
# vwa:  1.2629174111124968
# v:  30.839771909311764
# begin_vw:  338.4671
# begin_v:  1521253.0
# previous ticker and new ticker:  KLAC and KLAC
# last_vw:  328.3266
# last_v:  1555920.0
# previous ticker and new ticker:  KLAC and KLAC
# last_vw:  326.6187
# last_v:  958881.0
# previous ticker and new ticker:  KLAC and KHC
# new
# vwa:  3.5006061150404406
# v:  36.96768387638348
# begin_vw:  38.5197
# begin_v:  10448481.0
# previous ticker and new ticker:  KHC and KHC
# last_vw:  37.4623
# last_v:  5216457.0
# previous ticker and new ticker:  KHC and KHC
# last_vw:  37.6486
# last_v:  4722638.0
# previous ticker and new ticker:  KHC and LRCX
# new
# vwa:  2.261440250053866
# v:  54.80072175084589
# begin_vw:  515.2334
# begin_v:  1443926.0
# previous ticker and new ticker:  LRCX and LRCX
# last_vw:  495.6429
# last_v:  1110604.0
# previous ticker and new ticker:  LRCX and LRCX
# last_vw:  488.7582
# last_v:  1038936.0
# previous ticker and new ticker:  LRCX and LCID
# new
# vwa:  5.138486751829362
# v:  28.047836246455844
# begin_vw:  25.2081
# begin_v:  18168840.0
# previous ticker and new ticker:  LCID and LCID
# last_vw:  24.1074
# last_v:  16508757.0
# previous ticker and new ticker:  LCID and LCID
# last_vw:  23.2549
# last_v:  18824699.0
# previous ticker and new ticker:  LCID and LULU
# new
# vwa:  7.748303124789274
# v:  -3.609801176079472
# begin_vw:  304.8735
# begin_v:  1574343.0
# previous ticker and new ticker:  LULU and LULU
# last_vw:  300.6244
# last_v:  934837.0
# previous ticker and new ticker:  LULU and LULU
# last_vw:  295.5002
# last_v:  978426.0
# previous ticker and new ticker:  LULU and MELI
# new
# vwa:  3.0744882713649986
# v:  37.85178960366324
# begin_vw:  960.0765
# begin_v:  1123495.0
# previous ticker and new ticker:  MELI and MELI
# last_vw:  935.0841
# last_v:  634605.0
# previous ticker and new ticker:  MELI and MELI
# last_vw:  903.7596
# last_v:  575187.0
# previous ticker and new ticker:  MELI and MAR
# new
# vwa:  5.865876312981314
# v:  48.80377749789718
# begin_vw:  160.2369
# begin_v:  3509843.0
# previous ticker and new ticker:  MAR and MAR
# last_vw:  161.8691
# last_v:  2573293.0
# previous ticker and new ticker:  MAR and MAR
# last_vw:  163.0318
# last_v:  2316271.0
# previous ticker and new ticker:  MAR and MTCH
# new
# vwa:  -1.7442299495309896
# v:  34.00642136984476
# begin_vw:  98.4019
# begin_v:  5407345.0
# previous ticker and new ticker:  MTCH and MTCH
# last_vw:  95.3778
# last_v:  2462202.0
# previous ticker and new ticker:  MTCH and MTCH
# last_vw:  90.1154
# last_v:  3162002.0
# previous ticker and new ticker:  MTCH and MCHP
# new
# vwa:  8.42107723529729
# v:  41.5239456701949
# begin_vw:  70.8634
# begin_v:  6711334.0
# previous ticker and new ticker:  MCHP and MCHP
# last_vw:  69.5075
# last_v:  3607907.0
# previous ticker and new ticker:  MCHP and MCHP
# last_vw:  69.7539
# last_v:  3528704.0
# previous ticker and new ticker:  MCHP and MDLZ
# new
# vwa:  1.5656883525204819
# v:  47.42171973559951
# begin_vw:  61.5561
# begin_v:  8709398.0
# previous ticker and new ticker:  MDLZ and MDLZ
# last_vw:  60.1671
# last_v:  7341958.0
# previous ticker and new ticker:  MDLZ and MDLZ
# last_vw:  59.737
# last_v:  9385282.0
# previous ticker and new ticker:  MDLZ and MRNA
# new
# vwa:  2.9551904685319528
# v:  -7.760398594713422
# begin_vw:  140.7141
# begin_v:  9533949.0
# previous ticker and new ticker:  MRNA and MRNA
# last_vw:  138.5617
# last_v:  5557146.0
# previous ticker and new ticker:  MRNA and MRNA
# last_vw:  140.7167
# last_v:  5356440.0
# previous ticker and new ticker:  MRNA and MNST
# new
# vwa:  -0.0018477181746590077
# v:  43.81719474270316
# begin_vw:  76.4294
# begin_v:  3537523.0
# previous ticker and new ticker:  MNST and MNST
# last_vw:  75.3567
# last_v:  2758616.0
# previous ticker and new ticker:  MNST and MNST
# last_vw:  74.0202
# last_v:  1687512.0
# previous ticker and new ticker:  MNST and MSFT
# new
# vwa:  3.1521901257892893
# v:  52.29679072051263
# begin_vw:  286.2058
# begin_v:  35204480.0
# previous ticker and new ticker:  MSFT and MSFT
# last_vw:  283.9699
# last_v:  30628012.0
# previous ticker and new ticker:  MSFT and MSFT
# last_vw:  283.7288
# last_v:  27209330.0
# previous ticker and new ticker:  MSFT and MU
# new
# vwa:  0.8654611471885119
# v:  22.7106038776883
# begin_vw:  79.2627
# begin_v:  19647851.0
# previous ticker and new ticker:  MU and MU
# last_vw:  75.3013
# last_v:  21691955.0
# previous ticker and new ticker:  MU and MU
# last_vw:  73.5912
# last_v:  22786509.0
# previous ticker and new ticker:  MU and NFLX
# new
# vwa:  7.155320219977355
# v:  -15.974561289171007
# begin_vw:  358.5485
# begin_v:  6485186.0
# previous ticker and new ticker:  NFLX and NFLX
# last_vw:  358.9168
# last_v:  4807767.0
# previous ticker and new ticker:  NFLX and NFLX
# last_vw:  346.3833
# last_v:  4819925.0
# previous ticker and new ticker:  NFLX and NTES
# new
# vwa:  3.3929022154603814
# v:  25.67792195937018
# begin_vw:  88.5448
# begin_v:  3654682.0
# previous ticker and new ticker:  NTES and NTES
# last_vw:  80.8696
# last_v:  5597701.0
# previous ticker and new ticker:  NTES and NTES
# last_vw:  80.1779
# last_v:  4742719.0
# previous ticker and new ticker:  NTES and NVDA
# new
# vwa:  9.449340898618559
# v:  -29.77104437540669
# begin_vw:  227.8595
# begin_v:  49274195.0
# previous ticker and new ticker:  NVDA and NVDA
# last_vw:  223.6303
# last_v:  42806565.0
# previous ticker and new ticker:  NVDA and NVDA
# last_vw:  224.9843
# last_v:  36695857.0
# previous ticker and new ticker:  NVDA and NXPI
# new
# vwa:  1.26183020677216
# v:  25.527231850261572
# begin_vw:  183.8995
# begin_v:  3108923.0
# previous ticker and new ticker:  NXPI and NXPI
# last_vw:  179.3581
# last_v:  1899207.0
# previous ticker and new ticker:  NXPI and NXPI
# last_vw:  180.2879
# last_v:  2159407.0
# previous ticker and new ticker:  NXPI and OKTA
# new
# vwa:  1.9638987599204967
# v:  30.541637731137115
# begin_vw:  168.4818
# begin_v:  2456727.0
# previous ticker and new ticker:  OKTA and OKTA
# last_vw:  165.3699
# last_v:  1374880.0
# previous ticker and new ticker:  OKTA and OKTA
# last_vw:  157.0688
# last_v:  2056977.0
# previous ticker and new ticker:  OKTA and ODFL
# new
# vwa:  6.7740254436977665
# v:  16.271649230866927
# begin_vw:  305.9245
# begin_v:  880700.0
# previous ticker and new ticker:  ODFL and ODFL
# last_vw:  307.8806
# last_v:  587580.0
# previous ticker and new ticker:  ODFL and ODFL
# last_vw:  308.1769
# last_v:  619717.0
# previous ticker and new ticker:  ODFL and ORLY
# new
# vwa:  -0.7362600903163923
# v:  29.633586919495855
# begin_vw:  673.5724
# begin_v:  493633.0
# previous ticker and new ticker:  ORLY and ORLY
# last_vw:  672.3348
# last_v:  454342.0
# previous ticker and new ticker:  ORLY and ORLY
# last_vw:  679.5612
# last_v:  404854.0
# previous ticker and new ticker:  ORLY and PCAR
# new
# vwa:  -0.8891100644860188
# v:  17.98481868108493
# begin_vw:  87.198
# begin_v:  2786430.0
# previous ticker and new ticker:  PCAR and PCAR
# last_vw:  85.9713
# last_v:  1738721.0
# previous ticker and new ticker:  PCAR and PCAR
# last_vw:  85.8099
# last_v:  1367450.0
# previous ticker and new ticker:  PCAR and PANW
# new
# vwa:  1.591894309502507
# v:  50.92465986943867
# begin_vw:  551.7975
# begin_v:  1731623.0
# previous ticker and new ticker:  PANW and PANW
# last_vw:  551.1671
# last_v:  1074692.0
# previous ticker and new ticker:  PANW and PANW
# last_vw:  551.3746
# last_v:  1175810.0
# previous ticker and new ticker:  PANW and PAYX
# new
# vwa:  0.07664043421726774
# v:  32.09780650869156
# begin_vw:  121.6811
# begin_v:  1679589.0
# previous ticker and new ticker:  PAYX and PAYX
# last_vw:  121.3758
# last_v:  1317611.0
# previous ticker and new ticker:  PAYX and PAYX
# last_vw:  121.6751
# last_v:  1071014.0
# previous ticker and new ticker:  PAYX and PDD
# new
# vwa:  0.004930921893375739
# v:  36.23356666422559
# begin_vw:  42.7136
# begin_v:  7731168.0
# previous ticker and new ticker:  PDD and PDD
# last_vw:  36.3579
# last_v:  18296948.0
# previous ticker and new ticker:  PDD and PDD
# last_vw:  33.4402
# last_v:  17274393.0
# previous ticker and new ticker:  PDD and PYPL
# new
# vwa:  21.71064953551094
# v:  -123.43833428532403
# begin_vw:  99.3076
# begin_v:  20811232.0
# previous ticker and new ticker:  PYPL and PYPL
# last_vw:  97.9276
# last_v:  14683698.0
# previous ticker and new ticker:  PYPL and PYPL
# last_vw:  97.3225
# last_v:  15141665.0
# previous ticker and new ticker:  PYPL and PEP
# new
# vwa:  1.9989406651655912
# v:  27.242822529680126
# begin_vw:  157.6512
# begin_v:  5764927.0
# previous ticker and new ticker:  PEP and PEP
# last_vw:  154.6174
# last_v:  5965671.0
# previous ticker and new ticker:  PEP and PEP
# last_vw:  154.793
# last_v:  4762675.0
# previous ticker and new ticker:  PEP and QCOM
# new
# vwa:  1.8129896886290595
# v:  17.385337229768922
# begin_vw:  156.6853
# begin_v:  9276774.0
# previous ticker and new ticker:  QCOM and QCOM
# last_vw:  153.5928
# last_v:  8888772.0
# previous ticker and new ticker:  QCOM and QCOM
# last_vw:  154.1756
# last_v:  7394419.0
# previous ticker and new ticker:  QCOM and REGN
# new
# vwa:  1.601745664717754
# v:  20.291051609104628
# begin_vw:  622.528
# begin_v:  538933.0
# previous ticker and new ticker:  REGN and REGN
# last_vw:  626.3473
# last_v:  480626.0
# previous ticker and new ticker:  REGN and REGN
# last_vw:  645.0864
# last_v:  803192.0
# previous ticker and new ticker:  REGN and ROST
# new
# vwa:  -3.623676364757884
# v:  -49.03373888776528
# begin_vw:  88.3599
# begin_v:  3488185.0
# previous ticker and new ticker:  ROST and ROST
# last_vw:  88.9545
# last_v:  2235105.0
# previous ticker and new ticker:  ROST and ROST
# last_vw:  88.5806
# last_v:  2228206.0
# previous ticker and new ticker:  ROST and SIRI
# new
# vwa:  -0.24977393591439068
# v:  36.121335307616995
# begin_vw:  6.2707
# begin_v:  29496325.0
# previous ticker and new ticker:  SIRI and SIRI
# last_vw:  6.2
# last_v:  25034845.0
# previous ticker and new ticker:  SIRI and SIRI
# last_vw:  6.2143
# last_v:  21245836.0
# previous ticker and new ticker:  SIRI and SGEN
# new
# vwa:  0.8994211172596351
# v:  27.971243875296324
# begin_vw:  139.8033
# begin_v:  986096.0
# previous ticker and new ticker:  SGEN and SGEN
# last_vw:  140.4637
# last_v:  820110.0
# previous ticker and new ticker:  SGEN and SGEN
# last_vw:  138.8715
# last_v:  754717.0
# previous ticker and new ticker:  SGEN and SPLK
# new
# vwa:  0.6665078721317883
# v:  23.464145478736356
# begin_vw:  128.0419
# begin_v:  1838217.0
# previous ticker and new ticker:  SPLK and SPLK
# last_vw:  127.1526
# last_v:  1726490.0
# previous ticker and new ticker:  SPLK and SPLK
# last_vw:  123.9052
# last_v:  1901661.0
# previous ticker and new ticker:  SPLK and SWKS
# new
# vwa:  3.230739312678125
# v:  -3.4513879482128687
# begin_vw:  134.2065
# begin_v:  1826248.0
# previous ticker and new ticker:  SWKS and SWKS
# last_vw:  131.1486
# last_v:  1262372.0
# previous ticker and new ticker:  SWKS and SWKS
# last_vw:  128.9609
# last_v:  1388463.0
# previous ticker and new ticker:  SWKS and SBUX
# new
# vwa:  3.9086035326157855
# v:  23.971826389406033
# begin_vw:  87.4006
# begin_v:  8811617.0
# previous ticker and new ticker:  SBUX and SBUX
# last_vw:  86.6866
# last_v:  9114348.0
# previous ticker and new ticker:  SBUX and SBUX
# last_vw:  84.2136
# last_v:  15351744.0
# previous ticker and new ticker:  SBUX and SNPS
# new
# vwa:  3.6464280565579656
# v:  -74.22164399564801
# begin_vw:  306.8868
# begin_v:  809770.0
# previous ticker and new ticker:  SNPS and SNPS
# last_vw:  297.4164
# last_v:  941777.0
# previous ticker and new ticker:  SNPS and SNPS
# last_vw:  297.5679
# last_v:  953157.0
# previous ticker and new ticker:  SNPS and TSLA
# new
# vwa:  3.0365919941815633
# v:  -17.70712671499315
# begin_vw:  850.6831
# begin_v:  19724223.0
# previous ticker and new ticker:  TSLA and TSLA
# last_vw:  830.2271
# last_v:  19549548.0
# previous ticker and new ticker:  TSLA and TSLA
# last_vw:  808.9169
# last_v:  22345722.0
# previous ticker and new ticker:  TSLA and TXN
# new
# vwa:  4.909724902257949
# v:  -13.290759286183288
# begin_vw:  172.402
# begin_v:  6047344.0
# previous ticker and new ticker:  TXN and TXN
# last_vw:  171.6576
# last_v:  6079155.0
# previous ticker and new ticker:  TXN and TXN
# last_vw:  171.846
# last_v:  4869906.0
# previous ticker and new ticker:  TXN and TMUS
# new
# vwa:  0.3225020591408452
# v:  19.470332760960844
# begin_vw:  121.8272
# begin_v:  4290357.0
# previous ticker and new ticker:  TMUS and TMUS
# last_vw:  122.625
# last_v:  4200597.0
# previous ticker and new ticker:  TMUS and TMUS
# last_vw:  125.2409
# last_v:  4207189.0
# previous ticker and new ticker:  TMUS and VRSN
# new
# vwa:  -2.802083606944919
# v:  1.9384867040202067
# begin_vw:  209.1856
# begin_v:  813669.0
# previous ticker and new ticker:  VRSN and VRSN
# last_vw:  206.7204
# last_v:  785306.0
# previous ticker and new ticker:  VRSN and VRSN
# last_vw:  205.8594
# last_v:  438066.0
# previous ticker and new ticker:  VRSN and VRSK
# new
# vwa:  1.5900712094905174
# v:  46.16164558315482
# begin_vw:  186.674
# begin_v:  1419459.0
# previous ticker and new ticker:  VRSK and VRSK
# last_vw:  184.6647
# last_v:  1247375.0
# previous ticker and new ticker:  VRSK and VRSK
# last_vw:  183.5925
# last_v:  1371564.0
# previous ticker and new ticker:  VRSK and VRTX
# new
# vwa:  1.650738720978822
# v:  3.3741728362707164
# begin_vw:  238.6797
# begin_v:  1379009.0
# previous ticker and new ticker:  VRTX and VRTX
# last_vw:  239.5513
# last_v:  1080110.0
# previous ticker and new ticker:  VRTX and VRTX
# last_vw:  239.6352
# last_v:  1374036.0
# previous ticker and new ticker:  VRTX and WBA
# new
# vwa:  -0.40032730056221055
# v:  0.360621286735622
# begin_vw:  48.1664
# begin_v:  5408382.0
# previous ticker and new ticker:  WBA and WBA
# last_vw:  47.7198
# last_v:  4999822.0
# previous ticker and new ticker:  WBA and WBA
# last_vw:  47.9174
# last_v:  5737993.0
# previous ticker and new ticker:  WBA and WDAY
# new
# vwa:  0.5169578793515939
# v:  -6.094447470611357
# begin_vw:  233.0048
# begin_v:  2392043.0
# previous ticker and new ticker:  WDAY and WDAY
# last_vw:  229.0807
# last_v:  1478994.0
# previous ticker and new ticker:  WDAY and WDAY
# last_vw:  226.195
# last_v:  1789032.0
# previous ticker and new ticker:  WDAY and XEL
# new
# vwa:  2.9226007361221775
# v:  25.20903679407101
# begin_vw:  69.9416
# begin_v:  2866881.0
# previous ticker and new ticker:  XEL and XEL
# last_vw:  69.9773
# last_v:  1945242.0
# previous ticker and new ticker:  XEL and XEL
# last_vw:  70.4602
# last_v:  3031491.0
# previous ticker and new ticker:  XEL and ZM
# new
# vwa:  -0.741475745479093
# v:  -5.741780004122958
# begin_vw:  109.3114
# begin_v:  6427507.0
# previous ticker and new ticker:  ZM and ZM
# last_vw:  103.3206
# last_v:  5030777.0
# previous ticker and new ticker:  ZM and ZM
# last_vw:  99.6973
# last_v:  6454629.0
# previous ticker and new ticker:  ZM and ZS
# new
# vwa:  8.795148538944701
# v:  -0.42196764624293337
# begin_vw:  209.3268
# begin_v:  3050554.0
# previous ticker and new ticker:  ZS and ZS
# last_vw:  208.7971
# last_v:  2305091.0
# previous ticker and new ticker:  ZS and ZS
# last_vw:  202.9376
# last_v:  1893573.0

# %%
len(process_list)
# Out:
# 102

# %%
len(process_list_v)
# Out:
# 102

# %%
# process_list

# %%
#combine object dataframe with process list into process_df
stock_df = stock_df.drop(['volume', 'volume_weight', 'percent_change','date'], axis=1)
stock_df.columns.tolist()
#stock_df = stock_df.drop_duplicates(subset='ticker')
stock_df["volume_weight_avg"] = process_list
stock_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-f1de75cdafdc> in <module>
#       3 stock_df.columns.tolist()
#       4 #stock_df = stock_df.drop_duplicates(subset='ticker')
# ----> 5 stock_df["volume_weight_avg"] = process_list
#       6 stock_df
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# -> 3899             value = sanitize_index(value, self.index)
#    3900             if not isinstance(value, (np.ndarray, Index)):
#    3901                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     750     if len(data) != len(index):
#     751         raise ValueError(
# --> 752             "Length of values "
#     753             f"({len(data)}) "
#     754             "does not match length of index "
#
# ValueError: Length of values (102) does not match length of index (306)

# %%
# unique values for each column (getting to know your data)
stock_df.nunique()

# %%
stock_df.dtypes

# %% [markdown]
# ## Indexes, Features (the possible causes), Targets (the desired effects), Throw-Aways
#
# ### NOTE: we have to keep our ticker columns (so all this must called within the gradient_boosting_decision_tree_model)
#
# #### Indexes/Primary Key:
#
# - Concatinate ticker and date to yield ticker_and_date
#
# #### Features are:
# - TICKER,
# - DATE
# - EMPLOYEE COUNT
# - REVENUE
# - SECTOR
# - CITY NAME
# - STATE NAME
# - COUNTRY CODE
# - VOLUME
# - VOLUME WEIGHT
# - AVERAGE_VOLUME (calculate average using begin_date/end_date) (???)
# - AVERAGE_VOLUME_WEIGHT (calculate average using begin_date/end_date) (???)
# - PERCENT CHANGE (% change from close to open)
#
# #### Target is:
# - PERCENT CHANGE (and/or) Volume Weight (???)(I think the percent change matters more because percent change yields better
#
# #### Throw-aways for modeling:
# - COMPANY NAME
# - COMPANY URL
# - LATITUDE
# - LONGITUDE
# - OPEN
# - HIGH
# - LOW
# - CLOSE
# - VOLUME
# - VOLUME WEIGHT
# - NUMBER OF TRANSACTIONS

# %%
# drop stock ticker
# filtered_df = filtered_df.drop(columns = ['city_name'])
# filtered_df.head()
stock_df.drop(columns="ticker", inplace=True)
stock_df.drop(columns="city_name", inplace=True)
stock_df.drop(columns="state_name", inplace=True)

# %%
# generate our categorical variable list
# categorical preprocessing can be done easiest using Dataframe.dtypes == 'object'
stock_categories = stock_df.dtypes[stock_df.dtypes == "object"].index.tolist()
stock_categories

# %%
# Checking the number of unique values in each column
stock_df[stock_categories].nunique()
# there needs to be only 10 at most in each categorie, how are we going to make this smaller...by sector ???

# %%
# replace stock's employee count string with integer
stock_df.loc[(stock_df['employee_count'] == '5k-10k'), 'employee_count'] = 0
stock_df.loc[(stock_df['employee_count'] == 'over-10k'), 'employee_count'] = 1
stock_df.loc[(stock_df['employee_count'] == '1k-5k'), 'employee_count'] = 2
stock_df.loc[(stock_df['employee_count'] == '500-1k'), 'employee_count'] = 3

# replace stock's revenue string with integer
stock_df.loc[(stock_df['revenue'] == '1m-10m'), 'revenue'] = 0
stock_df.loc[(stock_df['revenue'] == '10m-50m'), 'revenue'] = 1
stock_df.loc[(stock_df['revenue'] == '50m-100m'), 'revenue'] = 2
stock_df.loc[(stock_df['revenue'] == '100m-200m'), 'revenue'] = 3
stock_df.loc[(stock_df['revenue'] == '200m-1b'), 'revenue'] = 4
stock_df.loc[(stock_df['revenue'] == 'over-1b'), 'revenue'] = 5

# replace stock's sector string with integer
stock_df.loc[(stock_df['sector'] == 'Technology'), 'sector'] = 0
stock_df.loc[(stock_df['sector'] == 'Energy'), 'sector'] = 1
stock_df.loc[(stock_df['sector'] == 'Healthcare'), 'sector'] = 2
stock_df.loc[(stock_df['sector'] == 'Consumer Discretionary'), 'sector'] = 3
stock_df.loc[(stock_df['sector'] == 'Industrials'), 'sector'] = 4
stock_df.loc[(stock_df['sector'] == 'Consumer Staples'), 'sector'] = 5
stock_df.loc[(stock_df['sector'] == 'Communication Services'), 'sector'] = 6
stock_df.loc[(stock_df['sector'] == 'Financials'), 'sector'] = 7
stock_df.loc[(stock_df['sector'] == 'Utilities'), 'sector'] = 8

# replace stock's country code string with integer (Note: China was CN and CH for some reason)
stock_df.loc[(stock_df['country_code'] == 'US'), 'country_code'] = 0
stock_df.loc[(stock_df['country_code'] == 'Netherlands'), 'country_code'] = 1
stock_df.loc[(stock_df['country_code'] == 'Australia'), 'country_code'] = 2
stock_df.loc[(stock_df['country_code'] == 'UK'), 'country_code'] = 3
stock_df.loc[(stock_df['country_code'] == 'CH'), 'country_code'] = 4
stock_df.loc[(stock_df['country_code'] == 'CN'), 'country_code'] = 4
stock_df.loc[(stock_df['country_code'] == 'CA'), 'country_code'] = 5
stock_df.loc[(stock_df['country_code'] == 'Argentina'), 'country_code'] = 6

# replace stock's region string with integer 
stock_df.loc[(stock_df['region'] == 'W'), 'region'] = 0
stock_df.loc[(stock_df['region'] == 'MW'), 'region'] = 1
stock_df.loc[(stock_df['region'] == 'SW'), 'region'] = 2
stock_df.loc[(stock_df['region'] == 'NW'), 'region'] = 3
stock_df.loc[(stock_df['region'] == 'SE'), 'region'] = 4
stock_df.loc[(stock_df['region'] == 'NL'), 'region'] = 5
stock_df.loc[(stock_df['region'] == 'AU'), 'region'] = 6
stock_df.loc[(stock_df['region'] == 'NE'), 'region'] = 7
stock_df.loc[(stock_df['region'] == 'GB'), 'region'] = 8
stock_df.loc[(stock_df['region'] == 'CH'), 'region'] = 9
stock_df.loc[(stock_df['region'] == 'CA'), 'region'] = 10


#create buckets for vwa
stock_df.loc[(stock_df['volume_weight_avg'] < 0), 'volume_weight_avg'] = 0
stock_df.loc[(stock_df['volume_weight_avg'] > 0) & (stock_df['volume_weight_avg'] <= 1), 'volume_weight_avg'] = 1
stock_df.loc[(stock_df['volume_weight_avg'] > 1) & (stock_df['volume_weight_avg'] <= 2), 'volume_weight_avg'] = 2
stock_df.loc[(stock_df['volume_weight_avg'] > 2) & (stock_df['volume_weight_avg'] <= 3), 'volume_weight_avg'] = 3
stock_df.loc[(stock_df['volume_weight_avg'] > 3) & (stock_df['volume_weight_avg'] <= 4), 'volume_weight_avg'] = 4
stock_df.loc[(stock_df['volume_weight_avg'] > 4) & (stock_df['volume_weight_avg'] <= 5), 'volume_weight_avg'] = 5
stock_df.loc[(stock_df['volume_weight_avg'] > 5) & (stock_df['volume_weight_avg'] <= 6), 'volume_weight_avg'] = 6
stock_df.loc[(stock_df['volume_weight_avg'] > 6) & (stock_df['volume_weight_avg'] <= 7), 'volume_weight_avg'] = 7
stock_df.loc[(stock_df['volume_weight_avg'] > 7) & (stock_df['volume_weight_avg'] <= 8), 'volume_weight_avg'] = 8
stock_df.loc[(stock_df['volume_weight_avg'] > 8) & (stock_df['volume_weight_avg'] <= 9), 'volume_weight_avg'] = 9
stock_df.loc[(stock_df['volume_weight_avg'] > 9) & (stock_df['volume_weight_avg'] <= 10), 'volume_weight_avg'] = 10
stock_df.loc[(stock_df['volume_weight_avg'] > 10), 'volume_weight_avg'] = 11

stock_df

# %%
# #obj_df["body_style"].astype('category').cat.codes

# # stock_df['employee_count'] = stock_df['employee_count'].astype('category').cat.codes

# # stock_df['revenue'] = stock_df['revenue'].astype('category').cat.codes

# stock_df['sector'] = stock_df['sector'].astype('category').cat.codes
# #stock_df['city_name'] = stock_df['city_name'].astype('category').cat.codes
# # stock_df['state_name'] = stock_df['state_name'].astype('category').cat.codes
# stock_df['country_code'] = stock_df['country_code'].astype('category').cat.codes
# stock_df['region'] = stock_df['region'].astype('category').cat.codes

# stock_df
# # # NOTE: Scikit-learn is flexible enough to perform all of the one-hot encodings at the same time.
# # #       Remember, the only difference from our single variable examples is that we need to pass our 
# # #       categorical variable list

# # # Create a OneHotEncoder instance
# # enc = OneHotEncoder(sparse=False)

# # # Fit and transform the OneHotEncoder using the categorical variable list
# # encode_df = pd.DataFrame(enc.fit_transform(stock_df[stock_categories]))

# # # Add the encoded variable names to the dataframe
# # encode_df.columns = enc.get_feature_names(stock_categories)
# # encode_df.head()

# %%
# # NOTE: Scikit-learn is flexible enough to perform all of the one-hot encodings at the same time.
# #       Remember, the only difference from our single variable examples is that we need to pass our 
# #       categorical variable list

# # Create a OneHotEncoder instance
# enc = OneHotEncoder(sparse=False)

# # Fit and transform the OneHotEncoder using the categorical variable list
# encode_df = pd.DataFrame(enc.fit_transform(stock_df[stock_categories]))

# # Add the encoded variable names to the dataframe
# encode_df.columns = enc.get_feature_names(stock_categories)
# encode_df.head()

# NOTE: OneHotEncoder was giving us mean_squared_error of around 32.00. So, we removed it and categorical codes instead.
#       Now the mean_squared_error is around 25.00. I have tried to remove city. This didn't work so I added region and 
#       removed city and state. I am still getting the same mean_squared_error. This didn't help.

# %%
# # So what happens if I try buckets for volumne weight average?

# vwa_counts = stock_df['volume_weight_avg'].value_counts()
# vwa_counts

# %%
# ['employee_count', 'revenue', 'sector', 'region', 'country_code']
# # using employee_count, revenue, sector, region, country_code and variable weighted average 
# # as the predictor variable and rating as the response variable
# #fit multiple linear regression model
# model = ols('rating ~ assists + rebounds', data=df).fit()

model = ols('volume_weight_avg ~ employee_count + revenue + sector + region + country_code', data = stock_df).fit()

# %%
#view model summary
print(model.summary())

# %%
# Once again we can create a residual vs. predictor plot for each 
# of the individual predictors using the plot_regress_exog() function 
# from the statsmodels library.

# For example, here’s what the residual vs. predictor plot looks like for the predictor variable assists:
#create residual vs. predictor plot for 'assists'
# fig = plt.figure(figsize=(12,8))
# fig = sm.graphics.plot_regress_exog(model, 'assists', fig=fig)

# create residual vs. predictor plot for the single feature employee_count
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(model, 'region[T.1]', fig=fig)

# %%
# # After examining the data, here are the categories I am going to divide the VWA into these "buckets"

# replace_below_0 = list(vwa_counts[vwa_counts < 0].index)
# below 0%
# above 0%
# above 1%
# above 2%
# above 4%
# above 10
# # Determine which values to replace if counts are less than 1000?
# replace_app_type = list(app_type_counts[app_type_counts < 1000].index)

# # Replace in dataframe
# for app in replace_app_type:
#     application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app, "Other")
    
# # Check to make sure binning was successful
# application_df.APPLICATION_TYPE.value_counts()

# %%
#stock_df.reset_index(drop=True,inplace=True)

# %%
#print(stock_df.index)
#print(encode_df.index)

# %%
# I AM COMING UP WITH NO ROWS HERE ???

# Now that our categorical variables have been encoded, 
# they are ready to replace our unencoded categorical 
# variables in our dataset.

# TWO STEP REPLACE: 

# Merge one-hot encoded features 
#new_stock_df = stock_df.merge(encode_df,left_index=True, right_index=True)

# Drop the original stock categories
#new_stock_df = new_stock_df.drop(columns=stock_categories)
#new_stock_df.head()

# %%
# create features array
X = stock_df.drop(columns=["volume_weight_avg"]).values
    
# create target
y = stock_df["volume_weight_avg"].values

# %%
# split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
# max_depth refers to the number of leaves of each tree 
# n_estimators refers to the total number of trees in the ensemble
# learning_rate hyperparameter scales the contribution of each tree NOTE: If you set it to a low value, 
# you will need more trees in the ensemble to fit the training set, but the overall variance will be lower.

# best way to tune the model: https://neptune.ai/blog/lightgbm-parameters-guide
    
regressor = GradientBoostingRegressor(
max_depth=100,
n_estimators=100,
learning_rate=.001
)
regressor.fit(X_train, y_train)

# %%
# Use staged_predict() method to measures the validation error at each stage of training 
# (i.e. with one tree, with two trees…) to find the optimal number of trees.
errors = [mean_squared_error(y_test, y_pred) for y_pred in 
           regressor.staged_predict(X_test)]
print(errors)

# mean_squared_error: 
# The smaller the mean squared error, the closer you are to finding the line of best fit. Depending on your data, 
# it may be impossible to get a very small value for the mean squared error. For example, the above data is scattered 
# wildly around the regression line, so 6.08 is as good as it gets (and is in fact, the line of best fit). It is 
# bucketting the VWA that works.

# %%
best_n_estimators = np.argmin(errors)

print(best_n_estimators)

# %%
# build and fit our model using the optimal number of trees
best_regressor = GradientBoostingRegressor(
     max_depth=10,
     n_estimators=best_n_estimators,
     learning_rate=.01
)

best_regressor.fit(X_train, y_train)

# # Sklearn provides numerous metrics to evaluate 
# # the performance of our machine learning models.
# # They categorize the each metric according 
# # to the problem domain which they’re applicable. 
# # https://scikit-learn.org/stable/modules/model_evaluation.html <-- GO TO THIS SITE TO SEE WHICH METRICS YOU WILL USE.

# # We use the mean absolute error 
# # which can be interpreted as 
# # the average distance from 
# # our predictions and the actual values

# # this will give you the value of the stocks for the next period of time
y_pred = best_regressor.predict(X_test)
print(y_pred)
print(X_test)
print(X_train)
print(y_train)
# # this is the how well the model performed (looking for smallest error)
mean_absolute_error(y_test, y_pred)

# %%
# should we be using r2_score?
# how do you do residual plots?

# %%
print(r2_score(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))

# %%
# #     # Tomas: correlation analysis to see how your features are correlated to each other
    
# #     # as with any regression you need to minimize the mean square error.
#                                                         ------------------
# #     examples are at : 
# # https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html#sklearn.metrics.mean_squared_error
# #     from sklearn.metrics import mean_squared_error
    
# # EMPTY PROCESS DATAFRAME   
    
# #     # accrossed all stocks, what is the average score.
# #     # what is the mean?
# #     # what is the median?
# #     # do we have any outliers that we need to note
# #     # does this work better for same sectors?
