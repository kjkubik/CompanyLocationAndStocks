# %%
#dependencies
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sqlalchemy import create_engine
from config import db_password
import psycopg2

# %%
# GET Tabled input
# creating database engine
db_name = 'Company_Stocks_DB'
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/{db_name}"
engine = create_engine(db_string)
# read data from PostgreSQL database table and load into Dataframe instance
stock_df = pd.read_sql("select * from \"company_all_star\"", engine);
# sort the dataframe by ticker column
stock_df.sort_values(by=["ticker"])
# Print the DataFrame
stock_df.head()
# Out:
#   ticker    date_val                company_name company_url employee_count  \
# 0    AMD  2020-03-12  Advanced Micro Devices Inc     amd.com         5k-10k
# 1    AMD  2020-03-15  Advanced Micro Devices Inc     amd.com         5k-10k
# 2    AMD  2020-03-16  Advanced Micro Devices Inc     amd.com         5k-10k
# 3    AMD  2020-03-17  Advanced Micro Devices Inc     amd.com         5k-10k
# 4    AMD  2020-03-18  Advanced Micro Devices Inc     amd.com         5k-10k
#
#    revenue      sector    city_name state_name region  ...   latitude  \
# 0  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 1  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 2  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 3  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 4  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                381223.0        4.028436
# 1        41.0812                374962.0        0.946776
# 2        41.1240                434519.0        4.205026
# 3        39.6363                591862.0        1.062215
# 4        40.2337                396388.0        0.657230
#
# [5 rows x 21 columns]

# %%
# process_list = []  
# inner_list = []

# %%
process_list = []
def stock_data(begin, end, df, process_list):
    stock_df = df 
    # preserve date column as type object
    stock_df['date'] = stock_df['date_val']
    # have the user enter beginning date as yyyy-mm-dd
    begin_date = begin
    # have the user enter ending date as yyyy-mm-dd
    end_date = end
    # Convert the date to datetime64
    stock_df['date_val'] = pd.to_datetime(stock_df['date_val'], format='%Y-%m-%d')
    stock_df = stock_df.loc[(stock_df['date_val'] >= begin_date)
                     & (stock_df['date_val'] <= end_date)]
    # drop throw-aways
    stock_df.drop(["longitude", "latitude", "company_name", "company_url","date_val"], axis=1, inplace=True)
    stock_df
    
    # get first stock ticker in first row
    #process_list = []   #change 1
    prev_ticker = stock_df.iat[0,0]
    print (prev_ticker)
    i = 0
    new_ticker_flag = 'yes'
    for x in stock_df:
        inner_list = [] #change 2
        for y in stock_df.iterrows():  #change 3
            new_ticker = stock_df['ticker']
            new_ticker = new_ticker.iloc[i]
            print("previous ticker and new ticker: ", prev_ticker, "and", new_ticker)
            if (prev_ticker == new_ticker):
                if (new_ticker_flag == 'yes'):
                    new_ticker_flag = 'no'
                    print(new_ticker_flag)
                    begin_vw = stock_df['volume_weight']
                    begin_vw = begin_vw.iloc[i]
                    print("begin_vw: ", begin_vw)
                else:
                    last_vw = stock_df['volume_weight']
                    last_vw = last_vw.iloc[i]
                    print("last_vw: ", last_vw)
            else:
                    print ("new")
                    vw_average = 100 - (last_vw/begin_vw) * 100
                    print(f" {prev_ticker} vwa: ", vw_average)
            
                    prev_ticker = new_ticker
                    new_ticker_flag == 'yes'
                    begin_vw = stock_df['volume_weight']
                    begin_vw = begin_vw.iloc[i]
                    
                    inner_list.append(vw_average) #change 4
                    
            i=i+1
        vw_average = 100 - (last_vw/begin_vw) * 100
        print(f" {prev_ticker} vwa: ", vw_average)
        inner_list.append(vw_average)
        process_list.append(inner_list) #change 5
    
        return process_list

# %%
#stock_df.sort_values(by="date_val", ascending=False).tail()

# %%
output1 = stock_data('2022-03-01', '2022-03-03', stock_df, process_list)
# Out:
# AMD
# previous ticker and new ticker:  AMD and AMD
# no
# begin_vw:  116.7418
# previous ticker and new ticker:  AMD and AMD
# last_vw:  113.6286
# previous ticker and new ticker:  AMD and AMD
# last_vw:  109.0619
# previous ticker and new ticker:  AMD and ADBE
# new
#  AMD vwa:  6.5785348521266656
# previous ticker and new ticker:  ADBE and ADBE
# last_vw:  462.3042
# previous ticker and new ticker:  ADBE and ADBE
# last_vw:  452.735
# previous ticker and new ticker:  ADBE and ABNB
# new
#  ADBE vwa:  4.0784991214761135
# previous ticker and new ticker:  ABNB and ABNB
# last_vw:  153.1107
# previous ticker and new ticker:  ABNB and ABNB
# last_vw:  143.411
# previous ticker and new ticker:  ABNB and ALGN
# new
#  ABNB vwa:  8.060559979792814
# previous ticker and new ticker:  ALGN and ALGN
# last_vw:  481.2937
# previous ticker and new ticker:  ALGN and ALGN
# last_vw:  461.5372
# previous ticker and new ticker:  ALGN and AMZN
# new
#  ALGN vwa:  6.729994893297814
# previous ticker and new ticker:  AMZN and AMZN
# last_vw:  2987.4637
# previous ticker and new ticker:  AMZN and AMZN
# last_vw:  2906.0813
# previous ticker and new ticker:  AMZN and AMGN
# new
#  AMZN vwa:  4.051147033805719
# previous ticker and new ticker:  AMGN and AMGN
# last_vw:  232.291
# previous ticker and new ticker:  AMGN and AMGN
# last_vw:  233.3114
# previous ticker and new ticker:  AMGN and AEP
# new
#  AMGN vwa:  -2.2461948788246673
# previous ticker and new ticker:  AEP and AEP
# last_vw:  93.6477
# previous ticker and new ticker:  AEP and AEP
# last_vw:  95.5682
# previous ticker and new ticker:  AEP and ADI
# new
#  AEP vwa:  -5.06907071984169
# previous ticker and new ticker:  ADI and ADI
# last_vw:  159.5458
# previous ticker and new ticker:  ADI and ADI
# last_vw:  157.0311
# previous ticker and new ticker:  ADI and ANSS
# new
#  ADI vwa:  1.7381395767942678
# previous ticker and new ticker:  ANSS and ANSS
# last_vw:  318.0048
# previous ticker and new ticker:  ANSS and ANSS
# last_vw:  311.8182
# previous ticker and new ticker:  ANSS and AAPL
# new
#  ANSS vwa:  2.9694651714007705
# previous ticker and new ticker:  AAPL and AAPL
# last_vw:  166.918
# previous ticker and new ticker:  AAPL and AAPL
# last_vw:  163.398
# previous ticker and new ticker:  AAPL and AMAT
# new
#  AAPL vwa:  1.454379875700738
# previous ticker and new ticker:  AMAT and AMAT
# last_vw:  131.0939
# previous ticker and new ticker:  AMAT and AMAT
# last_vw:  126.1637
# previous ticker and new ticker:  AMAT and ASML
# new
#  AMAT vwa:  4.762778254604129
# previous ticker and new ticker:  ASML and ASML
# last_vw:  636.6928
# previous ticker and new ticker:  ASML and ASML
# last_vw:  591.7875
# previous ticker and new ticker:  ASML and TEAM
# new
#  ASML vwa:  9.018112819308115
# previous ticker and new ticker:  TEAM and TEAM
# last_vw:  290.3988
# previous ticker and new ticker:  TEAM and TEAM
# last_vw:  272.7191
# previous ticker and new ticker:  TEAM and ADSK
# new
#  TEAM vwa:  10.52200046589607
# previous ticker and new ticker:  ADSK and ADSK
# last_vw:  211.8108
# previous ticker and new ticker:  ADSK and ADSK
# last_vw:  208.8198
# previous ticker and new ticker:  ADSK and ATVI
# new
#  ADSK vwa:  3.0295290737551284
# previous ticker and new ticker:  ATVI and ATVI
# last_vw:  81.4282
# previous ticker and new ticker:  ATVI and ATVI
# last_vw:  81.4812
# previous ticker and new ticker:  ATVI and ADP
# new
#  ATVI vwa:  -0.09569636611783494
# previous ticker and new ticker:  ADP and ADP
# last_vw:  206.0616
# previous ticker and new ticker:  ADP and ADP
# last_vw:  206.8779
# previous ticker and new ticker:  ADP and AZN
# new
#  ADP vwa:  -0.34783528197408486
# previous ticker and new ticker:  AZN and AZN
# last_vw:  60.0451
# previous ticker and new ticker:  AZN and AZN
# last_vw:  57.6451
# previous ticker and new ticker:  AZN and AVGO
# new
#  AZN vwa:  7.143098768514562
# previous ticker and new ticker:  AVGO and AVGO
# last_vw:  581.4769
# previous ticker and new ticker:  AVGO and AVGO
# last_vw:  596.5659
# previous ticker and new ticker:  AVGO and BIDU
# new
#  AVGO vwa:  -1.8488344419659057
# previous ticker and new ticker:  BIDU and BIDU
# last_vw:  155.9821
# previous ticker and new ticker:  BIDU and BIDU
# last_vw:  148.3494
# previous ticker and new ticker:  BIDU and BIIB
# new
#  BIDU vwa:  6.640184719135917
# previous ticker and new ticker:  BIIB and BIIB
# last_vw:  211.1512
# previous ticker and new ticker:  BIIB and BIIB
# last_vw:  209.9856
# previous ticker and new ticker:  BIIB and BMRN
# new
#  BIIB vwa:  -0.9937990364530975
# previous ticker and new ticker:  BMRN and BMRN
# last_vw:  75.8573
# previous ticker and new ticker:  BMRN and BMRN
# last_vw:  75.7308
# previous ticker and new ticker:  BMRN and BKNG
# new
#  BMRN vwa:  2.5455256733784637
# previous ticker and new ticker:  BKNG and BKNG
# last_vw:  2125.0297
# previous ticker and new ticker:  BKNG and BKNG
# last_vw:  1997.0664
# previous ticker and new ticker:  BKNG and CDNS
# new
#  BKNG vwa:  7.706364042337938
# previous ticker and new ticker:  CDNS and CDNS
# last_vw:  154.7577
# previous ticker and new ticker:  CDNS and CDNS
# last_vw:  154.0793
# previous ticker and new ticker:  CDNS and CHTR
# new
#  CDNS vwa:  1.256726627672478
# previous ticker and new ticker:  CHTR and CHTR
# last_vw:  570.0417
# previous ticker and new ticker:  CHTR and CHTR
# last_vw:  553.2415
# previous ticker and new ticker:  CHTR and CPRT
# new
#  CHTR vwa:  3.778631623288561
# previous ticker and new ticker:  CPRT and CPRT
# last_vw:  121.9263
# previous ticker and new ticker:  CPRT and CPRT
# last_vw:  118.7359
# previous ticker and new ticker:  CPRT and CRWD
# new
#  CPRT vwa:  3.554489858413362
# previous ticker and new ticker:  CRWD and CRWD
# last_vw:  193.6019
# previous ticker and new ticker:  CRWD and CRWD
# last_vw:  181.2748
# previous ticker and new ticker:  CRWD and CTAS
# new
#  CRWD vwa:  8.362051054437885
# previous ticker and new ticker:  CTAS and CTAS
# last_vw:  379.4819
# previous ticker and new ticker:  CTAS and CTAS
# last_vw:  378.1906
# previous ticker and new ticker:  CTAS and CSCO
# new
#  CTAS vwa:  0.5499864442738698
# previous ticker and new ticker:  CSCO and CSCO
# last_vw:  56.2193
# previous ticker and new ticker:  CSCO and CSCO
# last_vw:  56.2343
# previous ticker and new ticker:  CSCO and CMCSA
# new
#  CSCO vwa:  -0.5036414816138546
# previous ticker and new ticker:  CMCSA and CMCSA
# last_vw:  47.1347
# previous ticker and new ticker:  CMCSA and CMCSA
# last_vw:  47.1186
# previous ticker and new ticker:  CMCSA and COST
# new
#  CMCSA vwa:  -1.1495585308835246
# previous ticker and new ticker:  COST and COST
# last_vw:  533.1467
# previous ticker and new ticker:  COST and COST
# last_vw:  521.818
# previous ticker and new ticker:  COST and CSX
# new
#  COST vwa:  1.1645438043027099
# previous ticker and new ticker:  CSX and CSX
# last_vw:  35.4563
# previous ticker and new ticker:  CSX and CSX
# last_vw:  36.8452
# previous ticker and new ticker:  CSX and CTSH
# new
#  CSX vwa:  -7.368758468958077
# previous ticker and new ticker:  CTSH and CTSH
# last_vw:  88.0802
# previous ticker and new ticker:  CTSH and CTSH
# last_vw:  88.0033
# previous ticker and new ticker:  CTSH and DDOG
# new
#  CTSH vwa:  -0.035693215674541534
# previous ticker and new ticker:  DDOG and DDOG
# last_vw:  151.4198
# previous ticker and new ticker:  DDOG and DDOG
# last_vw:  143.3025
# previous ticker and new ticker:  DDOG and DOCU
# new
#  DDOG vwa:  10.658899384224242
# previous ticker and new ticker:  DOCU and DOCU
# last_vw:  109.8457
# previous ticker and new ticker:  DOCU and DOCU
# last_vw:  103.5316
# previous ticker and new ticker:  DOCU and DXCM
# new
#  DOCU vwa:  8.255381594291777
# previous ticker and new ticker:  DXCM and DXCM
# last_vw:  424.9995
# previous ticker and new ticker:  DXCM and DXCM
# last_vw:  429.2714
# previous ticker and new ticker:  DXCM and DLTR
# new
#  DXCM vwa:  -2.1976457502659343
# previous ticker and new ticker:  DLTR and DLTR
# last_vw:  146.4967
# previous ticker and new ticker:  DLTR and DLTR
# last_vw:  143.4648
# previous ticker and new ticker:  DLTR and EA
# new
#  DLTR vwa:  -4.277896456807099
# previous ticker and new ticker:  EA and EA
# last_vw:  128.2812
# previous ticker and new ticker:  EA and EA
# last_vw:  126.7896
# previous ticker and new ticker:  EA and EBAY
# new
#  EA vwa:  1.6386880255450222
# previous ticker and new ticker:  EBAY and EBAY
# last_vw:  54.2011
# previous ticker and new ticker:  EBAY and EBAY
# last_vw:  55.4868
# previous ticker and new ticker:  EBAY and EXC
# new
#  EBAY vwa:  -1.7048318538328147
# previous ticker and new ticker:  EXC and EXC
# last_vw:  43.0634
# previous ticker and new ticker:  EXC and EXC
# last_vw:  43.7863
# previous ticker and new ticker:  EXC and FAST
# new
#  EXC vwa:  -2.454530351706822
# previous ticker and new ticker:  FAST and FAST
# last_vw:  53.0917
# previous ticker and new ticker:  FAST and FAST
# last_vw:  53.7313
# previous ticker and new ticker:  FAST and FB
# new
#  FAST vwa:  -2.2039998021783163
# previous ticker and new ticker:  FB and FB
# last_vw:  204.809
# previous ticker and new ticker:  FB and FB
# last_vw:  200.4858
# previous ticker and new ticker:  FB and FISV
# new
#  FB vwa:  2.785053925385995
# previous ticker and new ticker:  FISV and FISV
# last_vw:  98.3654
# previous ticker and new ticker:  FISV and FISV
# last_vw:  96.8091
# previous ticker and new ticker:  FISV and FTNT
# new
#  FISV vwa:  1.58736451744727
# previous ticker and new ticker:  FTNT and FTNT
# last_vw:  336.8546
# previous ticker and new ticker:  FTNT and FTNT
# last_vw:  333.8625
# previous ticker and new ticker:  FTNT and GILD
# new
#  FTNT vwa:  2.3286654122140646
# previous ticker and new ticker:  GILD and GILD
# last_vw:  61.6473
# previous ticker and new ticker:  GILD and GILD
# last_vw:  61.8454
# previous ticker and new ticker:  GILD and GOOG
# new
#  GILD vwa:  -1.4868894129076011
# previous ticker and new ticker:  GOOG and GOOG
# last_vw:  2695.8916
# previous ticker and new ticker:  GOOG and GOOG
# last_vw:  2635.413
# previous ticker and new ticker:  GOOG and GOOGL
# new
#  GOOG vwa:  2.228368977348808
# previous ticker and new ticker:  GOOGL and GOOGL
# last_vw:  2690.1497
# previous ticker and new ticker:  GOOGL and GOOGL
# last_vw:  2631.4322
# previous ticker and new ticker:  GOOGL and HON
# new
#  GOOGL vwa:  2.161896693016658
# previous ticker and new ticker:  HON and HON
# last_vw:  188.6505
# previous ticker and new ticker:  HON and HON
# last_vw:  186.4996
# previous ticker and new ticker:  HON and ILMN
# new
#  HON vwa:  0.030928835269378396
# previous ticker and new ticker:  ILMN and ILMN
# last_vw:  330.5614
# previous ticker and new ticker:  ILMN and ILMN
# last_vw:  324.2319
# previous ticker and new ticker:  ILMN and INTC
# new
#  ILMN vwa:  1.8698283950243706
# previous ticker and new ticker:  INTC and INTC
# last_vw:  48.048
# previous ticker and new ticker:  INTC and INTC
# last_vw:  47.8436
# previous ticker and new ticker:  INTC and INTU
# new
#  INTC vwa:  1.2644382670571161
# previous ticker and new ticker:  INTU and INTU
# last_vw:  477.6385
# previous ticker and new ticker:  INTU and INTU
# last_vw:  465.3617
# previous ticker and new ticker:  INTU and ISRG
# new
#  INTU vwa:  3.54712164778455
# previous ticker and new ticker:  ISRG and ISRG
# last_vw:  300.5049
# previous ticker and new ticker:  ISRG and ISRG
# last_vw:  299.8862
# previous ticker and new ticker:  ISRG and MRVL
# new
#  ISRG vwa:  -0.5535899182926585
# previous ticker and new ticker:  MRVL and MRVL
# last_vw:  65.8693
# previous ticker and new ticker:  MRVL and MRVL
# last_vw:  64.8271
# previous ticker and new ticker:  MRVL and IDXX
# new
#  MRVL vwa:  3.822068058982282
# previous ticker and new ticker:  IDXX and IDXX
# last_vw:  539.9103
# previous ticker and new ticker:  IDXX and IDXX
# last_vw:  534.7412
# previous ticker and new ticker:  IDXX and JD
# new
#  IDXX vwa:  1.2996361638916198
# previous ticker and new ticker:  JD and JD
# last_vw:  68.9325
# previous ticker and new ticker:  JD and JD
# last_vw:  64.2392
# previous ticker and new ticker:  JD and KDP
# new
#  JD vwa:  10.189256409790389
# previous ticker and new ticker:  KDP and KDP
# last_vw:  38.6482
# previous ticker and new ticker:  KDP and KDP
# last_vw:  38.7304
# previous ticker and new ticker:  KDP and KLAC
# new
#  KDP vwa:  -0.43331353903840863
# previous ticker and new ticker:  KLAC and KLAC
# last_vw:  343.4151
# previous ticker and new ticker:  KLAC and KLAC
# last_vw:  332.5158
# previous ticker and new ticker:  KLAC and KHC
# new
#  KLAC vwa:  3.5463383433674096
# previous ticker and new ticker:  KHC and KHC
# last_vw:  39.7767
# previous ticker and new ticker:  KHC and KHC
# last_vw:  39.8251
# previous ticker and new ticker:  KHC and LRCX
# new
#  KHC vwa:  -2.3047736970142267
# previous ticker and new ticker:  LRCX and LRCX
# last_vw:  545.9558
# previous ticker and new ticker:  LRCX and LRCX
# last_vw:  526.8968
# previous ticker and new ticker:  LRCX and LCID
# new
#  LRCX vwa:  4.624966037484484
# previous ticker and new ticker:  LCID and LCID
# last_vw:  23.0215
# previous ticker and new ticker:  LCID and LCID
# last_vw:  22.6361
# previous ticker and new ticker:  LCID and LULU
# new
#  LCID vwa:  6.649868446013386
# previous ticker and new ticker:  LULU and LULU
# last_vw:  323.516
# previous ticker and new ticker:  LULU and LULU
# last_vw:  319.7148
# previous ticker and new ticker:  LULU and MELI
# new
#  LULU vwa:  2.4958920252224033
# previous ticker and new ticker:  MELI and MELI
# last_vw:  1105.8532
# previous ticker and new ticker:  MELI and MELI
# last_vw:  1067.1472
# previous ticker and new ticker:  MELI and MAR
# new
#  MELI vwa:  4.59342962018134
# previous ticker and new ticker:  MAR and MAR
# last_vw:  165.855
# previous ticker and new ticker:  MAR and MAR
# last_vw:  158.6659
# previous ticker and new ticker:  MAR and MTCH
# new
#  MAR vwa:  6.109296408071501
# previous ticker and new ticker:  MTCH and MTCH
# last_vw:  104.1719
# previous ticker and new ticker:  MTCH and MTCH
# last_vw:  97.8087
# previous ticker and new ticker:  MTCH and MCHP
# new
#  MTCH vwa:  10.319739455254634
# previous ticker and new ticker:  MCHP and MCHP
# last_vw:  69.1587
# previous ticker and new ticker:  MCHP and MCHP
# last_vw:  67.628
# previous ticker and new ticker:  MCHP and MDLZ
# new
#  MCHP vwa:  3.0982815663494847
# previous ticker and new ticker:  MDLZ and MDLZ
# last_vw:  64.9532
# previous ticker and new ticker:  MDLZ and MDLZ
# last_vw:  63.7406
# previous ticker and new ticker:  MDLZ and MRNA
# new
#  MDLZ vwa:  1.4819302806517385
# previous ticker and new ticker:  MRNA and MRNA
# last_vw:  142.5653
# previous ticker and new ticker:  MRNA and MRNA
# last_vw:  138.2611
# previous ticker and new ticker:  MRNA and MNST
# new
#  MRNA vwa:  5.156272079836583
# previous ticker and new ticker:  MNST and MNST
# last_vw:  83.4436
# previous ticker and new ticker:  MNST and MNST
# last_vw:  81.3468
# previous ticker and new ticker:  MNST and MSFT
# new
#  MNST vwa:  2.889436438128527
# previous ticker and new ticker:  MSFT and MSFT
# last_vw:  297.4481
# previous ticker and new ticker:  MSFT and MSFT
# last_vw:  289.9672
# previous ticker and new ticker:  MSFT and MU
# new
#  MSFT vwa:  2.9770672070228414
# previous ticker and new ticker:  MU and MU
# last_vw:  89.9948
# previous ticker and new ticker:  MU and MU
# last_vw:  82.9239
# previous ticker and new ticker:  MU and NFLX
# new
#  MU vwa:  9.681547670912977
# previous ticker and new ticker:  NFLX and NFLX
# last_vw:  370.1987
# previous ticker and new ticker:  NFLX and NFLX
# last_vw:  361.9986
# previous ticker and new ticker:  NFLX and NTES
# new
#  NFLX vwa:  4.692993091268377
# previous ticker and new ticker:  NTES and NTES
# last_vw:  87.222
# previous ticker and new ticker:  NTES and NTES
# last_vw:  85.3495
# previous ticker and new ticker:  NTES and NVDA
# new
#  NTES vwa:  6.80944685869018
# previous ticker and new ticker:  NVDA and NVDA
# last_vw:  238.5637
# previous ticker and new ticker:  NVDA and NVDA
# last_vw:  229.4047
# previous ticker and new ticker:  NVDA and NXPI
# new
#  NVDA vwa:  4.5245448881515955
# previous ticker and new ticker:  NXPI and NXPI
# last_vw:  185.9007
# previous ticker and new ticker:  NXPI and NXPI
# last_vw:  176.9022
# previous ticker and new ticker:  NXPI and OKTA
# new
#  NXPI vwa:  5.963908450704224
# previous ticker and new ticker:  OKTA and OKTA
# last_vw:  167.502
# previous ticker and new ticker:  OKTA and OKTA
# last_vw:  160.7177
# previous ticker and new ticker:  OKTA and ODFL
# new
#  OKTA vwa:  11.111350776155234
# previous ticker and new ticker:  ODFL and ODFL
# last_vw:  323.4764
# previous ticker and new ticker:  ODFL and ODFL
# last_vw:  319.5376
# previous ticker and new ticker:  ODFL and ORLY
# new
#  ODFL vwa:  -0.6645599428658073
# previous ticker and new ticker:  ORLY and ORLY
# last_vw:  682.3143
# previous ticker and new ticker:  ORLY and ORLY
# last_vw:  678.0174
# previous ticker and new ticker:  ORLY and PCAR
# new
#  ORLY vwa:  -0.261619920023449
# previous ticker and new ticker:  PCAR and PCAR
# last_vw:  91.5582
# previous ticker and new ticker:  PCAR and PCAR
# last_vw:  87.9186
# previous ticker and new ticker:  PCAR and PANW
# new
#  PCAR vwa:  3.7596931470380923
# previous ticker and new ticker:  PANW and PANW
# last_vw:  577.5739
# previous ticker and new ticker:  PANW and PANW
# last_vw:  557.9109
# previous ticker and new ticker:  PANW and PAYX
# new
#  PANW vwa:  3.6763526526468695
# previous ticker and new ticker:  PAYX and PAYX
# last_vw:  120.6333
# previous ticker and new ticker:  PAYX and PAYX
# last_vw:  122.3885
# previous ticker and new ticker:  PAYX and PDD
# new
#  PAYX vwa:  -1.8800466161658136
# previous ticker and new ticker:  PDD and PDD
# last_vw:  46.0453
# previous ticker and new ticker:  PDD and PDD
# last_vw:  41.9156
# previous ticker and new ticker:  PDD and PYPL
# new
#  PDD vwa:  14.178074618859057
# previous ticker and new ticker:  PYPL and PYPL
# last_vw:  103.1012
# previous ticker and new ticker:  PYPL and PYPL
# last_vw:  100.1997
# previous ticker and new ticker:  PYPL and PEP
# new
#  PYPL vwa:  5.295258510692591
# previous ticker and new ticker:  PEP and PEP
# last_vw:  163.6945
# previous ticker and new ticker:  PEP and PEP
# last_vw:  164.6219
# previous ticker and new ticker:  PEP and QCOM
# new
#  PEP vwa:  0.003280136405066969
# previous ticker and new ticker:  QCOM and QCOM
# last_vw:  167.2905
# previous ticker and new ticker:  QCOM and QCOM
# last_vw:  162.4782
# previous ticker and new ticker:  QCOM and REGN
# new
#  QCOM vwa:  3.740294979308814
# previous ticker and new ticker:  REGN and REGN
# last_vw:  612.3568
# previous ticker and new ticker:  REGN and REGN
# last_vw:  619.7571
# previous ticker and new ticker:  REGN and ROST
# new
#  REGN vwa:  -0.7422247724690294
# previous ticker and new ticker:  ROST and ROST
# last_vw:  93.5117
# previous ticker and new ticker:  ROST and ROST
# last_vw:  89.6402
# previous ticker and new ticker:  ROST and SIRI
# new
#  ROST vwa:  6.279980093427071
# previous ticker and new ticker:  SIRI and SIRI
# last_vw:  6.1653
# previous ticker and new ticker:  SIRI and SIRI
# last_vw:  6.1807
# previous ticker and new ticker:  SIRI and SGEN
# new
#  SIRI vwa:  -0.4975528853189388
# previous ticker and new ticker:  SGEN and SGEN
# last_vw:  127.0041
# previous ticker and new ticker:  SGEN and SGEN
# last_vw:  130.3539
# previous ticker and new ticker:  SGEN and SPLK
# new
#  SGEN vwa:  -2.3675367581520703
# previous ticker and new ticker:  SPLK and SPLK
# last_vw:  122.6487
# previous ticker and new ticker:  SPLK and SPLK
# last_vw:  128.4009
# previous ticker and new ticker:  SPLK and SWKS
# new
#  SPLK vwa:  -11.606275983697259
# previous ticker and new ticker:  SWKS and SWKS
# last_vw:  137.1315
# previous ticker and new ticker:  SWKS and SWKS
# last_vw:  135.4487
# previous ticker and new ticker:  SWKS and SBUX
# new
#  SWKS vwa:  0.6540976452338043
# previous ticker and new ticker:  SBUX and SBUX
# last_vw:  91.9095
# previous ticker and new ticker:  SBUX and SBUX
# last_vw:  90.0354
# previous ticker and new ticker:  SBUX and SNPS
# new
#  SBUX vwa:  2.7834045254888196
# previous ticker and new ticker:  SNPS and SNPS
# last_vw:  310.1132
# previous ticker and new ticker:  SNPS and SNPS
# last_vw:  307.555
# previous ticker and new ticker:  SNPS and TSLA
# new
#  SNPS vwa:  2.176478334135936
# previous ticker and new ticker:  TSLA and TSLA
# last_vw:  855.1002
# previous ticker and new ticker:  TSLA and TSLA
# last_vw:  839.6696
# previous ticker and new ticker:  TSLA and TXN
# new
#  TSLA vwa:  3.020270848538104
# previous ticker and new ticker:  TXN and TXN
# last_vw:  171.1629
# previous ticker and new ticker:  TXN and TXN
# last_vw:  169.7261
# previous ticker and new ticker:  TXN and TMUS
# new
#  TXN vwa:  0.22749570726770685
# previous ticker and new ticker:  TMUS and TMUS
# last_vw:  125.0859
# previous ticker and new ticker:  TMUS and TMUS
# last_vw:  123.5201
# previous ticker and new ticker:  TMUS and VRSN
# new
#  TMUS vwa:  1.5162435876378737
# previous ticker and new ticker:  VRSN and VRSN
# last_vw:  218.6951
# previous ticker and new ticker:  VRSN and VRSN
# last_vw:  217.5125
# previous ticker and new ticker:  VRSN and VRSK
# new
#  VRSN vwa:  -0.055107646208909955
# previous ticker and new ticker:  VRSK and VRSK
# last_vw:  183.4056
# previous ticker and new ticker:  VRSK and VRSK
# last_vw:  187.0971
# previous ticker and new ticker:  VRSK and VRTX
# new
#  VRSK vwa:  -2.7432488237335804
# previous ticker and new ticker:  VRTX and VRTX
# last_vw:  236.0148
# previous ticker and new ticker:  VRTX and VRTX
# last_vw:  239.2854
# previous ticker and new ticker:  VRTX and WBA
# new
#  VRTX vwa:  -2.4163252937533315
# previous ticker and new ticker:  WBA and WBA
# last_vw:  46.7042
# previous ticker and new ticker:  WBA and WBA
# last_vw:  47.2177
# previous ticker and new ticker:  WBA and WDAY
# new
#  WBA vwa:  -3.09338899453941
# previous ticker and new ticker:  WDAY and WDAY
# last_vw:  245.0289
# previous ticker and new ticker:  WDAY and WDAY
# last_vw:  240.2588
# previous ticker and new ticker:  WDAY and XEL
# new
#  WDAY vwa:  2.1340712079410764
# previous ticker and new ticker:  XEL and XEL
# last_vw:  68.9333
# previous ticker and new ticker:  XEL and XEL
# last_vw:  70.6307
# previous ticker and new ticker:  XEL and ZM
# new
#  XEL vwa:  -4.664744201485419
# previous ticker and new ticker:  ZM and ZM
# last_vw:  114.9198
# previous ticker and new ticker:  ZM and ZM
# last_vw:  110.5694
# previous ticker and new ticker:  ZM and ZS
# new
#  ZM vwa:  7.206650743643237
# previous ticker and new ticker:  ZS and ZS
# last_vw:  245.713
# previous ticker and new ticker:  ZS and ZS
# last_vw:  227.6627
#  ZS vwa:  9.160021466805262

# %%
output2 = stock_data('2022-03-04', '2022-03-06', stock_df, process_list)
# Out:
# AMD
# previous ticker and new ticker:  AMD and AMD
# no
# begin_vw:  105.5087
# previous ticker and new ticker:  AMD and ADBE
# new
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /var/folders/s0/4pw78f5x71s0c1tjvk4mtcyr0000gn/T/ipykernel_25315/1818783035.py in <module>
# ----> 1 output2 = stock_data('2022-03-04', '2022-03-06', stock_df, process_list)
#
# /var/folders/s0/4pw78f5x71s0c1tjvk4mtcyr0000gn/T/ipykernel_25315/3860026467.py in stock_data(begin, end, df, process_list)
#      41             else:
#      42                     print ("new")
# ---> 43                     vw_average = 100 - (last_vw/begin_vw) * 100
#      44                     print(f" {prev_ticker} vwa: ", vw_average)
#      45
#
# UnboundLocalError: local variable 'last_vw' referenced before assignment

# %%
output3 = stock_data('2022-03-07', '2022-03-10', stock_df, process_list)
# Out:
# AMD
# previous ticker and new ticker:  AMD and AMD
# no
# begin_vw:  105.1526
# previous ticker and new ticker:  AMD and AMD
# last_vw:  109.6319
# previous ticker and new ticker:  AMD and AMD
# last_vw:  105.3382
# previous ticker and new ticker:  AMD and AMD
# last_vw:  105.9691
# previous ticker and new ticker:  AMD and ADBE
# new
#  AMD vwa:  -0.7764905480225792
# previous ticker and new ticker:  ADBE and ADBE
# last_vw:  447.8637
# previous ticker and new ticker:  ADBE and ADBE
# last_vw:  437.7568
# previous ticker and new ticker:  ADBE and ADBE
# last_vw:  422.5279
# previous ticker and new ticker:  ADBE and ABNB
# new
#  ADBE vwa:  2.2990238640554708
# previous ticker and new ticker:  ABNB and ABNB
# last_vw:  148.5454
# previous ticker and new ticker:  ABNB and ABNB
# last_vw:  149.8916
# previous ticker and new ticker:  ABNB and ABNB
# last_vw:  147.8527
# previous ticker and new ticker:  ABNB and ALGN
# new
#  ABNB vwa:  -5.839271844833931
# previous ticker and new ticker:  ALGN and ALGN
# last_vw:  438.9188
# previous ticker and new ticker:  ALGN and ALGN
# last_vw:  427.7159
# previous ticker and new ticker:  ALGN and ALGN
# last_vw:  409.9722
# previous ticker and new ticker:  ALGN and AMZN
# new
#  ALGN vwa:  2.500253278710744
# previous ticker and new ticker:  AMZN and AMZN
# last_vw:  2821.5439
# previous ticker and new ticker:  AMZN and AMZN
# last_vw:  2930.5557
# previous ticker and new ticker:  AMZN and AMZN
# last_vw:  2946.3903
# previous ticker and new ticker:  AMZN and AMGN
# new
#  AMZN vwa:  -7.7058480147188675
# previous ticker and new ticker:  AMGN and AMGN
# last_vw:  231.8198
# previous ticker and new ticker:  AMGN and AMGN
# last_vw:  227.5793
# previous ticker and new ticker:  AMGN and AMGN
# last_vw:  228.6386
# previous ticker and new ticker:  AMGN and AEP
# new
#  AMGN vwa:  1.5495364222441594
# previous ticker and new ticker:  AEP and AEP
# last_vw:  95.0679
# previous ticker and new ticker:  AEP and AEP
# last_vw:  95.5087
# previous ticker and new ticker:  AEP and AEP
# last_vw:  95.8241
# previous ticker and new ticker:  AEP and ADI
# new
#  AEP vwa:  0.5116443739364627
# previous ticker and new ticker:  ADI and ADI
# last_vw:  153.5888
# previous ticker and new ticker:  ADI and ADI
# last_vw:  150.1401
# previous ticker and new ticker:  ADI and ADI
# last_vw:  149.4415
# previous ticker and new ticker:  ADI and ANSS
# new
#  ADI vwa:  -0.8869374195373183
# previous ticker and new ticker:  ANSS and ANSS
# last_vw:  310.8922
# previous ticker and new ticker:  ANSS and ANSS
# last_vw:  301.8731
# previous ticker and new ticker:  ANSS and ANSS
# last_vw:  298.0095
# previous ticker and new ticker:  ANSS and AAPL
# new
#  ANSS vwa:  1.3829116594443462
# previous ticker and new ticker:  AAPL and AAPL
# last_vw:  161.9446
# previous ticker and new ticker:  AAPL and AAPL
# last_vw:  158.0284
# previous ticker and new ticker:  AAPL and AAPL
# last_vw:  156.1598
# previous ticker and new ticker:  AAPL and AMAT
# new
#  AAPL vwa:  1.6463054019651935
# previous ticker and new ticker:  AMAT and AMAT
# last_vw:  128.1947
# previous ticker and new ticker:  AMAT and AMAT
# last_vw:  124.5674
# previous ticker and new ticker:  AMAT and AMAT
# last_vw:  125.9169
# previous ticker and new ticker:  AMAT and ASML
# new
#  AMAT vwa:  -1.9979684148451469
# previous ticker and new ticker:  ASML and ASML
# last_vw:  614.6359
# previous ticker and new ticker:  ASML and ASML
# last_vw:  601.0389
# previous ticker and new ticker:  ASML and ASML
# last_vw:  595.6976
# previous ticker and new ticker:  ASML and TEAM
# new
#  ASML vwa:  -3.618342033749073
# previous ticker and new ticker:  TEAM and TEAM
# last_vw:  260.458
# previous ticker and new ticker:  TEAM and TEAM
# last_vw:  256.1528
# previous ticker and new ticker:  TEAM and TEAM
# last_vw:  248.8555
# previous ticker and new ticker:  TEAM and ADSK
# new
#  TEAM vwa:  -3.708113433373228
# previous ticker and new ticker:  ADSK and ADSK
# last_vw:  205.2018
# previous ticker and new ticker:  ADSK and ADSK
# last_vw:  199.9849
# previous ticker and new ticker:  ADSK and ADSK
# last_vw:  195.0114
# previous ticker and new ticker:  ADSK and ATVI
# new
#  ADSK vwa:  1.0594643520331886
# previous ticker and new ticker:  ATVI and ATVI
# last_vw:  80.9645
# previous ticker and new ticker:  ATVI and ATVI
# last_vw:  80.813
# previous ticker and new ticker:  ATVI and ATVI
# last_vw:  80.4348
# previous ticker and new ticker:  ATVI and ADP
# new
#  ATVI vwa:  0.5129283421666315
# previous ticker and new ticker:  ADP and ADP
# last_vw:  209.3495
# previous ticker and new ticker:  ADP and ADP
# last_vw:  207.7212
# previous ticker and new ticker:  ADP and ADP
# last_vw:  208.5401
# previous ticker and new ticker:  ADP and AZN
# new
#  ADP vwa:  -0.29153495413687835
# previous ticker and new ticker:  AZN and AZN
# last_vw:  59.9165
# previous ticker and new ticker:  AZN and AZN
# last_vw:  60.6449
# previous ticker and new ticker:  AZN and AZN
# last_vw:  60.5447
# previous ticker and new ticker:  AZN and AVGO
# new
#  AZN vwa:  -5.241320090249488
# previous ticker and new ticker:  AVGO and AVGO
# last_vw:  595.6417
# previous ticker and new ticker:  AVGO and AVGO
# last_vw:  584.2682
# previous ticker and new ticker:  AVGO and AVGO
# last_vw:  582.1116
# previous ticker and new ticker:  AVGO and BIDU
# new
#  AVGO vwa:  -0.6874144450782751
# previous ticker and new ticker:  BIDU and BIDU
# last_vw:  143.0105
# previous ticker and new ticker:  BIDU and BIDU
# last_vw:  135.0444
# previous ticker and new ticker:  BIDU and BIDU
# last_vw:  123.212
# previous ticker and new ticker:  BIDU and BIIB
# new
#  BIDU vwa:  9.64755712842144
# previous ticker and new ticker:  BIIB and BIIB
# last_vw:  204.3033
# previous ticker and new ticker:  BIIB and BIIB
# last_vw:  198.5026
# previous ticker and new ticker:  BIIB and BIIB
# last_vw:  199.0211
# previous ticker and new ticker:  BIIB and BMRN
# new
#  BIIB vwa:  2.249544698164854
# previous ticker and new ticker:  BMRN and BMRN
# last_vw:  78.6484
# previous ticker and new ticker:  BMRN and BMRN
# last_vw:  77.6476
# previous ticker and new ticker:  BMRN and BMRN
# last_vw:  76.5255
# previous ticker and new ticker:  BMRN and BKNG
# new
#  BMRN vwa:  -0.14172202069690343
# previous ticker and new ticker:  BKNG and BKNG
# last_vw:  2049.4691
# previous ticker and new ticker:  BKNG and BKNG
# last_vw:  2028.467
# previous ticker and new ticker:  BKNG and BKNG
# last_vw:  2030.8021
# previous ticker and new ticker:  BKNG and CDNS
# new
#  BKNG vwa:  -7.58700576210785
# previous ticker and new ticker:  CDNS and CDNS
# last_vw:  150.3021
# previous ticker and new ticker:  CDNS and CDNS
# last_vw:  148.147
# previous ticker and new ticker:  CDNS and CDNS
# last_vw:  146.3686
# previous ticker and new ticker:  CDNS and CHTR
# new
#  CDNS vwa:  0.6620556914053566
# previous ticker and new ticker:  CHTR and CHTR
# last_vw:  561.2489
# previous ticker and new ticker:  CHTR and CHTR
# last_vw:  561.1658
# previous ticker and new ticker:  CHTR and CHTR
# last_vw:  567.4888
# previous ticker and new ticker:  CHTR and CPRT
# new
#  CHTR vwa:  -1.907348140688427
# previous ticker and new ticker:  CPRT and CPRT
# last_vw:  114.6927
# previous ticker and new ticker:  CPRT and CPRT
# last_vw:  115.1458
# previous ticker and new ticker:  CPRT and CPRT
# last_vw:  115.7932
# previous ticker and new ticker:  CPRT and CRWD
# new
#  CPRT vwa:  -6.18163811759527
# previous ticker and new ticker:  CRWD and CRWD
# last_vw:  171.3546
# previous ticker and new ticker:  CRWD and CRWD
# last_vw:  191.8395
# previous ticker and new ticker:  CRWD and CRWD
# last_vw:  193.156
# previous ticker and new ticker:  CRWD and CTAS
# new
#  CRWD vwa:  -21.330365129297803
# previous ticker and new ticker:  CTAS and CTAS
# last_vw:  373.3328
# previous ticker and new ticker:  CTAS and CTAS
# last_vw:  368.7097
# previous ticker and new ticker:  CTAS and CTAS
# last_vw:  370.587
# previous ticker and new ticker:  CTAS and CSCO
# new
#  CTAS vwa:  -0.47206718905299283
# previous ticker and new ticker:  CSCO and CSCO
# last_vw:  55.738
# previous ticker and new ticker:  CSCO and CSCO
# last_vw:  54.6294
# previous ticker and new ticker:  CSCO and CSCO
# last_vw:  55.0892
# previous ticker and new ticker:  CSCO and CMCSA
# new
#  CSCO vwa:  -0.49729461513483386
# previous ticker and new ticker:  CMCSA and CMCSA
# last_vw:  46.3043
# previous ticker and new ticker:  CMCSA and CMCSA
# last_vw:  45.3313
# previous ticker and new ticker:  CMCSA and CMCSA
# last_vw:  45.3243
# previous ticker and new ticker:  CMCSA and COST
# new
#  CMCSA vwa:  2.496934494998385
# previous ticker and new ticker:  COST and COST
# last_vw:  525.2468
# previous ticker and new ticker:  COST and COST
# last_vw:  527.6596
# previous ticker and new ticker:  COST and COST
# last_vw:  532.3424
# previous ticker and new ticker:  COST and CSX
# new
#  COST vwa:  -0.5928895580690181
# previous ticker and new ticker:  CSX and CSX
# last_vw:  34.6627
# previous ticker and new ticker:  CSX and CSX
# last_vw:  34.833
# previous ticker and new ticker:  CSX and CSX
# last_vw:  34.9849
# previous ticker and new ticker:  CSX and CTSH
# new
#  CSX vwa:  2.038753395122214
# previous ticker and new ticker:  CTSH and CTSH
# last_vw:  88.5163
# previous ticker and new ticker:  CTSH and CTSH
# last_vw:  87.1445
# previous ticker and new ticker:  CTSH and CTSH
# last_vw:  88.5223
# previous ticker and new ticker:  CTSH and DDOG
# new
#  CTSH vwa:  -1.065544760186782
# previous ticker and new ticker:  DDOG and DDOG
# last_vw:  139.3596
# previous ticker and new ticker:  DDOG and DDOG
# last_vw:  139.1711
# previous ticker and new ticker:  DDOG and DDOG
# last_vw:  130.0496
# previous ticker and new ticker:  DDOG and DOCU
# new
#  DDOG vwa:  -2.699006094835582
# previous ticker and new ticker:  DOCU and DOCU
# last_vw:  98.2739
# previous ticker and new ticker:  DOCU and DOCU
# last_vw:  88.3931
# previous ticker and new ticker:  DOCU and DOCU
# last_vw:  74.0216
# previous ticker and new ticker:  DOCU and DXCM
# new
#  DOCU vwa:  20.787866530119103
# previous ticker and new ticker:  DXCM and DXCM
# last_vw:  407.0818
# previous ticker and new ticker:  DXCM and DXCM
# last_vw:  404.807
# previous ticker and new ticker:  DXCM and DXCM
# last_vw:  396.9054
# previous ticker and new ticker:  DXCM and DLTR
# new
#  DXCM vwa:  1.558719214266219
# previous ticker and new ticker:  DLTR and DLTR
# last_vw:  148.2673
# previous ticker and new ticker:  DLTR and DLTR
# last_vw:  147.4767
# previous ticker and new ticker:  DLTR and DLTR
# last_vw:  147.3746
# previous ticker and new ticker:  DLTR and EA
# new
#  DLTR vwa:  0.2469212681248223
# previous ticker and new ticker:  EA and EA
# last_vw:  125.1684
# previous ticker and new ticker:  EA and EA
# last_vw:  123.7974
# previous ticker and new ticker:  EA and EA
# last_vw:  122.9628
# previous ticker and new ticker:  EA and EBAY
# new
#  EA vwa:  0.5870373170106689
# previous ticker and new ticker:  EBAY and EBAY
# last_vw:  53.0511
# previous ticker and new ticker:  EBAY and EBAY
# last_vw:  53.0869
# previous ticker and new ticker:  EBAY and EBAY
# last_vw:  50.9199
# previous ticker and new ticker:  EBAY and EXC
# new
#  EBAY vwa:  6.1709490535998555
# previous ticker and new ticker:  EXC and EXC
# last_vw:  43.5758
# previous ticker and new ticker:  EXC and EXC
# last_vw:  43.53
# previous ticker and new ticker:  EXC and EXC
# last_vw:  43.8972
# previous ticker and new ticker:  EXC and FAST
# new
#  EXC vwa:  -0.6151899662608145
# previous ticker and new ticker:  FAST and FAST
# last_vw:  54.6028
# previous ticker and new ticker:  FAST and FAST
# last_vw:  54.2348
# previous ticker and new ticker:  FAST and FAST
# last_vw:  54.3752
# previous ticker and new ticker:  FAST and FB
# new
#  FAST vwa:  0.38599711647147217
# previous ticker and new ticker:  FB and FB
# last_vw:  196.9614
# previous ticker and new ticker:  FB and FB
# last_vw:  193.9663
# previous ticker and new ticker:  FB and FB
# last_vw:  189.4396
# previous ticker and new ticker:  FB and FISV
# new
#  FB vwa:  0.9811480126930832
# previous ticker and new ticker:  FISV and FISV
# last_vw:  96.1614
# previous ticker and new ticker:  FISV and FISV
# last_vw:  94.8574
# previous ticker and new ticker:  FISV and FISV
# last_vw:  94.8533
# previous ticker and new ticker:  FISV and FTNT
# new
#  FISV vwa:  0.08458543655775941
# previous ticker and new ticker:  FTNT and FTNT
# last_vw:  283.2592
# previous ticker and new ticker:  FTNT and FTNT
# last_vw:  283.9637
# previous ticker and new ticker:  FTNT and FTNT
# last_vw:  282.1387
# previous ticker and new ticker:  FTNT and GILD
# new
#  FTNT vwa:  -1.2452788887154327
# previous ticker and new ticker:  GILD and GILD
# last_vw:  59.3244
# previous ticker and new ticker:  GILD and GILD
# last_vw:  57.8358
# previous ticker and new ticker:  GILD and GILD
# last_vw:  58.4238
# previous ticker and new ticker:  GILD and GOOG
# new
#  GILD vwa:  2.1876595709059927
# previous ticker and new ticker:  GOOG and GOOG
# last_vw:  2650.3074
# previous ticker and new ticker:  GOOG and GOOG
# last_vw:  2649.0884
# previous ticker and new ticker:  GOOG and GOOG
# last_vw:  2637.3465
# previous ticker and new ticker:  GOOG and GOOGL
# new
#  GOOG vwa:  -2.998382235710892
# previous ticker and new ticker:  GOOGL and GOOGL
# last_vw:  2643.6693
# previous ticker and new ticker:  GOOGL and GOOGL
# last_vw:  2640.1379
# previous ticker and new ticker:  GOOGL and GOOGL
# last_vw:  2626.3924
# previous ticker and new ticker:  GOOGL and HON
# new
#  GOOGL vwa:  -2.6463801647724807
# previous ticker and new ticker:  HON and HON
# last_vw:  185.6762
# previous ticker and new ticker:  HON and HON
# last_vw:  184.1054
# previous ticker and new ticker:  HON and HON
# last_vw:  183.66
# previous ticker and new ticker:  HON and ILMN
# new
#  HON vwa:  0.33844555975379365
# previous ticker and new ticker:  ILMN and ILMN
# last_vw:  324.633
# previous ticker and new ticker:  ILMN and ILMN
# last_vw:  315.4683
# previous ticker and new ticker:  ILMN and ILMN
# last_vw:  308.8718
# previous ticker and new ticker:  ILMN and INTC
# new
#  ILMN vwa:  1.8317409596068615
# previous ticker and new ticker:  INTC and INTC
# last_vw:  47.5889
# previous ticker and new ticker:  INTC and INTC
# last_vw:  46.5762
# previous ticker and new ticker:  INTC and INTC
# last_vw:  46.2802
# previous ticker and new ticker:  INTC and INTU
# new
#  INTC vwa:  2.9174970107612666
# previous ticker and new ticker:  INTU and INTU
# last_vw:  463.3738
# previous ticker and new ticker:  INTU and INTU
# last_vw:  450.4148
# previous ticker and new ticker:  INTU and INTU
# last_vw:  443.7956
# previous ticker and new ticker:  INTU and ISRG
# new
#  INTU vwa:  -0.04488313140431899
# previous ticker and new ticker:  ISRG and ISRG
# last_vw:  277.0114
# previous ticker and new ticker:  ISRG and ISRG
# last_vw:  274.4961
# previous ticker and new ticker:  ISRG and ISRG
# last_vw:  276.1064
# previous ticker and new ticker:  ISRG and MRVL
# new
#  ISRG vwa:  -0.7019430173702261
# previous ticker and new ticker:  MRVL and MRVL
# last_vw:  66.578
# previous ticker and new ticker:  MRVL and MRVL
# last_vw:  65.2805
# previous ticker and new ticker:  MRVL and MRVL
# last_vw:  64.1245
# previous ticker and new ticker:  MRVL and IDXX
# new
#  MRVL vwa:  0.7368364021950242
# previous ticker and new ticker:  IDXX and IDXX
# last_vw:  527.6219
# previous ticker and new ticker:  IDXX and IDXX
# last_vw:  520.0078
# previous ticker and new ticker:  IDXX and IDXX
# last_vw:  506.76
# previous ticker and new ticker:  IDXX and JD
# new
#  IDXX vwa:  0.616391745096621
# previous ticker and new ticker:  JD and JD
# last_vw:  61.8761
# previous ticker and new ticker:  JD and JD
# last_vw:  52.8668
# previous ticker and new ticker:  JD and JD
# last_vw:  49.7949
# previous ticker and new ticker:  JD and KDP
# new
#  JD vwa:  14.808136143013812
# previous ticker and new ticker:  KDP and KDP
# last_vw:  37.5559
# previous ticker and new ticker:  KDP and KDP
# last_vw:  37.0888
# previous ticker and new ticker:  KDP and KDP
# last_vw:  37.0816
# previous ticker and new ticker:  KDP and KLAC
# new
#  KDP vwa:  1.1528998429923547
# previous ticker and new ticker:  KLAC and KLAC
# last_vw:  338.4671
# previous ticker and new ticker:  KLAC and KLAC
# last_vw:  328.3266
# previous ticker and new ticker:  KLAC and KLAC
# last_vw:  326.6187
# previous ticker and new ticker:  KLAC and KHC
# new
#  KLAC vwa:  -1.746063095146127
# previous ticker and new ticker:  KHC and KHC
# last_vw:  38.5197
# previous ticker and new ticker:  KHC and KHC
# last_vw:  37.4623
# previous ticker and new ticker:  KHC and KHC
# last_vw:  37.6486
# previous ticker and new ticker:  KHC and LRCX
# new
#  KHC vwa:  3.7600173826352545
# previous ticker and new ticker:  LRCX and LRCX
# last_vw:  515.2334
# previous ticker and new ticker:  LRCX and LRCX
# last_vw:  495.6429
# previous ticker and new ticker:  LRCX and LRCX
# last_vw:  488.7582
# previous ticker and new ticker:  LRCX and LCID
# new
#  LRCX vwa:  0.7605623507626404
# previous ticker and new ticker:  LCID and LCID
# last_vw:  25.2081
# previous ticker and new ticker:  LCID and LCID
# last_vw:  24.1074
# previous ticker and new ticker:  LCID and LCID
# last_vw:  23.2549
# previous ticker and new ticker:  LCID and LULU
# new
#  LCID vwa:  4.465943636513032
# previous ticker and new ticker:  LULU and LULU
# last_vw:  304.8735
# previous ticker and new ticker:  LULU and LULU
# last_vw:  300.6244
# previous ticker and new ticker:  LULU and LULU
# last_vw:  295.5002
# previous ticker and new ticker:  LULU and MELI
# new
#  LULU vwa:  1.0266095892590243
# previous ticker and new ticker:  MELI and MELI
# last_vw:  960.0765
# previous ticker and new ticker:  MELI and MELI
# last_vw:  935.0841
# previous ticker and new ticker:  MELI and MELI
# last_vw:  903.7596
# previous ticker and new ticker:  MELI and MAR
# new
#  MELI vwa:  3.6782526509381768
# previous ticker and new ticker:  MAR and MAR
# last_vw:  160.2369
# previous ticker and new ticker:  MAR and MAR
# last_vw:  161.8691
# previous ticker and new ticker:  MAR and MAR
# last_vw:  163.0318
# previous ticker and new ticker:  MAR and MTCH
# new
#  MAR vwa:  -6.743009041922846
# previous ticker and new ticker:  MTCH and MTCH
# last_vw:  98.4019
# previous ticker and new ticker:  MTCH and MTCH
# last_vw:  95.3778
# previous ticker and new ticker:  MTCH and MTCH
# last_vw:  90.1154
# previous ticker and new ticker:  MTCH and MCHP
# new
#  MTCH vwa:  -3.216813333195873
# previous ticker and new ticker:  MCHP and MCHP
# last_vw:  70.8634
# previous ticker and new ticker:  MCHP and MCHP
# last_vw:  69.5075
# previous ticker and new ticker:  MCHP and MCHP
# last_vw:  69.7539
# previous ticker and new ticker:  MCHP and MDLZ
# new
#  MCHP vwa:  -2.285194770915979
# previous ticker and new ticker:  MDLZ and MDLZ
# last_vw:  61.5561
# previous ticker and new ticker:  MDLZ and MDLZ
# last_vw:  60.1671
# previous ticker and new ticker:  MDLZ and MDLZ
# last_vw:  59.737
# previous ticker and new ticker:  MDLZ and MRNA
# new
#  MDLZ vwa:  2.517473159953454
# previous ticker and new ticker:  MRNA and MRNA
# last_vw:  140.7141
# previous ticker and new ticker:  MRNA and MRNA
# last_vw:  138.5617
# previous ticker and new ticker:  MRNA and MRNA
# last_vw:  140.7167
# previous ticker and new ticker:  MRNA and MNST
# new
#  MRNA vwa:  -9.174199464822848
# previous ticker and new ticker:  MNST and MNST
# last_vw:  76.4294
# previous ticker and new ticker:  MNST and MNST
# last_vw:  75.3567
# previous ticker and new ticker:  MNST and MNST
# last_vw:  74.0202
# previous ticker and new ticker:  MNST and MSFT
# new
#  MNST vwa:  -0.9646311022601708
# previous ticker and new ticker:  MSFT and MSFT
# last_vw:  286.2058
# previous ticker and new ticker:  MSFT and MSFT
# last_vw:  283.9699
# previous ticker and new ticker:  MSFT and MSFT
# last_vw:  283.7288
# previous ticker and new ticker:  MSFT and MU
# new
#  MSFT vwa:  -2.5840085703366498
# previous ticker and new ticker:  MU and MU
# last_vw:  79.2627
# previous ticker and new ticker:  MU and MU
# last_vw:  75.3013
# previous ticker and new ticker:  MU and MU
# last_vw:  73.5912
# previous ticker and new ticker:  MU and NFLX
# new
#  MU vwa:  4.84384637167318
# previous ticker and new ticker:  NFLX and NFLX
# last_vw:  358.5485
# previous ticker and new ticker:  NFLX and NFLX
# last_vw:  358.9168
# previous ticker and new ticker:  NFLX and NFLX
# last_vw:  346.3833
# previous ticker and new ticker:  NFLX and NTES
# new
#  NFLX vwa:  0.1423846825331765
# previous ticker and new ticker:  NTES and NTES
# last_vw:  88.5448
# previous ticker and new ticker:  NTES and NTES
# last_vw:  80.8696
# previous ticker and new ticker:  NTES and NTES
# last_vw:  80.1779
# previous ticker and new ticker:  NTES and NVDA
# new
#  NTES vwa:  5.31984615548123
# previous ticker and new ticker:  NVDA and NVDA
# last_vw:  227.8595
# previous ticker and new ticker:  NVDA and NVDA
# last_vw:  223.6303
# previous ticker and new ticker:  NVDA and NVDA
# last_vw:  224.9843
# previous ticker and new ticker:  NVDA and NXPI
# new
#  NVDA vwa:  -4.471506774637362
# previous ticker and new ticker:  NXPI and NXPI
# last_vw:  183.8995
# previous ticker and new ticker:  NXPI and NXPI
# last_vw:  179.3581
# previous ticker and new ticker:  NXPI and NXPI
# last_vw:  180.2879
# previous ticker and new ticker:  NXPI and OKTA
# new
#  NXPI vwa:  -1.5410722623326052
# previous ticker and new ticker:  OKTA and OKTA
# last_vw:  168.4818
# previous ticker and new ticker:  OKTA and OKTA
# last_vw:  165.3699
# previous ticker and new ticker:  OKTA and OKTA
# last_vw:  157.0688
# previous ticker and new ticker:  OKTA and ODFL
# new
#  OKTA vwa:  1.2846232358427443
# previous ticker and new ticker:  ODFL and ODFL
# last_vw:  305.9245
# previous ticker and new ticker:  ODFL and ODFL
# last_vw:  307.8806
# previous ticker and new ticker:  ODFL and ODFL
# last_vw:  308.1769
# previous ticker and new ticker:  ODFL and ORLY
# new
#  ODFL vwa:  -2.139048776211567
# previous ticker and new ticker:  ORLY and ORLY
# last_vw:  673.5724
# previous ticker and new ticker:  ORLY and ORLY
# last_vw:  672.3348
# previous ticker and new ticker:  ORLY and ORLY
# last_vw:  679.5612
# previous ticker and new ticker:  ORLY and PCAR
# new
#  ORLY vwa:  -2.7801842526201597
# previous ticker and new ticker:  PCAR and PCAR
# last_vw:  87.198
# previous ticker and new ticker:  PCAR and PCAR
# last_vw:  85.9713
# previous ticker and new ticker:  PCAR and PCAR
# last_vw:  85.8099
# previous ticker and new ticker:  PCAR and PANW
# new
#  PCAR vwa:  -1.8628784695265779
# previous ticker and new ticker:  PANW and PANW
# last_vw:  551.7975
# previous ticker and new ticker:  PANW and PANW
# last_vw:  551.1671
# previous ticker and new ticker:  PANW and PANW
# last_vw:  551.3746
# previous ticker and new ticker:  PANW and PAYX
# new
#  PANW vwa:  -3.809654704974207
# previous ticker and new ticker:  PAYX and PAYX
# last_vw:  121.6811
# previous ticker and new ticker:  PAYX and PAYX
# last_vw:  121.3758
# previous ticker and new ticker:  PAYX and PAYX
# last_vw:  121.6751
# previous ticker and new ticker:  PAYX and PDD
# new
#  PAYX vwa:  -1.1198594503671728
# previous ticker and new ticker:  PDD and PDD
# last_vw:  42.7136
# previous ticker and new ticker:  PDD and PDD
# last_vw:  36.3579
# previous ticker and new ticker:  PDD and PDD
# last_vw:  33.4402
# previous ticker and new ticker:  PDD and PYPL
# new
#  PDD vwa:  15.508964485679073
# previous ticker and new ticker:  PYPL and PYPL
# last_vw:  99.3076
# previous ticker and new ticker:  PYPL and PYPL
# last_vw:  97.9276
# previous ticker and new ticker:  PYPL and PYPL
# last_vw:  97.3225
# previous ticker and new ticker:  PYPL and PEP
# new
#  PYPL vwa:  -2.168988120483249
# previous ticker and new ticker:  PEP and PEP
# last_vw:  157.6512
# previous ticker and new ticker:  PEP and PEP
# last_vw:  154.6174
# previous ticker and new ticker:  PEP and PEP
# last_vw:  154.793
# previous ticker and new ticker:  PEP and QCOM
# new
#  PEP vwa:  2.906720375645037
# previous ticker and new ticker:  QCOM and QCOM
# last_vw:  156.6853
# previous ticker and new ticker:  QCOM and QCOM
# last_vw:  153.5928
# previous ticker and new ticker:  QCOM and QCOM
# last_vw:  154.1756
# previous ticker and new ticker:  QCOM and REGN
# new
#  QCOM vwa:  -1.246540852418022
# previous ticker and new ticker:  REGN and REGN
# last_vw:  622.528
# previous ticker and new ticker:  REGN and REGN
# last_vw:  626.3473
# previous ticker and new ticker:  REGN and REGN
# last_vw:  645.0864
# previous ticker and new ticker:  REGN and ROST
# new
#  REGN vwa:  -4.49616752914406
# previous ticker and new ticker:  ROST and ROST
# last_vw:  88.3599
# previous ticker and new ticker:  ROST and ROST
# last_vw:  88.9545
# previous ticker and new ticker:  ROST and ROST
# last_vw:  88.5806
# previous ticker and new ticker:  ROST and SIRI
# new
#  ROST vwa:  -2.7587366955714714
# previous ticker and new ticker:  SIRI and SIRI
# last_vw:  6.2707
# previous ticker and new ticker:  SIRI and SIRI
# last_vw:  6.2
# previous ticker and new ticker:  SIRI and SIRI
# last_vw:  6.2143
# previous ticker and new ticker:  SIRI and SGEN
# new
#  SIRI vwa:  3.787022558020709
# previous ticker and new ticker:  SGEN and SGEN
# last_vw:  139.8033
# previous ticker and new ticker:  SGEN and SGEN
# last_vw:  140.4637
# previous ticker and new ticker:  SGEN and SGEN
# last_vw:  138.8715
# previous ticker and new ticker:  SGEN and SPLK
# new
#  SGEN vwa:  -0.7085126672927515
# previous ticker and new ticker:  SPLK and SPLK
# last_vw:  128.0419
# previous ticker and new ticker:  SPLK and SPLK
# last_vw:  127.1526
# previous ticker and new ticker:  SPLK and SPLK
# last_vw:  123.9052
# previous ticker and new ticker:  SPLK and SWKS
# new
#  SPLK vwa:  1.9015573166966249
# previous ticker and new ticker:  SWKS and SWKS
# last_vw:  134.2065
# previous ticker and new ticker:  SWKS and SWKS
# last_vw:  131.1486
# previous ticker and new ticker:  SWKS and SWKS
# last_vw:  128.9609
# previous ticker and new ticker:  SWKS and SBUX
# new
#  SWKS vwa:  2.3862076064956455
# previous ticker and new ticker:  SBUX and SBUX
# last_vw:  87.4006
# previous ticker and new ticker:  SBUX and SBUX
# last_vw:  86.6866
# previous ticker and new ticker:  SBUX and SBUX
# last_vw:  84.2136
# previous ticker and new ticker:  SBUX and SNPS
# new
#  SBUX vwa:  0.756111587740051
# previous ticker and new ticker:  SNPS and SNPS
# last_vw:  306.8868
# previous ticker and new ticker:  SNPS and SNPS
# last_vw:  297.4164
# previous ticker and new ticker:  SNPS and SNPS
# last_vw:  297.5679
# previous ticker and new ticker:  SNPS and TSLA
# new
#  SNPS vwa:  -0.1601186433033206
# previous ticker and new ticker:  TSLA and TSLA
# last_vw:  850.6831
# previous ticker and new ticker:  TSLA and TSLA
# last_vw:  830.2271
# previous ticker and new ticker:  TSLA and TSLA
# last_vw:  808.9169
# previous ticker and new ticker:  TSLA and TXN
# new
#  TSLA vwa:  1.5213291530585167
# previous ticker and new ticker:  TXN and TXN
# last_vw:  172.402
# previous ticker and new ticker:  TXN and TXN
# last_vw:  171.6576
# previous ticker and new ticker:  TXN and TXN
# last_vw:  171.846
# previous ticker and new ticker:  TXN and TMUS
# new
#  TXN vwa:  -2.595606883409033
# previous ticker and new ticker:  TMUS and TMUS
# last_vw:  121.8272
# previous ticker and new ticker:  TMUS and TMUS
# last_vw:  122.625
# previous ticker and new ticker:  TMUS and TMUS
# last_vw:  125.2409
# previous ticker and new ticker:  TMUS and VRSN
# new
#  TMUS vwa:  -4.803574207995595
# previous ticker and new ticker:  VRSN and VRSN
# last_vw:  209.1856
# previous ticker and new ticker:  VRSN and VRSN
# last_vw:  206.7204
# previous ticker and new ticker:  VRSN and VRSN
# last_vw:  205.8594
# previous ticker and new ticker:  VRSN and VRSK
# new
#  VRSN vwa:  1.8879452789929587
# previous ticker and new ticker:  VRSK and VRSK
# last_vw:  186.674
# previous ticker and new ticker:  VRSK and VRSK
# last_vw:  184.6647
# previous ticker and new ticker:  VRSK and VRSK
# last_vw:  183.5925
# previous ticker and new ticker:  VRSK and VRTX
# new
#  VRSK vwa:  1.0540651679374093
# previous ticker and new ticker:  VRTX and VRTX
# last_vw:  238.6797
# previous ticker and new ticker:  VRTX and VRTX
# last_vw:  239.5513
# previous ticker and new ticker:  VRTX and VRTX
# last_vw:  239.6352
# previous ticker and new ticker:  VRTX and WBA
# new
#  VRTX vwa:  -0.10619054979301268
# previous ticker and new ticker:  WBA and WBA
# last_vw:  48.1664
# previous ticker and new ticker:  WBA and WBA
# last_vw:  47.7198
# previous ticker and new ticker:  WBA and WBA
# last_vw:  47.9174
# previous ticker and new ticker:  WBA and WDAY
# new
#  WBA vwa:  -0.29302557276034236
# previous ticker and new ticker:  WDAY and WDAY
# last_vw:  233.0048
# previous ticker and new ticker:  WDAY and WDAY
# last_vw:  229.0807
# previous ticker and new ticker:  WDAY and WDAY
# last_vw:  226.195
# previous ticker and new ticker:  WDAY and XEL
# new
#  WDAY vwa:  -2.7159944417702917
# previous ticker and new ticker:  XEL and XEL
# last_vw:  69.9416
# previous ticker and new ticker:  XEL and XEL
# last_vw:  69.9773
# previous ticker and new ticker:  XEL and XEL
# last_vw:  70.4602
# previous ticker and new ticker:  XEL and ZM
# new
#  XEL vwa:  0.4300178761949809
# previous ticker and new ticker:  ZM and ZM
# last_vw:  109.3114
# previous ticker and new ticker:  ZM and ZM
# last_vw:  103.3206
# previous ticker and new ticker:  ZM and ZM
# last_vw:  99.6973
# previous ticker and new ticker:  ZM and ZS
# new
#  ZM vwa:  9.780526363893856
# previous ticker and new ticker:  ZS and ZS
# last_vw:  209.3268
# previous ticker and new ticker:  ZS and ZS
# last_vw:  208.7971
# previous ticker and new ticker:  ZS and ZS
# last_vw:  202.9376
#  ZS vwa:  -3.0514643901031917

# %%
print(len(output1[0]))
output1

# %%
newlist = []
for x in range(10):
    innerlist = []
    for y in range(10):
        innerlist.append(y)
    newlist.append(innerlist)

print(newlist)

# %%
print(newlist[3])
print(newlist[4])

# %%
def many_dates(date_interval_1, date_interval_2):
    # insert begin and end date with large gap
    # idea: have this function return a list

# %%
# # preserve date column as type object
# stock_df['date'] = stock_df['date_val']
# # have the user enter beginning date as yyyy-mm-dd
# begin_date = '2022-03-08'
# # have the user enter ending date as yyyy-mm-dd
# end_date = '2022-03-10'
# # Convert the date to datetime64
# stock_df['date_val'] = pd.to_datetime(stock_df['date_val'], format='%Y-%m-%d')
# stock_df = stock_df.loc[(stock_df['date_val'] >= begin_date)
#                      & (stock_df['date_val'] <= end_date)]
# # drop throw-aways
# stock_df.drop(["longitude", "latitude", "company_name", "company_url","date_val"], axis=1, inplace=True)
# stock_df

# %%
stock_df.drop(['open_val', 'high_val', 'low_val', 'close_val','number_of_transactions'], axis=1, inplace=True)
stock_df.head(20)

# %%
# # get first stock ticker in first row
# process_list = []
# prev_ticker = stock_df.iat[0,0]
# print (prev_ticker)
# i = 0
# new_ticker_flag = 'yes'
# #for rec in stock_df.iterrows():
# for rec in stock_df.iterrows():
#     new_ticker = stock_df['ticker']
#     new_ticker = new_ticker.iloc[i]
#     print("previous ticker and new ticker: ", prev_ticker, "and", new_ticker)
#     if (prev_ticker == new_ticker):
#         if (new_ticker_flag == 'yes'):
#             new_ticker_flag = 'no'
#             print(new_ticker_flag)
#             begin_vw = stock_df['volume_weight']
#             begin_vw = begin_vw.iloc[i]
#             print("begin_vw: ", begin_vw)
#         else:
#             last_vw = stock_df['volume_weight']
#             last_vw = last_vw.iloc[i]
#             print("last_vw: ", last_vw)
#     else:
#             print ("new")
#             vw_average = 100 -  (last_vw/begin_vw) * 100
#             print("vwa: ", vw_average)
            
#             process_list.append(vw_average)
            
#             prev_ticker = new_ticker
#             new_ticker_flag == 'yes'
#             begin_vw = stock_df['volume_weight']
#             begin_vw = begin_vw.iloc[i]
#     i=i+1
# vw_average = 100 -  (last_vw/begin_vw) * 100
# print("vwa: ", vw_average)
# process_list.append(vw_average)

# %%
process_list

# %%
# ticker, to volume columns.  
#vw_average is our target

# combine object columns from stock_df with proces_list into new DataFrame process_df.
# ticker, employee_count, revenue, sector, city_name, state_name, country_code

#stock_df.columns.tolist()

# %%
#len(process_list)

# %%
#len(stock_df)

# %%
# make copy for testing adding process_list as column to new dataframe for model
stock_df = stock_df.copy(deep=True)

# %%
stock_df = stock_df.drop(["volume", "volume_weight", "percent_change","date"], axis=1)
stock_df.columns.tolist()

# %%
stock_df = stock_df.drop_duplicates(subset="ticker")
stock_df.sort_values(by=["ticker"])
stock_df

# %%
### HERE IS WHERE ISSUE LIES, length of dataframe is 102, 
### and the volume weight average from for loop list lenght is 101

stock_df["volume_weight_avg"] = process_list

# %%
stock_df.head()

# %%
stock_df.drop(columns="ticker", inplace=True)

# %%
stock_df.drop(columns="city_name", inplace=True)

# %%
stock_cat = stock_df.dtypes[stock_df.dtypes=="object"].index.tolist()
stock_df[stock_cat].nunique()

# %%
stock_df.reset_index(drop=True,inplace=True)

# %%
#----------------------------------- ONE HOT ENCODE METHOD

# # Create OneHotEnocder Instance
# enc = OneHotEncoder(sparse=False)

# # Fit and transform categorical data
# encode_df = pd.DataFrame(enc.fit_transform(stock_df[stock_cat]))

# # Add the encoded variable names to encode_df
# encode_df.columns = enc.get_feature_names_out(stock_cat)
# encode_df.head()


#-------------------------------------- OLD "BUCKETING" METHOD

# #stock_df["employee_count"].astype('category').cat.codes
# stock_df['employee_count'] = stock_df['employee_count'].astype('category').cat.codes
# stock_df['revenue'] = stock_df['revenue'].astype('category').cat.codes
# stock_df['sector'] = stock_df['sector'].astype('category').cat.codes
# stock_df['region'] = stock_df['region'].astype('category').cat.codes
# #stock_df['city_name'] = stock_df['city_name'].astype('category').cat.codes
# stock_df['state_name'] = stock_df['state_name'].astype('category').cat.codes
# stock_df['country_code'] = stock_df['country_code'].astype('category').cat.codes

# processing_df = stock_df.copy()

# %%
#------------------------------------------------ SUPER MANUAL "BUCKET" METHOD
# replace stock's employee count string with integer
stock_df.loc[(stock_df['employee_count'] == '5k-10k'), 'employee_count'] = 0
stock_df.loc[(stock_df['employee_count'] == 'over-10k'), 'employee_count'] = 1
stock_df.loc[(stock_df['employee_count'] == '1k-5k'), 'employee_count'] = 2
stock_df.loc[(stock_df['employee_count'] == '500-1k'), 'employee_count'] = 3

# replace stock's revenue string with integer
stock_df.loc[(stock_df['revenue'] == '1m-10m'), 'revenue'] = 0
stock_df.loc[(stock_df['revenue'] == '10m-50m'), 'revenue'] = 1
stock_df.loc[(stock_df['revenue'] == '50m-100m'), 'revenue'] = 2
stock_df.loc[(stock_df['revenue'] == '100m-200m'), 'revenue'] = 3
stock_df.loc[(stock_df['revenue'] == '200m-1b'), 'revenue'] = 4
stock_df.loc[(stock_df['revenue'] == 'over-1b'), 'revenue'] = 5

# replace stock's sector string with integer
stock_df.loc[(stock_df['sector'] == 'Technology'), 'sector'] = 0
stock_df.loc[(stock_df['sector'] == 'Energy'), 'sector'] = 1
stock_df.loc[(stock_df['sector'] == 'Healthcare'), 'sector'] = 2
stock_df.loc[(stock_df['sector'] == 'Consumer Discretionary'), 'sector'] = 3
stock_df.loc[(stock_df['sector'] == 'Industrials'), 'sector'] = 4
stock_df.loc[(stock_df['sector'] == 'Consumer Staples'), 'sector'] = 5
stock_df.loc[(stock_df['sector'] == 'Communication Services'), 'sector'] = 6
stock_df.loc[(stock_df['sector'] == 'Financials'), 'sector'] = 7
stock_df.loc[(stock_df['sector'] == 'Utilities'), 'sector'] = 8

# replace stock's country code string with integer (Note: China was CN and CH for some reason)
stock_df.loc[(stock_df['country_code'] == 'US'), 'country_code'] = 0
stock_df.loc[(stock_df['country_code'] == 'Netherlands'), 'country_code'] = 1
stock_df.loc[(stock_df['country_code'] == 'Australia'), 'country_code'] = 2
stock_df.loc[(stock_df['country_code'] == 'UK'), 'country_code'] = 3
stock_df.loc[(stock_df['country_code'] == 'CH'), 'country_code'] = 4
stock_df.loc[(stock_df['country_code'] == 'CN'), 'country_code'] = 4
stock_df.loc[(stock_df['country_code'] == 'CA'), 'country_code'] = 5
stock_df.loc[(stock_df['country_code'] == 'Argentina'), 'country_code'] = 6

# replace stock's region string with integer 
stock_df.loc[(stock_df['region'] == 'W'), 'region'] = 0
stock_df.loc[(stock_df['region'] == 'MW'), 'region'] = 1
stock_df.loc[(stock_df['region'] == 'SW'), 'region'] = 2
stock_df.loc[(stock_df['region'] == 'NW'), 'region'] = 3
stock_df.loc[(stock_df['region'] == 'SE'), 'region'] = 4
stock_df.loc[(stock_df['region'] == 'NL'), 'region'] = 5
stock_df.loc[(stock_df['region'] == 'AU'), 'region'] = 6
stock_df.loc[(stock_df['region'] == 'NE'), 'region'] = 7
stock_df.loc[(stock_df['region'] == 'GB'), 'region'] = 8
stock_df.loc[(stock_df['region'] == 'CH'), 'region'] = 9
stock_df.loc[(stock_df['region'] == 'CA'), 'region'] = 10


#create buckets for vwa
stock_df.loc[(stock_df['volume_weight_avg'] < 0), 'volume_weight_avg'] = 0
stock_df.loc[(stock_df['volume_weight_avg'] > 0) & (stock_df['volume_weight_avg'] <= 1), 'volume_weight_avg'] = 1
stock_df.loc[(stock_df['volume_weight_avg'] > 1) & (stock_df['volume_weight_avg'] <= 2), 'volume_weight_avg'] = 2
stock_df.loc[(stock_df['volume_weight_avg'] > 2) & (stock_df['volume_weight_avg'] <= 3), 'volume_weight_avg'] = 3
stock_df.loc[(stock_df['volume_weight_avg'] > 3) & (stock_df['volume_weight_avg'] <= 4), 'volume_weight_avg'] = 4
stock_df.loc[(stock_df['volume_weight_avg'] > 4) & (stock_df['volume_weight_avg'] <= 5), 'volume_weight_avg'] = 5
stock_df.loc[(stock_df['volume_weight_avg'] > 5) & (stock_df['volume_weight_avg'] <= 6), 'volume_weight_avg'] = 6
# stock_df.loc[(stock_df['volume_weight_avg'] > 6) & (stock_df['volume_weight_avg'] <= 7), 'volume_weight_avg'] = 7
# stock_df.loc[(stock_df['volume_weight_avg'] > 7) & (stock_df['volume_weight_avg'] <= 8), 'volume_weight_avg'] = 8
# stock_df.loc[(stock_df['volume_weight_avg'] > 8) & (stock_df['volume_weight_avg'] <= 9), 'volume_weight_avg'] = 9
# stock_df.loc[(stock_df['volume_weight_avg'] > 9) & (stock_df['volume_weight_avg'] <= 10), 'volume_weight_avg'] = 10
stock_df.loc[(stock_df['volume_weight_avg'] > 6), 'volume_weight_avg'] = 7

stock_df

# %%
# ticker, to volume columns.  
#vw_average is our target

# combine object columns from stock_df with proces_list into new DataFrame process_df.

# %%
#float_stock_df = stock_df.select_dtypes(exclude=['object'])
#float_stock_df.head()

# %%
# Merge encode_df features and drop originals, n means new
#processing_df = encode_df.merge(stock_df, left_index=True, right_index=True) 
#processing_df = stock_df.drop(stock_cat, axis=1)
#processing_df.head()

# %%
# Function to run model (run each ticker and date through model in for loop)
# def random_forest(processing_df): does not need to be a functino for 'for loop' anymore
X = stock_df.drop(["volume_weight_avg"], axis=1)
X = pd.get_dummies(X)
    
y = stock_df["volume_weight_avg"] #<- weighted volume

# %%
X.describe()

# %%
np.unique(y)

# %%
# train the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# random forest classfier
# n_estimator default at 100
random_forest = RandomForestRegressor(n_estimators=100, max_depth=15,random_state=1)
random_forest.fit(X_train, y_train)

# %%
y_pred = random_forest.predict(X_test)
y_true = y_test

# %%
print(f"r2 Score: {metrics.r2_score(y_test, y_pred)}")
print(f"mean absolute error: {metrics.mean_absolute_error(y_test, y_pred)}")

# %%
# print(classification_report_imbalanced(y_test, y_pred))

# with open("random_forest_result.txt", "w") as external_file:
#     add_text = classification_report_imbalanced(y_test, y_pred)
#     print(add_text, file=external_file)
#     external_file.close()

# %%
#sorted(zip(X.columns, random_forest.feature_importances_), reverse=True)
