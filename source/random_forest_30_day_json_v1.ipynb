# %%
#dependencies
import warnings
warnings.filterwarnings("ignore")
import json
import pandas as pd
from config import db_password
from sqlalchemy import create_engine
from datetime import datetime, timedelta, date

# %%
# GET Tabled input
# creating database engine
db_name = 'Company_Stocks_DB'
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/{db_name}"
engine = create_engine(db_string)
# read data from PostgreSQL database table and load into Dataframe instance
stock_df = pd.read_sql("select * from \"company_all_star\"", engine);
# sort the dataframe by ticker column
stock_df.sort_values(by=["ticker"])
# Print the DataFrame
stock_df.head()
# ticker, date_val, region, open_val, high_val, low_val, close_val, volume_weight
# Out:
#   ticker    date_val                company_name company_url employee_count  \
# 0    AMD  2020-03-12  Advanced Micro Devices Inc     amd.com         5k-10k
# 1    AMD  2020-03-15  Advanced Micro Devices Inc     amd.com         5k-10k
# 2    AMD  2020-03-16  Advanced Micro Devices Inc     amd.com         5k-10k
# 3    AMD  2020-03-17  Advanced Micro Devices Inc     amd.com         5k-10k
# 4    AMD  2020-03-18  Advanced Micro Devices Inc     amd.com         5k-10k
#
#    revenue      sector    city_name state_name region  ...   latitude  \
# 0  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 1  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 2  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 3  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
# 4  over-1b  Technology  Santa Clara         CA      W  ...  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                381223.0        4.028436
# 1        41.0812                374962.0        0.946776
# 2        41.1240                434519.0        4.205026
# 3        39.6363                591862.0        1.062215
# 4        40.2337                396388.0        0.657230
#
# [5 rows x 21 columns]

# %%
# save original dataframe as .csv
# stock_df.to_csv("../resources/company_all_star.csv")
# completed

# %%
# save original datafrom as .json
#stock_df.to_json("../resources/company_all_star.json")

# %%
# preserve date column as type object
# stock_df['date'] = stock_df['date_val']

# have the user enter beginning date as yyyy-mm-dd
begin_date = '2022-01-10'
# have the user enter ending date as yyyy-mm-dd
end_date = '2022-03-10'

# Convert the date to datetime64
stock_df['date_val'] = pd.to_datetime(stock_df['date_val'], format='%Y-%m-%d')

begin_df = stock_df.loc[(stock_df['date_val'] >= begin_date)]
end_df = stock_df.loc[(stock_df['date_val'] <= end_date)]

# drop date_val
begin_df.drop(['date_val'], axis=1, inplace=True)
end_df.drop(['date_val'], axis=1, inplace=True)

begin_df.reset_index(drop=True,inplace=True)
begin_df.head()
# Out:
#   ticker                company_name company_url employee_count  revenue  \
# 0    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 1    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 2    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 3    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 4    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
#
#        sector    city_name state_name region country_code   latitude  \
# 0  Technology  Santa Clara         CA      W           US  37.233325
# 1  Technology  Santa Clara         CA      W           US  37.233325
# 2  Technology  Santa Clara         CA      W           US  37.233325
# 3  Technology  Santa Clara         CA      W           US  37.233325
# 4  Technology  Santa Clara         CA      W           US  37.233325
#
#     longitude  open_val  high_val  low_val  close_val      volume  \
# 0 -121.684635   133.450  138.9900   131.59     137.31  77153906.0
# 1 -121.684635   138.585  140.5700   135.77     137.47  69669598.0
# 2 -121.684635   139.440  141.2500   131.81     132.74  76618059.0
# 3 -121.684635   131.680  137.0000   131.43     136.88  71078438.0
# 4 -121.684635   134.500  136.3893   131.59     131.93  56589456.0
#
#    volume_weight  number_of_transactions  percent_change
# 0       136.1279                499284.0        2.892469
# 1       138.0222                458692.0        0.804560
# 2       135.7041                535482.0        4.804934
# 3       135.0553                466893.0        3.948967
# 4       133.7456                426778.0        1.910781

# %%
end_df.reset_index(drop=True,inplace=True)
end_df.head()
# Out:
#   ticker                company_name company_url employee_count  revenue  \
# 0    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 1    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 2    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 3    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
# 4    AMD  Advanced Micro Devices Inc     amd.com         5k-10k  over-1b
#
#        sector    city_name state_name region country_code   latitude  \
# 0  Technology  Santa Clara         CA      W           US  37.233325
# 1  Technology  Santa Clara         CA      W           US  37.233325
# 2  Technology  Santa Clara         CA      W           US  37.233325
# 3  Technology  Santa Clara         CA      W           US  37.233325
# 4  Technology  Santa Clara         CA      W           US  37.233325
#
#     longitude  open_val  high_val  low_val  close_val       volume  \
# 0 -121.684635     42.20     43.91    39.60      43.90   86689681.0
# 1 -121.684635     39.08     43.37    38.51      38.71   84545868.0
# 2 -121.684635     40.19     42.88    38.30      41.88   92741881.0
# 3 -121.684635     39.54     41.95    36.75      39.12  106949287.0
# 4 -121.684635     39.56     41.70    37.69      39.82   88939024.0
#
#    volume_weight  number_of_transactions  percent_change
# 0        41.6701                381223.0        4.028436
# 1        41.0812                374962.0        0.946776
# 2        41.1240                434519.0        4.205026
# 3        39.6363                591862.0        1.062215
# 4        40.2337                396388.0        0.657230

# %%
# merge together the beginning and ending dataframes
merged_df = pd.merge(begin_df, end_df, left_index=True, right_index=True)
merged_df
# Out:
#      ticker_x              company_name_x company_url_x employee_count_x  \
# 0         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 1         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 2         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 3         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# 4         AMD  Advanced Micro Devices Inc       amd.com           5k-10k
# ...       ...                         ...           ...              ...
# 4279       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 4280       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 4281       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 4282       ZS                 Zscaler Inc   zscaler.com            1k-5k
# 4283       ZS                 Zscaler Inc   zscaler.com            1k-5k
#
#       revenue_x    sector_x  city_name_x state_name_x region_x country_code_x  \
# 0       over-1b  Technology  Santa Clara           CA        W             US
# 1       over-1b  Technology  Santa Clara           CA        W             US
# 2       over-1b  Technology  Santa Clara           CA        W             US
# 3       over-1b  Technology  Santa Clara           CA        W             US
# 4       over-1b  Technology  Santa Clara           CA        W             US
# ...         ...         ...          ...          ...      ...            ...
# 4279  100m-200m  Technology     San Jose           CA        W             US
# 4280  100m-200m  Technology     San Jose           CA        W             US
# 4281  100m-200m  Technology     San Jose           CA        W             US
# 4282  100m-200m  Technology     San Jose           CA        W             US
# 4283  100m-200m  Technology     San Jose           CA        W             US
#
#       ...  latitude_y  longitude_y  open_val_y  high_val_y  low_val_y  \
# 0     ...   37.233325  -121.684635       42.20       43.91     39.600
# 1     ...   37.233325  -121.684635       39.08       43.37     38.510
# 2     ...   37.233325  -121.684635       40.19       42.88     38.300
# 3     ...   37.233325  -121.684635       39.54       41.95     36.750
# 4     ...   37.233325  -121.684635       39.56       41.70     37.690
# ...   ...         ...          ...         ...         ...        ...
# 4279  ...   40.262570   -80.187280      395.71      395.71    379.225
# 4280  ...   40.262570   -80.187280      387.52      395.20    383.010
# 4281  ...   40.262570   -80.187280      398.95      407.78    398.950
# 4282  ...   40.262570   -80.187280      405.14      407.37    402.765
# 4283  ...   40.262570   -80.187280      402.93      405.61    394.020
#
#       close_val_y     volume_y  volume_weight_y  number_of_transactions_y  \
# 0           43.90   86689681.0          41.6701                  381223.0
# 1           38.71   84545868.0          41.0812                  374962.0
# 2           41.88   92741881.0          41.1240                  434519.0
# 3           39.12  106949287.0          39.6363                  591862.0
# 4           39.82   88939024.0          40.2337                  396388.0
# ...           ...          ...              ...                       ...
# 4279       385.38     431244.0         384.8870                   16100.0
# 4280       394.43     350994.0         391.7881                   12501.0
# 4281       403.60     485909.0         404.2643                   14403.0
# 4282       404.61     376352.0         404.8678                   12237.0
# 4283       394.27     320142.0         398.0831                   12581.0
#
#       percent_change_y
# 0             4.028436
# 1             0.946776
# 2             4.205026
# 3             1.062215
# 4             0.657230
# ...                ...
# 4279          2.610498
# 4280          1.783134
# 4281          1.165560
# 4282          0.130819
# 4283          2.149257
#
# [4284 rows x 40 columns]

# %%
# calculate the absolute value of the diffence in the beginning percentage change and the ending percentage change
merged_df['percent_change_difference'] = abs(merged_df['percent_change_y'] - merged_df['percent_change_x'])
merged_df.columns
# Out:
# Index(['ticker_x', 'company_name_x', 'company_url_x', 'employee_count_x',
#        'revenue_x', 'sector_x', 'city_name_x', 'state_name_x', 'region_x',
#        'country_code_x', 'latitude_x', 'longitude_x', 'open_val_x',
#        'high_val_x', 'low_val_x', 'close_val_x', 'volume_x', 'volume_weight_x',
#        'number_of_transactions_x', 'percent_change_x', 'ticker_y',
#        'company_name_y', 'company_url_y', 'employee_count_y', 'revenue_y',
#        'sector_y', 'city_name_y', 'state_name_y', 'region_y', 'country_code_y',
#        'latitude_y', 'longitude_y', 'open_val_y', 'high_val_y', 'low_val_y',
#        'close_val_y', 'volume_y', 'volume_weight_y',
#        'number_of_transactions_y', 'percent_change_y',
#        'percent_change_difference'],
#       dtype='object')

# %%
# drop all *_y's
merged_df.drop(columns = ['ticker_y',
       'company_name_y', 'company_url_y', 'employee_count_y', 'revenue_y',
       'sector_y', 'city_name_y', 'state_name_y', 'region_y', 'country_code_y',
       'latitude_y', 'longitude_y', 'open_val_y', 'high_val_y', 'low_val_y',
       'close_val_y', 'volume_y', 'volume_weight_y',
       'number_of_transactions_y', 'percent_change_y'], axis=1, inplace=True)

# %%
merged_df.set_index("company_name_x").head()
# Out:
#                            ticker_x company_url_x employee_count_x revenue_x  \
# company_name_x
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
# Advanced Micro Devices Inc      AMD       amd.com           5k-10k   over-1b
#
#                               sector_x  city_name_x state_name_x region_x  \
# company_name_x
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
# Advanced Micro Devices Inc  Technology  Santa Clara           CA        W
#
#                            country_code_x  latitude_x  longitude_x  \
# company_name_x
# Advanced Micro Devices Inc             US   37.233325  -121.684635
# Advanced Micro Devices Inc             US   37.233325  -121.684635
# Advanced Micro Devices Inc             US   37.233325  -121.684635
# Advanced Micro Devices Inc             US   37.233325  -121.684635
# Advanced Micro Devices Inc             US   37.233325  -121.684635
#
#                             open_val_x  high_val_x  low_val_x  close_val_x  \
# company_name_x
# Advanced Micro Devices Inc     133.450    138.9900     131.59       137.31
# Advanced Micro Devices Inc     138.585    140.5700     135.77       137.47
# Advanced Micro Devices Inc     139.440    141.2500     131.81       132.74
# Advanced Micro Devices Inc     131.680    137.0000     131.43       136.88
# Advanced Micro Devices Inc     134.500    136.3893     131.59       131.93
#
#                               volume_x  volume_weight_x  \
# company_name_x
# Advanced Micro Devices Inc  77153906.0         136.1279
# Advanced Micro Devices Inc  69669598.0         138.0222
# Advanced Micro Devices Inc  76618059.0         135.7041
# Advanced Micro Devices Inc  71078438.0         135.0553
# Advanced Micro Devices Inc  56589456.0         133.7456
#
#                             number_of_transactions_x  percent_change_x  \
# company_name_x
# Advanced Micro Devices Inc                  499284.0          2.892469
# Advanced Micro Devices Inc                  458692.0          0.804560
# Advanced Micro Devices Inc                  535482.0          4.804934
# Advanced Micro Devices Inc                  466893.0          3.948967
# Advanced Micro Devices Inc                  426778.0          1.910781
#
#                             percent_change_difference
# company_name_x
# Advanced Micro Devices Inc                   1.135967
# Advanced Micro Devices Inc                   0.142215
# Advanced Micro Devices Inc                   0.599908
# Advanced Micro Devices Inc                   2.886752
# Advanced Micro Devices Inc                   1.253551

# %%
merged_df.columns
# Out:
# Index(['ticker_x', 'company_name_x', 'company_url_x', 'employee_count_x',
#        'revenue_x', 'sector_x', 'city_name_x', 'state_name_x', 'region_x',
#        'country_code_x', 'latitude_x', 'longitude_x', 'open_val_x',
#        'high_val_x', 'low_val_x', 'close_val_x', 'volume_x', 'volume_weight_x',
#        'number_of_transactions_x', 'percent_change_x',
#        'percent_change_difference'],
#       dtype='object')

# %%
merged_df['coordinates_x'] = merged_df['latitude_x'].astype('str') + ", " + merged_df['longitude_x'].astype('str')
merged_df.drop(['latitude_x', 'longitude_x'], axis=1, inplace=True)

# %%
merged_df.rename(columns={"ticker_x":"ticker",
                         "company_name_x": "company_name",
                         "company_url_x": "company_url",
                         "employee_count_x": "company_count",
                         "revenue_x": "revenue",
                         "sector_x": "sector",
                         "city_name_x":"city_name",
                         "state_name_x":"state_name",
                         "region_x":"region",
                         "country_code_x":"country_code",
                         "open_val_x":"open_val",
                         "high_val_x":"high_val",
                         "low_val_x":"low_val",
                         "close_val_x":"close_val",
                         "volume_x":"volume",
                         "volume_weight_x":"volume_weight",
                         "number_of_transactions_x":"number_of_transactions",
                         "percent_change_x":"percent_change",
                         "percent_change_difference_x":"percent_change_difference",
                         "coordinates_x":"coordinates"}, inplace=True)

# %%
# month_dict = merged_df.to_dict(orient="records")
# month_dict[0]

merged_df.columns
# Out:
# Index(['ticker', 'company_name', 'company_url', 'company_count', 'revenue',
#        'sector', 'city_name', 'state_name', 'region', 'country_code',
#        'open_val', 'high_val', 'low_val', 'close_val', 'volume',
#        'volume_weight', 'number_of_transactions', 'percent_change',
#        'percent_change_difference', 'coordinates'],
#       dtype='object')

# %%
def df_to_geojson(merged_df, properties, cor='coordinates', pc='percent_change', location='city_name', state='state_name'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in merged_df.iterrows():
        feature = {'type':'Feature',
                   'properties':{'mag':[row[pc]], 'place':[row[location]]},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[cor]]
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
cols = ['company_name', 'city_name', 'state_name', 'region', 'country_code', 'percent_change', 'coordinates']
geojson = df_to_geojson(merged_df, cols)

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'mag': [2.89246908954666],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.89246908954666,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.804560378107305],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.804560378107305,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.80493402180148],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.80493402180148,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.94896719319562],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.94896719319562,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.91078066914498],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.91078066914498,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.95357543991015],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.95357543991015,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.29260552205649],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.29260552205649,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.10704178458465],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.10704178458465,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.979202772963601],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.979202772963601,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.60297984224364],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.60297984224364,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.35224792666958],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.35224792666958,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [8.36012861736334],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 8.36012861736334,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.63367799113737],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.63367799113737,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.85564717872695],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.85564717872695,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.025695931477517],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.025695931477517,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.48926014319808],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.48926014319808,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.199468085106379],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.199468085106379,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.70899119162373],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.70899119162373,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0890255746196175],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0890255746196175,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.78019284196764],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.78019284196764,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.50771604938272],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.50771604938272,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.38280037255511],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.38280037255511,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [10.2742983986047],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 10.2742983986047,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.07350012985889],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.07350012985889,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.6521887533066],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.6521887533066,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.14237715245695],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.14237715245695,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.34594873559264],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.34594873559264,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0614574187884174],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0614574187884174,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.32966079639109],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.32966079639109,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.5076660988075],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 6.5076660988075,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [11.5244835501148],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 11.5244835501148,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.32878115397747],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.32878115397747,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.51849389078215],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.51849389078215,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.94841821303033],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 6.94841821303033,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.43353251926908],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.43353251926908,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.20612884110725],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.20612884110725,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.20535714285715],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.20535714285715,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.14143554777481],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.14143554777481,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.64565703725318],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.64565703725318,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.43519970482428],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.43519970482428,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.23160988153183],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.23160988153183,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.5512808656247],
#     'place': ['Santa Clara'],
#     'company_name': 'Advanced Micro Devices Inc',
#     'city_name': 'Santa Clara',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.5512808656247,
#     'coordinates': '37.2333253, -121.6846349'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.2333253, -121.6846349']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.825168446283174],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.825168446283174,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.135061621864981],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.135061621864981,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.87850888730225],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.87850888730225,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.18758382087116],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.18758382087116,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.577989380669693],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.577989380669693,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0193618339529164],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0193618339529164,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.20720548259887],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.20720548259887,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.68928220255653],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.68928220255653,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.82198057303439],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.82198057303439,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.551917865126301],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.551917865126301,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.56614785992218],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.56614785992218,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.12217550202381],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.12217550202381,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.87156087523307],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.87156087523307,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.95194419823499],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.95194419823499,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0037313432835787],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0037313432835787,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.589277389277383],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.589277389277383,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.30267561726625],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.30267561726625,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.93937709669095],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.93937709669095,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.72480620155038],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.72480620155038,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.92970914817694],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.92970914817694,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.269049678101274],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.269049678101274,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.57046134467013],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.57046134467013,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.81000964010283],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.81000964010283,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.171174978867287],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.171174978867287,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.628702202561191],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.628702202561191,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.254992287270318],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.254992287270318,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.26119119076806],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.26119119076806,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.51653622272123],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.51653622272123,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.442829567389587],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.442829567389587,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.09352807182098],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.09352807182098,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [10.8053226307365],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 10.8053226307365,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0322310320376532],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0322310320376532,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.14186851211073],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.14186851211073,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.282051282051281],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.282051282051281,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.161037420011016],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.161037420011016,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.5201647647269],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.5201647647269,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.737667127708625],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.737667127708625,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.00026303099382],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.00026303099382,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.226584356431069],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.226584356431069,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.59305993690852],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.59305993690852,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.28856705945849],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.28856705945849,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.29500068234545],
#     'place': ['San Jose'],
#     'company_name': 'Adobe Inc.',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.29500068234545,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.91568664053264],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.91568664053264,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.411184210526326],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.411184210526326,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.4866491886713],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.4866491886713,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.06184012066364],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.06184012066364,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.41482378433497],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.41482378433497,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.54140127388534],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.54140127388534,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.121413055325315],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.121413055325315,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.0542039983420004],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.0542039983420004,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.4],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.4,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.458651841556634],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.458651841556634,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.78614730214021],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.78614730214021,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.53359353219961],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.53359353219961,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.04955068750227],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.04955068750227,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [6.33081680740981],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 6.33081680740981,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.02349533311877],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.02349533311877,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.91268347014227],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.91268347014227,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.08130026356694],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.08130026356694,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.60996403356868],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.60996403356868,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.714331271126988],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.714331271126988,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.36363636363636],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.36363636363636,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.5155711434964],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.5155711434964,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.05761142545916],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.05761142545916,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.00756665242511],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 5.00756665242511,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.81840004801056],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.81840004801056,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.13486005089059],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.13486005089059,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.68044532936986],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.68044532936986,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.70308274743105],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.70308274743105,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.97348274714301],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.97348274714301,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.00278859001916],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.00278859001916,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [9.57632736696198],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 9.57632736696198,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [12.002830856334],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 12.002830856334,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.61835991460504],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.61835991460504,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.280277374617],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.280277374617,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.318873314289504],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.318873314289504,
#     'coordinates': '37.7790262, -122.419906'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.7790262, -122.419906']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.31190975865688],
#     'place': ['San Francisco'],
#     'company_name': 'Airbnb Inc',
#     'city_name': 'San Francisco',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 3.31190975865688,
#     'coordinates': '37.7790262, -122.419906'},
# ...
#   {'type': 'Feature',
#    'properties': {'mag': [2.93016651607073],
#     'place': ['San Jose'],
#     'company_name': 'Cadence Design Systems Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.93016651607073,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.31613927654984],
#     'place': ['San Jose'],
#     'company_name': 'Cadence Design Systems Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 2.31613927654984,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.950023416070106],
#     'place': ['San Jose'],
#     'company_name': 'Cadence Design Systems Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 0.950023416070106,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.22587199458178],
#     'place': ['San Jose'],
#     'company_name': 'Cadence Design Systems Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 1.22587199458178,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [4.083929044215],
#     'place': ['San Jose'],
#     'company_name': 'Cadence Design Systems Inc',
#     'city_name': 'San Jose',
#     'state_name': 'CA',
#     'region': 'W',
#     'country_code': 'US',
#     'percent_change': 4.083929044215,
#     'coordinates': '37.3361905, -121.890583'},
#    'geometry': {'type': 'Point', 'coordinates': ['37.3361905, -121.890583']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.636272462719696],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.636272462719696,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.256364200453952],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.256364200453952,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.16989466530752],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.16989466530752,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.68896510442786],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 1.68896510442786,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.79308717706736],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 1.79308717706736,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.511732187783465],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.511732187783465,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.09445585215606],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 2.09445585215606,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.901073286134248],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.901073286134248,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.513695678405823],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.513695678405823,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.17147767528324],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 1.17147767528324,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.59225504450513],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 1.59225504450513,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.03328180412839],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 2.03328180412839,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [5.32446220256145],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 5.32446220256145,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.738552437223047],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.738552437223047,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.04277758028202],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 1.04277758028202,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.332636857501046],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.332636857501046,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.61972299906779],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 1.61972299906779,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.49174125372934],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 1.49174125372934,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.10325837540156],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.10325837540156,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.613496932515336],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.613496932515336,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.285481239804241],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.285481239804241,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.107054037584198],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.107054037584198,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.699518875515196],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.699518875515196,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.37147715828229],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.37147715828229,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.374342040736255],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.374342040736255,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.428434894374324],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.428434894374324,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.890251989389921],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.890251989389921,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.327326775664243],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.327326775664243,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.640704775252783],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.640704775252783,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [3.59369456130569],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 3.59369456130569,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.46113537117904],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 2.46113537117904,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [2.25200707579263],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 2.25200707579263,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [1.34900719133671],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 1.34900719133671,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   {'type': 'Feature',
#    'properties': {'mag': [0.634528503020356],
#     'place': ['Stamford'],
#     'company_name': 'Charter Communications Inc',
#     'city_name': 'Stamford',
#     'state_name': 'CT',
#     'region': 'NE',
#     'country_code': 'US',
#     'percent_change': 0.634528503020356,
#     'coordinates': '41.0534302, -73.5387341'},
#    'geometry': {'type': 'Point', 'coordinates': ['41.0534302, -73.5387341']}},
#   ...]}

# %%
#month_json = json.dumps(month_dict, indent=2)

# %%
with open("../resources/random_tree_monthly_stocks_new.geojson", "w") as outfile:
    json.dump(geojson, outfile)

# %%
# file_path = open("../resources/random_tree_monthly_stocks.json")
# rforest_json = json.load(file_path)
# rforest_json
