# %%
import requests
import datetime
import time
import pandas as pd
from io import open
from numpy import record
import json
import bs4 as bs
import re
from config import url, headers

# %%
# ORIGINAL URL: querystring = {"url":"adobe.com"}

# Create dataframe for URL input
url_df = pd.read_csv("compcom.csv")
print(url_df.head())
# Out:
#   Ticker                   url
# 0   AAPL   {"url":"apple.com"}
# 1   ABNB  {"url":"airbnb.com"}
# 2   ADBE   {"url":"adobe.com"}
# 3    ADI  {"url":"analog.com"}
# 4    ADP     {"url":"adp.com"}

# %%
#OUTPUT FILE
output = open("StockFacts.json", "w", encoding="utf-8")
print(output)
# Out:
# <_io.TextIOWrapper name='StockFacts.json' mode='w' encoding='utf-8'>

# %%
# write header record once
# record = f"ticker, url, revenue, employee_count\n"
# print(record)
# output.write(record)

# for record, row in url_df.iterrows():
#         querystring = json.loads(row['url'])
#         print(type(querystring))
        
#         url_string = row['url']
#         print(type(url_string))

#         ticker = row['Ticker']
#         print(type(ticker))

# %%
# get company revenue and employee_count
with open("StockFacts.json", "w",encoding="utf-8") as outfile:
    for record, row in url_df.iterrows():
            # must do this
            time.sleep(5)
            querystring = json.loads(row['url'])
            
            response = requests.request("GET", url, headers=headers, params=querystring)
                        
            outfile.write(response.text)
            print(response.text)
        
        
        
        # DO THIS LATER
#         url_string = row['url']
#         ticker = row['Ticker']
        
############################################################################################        
        
#         company_revenue = response.json()['data']['revenue']
#         company_size = response.json()['data']['size']
        
#         print(f"{ticker},{url_string},{company_revenue},{company_size}\n")
#         record = f"{ticker},{url_string},{company_revenue},{company_size}\n"
# Out:
# {"result":"success","data":{"name":"Apple","alternate_name":null,"domain":"apple.com","domain_name":"apple","domain_tld":"com","business_type":null,"monthly_visitors":"over-1b","phone_number":"(408) 606-5775","revenue":"over-1b","size":"over-10k","year_founded":1976,"address":"1 apple park way","address_name":"Cupertino","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3228934,"address_lng":-122.0322895,"updated_at":"2020-09-22T15:50:09+00:00","description":"We're a diverse collection of thinkers and doers, continually reimagining what's possible to help us all do what we love in new ways. The people who work here have reinvented entire industries with the Mac, iPhone, iPad, and Apple Watch, as well as with services, including iTunes, the App Store, Apple Music, and Apple Pay. And the same passion for innovation that goes into our products also applies to our practices — strengthening our commitment to leave the world better than we found it.","social_networks":{"angellist":"http://angel.co/apple","facebook":"https://www.facebook.com/pages/Apple-Inc/137947732957611","linkedin":"https://www.linkedin.com/company/apple","twitter":"https://twitter.com/AppleSupport","youtube":"https://youtube.com/user/apple"},"email_patterns":[{"pattern":"[F1][L]","percentage":91.7316},{"pattern":"[L]","percentage":1.8704},{"pattern":"[F].[L]","percentage":1.8452},{"pattern":"[F]","percentage":1.4278},{"pattern":"[F]_[L]","percentage":1.3734},{"pattern":"[F][L1]","percentage":0.6589},{"pattern":"[F][L]","percentage":0.3642},{"pattern":"[F1].[L]","percentage":0.2226},{"pattern":"[L].[F1]","percentage":0.2099},{"pattern":"[L]_[F1]","percentage":0.0569},{"pattern":"[L].[F]","percentage":0.0468},{"pattern":"[L][F1]","percentage":0.0443},{"pattern":"[F].[L1]","percentage":0.0379},{"pattern":"[L1][F]","percentage":0.0291},{"pattern":"[F1][L1]","percentage":0.0291},{"pattern":"[L]_[F]","percentage":0.0278},{"pattern":"[F1]_[L]","percentage":0.0164}],"technologies":["apache"],"technology_categories":["web-server"],"industries":["computer-repair","computers","consumer-electronics","hardware","information-technology","innovative-product-development","it-services","local-services","mobile-phones","retail","shopping","software","telephone-support","world-class-operations"]}}
# {"result":"success","data":{"name":"Airbnb","alternate_name":null,"domain":"airbnb.com","domain_name":"airbnb","domain_tld":"com","business_type":null,"monthly_visitors":"over-1b","phone_number":"(415) 800-5959","revenue":"200m-1b","size":"5k-10k","year_founded":2008,"address":"888 brannan street","address_name":"San Francisco","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.7790262,"address_lng":-122.419906,"updated_at":"2020-09-22T16:29:32+00:00","description":"Founded in August of 2008 and based in San Francisco, California, Airbnb is a trusted community marketplace for people to list, discover, and book unique accommodations around the world — online or from a mobile phone. Whether an apartment for a night, a castle for a week, or a villa for a month, Airbnb connects people to unique travel experiences, at any price point, in more than 33,000 cities and 192 countries. And with world-class customer service and a growing community of users, Airbnb is the easiest way for people to monetize their extra space and showcase it to an audience of millions.  \\\\No global movement springs from individuals. It takes an entire team united behind something big. Together, we work hard, we laugh a lot, we brainstorm nonstop, we use hundreds of Post-Its a week, and we give the best high-fives in town. Headquartered in San Francisco, we have satellite offices in Dublin, London, Barcelona, Paris, Milan, Copenhagen, Berlin, Moscow, São Paolo, Sydney, and Singapore.","social_networks":{"angellist":"http://angel.co/airbnb","facebook":"https://www.facebook.com/airbnb","instagram":"https://instagram.com/airbnb","linkedin":"https://www.linkedin.com/company/airbnb","twitter":"http://twitter.com/airbnb"},"email_patterns":[{"pattern":"[F].[L]","percentage":97.2028},{"pattern":"[F]","percentage":1.3163},{"pattern":"[F].[L1]","percentage":1.0078},{"pattern":"[L]","percentage":0.2879},{"pattern":"[F1].[L]","percentage":0.0617},{"pattern":"[F][L]","percentage":0.0411},{"pattern":"[F1][L]","percentage":0.0411},{"pattern":"[F][L1]","percentage":0.0206},{"pattern":"[F1][L1]","percentage":0.0206}],"technologies":["amazon-s3","apache-traffic-server","apollo","envoy-proxy","facebook-social-plugins","google-analytics","google-cloud","google-tag-manager","nginx","react","ruby","ruby-on-rails","varnish","webpack"],"technology_categories":["analytics","caching","cdn","cloud-paas","graphql-library","javascript-bundler","javascript-framework","programming-language","reverse-proxy","ruby-framework","social-widget","tag-management","web-hosting","web-server"],"industries":["collaborative-economy","consumer-internet","hospitality","hotels","information-technology","internet","marketplaces","online-travel","peer-to-peer","travel-accommodations"]}}
# {"result":"success","data":{"name":"Adobe","alternate_name":null,"domain":"adobe.com","domain_name":"adobe","domain_tld":"com","business_type":null,"monthly_visitors":"over-1b","phone_number":"(408) 536-6000","revenue":"1m-10m","size":"over-10k","year_founded":1982,"address":"345 park avenue","address_name":"San Jose","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3361905,"address_lng":-121.890583,"updated_at":"2020-09-22T15:50:11+00:00","description":"Adobe is the global leader in digital media and digital marketing solutions. Our creative, marketing and document solutions empower everyone – from emerging artists to global brands – to bring digital creations to life and deliver immersive, compelling experiences to the right person at the right moment for the best results. In short, Adobe is everywhere, and we're changing the world through digital experiences.","social_networks":{"angellist":"http://angel.co/adobe-systems","facebook":"https://www.facebook.com/Adobe","linkedin":"https://www.linkedin.com/company/adobe","twitter":"http://twitter.com/Adobe"},"email_patterns":[{"pattern":"[F1][L]","percentage":86.3904},{"pattern":"[F].[L]","percentage":6.8195},{"pattern":"[L]","percentage":3.6897},{"pattern":"[F]","percentage":1.0845},{"pattern":"[F][L1]","percentage":0.9018},{"pattern":"[F][L]","percentage":0.4362},{"pattern":"[F]_[L]","percentage":0.4185},{"pattern":"[L1][F]","percentage":0.0825},{"pattern":"[F1].[L]","percentage":0.0413},{"pattern":"[L].[F]","percentage":0.0354},{"pattern":"[L][F1]","percentage":0.0354},{"pattern":"[F1][L1]","percentage":0.0295},{"pattern":"[L][F]","percentage":0.0118},{"pattern":"[F1][M1][L]","percentage":0.0118}],"technologies":["adobe-experience-manager","akamai","apache","java","office-365","react","webpack"],"technology_categories":["Calendar & Scheduling","Video Conferencing","cdn","cloud-storage","cms","collaboration","email-service","javascript-bundler","javascript-framework","productivity","programming-language","web-server"],"industries":["acrobat","computer-software","consumer-internet","creative","creative-cloud","creative-suite","deep-information-technology","design","digital-marketing","digital-media","digital-publishing","illustrator","image-recognition","information-technology","internet","mobile-apps","online-analytics","photo-editing","photography","photoshop","social-marketing","social-measurement","software","touch-apps","web-experience-management","web-marketing"]}}
# {"result":"success","data":{"name":"Analog Devices","alternate_name":null,"domain":"analog.com","domain_name":"analog","domain_tld":"com","business_type":null,"monthly_visitors":"10m-50m","phone_number":"(781) 329-4700","revenue":"over-1b","size":"over-10k","year_founded":1965,"address":"1 technology way","address_name":"Norwood","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":42.194543,"address_lng":-71.1994976,"updated_at":"2020-05-05T17:01:42+00:00","description":"Analog Devices, Inc. (NASDAQ: ADI) http://www.analog.com defines innovation and excellence in signal processing. ADI's analog, mixed-signal, and digital signal processing (DSP) integrated circuits (IC) play a fundamental role in converting, conditioning, and processing real-world phenomena such as light, sound, temperature, motion, and pressure into electrical signals to be used in a wide array of electronic equipment.","social_networks":{"angellist":"http://angel.co/analog-devices","facebook":"https://www.facebook.com/analogdevicesinc","instagram":"https://instagram.com/analogdevices","linkedin":"https://www.linkedin.com/company/analog-devices","twitter":"https://www.twitter.com/adi_news","youtube":"https://youtube.com/user/analogdevicesinc"},"email_patterns":[{"pattern":"[F].[L]","percentage":97.6779},{"pattern":"[L].[F]","percentage":0.9264},{"pattern":"[F1][L]","percentage":0.4694},{"pattern":"[L]","percentage":0.3211},{"pattern":"[F]_[L]","percentage":0.2594},{"pattern":"[F][L]","percentage":0.1606},{"pattern":"[F].[L1]","percentage":0.1112},{"pattern":"[F]","percentage":0.0371},{"pattern":"[F1].[L]","percentage":0.0124},{"pattern":"[L][F1]","percentage":0.0124},{"pattern":"[L1][F]","percentage":0.0124}],"technologies":["akamai","amazon-cloudfront","amazon-s3","babel","bootstrap","google-font-api","handlebars","jquery","microsoft-asp-net","microsoft-iis","modernizr","moment-js","nginx","react","sitecore","windows-server"],"technology_categories":["cdn","cms","dot-net-framework","font-library","javascript-compiler","javascript-framework","javascript-library","operating-system","ui-framework","web-server"],"industries":["analog","components","digital-signal-processing","electronic","mixedsignal","other-electrical-equipment","semiconductors","signal-processing"]}}
# {"result":"success","data":{"name":"ADP","alternate_name":null,"domain":"adp.com","domain_name":"adp","domain_tld":"com","business_type":null,"monthly_visitors":"over-1b","phone_number":"(800) 225-5237","revenue":"over-1b","size":"over-10k","year_founded":1949,"address":"1 adp boulevard","address_name":"Roseland","address_postal_code":"07068","address_country_code":"US","address_country":"United States","address_lat":40.8206555,"address_lng":-74.2937595,"updated_at":"2020-09-22T15:57:13+00:00","description":"We give companies of every size the tools to help their people thrive.  From payroll, benefits and regulatory compliance to talent management and analytics, we help our clients succeed. As one of the world's largest and most experienced HR providers, ADP offers you recruit-to-retire services and solutions that help you build the team that will take you into the future. What we deliver isn't just a better HR system; it's a better workforce. ","social_networks":{"angellist":"http://angel.co/adp","facebook":"https://www.facebook.com/ADPcareers","linkedin":"https://www.linkedin.com/company/adp","twitter":"http://www.twitter.com/ADP"},"email_patterns":[{"pattern":"[F].[L]","percentage":77.5153},{"pattern":"[F]_[L]","percentage":21.1088},{"pattern":"[L]_[F]","percentage":0.8534},{"pattern":"[F][L]","percentage":0.2297},{"pattern":"[L]","percentage":0.0766},{"pattern":"[L].[F]","percentage":0.0653},{"pattern":"[F]","percentage":0.045},{"pattern":"[F1].[L]","percentage":0.0293},{"pattern":"[F1][L]","percentage":0.0158},{"pattern":"[F]-[L]","percentage":0.0158},{"pattern":"[F]_[M1]_[L]","percentage":0.0135}],"technologies":["azure-cdn","facebook-social-plugins","google-analytics","google-tag-manager","jquery","jquery-ui","microsoft-asp-net","mouse-flow","optimizely","sitecore"],"technology_categories":["a-b-testing","analytics","cdn","cms","conversion-optimization","dot-net-framework","feedback-and-survey","heatmap","javascript-library","session-recording","social-widget","tag-management","ui-framework"],"industries":["aca-affordable-care-act","accountants","attendance","benefits-administration","business-financing","business-information-systems","compliance","enterprise-software","finance","finance-technology","financial-advising","financial-services","health-care-reform","hr-bpo","human-capital-management","human-resource-management","human-resources","information-services","information-technology","innovation-engineering","payment-solutions","payroll","payroll-services","peo","product-management","professional-services","project-management","retirement","social-innovation","software","talent-management","tax","tax-services","time"]}}
# {"result":"success","data":{"name":"Autodesk","alternate_name":null,"domain":"autodesk.com","domain_name":"autodesk","domain_tld":"com","business_type":null,"monthly_visitors":"100m-500m","phone_number":"(415) 507-6373","revenue":"over-1b","size":"over-10k","year_founded":1982,"address":"111 mcinnis parkway","address_name":"San Rafael","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.9735346,"address_lng":-122.5310874,"updated_at":"2020-09-22T15:59:42+00:00","description":"Autodesk makes software for people who make things.  If you've ever driven a high-performance car, admired a towering skyscraper, used a smartphone, or watched a great film, chances are you've experienced what millions of Autodesk customers are doing with our software. Autodesk gives you the power to make anything.  \\\\Over 100 million people use Autodesk software like AutoCAD, Revit, Maya, 3ds Max, Fusion 360, SketchBook, and more to unlock their creativity and solve important design, business and environmental challenges. Our software runs on both personal computers and mobile devices and taps the infinite computing power of the cloud to help teams around the world collaborate, design, simulate and fabricate their ideas in 3D.\\ \\Autodesk is consistently named a Great Place to Work®, globally.  We provide exceptional compensation/benefit packages and we'd love for you to join us. We're proud to be an equal opportunity employer and we consider all qualiﬁed applicants without regard to race, gender, disability, veteran status or other protected category.  To see our culture in action, check out #AutodeskLife.\\\\We are headquartered in the San Francisco Bay Area and have more than 9000 employees worldwide.\\ \\2017\\Fortune Best Companies to Work For in the Bay Area\\Great Place to Work in the UK, Canada, Singapore, & Germany\\PEOPLE's 50 Companies That Care​​\\100 Best Companies to Work For in America, Fortune Magazine​\\50 Best Workplaces for Giving Back, Fortune Magazine​\\Best Place to Work for LGBTQ Equality, Corporate Equality Index​\\\\2016\\Fortune's 25 Best Global Companies to Work For (#8)\\World's Best Multinational Workplaces\\Great Place to Work Laureate Award\\Fortune's Best Company Work For 2016 (#54)\\\\","social_networks":{"angellist":"http://angel.co/autodesk","facebook":"http://www.facebook.com/autodesk","linkedin":"https://www.linkedin.com/company/autodesk","twitter":"http://www.twitter.com/autodesk"},"email_patterns":[{"pattern":"[F].[L]","percentage":99.2774},{"pattern":"[L].[F]","percentage":0.2187},{"pattern":"[F1][L]","percentage":0.1046},{"pattern":"[L]","percentage":0.0951},{"pattern":"[F]-[L]","percentage":0.0951},{"pattern":"[F]","percentage":0.0761},{"pattern":"[F][L]","percentage":0.0475},{"pattern":"[F].[L1]","percentage":0.038},{"pattern":"[F][L1]","percentage":0.0285},{"pattern":"[F]_[L]","percentage":0.019}],"technologies":["adobe-experience-manager","akamai","amazon-cloudfront","amazon-s3","apache","express","google-analytics","java","jetty","jquery","jquery-ui","lodash","nginx","node-js","react","segment","tealium"],"technology_categories":["analytics","cdn","cms","javascript-framework","javascript-library","node-js-framework","programming-language","tag-management","ui-framework","web-server"],"industries":["cloud","computer-software","consumer-software","digital-prototyping","information-technology","media-entertainment","mobile","plm","prepackaged-software","software","technology"]}}
# {"result":"success","data":{"name":"American Electric Power","alternate_name":null,"domain":"aep.com","domain_name":"aep","domain_tld":"com","business_type":null,"monthly_visitors":"1m-10m","phone_number":"(888) 710-4237","revenue":"over-1b","size":"over-10k","year_founded":1906,"address":"1 riverside plaza","address_name":"Columbus","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":39.9622601,"address_lng":-83.0007065,"updated_at":"2020-09-25T01:42:18+00:00","description":"American Electric Power is one of the largest electric utilities in the United States, delivering electricity and custom energy solutions to nearly 5.4 million customers in 11 states. AEP owns the nation's largest electricity transmission system, a more than 40,000-mile network that includes more 765-kilovolt extra-high voltage transmission lines than all other U.S. transmission systems combined. AEP also operates 224,000 miles of distribution lines. AEP ranks among the nation's largest generators of electricity, owning approximately 26,000 megawatts of generating capacity in the U.S. AEP supplies 3,200 megawatts of renewable energy to customers. \\\\AEP's utility units operate as AEP Ohio, AEP Texas, Appalachian Power (in Virginia and West Virginia), AEP Appalachian Power (in Tennessee), Indiana Michigan Power, Kentucky Power, Public Service Company of Oklahoma, and Southwestern Electric Power Company (in Arkansas, Louisiana and east Texas). AEP's headquarters are in Columbus, Ohio.","social_networks":{"angellist":"http://angel.co/american-electric-power","facebook":"http://www.facebook.com/AmericanElectricPower","linkedin":"https://www.linkedin.com/company/american-electric-power","twitter":"http://www.twitter.com/AEPnews","youtube":"https://youtube.com/aeptv"},"email_patterns":[{"pattern":"[F1][L]","percentage":87.7076},{"pattern":"[F][L]","percentage":7.7907},{"pattern":"[F].[L]","percentage":2.6578},{"pattern":"[F]_[L]","percentage":0.5316},{"pattern":"[F1][M1][L]","percentage":0.515},{"pattern":"[L][F1]","percentage":0.1661},{"pattern":"[L1][F]","percentage":0.1495},{"pattern":"[L]","percentage":0.1163},{"pattern":"[F1].[L]","percentage":0.0997},{"pattern":"[F][L1]","percentage":0.0831},{"pattern":"[F]","percentage":0.0664},{"pattern":"[L].[F]","percentage":0.0498},{"pattern":"[L]_[F]","percentage":0.0332},{"pattern":"[F1][M1].[L]","percentage":0.0166},{"pattern":"[F]-[L]","percentage":0.0166}],"technologies":["appnexus","bootstrap","cloudflare","facebook-social-plugins","google-analytics","jquery","microsoft-asp-net","microsoft-iis","modernizr","nginx","windows-server"],"technology_categories":["advertising","analytics","cdn","dot-net-framework","javascript-library","operating-system","social-widget","ui-framework","web-server"],"industries":["clean-energy","clean-technology","distribution","electricity","energy","generation","power","solar","transmission","utilities","utility"]}}
# {"result":"success","data":{"name":"Align Technology","alternate_name":null,"domain":"aligntech.com","domain_name":"aligntech","domain_tld":"com","business_type":null,"monthly_visitors":"1m-10m","phone_number":"(408) 470-1000","revenue":"200m-1b","size":"over-10k","year_founded":1997,"address":"2820 orchard parkway","address_name":"San Jose","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3361905,"address_lng":-121.890583,"updated_at":"2020-09-28T20:53:15+00:00","description":"Work with technology that brings out millions of smiles.\\\\Discover your straight path to a bright future at Align. As a part of our smart, diverse and fast-moving global team, you'll make an impact for the market leader that's moving an industry forward.\\\\Want to find out what's next for us—and for you? \\\\Follow us here on LinkedIn for business updates and #lifeatalign stories, and check out our current opportunities at www.aligntech.com/careers.\\\\About Align\\\\Twenty years ago, we pioneered the world's first clear aligners. Since then, we have continuously innovated with new products and technologies that are revolutionizing treatments for doctors and their patients. Invisalign clear aligners and the iTero Intraoral scanner help dental professionals achieve the clinical results they expect and deliver effective, advanced dental options to their patients. \\\\Learn more about Align and our products:  \\www.aligntech.com  \\www.invisalign.com  \\www.itero.com  \\","social_networks":{"facebook":"http://www.facebook.com/invisalign","instagram":"https://instagram.com/aligntechinc","linkedin":"https://www.linkedin.com/company/align-technology","twitter":"http://twitter.com/Invisalign"},"email_patterns":[{"pattern":"[F1][L]","percentage":97.7422},{"pattern":"[F]","percentage":1.223},{"pattern":"[F][L]","percentage":0.7056},{"pattern":"[F][L1]","percentage":0.1411},{"pattern":"[L]","percentage":0.047},{"pattern":"[F].[L]","percentage":0.047},{"pattern":"[F1].[L]","percentage":0.047},{"pattern":"[F]_[L]","percentage":0.047}],"technologies":["bootstrap","cowboy","erlang","google-analytics","google-tag-manager","jquery","nginx","office-365","ruby","ruby-on-rails"],"technology_categories":["Calendar & Scheduling","Video Conferencing","analytics","cloud-storage","collaboration","email-service","javascript-library","productivity","programming-language","ruby-framework","tag-management","ui-framework","web-server"],"industries":["clear-aligners","dentists","digital-dentistry","health","intraoral-scanning","invisalign","medical","medical-devices","orthodontists"]}}
# {"result":"success","data":{"name":"Applied Materials","alternate_name":null,"domain":"appliedmaterials.com","domain_name":"appliedmaterials","domain_tld":"com","business_type":null,"monthly_visitors":"under-10k","phone_number":null,"revenue":null,"size":"over-10k","year_founded":1967,"address":"3050 bowers avenue","address_name":"Santa Clara","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3541132,"address_lng":-121.955174,"updated_at":"2020-09-28T11:36:07+00:00","description":null,"social_networks":{"angellist":"https://angel.co/applied-materials","facebook":"https://www.facebook.com/appliedmaterialsinc","linkedin":"https://www.linkedin.com/company/applied-materials","twitter":"https://twitter.com/applied_blog","youtube":"https://youtube.com/user/appliedschannel"},"email_patterns":[{"pattern":"[F]_[L]","percentage":60.7921},{"pattern":"[F].[L]","percentage":35.6436},{"pattern":"[F1][L]","percentage":3.1683},{"pattern":"[F1].[L]","percentage":0.198},{"pattern":"[L1].[F]","percentage":0.198}],"technologies":["acquia-cloud","amazon-ec2","amazon-s3","apache","bootstrap","drupal","google-analytics","google-tag-manager","jquery","modernizr","new-relic","nginx","php","varnish"],"technology_categories":["analytics","application-performance","caching","cdn","cms","email-hosting-provider","email-service","javascript-library","programming-language","tag-management","ui-framework","web-server"],"industries":["semiconductors"]}}
# {"result":"success","data":{"name":"AMD","alternate_name":null,"domain":"amd.com","domain_name":"amd","domain_tld":"com","business_type":null,"monthly_visitors":"100m-500m","phone_number":"(408) 749-4000","revenue":"over-1b","size":"5k-10k","year_founded":1969,"address":"2485 augustine drive","address_name":"Sunnyvale","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3688301,"address_lng":-122.036349,"updated_at":"2020-09-22T16:07:01+00:00","description":"For more than 45 years AMD (NASDAQ: AMD) has driven innovation in high-performance computing, graphics and visualization technologies ― the building blocks for gaming, immersive platforms, and the datacenter. Hundreds of millions of consumers, leading Fortune 500 businesses and cutting-edge scientific research facilities around the world rely on AMD technology daily to improve how they live, work and play. AMD employees around the world are focused on building great products that push the boundaries of what is possible. For more information about how AMD is enabling today and inspiring tomorrow, visit AMD.com.","social_networks":{"angellist":"http://angel.co/amd","facebook":"http://www.facebook.com/amd","linkedin":"https://www.linkedin.com/company/amd","twitter":"http://www.twitter.com/amd"},"email_patterns":[{"pattern":"[F].[L]","percentage":93.9712},{"pattern":"[L].[F]","percentage":1.8569},{"pattern":"[F]","percentage":1.3074},{"pattern":"[F]_[L]","percentage":1.2074},{"pattern":"[L]","percentage":0.7494},{"pattern":"[F][L1]","percentage":0.4497},{"pattern":"[F1][L]","percentage":0.3248},{"pattern":"[F][L]","percentage":0.05},{"pattern":"[F].[L1]","percentage":0.0416},{"pattern":"[F1].[L]","percentage":0.0333}],"technologies":[],"technology_categories":[],"industries":["apu","cloud-computing","components","computer-platforms","cpu","design","electronic","embedded-systems","energy-efficiency","gpu","graphic-cards","green-it","hardware","other-electrical-equipment","processors","semiconductor","semiconductors","semicustom","server","software","virtualization","x86"]}}
# {"result":"success","data":{"name":"Amgen","alternate_name":null,"domain":"amgen.com","domain_name":"amgen","domain_tld":"com","business_type":null,"monthly_visitors":"100k-500k","phone_number":"(805) 447-1000","revenue":"over-1b","size":"over-10k","year_founded":1980,"address":"1 amgen center drive","address_name":"Thousand Oaks","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":34.17142715,"address_lng":-118.91058772974445,"updated_at":"2020-09-28T10:17:33+00:00","description":"Amgen is committed to unlocking the potential of biology for patients suffering from serious illnesses by discovering, developing, manufacturing and delivering innovative human therapeutics. This approach begins by using tools like advanced human genetics to unravel the complexities of disease and understand the fundamentals of human biology.\\\\Amgen focuses on areas of high unmet medical need and leverages its expertise to strive for solutions that improve health outcomes and dramatically improve people's lives. A biotechnology pioneer since 1980, Amgen has grown to be one of the world's leading independent biotechnology companies, has reached millions of patients around the world and is developing a pipeline of medicines with breakaway potential.\\\\For more information, visit www.amgen.com and follow us on www.twitter.com/amgen.\\\\Special Advisory: Please be cautious of scam recruitment offers claiming to be from Amgen. Such scams may come from various sources, including fake websites and/or unsolicited emails and seek to obtain personal data or payment from victims by offering jobs that do not exist. Please be advised that Amgen would never ask for payment to progress a job application. When in doubt, please check to see if the position in question is posted on this website before applying. Additionally, please report any suspicious recruiting activity to https://complaint.ic3.gov/ and thank you for your assistance.","social_networks":{"angellist":"http://angel.co/amgen","facebook":"https://facebook.com/amgenbiotech","instagram":"https://instagram.com/amgenbiotech","linkedin":"https://www.linkedin.com/company/amgen","twitter":"http://www.twitter.com/amgen","youtube":"https://youtube.com/amgen"},"email_patterns":[{"pattern":"[F].[L]","percentage":64.0718},{"pattern":"[F1][L]","percentage":25.5426},{"pattern":"[F][L1]","percentage":5.3151},{"pattern":"[L]","percentage":1.9348},{"pattern":"[L][F1]","percentage":1.8714},{"pattern":"[F]","percentage":0.6797},{"pattern":"[L1][F]","percentage":0.4214},{"pattern":"[F][L]","percentage":0.0906},{"pattern":"[L].[F]","percentage":0.0272},{"pattern":"[F1].[L]","percentage":0.0136},{"pattern":"[F1][M1][L]","percentage":0.0136}],"technologies":["amazon-cloudfront","amazon-s3","azure-cdn","express","google-analytics","google-tag-manager","jquery","microsoft-asp-net","microsoft-iis","modernizr","nginx","node-js","office-365","sitecore","varnish","windows-server","zurb-foundation"],"technology_categories":["Calendar & Scheduling","Video Conferencing","analytics","caching","cdn","cloud-storage","cms","collaboration","dot-net-framework","email-service","javascript-library","node-js-framework","operating-system","productivity","tag-management","ui-framework","web-server"],"industries":["biologics","biotechnology","life-sciences"]}}
# {"result":"success","data":{"name":"Amazon","alternate_name":null,"domain":"amazon.com","domain_name":"amazon","domain_tld":"com","business_type":null,"monthly_visitors":"over-1b","phone_number":"(206) 266-1000","revenue":"over-1b","size":"over-10k","year_founded":1994,"address":"2127 7th avenue","address_name":"Seattle","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":47.6038321,"address_lng":-122.3300624,"updated_at":"2020-09-22T15:49:41+00:00","description":"Amazon strives to be Earth's most customer-centric company where people can find and discover virtually anything they want to buy online. By giving customers more of what they want - low prices, vast selection, and convenience - Amazon continues to grow and evolve as a world-class e-commerce platform.\\\\Founded by Jeff Bezos, the Amazon.com website started in 1995 as a place to buy books because of the unique customer experience the Web could offer book lovers. Bezos believed that only the Internet could offer customers the convenience of browsing a selection of millions of book titles in a single sitting. During the first 30 days of business, Amazon fulfilled orders for customers in 50 states and 45 countries - all shipped from his Seattle-area garage.\\\\Amazon's evolution from Web site to e-commerce partner to development platform is driven by the spirit of innovation that is part of the company's DNA. The world's brightest technology minds come to Amazon.com to research and develop technology that improves the lives of shoppers and sellers around the world.","social_networks":{"angellist":"http://angel.co/amazon","facebook":"http://www.facebook.com/Amazon","linkedin":"https://www.linkedin.com/company/amazon","twitter":"http://twitter.com/amazon"},"email_patterns":[{"pattern":"[F][L1]","percentage":67.9577},{"pattern":"[F1][L]","percentage":25.7796},{"pattern":"[L]","percentage":2.2574},{"pattern":"[F][L]","percentage":1.7769},{"pattern":"[F]","percentage":1.4367},{"pattern":"[L][F1]","percentage":0.5192},{"pattern":"[L1][F]","percentage":0.1451},{"pattern":"[F].[L]","percentage":0.0532},{"pattern":"[L][F]","percentage":0.05}],"technologies":["apache","jquery","lodash"],"technology_categories":["javascript-library","web-server"],"industries":["consumer-goods","consumer-internet","consumers","e-commerce","ebooks","ecommerce","information-technology","internet","internet-infrastructure","operations","retail","shopping"]}}
# {"result":"success","data":{"name":"ANSYS","alternate_name":null,"domain":"ansys.com","domain_name":"ansys","domain_tld":"com","business_type":null,"monthly_visitors":"1m-10m","phone_number":"(724) 746-3304","revenue":"200m-1b","size":"1k-5k","year_founded":1970,"address":"2600 ansys drive","address_name":"Canonsburg","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":40.2625702,"address_lng":-80.1872797,"updated_at":"2020-09-24T19:38:10+00:00","description":"Founded in 1970, ANSYS employs more than 2,900 professionals, and many of them are engineers expert in fields such as finite element analysis, computational fluid dynamics, electronics and electromagnetics, and design optimization. Our staff includes more master's and Ph.D.-level engineers than any other simulation provider. \\\\ANSYS is passionate about pushing the limits of world-class technology, all so our customers can turn their design concepts into successful, innovative products. \\\\The company has been recognized as one of the world's most innovative and fastest -growing companies by prestigious organizations including Business Week and FORTUNE magazines. \\\\Over the years, our steady growth and financial strength reflect our commitment to innovation and R&D. We reinvest 15 percent of our revenues each year into research to continually refine our software. We are listed on the NASDAQ stock exchange.","social_networks":{"facebook":"http://www.facebook.com/ANSYSInc","instagram":"https://instagram.com/ansys_inc","linkedin":"https://www.linkedin.com/company/ansys-inc","pinterest":"https://pinterest.com/ansysinc","twitter":"http://twitter.com/ANSYS_Inc","youtube":"https://youtube.com/user/ansysinc"},"email_patterns":[{"pattern":"[F].[L]","percentage":98.2362},{"pattern":"[F1][L]","percentage":0.9202},{"pattern":"[F]","percentage":0.3834},{"pattern":"[L]","percentage":0.1917},{"pattern":"[F][L]","percentage":0.0767},{"pattern":"[F1].[L]","percentage":0.0383},{"pattern":"[L].[F]","percentage":0.0383},{"pattern":"[L1][F]","percentage":0.0383},{"pattern":"[F]-[L]","percentage":0.0383},{"pattern":"[F1][L1]","percentage":0.0383}],"technologies":["amazon-cloudfront","amazon-s3","google-analytics","google-font-api","google-tag-manager","hotjar","jquery","microsoft-asp-net","microsoft-iis","modernizr","nginx","section-io","sitecore","unbounce","varnish","windows-server","zurb-foundation"],"technology_categories":["analytics","caching","cdn","cms","conversion-optimization","dot-net-framework","feedback-and-survey","font-library","heatmap","javascript-library","operating-system","session-recording","tag-management","ui-framework","web-server","website-builder"],"industries":["computational-fluid-dynamics","computer-software","consulting","design-optimization","electromagnetics","engineering-simulation","explicit-dynamics","fem","finite-element-analysis-fea","fsi","grid-generation","meshing","multibody-dynamics","multiphysics","prepackaged-software","virtual-prototyping"]}}
# {"result":"success","data":{"name":"ASML","alternate_name":null,"domain":"asml.com","domain_name":"asml","domain_tld":"com","business_type":null,"monthly_visitors":"500k-1m","phone_number":"+31 402683000","revenue":"over-1b","size":"over-10k","year_founded":1984,"address":"De Run 6501","address_name":"Veldhoven","address_postal_code":null,"address_country_code":"NL","address_country":"Netherlands","address_lat":51.40770635,"address_lng":5.392731058176404,"updated_at":"2020-09-28T14:12:02+00:00","description":"Be part of progress.\\We make machines that make chips; the hearts of the devices that keep us informed, entertained and safe. Devices that improve our quality of life and help to tackle the world's toughest problems. We build some of the most amazing machines that you will ever see, and the software to run them. Never satisfied, we measure our performance in units that begin with pico or nano.\\\\Whether you are a student or an experienced engineer, whether you want to design or build, work with customers or software code, we are looking for people like you to help us push technology further. Explore what we have to offer. If it sounds interesting, let's stay in touch. If it sounds right for you, let's talk about how you can be part of progress.","social_networks":{"facebook":"http://www.facebook.com/asml","instagram":"https://instagram.com/asmlcompany","linkedin":"https://www.linkedin.com/company/asml","twitter":"http://twitter.com/ASMLcompany","youtube":"https://youtube.com/channel/ucit9d3jjhensvi_w9gusxva"},"email_patterns":[{"pattern":"[F].[L]","percentage":99.0661},{"pattern":"[F].[M].[L]","percentage":0.2851},{"pattern":"[L]","percentage":0.1573},{"pattern":"[F1][L]","percentage":0.0885},{"pattern":"[F1].[L]","percentage":0.0885},{"pattern":"[F]","percentage":0.0688},{"pattern":"[L].[F]","percentage":0.0688},{"pattern":"[F][L]","percentage":0.059},{"pattern":"[F][L1]","percentage":0.059},{"pattern":"[F]_[L]","percentage":0.0492}],"technologies":["azure","azure-cdn","babel","chart-js","cloudflare","google-tag-manager","jquery","lodash","microsoft-asp-net","microsoft-iis","office-365","vue-js","windows-server"],"technology_categories":["Calendar & Scheduling","Video Conferencing","cdn","charting-library","cloud-paas","cloud-storage","collaboration","dot-net-framework","email-service","javascript-compiler","javascript-framework","javascript-library","operating-system","productivity","tag-management","web-hosting","web-server"],"industries":["hardware","nec","semiconductors"]}}
# {"result":"success","data":{"name":"Activision Blizzard","alternate_name":null,"domain":"activisionblizzard.com","domain_name":"activisionblizzard","domain_tld":"com","business_type":null,"monthly_visitors":"500k-1m","phone_number":null,"revenue":"over-1b","size":"5k-10k","year_founded":1990,"address":"3100 ocean park boulevard","address_name":"Santa Monica","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":34.0194704,"address_lng":-118.4912273,"updated_at":"2020-09-27T01:00:19+00:00","description":"Activision Blizzard is the world's most successful standalone interactive entertainment company. Our portfolio includes some of the biggest franchises in all of entertainment, developed by the incredibly talented teams at Activision Publishing, Blizzard Entertainment, King Digital Entertainment, Activision Blizzard Studios, Major League Gaming, and our independent studios, including Toys for Bob, Infinity Ward, Sledgehammer Games and Treyarch. Our central corporate operations provide shared services such as Finance, IT, Sales and Supply Chain, Human Resources and Legal. ","social_networks":{"facebook":"https://www.facebook.com/activision.blizzard.atvi","linkedin":"https://www.linkedin.com/company/activision-blizzard","twitter":"https://twitter.com/atvi_ab"},"email_patterns":[{"pattern":"[F1][L]","percentage":92.9348},{"pattern":"[F].[L]","percentage":6.5217},{"pattern":"[L]","percentage":0.5435}],"technologies":["adobe-experience-manager","amazon-ec2","apache","apache-traffic-server","azure-cdn","cloudflare","google-cloud","hammer-js","java","jquery","microsoft-asp-net","nginx","zurb-foundation"],"technology_categories":["cdn","cloud-paas","cms","dot-net-framework","javascript-library","programming-language","ui-framework","web-hosting","web-server"],"industries":["entertainment"]}}
# {"result":"success","data":{"name":"Broadcom","alternate_name":null,"domain":"broadcom.com","domain_name":"broadcom","domain_tld":"com","business_type":null,"monthly_visitors":"10m-50m","phone_number":"(408) 433-8000","revenue":"over-1b","size":"over-10k","year_founded":1991,"address":"1320 ridder park drive","address_name":"San Jose","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3361905,"address_lng":-121.890583,"updated_at":"2020-09-24T08:45:51+00:00","description":"Broadcom Limited is a leading designer, developer and global supplier of a broad range of digital and analog semiconductor connectivity solutions that serve the wired infrastructure, wireless communications, enterprise storage and industrial markets.","social_networks":{"angellist":"http://angel.co/gadzoox-networks","facebook":"https://www.facebook.com/broadcom","linkedin":"https://www.linkedin.com/company/broadcom","twitter":"https://www.twitter.com/broadcom","youtube":"https://youtube.com/user/broadcomcorporation"},"email_patterns":[{"pattern":"[F1][L]","percentage":51.9351},{"pattern":"[F].[L]","percentage":43.4246},{"pattern":"[F][L1]","percentage":1.8125},{"pattern":"[F]","percentage":1.0834},{"pattern":"[L]","percentage":0.8313},{"pattern":"[F][L]","percentage":0.5587},{"pattern":"[L1][F]","percentage":0.1295},{"pattern":"[L][F1]","percentage":0.0886},{"pattern":"[F1][L1]","percentage":0.0613},{"pattern":"[L][F]","percentage":0.0341},{"pattern":"[F1].[L]","percentage":0.0204},{"pattern":"[F].[L1]","percentage":0.0204}],"technologies":["amazon-cloudfront","amazon-s3","apache","azure-cdn","babel","backbone-js","cloudflare","crazy-egg","font-awesome","google-analytics","google-tag-manager","nginx","webpack"],"technology_categories":["analytics","cdn","conversion-optimization","font-library","heatmap","javascript-bundler","javascript-compiler","javascript-framework","tag-management","web-server"],"industries":["bluetooth-solutions","cable-modems","epon","gbe","gpon","gps","information-technology","mobile-communications","network-infrastructure","nfc","powerline-communications","semiconductors","software","wireless-networks","xdsl"]}}
# {"result":"success","data":{"name":"AstraZeneca","alternate_name":null,"domain":"astrazeneca.com","domain_name":"astrazeneca","domain_tld":"com","business_type":null,"monthly_visitors":"1m-10m","phone_number":"+971 4 362 4888","revenue":"over-1b","size":"over-10k","year_founded":1999,"address":"1 francis crick avenue","address_name":"Cambridge","address_postal_code":null,"address_country_code":"GB","address_country":"United Kingdom","address_lat":52.2034823,"address_lng":0.1235817,"updated_at":"2020-09-24T22:21:19+00:00","description":"AstraZeneca is a global, science-led biopharmaceutical company that focuses on the discovery, development and commercialisation of prescription medicines.\\\\Our Purpose is to push the boundaries of science to deliver life-changing medicines.  We believe the best way we can achieve our Purpose is to put science at the centre of everything we do. Science defines who we are. It is why we come to work every day and is part of our DNA. But this is only half of the story. We know that we do not have all the answers. We want to share ideas because we believe it results in better medicines.  We want the way we work to be inclusive, open and collaborative.  This approach runs through all that we do.\\\\We focus on three main therapy areas – Oncology, Cardiovascular & Metabolic Disease (CVMD) and Respiratory – and we are also selectively active in the areas of autoimmunity, neuroscience and infection. To put ourselves in the best position to push the boundaries of science, we seek to leverage our combination of capabilities, which encompass both small molecules and biologics, and include immunotherapies and developing innovative delivery devices that can offer choice to patients. These are reinforced by a strong focus on personalised healthcare capabilities, which aim to match medicines only to those patients who will benefit from them. Our teams also work alongside the world's leading academic and biotech research institutions to stimulate innovation and evaluate emerging technologies such as Modified RNA and CRISPR genome editing.\\\\AstraZeneca operates in over 100 countries and its innovative medicines are used by millions of patients worldwide. For more information, visit www.astrazeneca.com.\\","social_networks":{"angellist":"http://angel.co/astra-zeneca-1","facebook":"https://www.facebook.com/astrazenecacareers","instagram":"https://instagram.com/astrazeneca","linkedin":"https://www.linkedin.com/company/astrazeneca","twitter":"http://twitter.com/astrazeneca","youtube":"https://youtube.com/user/astrazeneca"},"email_patterns":[{"pattern":"[F].[L]","percentage":98.7171},{"pattern":"[L].[F]","percentage":1.1139},{"pattern":"[L]","percentage":0.0515},{"pattern":"[F1].[L]","percentage":0.0286},{"pattern":"[F]","percentage":0.02},{"pattern":"[F][L]","percentage":0.0172},{"pattern":"[F].[L1]","percentage":0.0172},{"pattern":"[F][L1]","percentage":0.0115}],"technologies":["adobe-experience-manager","amazon-cloudfront","apache","cloudflare","google-analytics","google-cloud","google-pagespeed","google-tag-manager","handlebars","java","jquery","jquery-ui","modernizr","moment-js","nginx","zurb-foundation"],"technology_categories":["analytics","application-performance","cdn","cloud-paas","cms","javascript-library","programming-language","tag-management","ui-framework","web-hosting","web-server"],"industries":["biopharmaceutical","development","global-business","health-care","health-care-information-technology","information-technology","innovation","mobile","pharmaceutical","pharmaceuticals","research","user-experience-design","ux-designer"]}}
# {"result":"success","data":{"name":"Baidu","alternate_name":null,"domain":"baidu.com","domain_name":"baidu","domain_tld":"com","business_type":null,"monthly_visitors":"over-1b","phone_number":null,"revenue":"over-1b","size":"over-10k","year_founded":2000,"address":null,"address_name":"Beijing","address_postal_code":"100010","address_country_code":"CN","address_country":"China","address_lat":39.906217,"address_lng":116.3912757,"updated_at":"2020-09-22T15:49:10+00:00","description":"Baidu was founded in 2000 by Internet pioneer Robin Li, creator of visionary search technology Hyperlink Analysis, with the mission of providing people with the best way to find information and connect users with services.\\\\Over the past decade we have strived to fulfill this mission by listening carefully to our users' needs and wants. To provide intelligent, relevant search results for the tens of billions of queries that are entered into our search platform every day, we focus on powering the best technology optimized for up-to-date local tastes and preferences. Our deep understanding of Chinese language and culture is central to our success and this kind of knowledge allows us to tailor our search technology for our users' needs. \\\\We provide our users with many channels to find and share information. In addition to our core web search product, we power many popular community-based products, such as Baidu PostBar, the world's first and largest Chinese-language query-based searchable online community platform, Baidu Knows, the world's largest Chinese-language interactive knowledge-sharing platform, and Baidu Encyclopedia, the world's largest user-generated Chinese-language encyclopedia, to name but a few. Beyond these marquee products we also offer dozens of helpful vertical search-based products, such as Maps, Image Search, Video Search, News Search, and many more. We power these through our cutting-edge technology, continually innovating to enhance these services. Our new Box Computing Open Platform brings users deep-linked content and even applications they can use directly through their search box. \\\\Baidu continues to innovate to meet Internet users'​ increasingly diverse tastes. With our goal of best serving the needs of our users and customers with intelligent and relevant solutions, we look forward to a robust future.","social_networks":{"angellist":"http://angel.co/baidu","facebook":"https://www.facebook.com/Baidu-8096389511/","linkedin":"https://www.linkedin.com/company/baidu-inc","twitter":"https://twitter.com/BaiduResearch"},"email_patterns":[{"pattern":"[F][L]","percentage":64.0886},{"pattern":"[L][F]","percentage":35.0289},{"pattern":"[L]","percentage":0.5616},{"pattern":"[F].[L]","percentage":0.0963},{"pattern":"[F1][L]","percentage":0.0802},{"pattern":"[F]","percentage":0.0642},{"pattern":"[F]_[L]","percentage":0.0321},{"pattern":"[F][L1]","percentage":0.016},{"pattern":"[F]-[L]","percentage":0.016},{"pattern":"[L]_[F]","percentage":0.016}],"technologies":[],"technology_categories":[],"industries":["artificial-intelligence","consumer-internet","games-entertainment","group-buying","information-technology","internet","map","mobile-service","o2o","online-music","online-video","search","social-media","social-networks","software","translator","website-navigation"]}}
# ...
# {"result":"success","data":{"name":"Xfinity Communities","alternate_name":null,"domain":"xfinity.com","domain_name":"xfinity","domain_tld":"com","business_type":null,"monthly_visitors":"over-1b","phone_number":"215 665-1700","revenue":"over-1b","size":"over-10k","year_founded":null,"address":"One Comcast Center1701 John F. Kennedy Blvd.","address_name":"Philadelphia","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":39.9527237,"address_lng":-75.1635262,"updated_at":"2020-09-22T15:53:31+00:00","description":"Xfinity Communities provides residents in multi-dwelling units (MDUs) with the best in Internet, TV, Voice, and Home Security. \\\\With Xfinity Communities' Advanced Communities Network (ACN), you and your residents can count on a better network that delivers fiber-based customized solutions to bring Gig speeds to more places – a game changer for your community. Plus, Xfinity xFi will give your residents the speed, coverage, and control they need for the ultimate in-home WiFi experience. You also get better entertainment as Xfinity X1 will change the way your residents experience TV with advanced search, personalized recommendations, and more. You and your residents will further benefit from better service with dedicated community account representatives (CARs) and round-the-clock live support.\\\\With our better network, better entertainment, and better service, we provide a luxury amenity that simply translates to a better experience – isn't it time you see what Xfinity can do for you?","social_networks":{"linkedin":"https://www.linkedin.com/company/xfinity-communities"},"email_patterns":[{"pattern":"[F].[L]","percentage":50},{"pattern":"[F][L1]","percentage":50}],"technologies":["akamai","amazon-cloudfront","apache-traffic-server","babel","facebook-social-plugins","google-analytics","google-tag-manager","gsap","jquery","microsoft-asp-net","react","sitecore","webpack"],"technology_categories":["analytics","animation-library","cdn","cms","dot-net-framework","javascript-bundler","javascript-compiler","javascript-framework","javascript-library","social-widget","tag-management","web-server"],"industries":["communications","entertainment","high-speed-internet","home-management","media","video"]}}
# {"result":"success","data":{"name":"Costco Wholesale","alternate_name":null,"domain":"costco.com","domain_name":"costco","domain_tld":"com","business_type":null,"monthly_visitors":"over-1b","phone_number":"(503) 825-4003","revenue":"over-1b","size":"over-10k","year_founded":1983,"address":"4401 4th avenue south","address_name":"Issaquah","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":47.5348778,"address_lng":-122.0432974,"updated_at":"2020-09-22T15:52:44+00:00","description":"Costco Wholesale is a multibillion dollar global retailer with warehouse club operations in 10 countries. We are the recognized leader in our field, dedicated to quality in every area of our business and respected for our outstanding business ethics. Despite our large size and rapid international expansion, we continue to provide an atmosphere in which our employees thrive and succeed. \\\\If you are an ambitious, energetic person who enjoys a fast-paced team environment filled with challenges and opportunities, you've come to the right place. Our successful employees are service-oriented with integrity and commitment toward a common goal of excellence. Costco offers great jobs, great pay, great benefits and a great place to work.\\\\Like us on Facebook: www.facebook.com/Costco\\Follow us on Pinterest: www.pinterest.com/Costco","social_networks":{"facebook":"https://www.facebook.com/Costco","linkedin":"https://www.linkedin.com/company/costco-wholesale","twitter":"https://twitter.com/costco?lang=en"},"email_patterns":[{"pattern":"[F1][L]","percentage":98.223},{"pattern":"[F].[L]","percentage":1.1533},{"pattern":"[F][L]","percentage":0.3589},{"pattern":"[F1].[L]","percentage":0.2001},{"pattern":"[F]","percentage":0.0294},{"pattern":"[L]","percentage":0.0177},{"pattern":"[L1][F]","percentage":0.0118}],"technologies":[],"technology_categories":[],"industries":["automotive","ecommerce","gas-stations","merchandising","operations","retail","shopping","travel","wholesale-stores"]}}
# {"result":"success","data":{"name":"Copart","alternate_name":null,"domain":"copart.com","domain_name":"copart","domain_tld":"com","business_type":null,"monthly_visitors":"100m-500m","phone_number":"(972) 391-5400","revenue":"over-1b","size":"5k-10k","year_founded":1982,"address":"14185 dallas parkway","address_name":"Dallas","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":32.7762719,"address_lng":-96.7968559,"updated_at":"2020-09-23T06:44:42+00:00","description":"Copart, founded in 1982, connects buyers and sellers around the world. Copart remarkets salvage and clean title vehicles to dealers, dismantlers, rebuilders, exporters and end users through internet sales utilizing its innovative VB3 technology. Copart sells vehicles on behalf of insurance companies, banks, finance companies, fleet owners, car dealerships, cars sourced from the general public and others. \\\\Copart currently operates in the United States (Copart.com), Canada (Copart.ca), the United Kingdom (Copart.co.uk), the Republic of Ireland (Copart.ie) Brazil (Copart.com.br), Germany (Copart.de), the United Arab Emirates, Oman and Bahrain (Copartmea.com), India, (Copart.in) and Spain (Copart.es). Copart links sellers to more than 750,000 Members in over 170 countries through our multi-channel online platform.\\\\Copart has a diverse and extensive inventory of nearly 125,000 vehicles available online every day, including early and late model cars, classics, trucks, SUVs, motorcycles, boats, jetskis, snowmobiles and RVs. Vehicles conditions range from damaged cars that can be used as project vehicles for repair and automotive enthusiasts to non-damaged vehicles that need nothing more than a turn-of-a-key.\\\\Because Copart is an online auction, Copart Members can browse inventory, set their own price and get great deals. If you are the highest bidder in the auction, you win the auction! And winning is awesome! Also, Members can shop our incredible inventory and find exactly what they need from their home computer, smartphone or other mobile device.","social_networks":{"facebook":"http://www.facebook.com/Copart","instagram":"https://instagram.com/p/b_s6aapln5l/embed/captioned","linkedin":"https://www.linkedin.com/company/copart","twitter":"http://twitter.com/copart","youtube":"https://youtube.com/copart"},"email_patterns":[{"pattern":"[F].[L]","percentage":97.4359},{"pattern":"[F1].[L]","percentage":0.9158},{"pattern":"[F1][L]","percentage":0.6716},{"pattern":"[F]","percentage":0.6105},{"pattern":"[L]","percentage":0.2442},{"pattern":"[F][L]","percentage":0.0611},{"pattern":"[F]_[L]","percentage":0.0611}],"technologies":["amazon-ecs","angularjs","azure-cdn","cloudflare","doubleclick-for-publishers","facebook-social-plugins","font-awesome","google-analytics","google-font-api","google-maps","google-tag-manager","incapsula","jquery","jquery-ui","lodash","moment-js","nginx","twitter-widgets"],"technology_categories":["advertising","analytics","cdn","font-library","iaas","javascript-framework","javascript-library","mapping","security","social-widget","tag-management","ui-framework","web-server"],"industries":["auto-auction","automotive","car-auction","car-auctions","online-auction"]}}
# {"result":"success","data":{"name":"CrowdStrike","alternate_name":null,"domain":"crowdstrike.com","domain_name":"crowdstrike","domain_tld":"com","business_type":null,"monthly_visitors":"10m-50m","phone_number":"(888) 512-8906","revenue":"50m-100m","size":"1k-5k","year_founded":2011,"address":"150 mathilda place","address_name":"Sunnyvale","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3688301,"address_lng":-122.036349,"updated_at":"2020-05-06T09:53:49+00:00","description":"CrowdStrike is the leader in cloud-delivered next-generation endpoint protection. CrowdStrike has revolutionized endpoint protection by being the first and only company to unify next-generation antivirus (AV), endpoint detection and response (EDR), and a 24/7 managed hunting service — all delivered via a single lightweight agent. \\\\Many of the world's largest organizations already put their trust in CrowdStrike, including three of the 10 largest global companies by revenue, five of the 10 largest financial institutions, three of the top 10 health care providers, and three of the top 10 energy companies.\\ \\We Stop Breaches. Learn more: https://www.crowdstrike.com/.  Follow us on Twitter, @CrowdStrike and our blog: https://www.crowdstrike.com/blog/","social_networks":{"angellist":"http://angel.co/crowdstrike","facebook":"https://www.facebook.com/CrowdStrike","linkedin":"https://www.linkedin.com/company/crowdstrike","twitter":"http://www.twitter.com/CrowdStrike","youtube":"https://youtube.com/user/crowdstrike"},"email_patterns":[{"pattern":"[F].[L]","percentage":93.6909},{"pattern":"[F1][L]","percentage":3.47},{"pattern":"[F]_[L]","percentage":1.735},{"pattern":"[F]","percentage":0.9464},{"pattern":"[F]-[L]","percentage":0.1577}],"technologies":["amazon-cloudfront","cloudflare","google-tag-manager","gsap","jquery","mysql","nginx","php","wordpress"],"technology_categories":["animation-library","cdn","cms","database","javascript-library","programming-language","tag-management","web-server"],"industries":["computer","computer-related-services","endpoint-detection","incident-response","information-technology","internet","machine-learning","malware-detection","malware-prevention","managed-threat-hunting","nec","network-security","next-generation-antivirus","nextgeneration-endpoint-protection","response","security","threat-intelligence"]}}
# {"result":"success","data":{"name":"Cis","alternate_name":null,"domain":"cisco.com","domain_name":"cisco","domain_tld":"com","business_type":null,"monthly_visitors":"100m-500m","phone_number":"(800) 553-6387","revenue":"over-1b","size":"over-10k","year_founded":1984,"address":"170 W Tasman Dr","address_name":"San Jose","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":37.3361905,"address_lng":-121.890583,"updated_at":"2020-09-22T16:06:41+00:00","description":"Cisco (NASDAQ: CSCO) enables people to make powerful connections--whether in business, education, philanthropy, or creativity. Cisco hardware, software, and service offerings are used to create the Internet solutions that make networks possible--providing easy access to information anywhere, at any time. \r\n\r\nCisco was founded in 1984 by a small group of computer scientists from Stanford University. Since the company's inception, Cisco engineers have been leaders in the development of Internet Protocol (IP)-based networking technologies. Today, with more than 71,000 employees worldwide, this tradition of innovation continues with industry-leading products and solutions in the company's core development areas of routing and switching, as well as in advanced technologies such as home networking, IP telephony, optical networking, security, storage area networking, and wireless technology. In addition to its products, Cisco provides a broad range of service offerings, including technical support and advanced services. \r\n\r\nCisco sells its products and services, both directly through its own sales force as well as through its channel partners, to large enterprises, commercial businesses, service providers, and consumers.","social_networks":{"angellist":"http://angel.co/cisco","facebook":"http://www.facebook.com/Cisco","instagram":"https://instagram.com/cisco","linkedin":"https://www.linkedin.com/company/cisco","twitter":"http://www.twitter.com/CiscoSystems","youtube":"https://youtube.com/user/cisco"},"email_patterns":[{"pattern":"[F1][L]","percentage":92.3513},{"pattern":"[F].[L]","percentage":2.9621},{"pattern":"[L]","percentage":0.9757},{"pattern":"[F][L1]","percentage":0.9321},{"pattern":"[F][L]","percentage":0.9303},{"pattern":"[F]","percentage":0.789},{"pattern":"[L][F1]","percentage":0.5812},{"pattern":"[L1][F]","percentage":0.2199},{"pattern":"[F1].[L]","percentage":0.1169},{"pattern":"[F1][L1]","percentage":0.0663},{"pattern":"[L][F]","percentage":0.0489},{"pattern":"[F]_[L]","percentage":0.014}],"technologies":["adobe-experience-manager","akamai","amazon-cloudfront","amazon-s3","apache","azure-cdn","cloudflare","java","jquery","lodash","nginx","polymer","tealium"],"technology_categories":["cdn","cms","javascript-library","programming-language","tag-management","web-server"],"industries":["collaboration","computer-networking","computer-peripheral-equipment","data-center","hardware","information-technology","nec","networking","security","software","telepresence","unified-communication","unified-computing-systems","virtualization","web-hosting","wireless"]}}
# {"result":"success","data":{"name":"CSX","alternate_name":null,"domain":"csx.com","domain_name":"csx","domain_tld":"com","business_type":null,"monthly_visitors":"under-10k","phone_number":"(877) 744-7279","revenue":"over-1b","size":"over-10k","year_founded":1827,"address":"500 water street","address_name":"Jacksonville","address_postal_code":null,"address_country_code":"US","address_country":"United States","address_lat":30.3321838,"address_lng":-81.655651,"updated_at":"2020-09-25T22:37:25+00:00","description":"CSX Corporation, together with its subsidiaries based in Jacksonville, Fla., is one of the nation's leading transportation suppliers. The company's rail and intermodal businesses provide rail-based transportation services including traditional rail service and the transport of intermodal containers and trailers.\\\\Overall, the CSX Transportation network encompasses about 21,000 route miles of track in 23 states, the District of Columbia and the Canadian provinces of Ontario and Quebec. Our transportation network serves some of the largest population centers in the nation. Nearly two-thirds of Americans live within CSX's service territory.\\\\CSX serves major markets in the eastern United States and has access to over 70 ocean, river and lake port terminals along the Atlantic and Gulf Coasts, the Mississippi River, the Great Lakes and the St. Lawrence Seaway. The company also has access to Pacific ports through alliances with western railroads.\\\\CSX moves a broad portfolio of products across the country in a way that minimizes the effect on the environment, takes traffic off an already congested highway system, and minimizes fuel consumption and transportation costs.","social_networks":{"facebook":"http://www.facebook.com/OfficialCSX","instagram":"https://instagram.com/officialcsx","linkedin":"https://www.linkedin.com/company/csx-transportation","twitter":"http://twitter.com/CSX","youtube":"https://youtube.com/howtomorrowmoves"},"email_patterns":[{"pattern":"[F]_[L]","percentage":96.3339},{"pattern":"[F].[L]","percentage":1.3129},{"pattern":"[F][L]","percentage":0.9413},{"pattern":"[L]_[F]","percentage":0.7927},{"pattern":"[F1][L]","percentage":0.2353},{"pattern":"[F1].[L]","percentage":0.161},{"pattern":"[L]","percentage":0.0495},{"pattern":"[L][F]","percentage":0.0495},{"pattern":"[L][F1]","percentage":0.0495},{"pattern":"[F1]_[L]","percentage":0.0495},{"pattern":"[F]","percentage":0.0124},{"pattern":"[F]-[L]","percentage":0.0124}],"technologies":["apache","facebook-social-plugins","google-analytics","google-tag-manager","jquery"],"technology_categories":["analytics","javascript-library","social-widget","tag-management","web-server"],"industries":["intermodal-transportation","railroad","railroads","transportation","trucking"]}}

# %%
type(response)

# %%
outfile.close()
print("We have the company data we need.")
